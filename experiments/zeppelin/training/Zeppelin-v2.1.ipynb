# %% [markdown]
# This time we will train with a modified reward scheme...

# %%
import gym
import time

# %%
import numpy as np

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import torch
from torch import nn

# %%
import zeppelin_gym.env5
# Out:
# `polytope` failed to import `cvxopt.glpk`.
# will use `scipy.optimize.linprog`

# %%
torch.manual_seed(42)

# %%
env = gym.make('zeppelin-v4')
# Out:
# /root/miniconda3/envs/snnt/lib/python3.9/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
env.seed(42)

# %%
env.unwrapped.FUEL_RESTRAINT = False
env.unwrapped.OBSTACLE_REWARD = -1000.
env.unwrapped.NO_FUEL_REWARD = 0.1
# done reward = (FUEL_RESTRAINT) ? r+fuel*r : 2*r
env.unwrapped.DONE_REWARD = 0.5
env.unwrapped.TIME_STEP_REWARD = 0.
env.unwrapped.INCLUDE_UNWINNABLE = False
env.unwrapped.EMERGENCY_REWARD = -1e-4
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
architecture = [dict(pi=[8,8], vf=[8,8])]
model = PPO("MlpPolicy", env, verbose=1,policy_kwargs={"activation_fn":nn.ReLU,"net_arch":architecture})
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /root/miniconda3/envs/snnt/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-288.88 +/- 453.38

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47       |
# |    ep_rew_mean     | -341     |
# | time/              |          |
# |    fps             | 1335     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | -295        |
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.062124114 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0759      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.0117      |
# |    std                  | 1           |
# |    value_loss           | 3.31e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.9       |
# |    ep_rew_mean          | -280       |
# | time/                   |            |
# |    fps                  | 823        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.03857389 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 0.207      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.75e+04   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.0189     |
# |    std                  | 1          |
# |    value_loss           | 2.63e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.7       |
# |    ep_rew_mean          | -260       |
# | time/                   |            |
# |    fps                  | 789        |
# |    iterations           | 4          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.44533634 |
# |    clip_fraction        | 0.352      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 0.252      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17e+04   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | 0.0162     |
# |    std                  | 1          |
# |    value_loss           | 2.42e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.1        |
# |    ep_rew_mean          | -240        |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.054135032 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.47e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0123      |
# |    std                  | 1.01        |
# |    value_loss           | 1.76e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49         |
# |    ep_rew_mean          | -220       |
# | time/                   |            |
# |    fps                  | 753        |
# |    iterations           | 6          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.03720241 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 0.348      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.51e+03   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.00631    |
# |    std                  | 1          |
# |    value_loss           | 1.77e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.5        |
# |    ep_rew_mean          | -240        |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.037643686 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00557     |
# |    std                  | 0.999       |
# |    value_loss           | 1.9e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.6        |
# |    ep_rew_mean          | -260        |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.035624973 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.43e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.0153      |
# |    std                  | 1           |
# |    value_loss           | 1.66e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.6       |
# |    ep_rew_mean          | -270       |
# | time/                   |            |
# |    fps                  | 739        |
# |    iterations           | 9          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.06088288 |
# |    clip_fraction        | 0.357      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.95e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.0144     |
# |    std                  | 0.999      |
# |    value_loss           | 1.53e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.5        |
# |    ep_rew_mean          | -260        |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 10          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.025897719 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00384     |
# |    std                  | 0.998       |
# |    value_loss           | 2.42e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.3       |
# |    ep_rew_mean          | -190       |
# | time/                   |            |
# |    fps                  | 733        |
# |    iterations           | 11         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02823035 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.432      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.25e+04   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.00636    |
# |    std                  | 0.995      |
# |    value_loss           | 1.82e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40         |
# |    ep_rew_mean          | -220       |
# | time/                   |            |
# |    fps                  | 731        |
# |    iterations           | 12         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02658122 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.372      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.72e+03   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.0108     |
# |    std                  | 1          |
# |    value_loss           | 1.76e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.9       |
# |    ep_rew_mean          | -220       |
# | time/                   |            |
# |    fps                  | 731        |
# |    iterations           | 13         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.03127008 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.517      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.25e+03   |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.00647    |
# |    std                  | 1          |
# |    value_loss           | 2.34e+04   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.5      |
# |    ep_rew_mean          | -240      |
# | time/                   |           |
# |    fps                  | 731       |
# |    iterations           | 14        |
# |    time_elapsed         | 39        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0683752 |
# |    clip_fraction        | 0.29      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.27     |
# |    explained_variance   | 0.51      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.56e+03  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | 0.0133    |
# |    std                  | 1.01      |
# |    value_loss           | 8.4e+03   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.6       |
# |    ep_rew_mean          | -260       |
# | time/                   |            |
# |    fps                  | 729        |
# |    iterations           | 15         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02944356 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.29      |
# |    explained_variance   | 0.543      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.37e+03   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.00189    |
# |    std                  | 1.01       |
# |    value_loss           | 1.8e+04    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.2        |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 16          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.038490757 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.08e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0011      |
# |    std                  | 1.02        |
# |    value_loss           | 2.07e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 59.2       |
# |    ep_rew_mean          | -260       |
# | time/                   |            |
# |    fps                  | 725        |
# |    iterations           | 17         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.19328837 |
# |    clip_fraction        | 0.508      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.31      |
# |    explained_variance   | 0.549      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 191        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.025      |
# |    std                  | 1.02       |
# |    value_loss           | 1e+04      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57          |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.055342313 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 643         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0104      |
# |    std                  | 1.02        |
# |    value_loss           | 1e+04       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39          |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 19          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012661938 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00649     |
# |    std                  | 1.01        |
# |    value_loss           | 2.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.3        |
# |    ep_rew_mean          | -260        |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 20          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.031316888 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.46e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00686     |
# |    std                  | 1.02        |
# |    value_loss           | 2.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.1        |
# |    ep_rew_mean          | -220        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 21          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.032423504 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.53e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00352     |
# |    std                  | 1.01        |
# |    value_loss           | 2.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.6        |
# |    ep_rew_mean          | -270        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 22          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031607155 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+04     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0156      |
# |    std                  | 1.01        |
# |    value_loss           | 1.19e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.1       |
# |    ep_rew_mean          | -300       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 23         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03188746 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.3       |
# |    explained_variance   | 0.327      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.34e+04   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00261    |
# |    std                  | 1.01       |
# |    value_loss           | 2.96e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 24          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.034134682 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.98e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00574     |
# |    std                  | 1.02        |
# |    value_loss           | 1.44e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 56.3      |
# |    ep_rew_mean          | -180      |
# | time/                   |           |
# |    fps                  | 718       |
# |    iterations           | 25        |
# |    time_elapsed         | 71        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 1.1821886 |
# |    clip_fraction        | 0.436     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.642     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.15e+03  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | 0.0301    |
# |    std                  | 1.02      |
# |    value_loss           | 8.02e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 52.8     |
# |    ep_rew_mean          | -190     |
# | time/                   |          |
# |    fps                  | 719      |
# |    iterations           | 26       |
# |    time_elapsed         | 73       |
# |    total_timesteps      | 53248    |
# | train/                  |          |
# |    approx_kl            | 6.267723 |
# |    clip_fraction        | 0.37     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.33    |
# |    explained_variance   | 0.151    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 5.01e+03 |
# |    n_updates            | 250      |
# |    policy_gradient_loss | 0.0212   |
# |    std                  | 1.03     |
# |    value_loss           | 1.4e+04  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -220        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 27          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.025039785 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0171      |
# |    std                  | 1.03        |
# |    value_loss           | 1.48e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.9        |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 28          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014100119 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00162     |
# |    std                  | 1.03        |
# |    value_loss           | 2.25e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 42.5      |
# |    ep_rew_mean          | -260      |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 29        |
# |    time_elapsed         | 82        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0268282 |
# |    clip_fraction        | 0.206     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.34     |
# |    explained_variance   | 0.425     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.16e+03  |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 0.00348   |
# |    std                  | 1.03      |
# |    value_loss           | 1.94e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 30          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.022756835 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.35e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00458     |
# |    std                  | 1.03        |
# |    value_loss           | 1.4e+04     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.4       |
# |    ep_rew_mean          | -120       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 31         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01999649 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.34      |
# |    explained_variance   | 0.418      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.86e+03   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.00674    |
# |    std                  | 1.03       |
# |    value_loss           | 1.1e+04    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.6        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 32          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.021313092 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -0.162      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 325         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0138      |
# |    std                  | 1.03        |
# |    value_loss           | 1.14e+04    |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 45.7     |
# |    ep_rew_mean          | -150     |
# | time/                   |          |
# |    fps                  | 720      |
# |    iterations           | 33       |
# |    time_elapsed         | 93       |
# |    total_timesteps      | 67584    |
# | train/                  |          |
# |    approx_kl            | 4.361581 |
# |    clip_fraction        | 0.653    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.33    |
# |    explained_variance   | 0.332    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 108      |
# |    n_updates            | 320      |
# |    policy_gradient_loss | 0.0618   |
# |    std                  | 1.03     |
# |    value_loss           | 8.63e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.3        |
# |    ep_rew_mean          | -180        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 34          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.054846913 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.31e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0133      |
# |    std                  | 1.03        |
# |    value_loss           | 1.27e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 49.7      |
# |    ep_rew_mean          | -130      |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 35        |
# |    time_elapsed         | 99        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 4.4372983 |
# |    clip_fraction        | 0.636     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.33     |
# |    explained_variance   | 0.509     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.36e+03  |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.0528    |
# |    std                  | 1.03      |
# |    value_loss           | 7.36e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.9       |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 36         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.13645074 |
# |    clip_fraction        | 0.342      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.33      |
# |    explained_variance   | -0.29      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 422        |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0208     |
# |    std                  | 1.03       |
# |    value_loss           | 8.69e+03   |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 49.3     |
# |    ep_rew_mean          | -39.9    |
# | time/                   |          |
# |    fps                  | 721      |
# |    iterations           | 37       |
# |    time_elapsed         | 104      |
# |    total_timesteps      | 75776    |
# | train/                  |          |
# |    approx_kl            | 6.803483 |
# |    clip_fraction        | 0.797    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.38    |
# |    explained_variance   | -0.757   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 25.1     |
# |    n_updates            | 360      |
# |    policy_gradient_loss | 0.104    |
# |    std                  | 1.06     |
# |    value_loss           | 311      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.4       |
# |    ep_rew_mean          | -89.9      |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 38         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.10185147 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.44      |
# |    explained_variance   | 0.0698     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.58e+03   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.0229     |
# |    std                  | 1.07       |
# |    value_loss           | 7.24e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 39          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.048638977 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.0338      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.23e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0171      |
# |    std                  | 1.07        |
# |    value_loss           | 8.25e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.9         |
# |    ep_rew_mean          | -220         |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 40           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0056830035 |
# |    clip_fraction        | 0.0862       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.45        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.58e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.000259     |
# |    std                  | 1.07         |
# |    value_loss           | 2.07e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.5        |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 41          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007496029 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00404    |
# |    std                  | 1.07        |
# |    value_loss           | 2.36e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46         |
# |    ep_rew_mean          | -140       |
# | time/                   |            |
# |    fps                  | 720        |
# |    iterations           | 42         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00651019 |
# |    clip_fraction        | 0.0602     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.45      |
# |    explained_variance   | 0.268      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.06e+03   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00215   |
# |    std                  | 1.07       |
# |    value_loss           | 1.66e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46         |
# |    ep_rew_mean          | -110       |
# | time/                   |            |
# |    fps                  | 720        |
# |    iterations           | 43         |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01450268 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.45      |
# |    explained_variance   | 0.512      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.1e+03    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.00132    |
# |    std                  | 1.07       |
# |    value_loss           | 4.38e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53          |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 44          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.063540965 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.331       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 1.07        |
# |    value_loss           | 8.05e+03    |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 59.8     |
# |    ep_rew_mean          | -39.9    |
# | time/                   |          |
# |    fps                  | 715      |
# |    iterations           | 45       |
# |    time_elapsed         | 128      |
# |    total_timesteps      | 92160    |
# | train/                  |          |
# |    approx_kl            | 1.051764 |
# |    clip_fraction        | 0.493    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.44    |
# |    explained_variance   | -0.0163  |
# |    learning_rate        | 0.0003   |
# |    loss                 | 47.5     |
# |    n_updates            | 440      |
# |    policy_gradient_loss | 0.0236   |
# |    std                  | 1.06     |
# |    value_loss           | 942      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 61.5     |
# |    ep_rew_mean          | -49.9    |
# | time/                   |          |
# |    fps                  | 715      |
# |    iterations           | 46       |
# |    time_elapsed         | 131      |
# |    total_timesteps      | 94208    |
# | train/                  |          |
# |    approx_kl            | 6.022841 |
# |    clip_fraction        | 0.668    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.44    |
# |    explained_variance   | 0.511    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 8.63     |
# |    n_updates            | 450      |
# |    policy_gradient_loss | 0.0255   |
# |    std                  | 1.07     |
# |    value_loss           | 1.41e+03 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.6       |
# |    ep_rew_mean          | -79.8      |
# | time/                   |            |
# |    fps                  | 714        |
# |    iterations           | 47         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.10366599 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | -0.063     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 42.3       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0121     |
# |    std                  | 1.06       |
# |    value_loss           | 7.05e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.1       |
# |    ep_rew_mean          | -69.8      |
# | time/                   |            |
# |    fps                  | 714        |
# |    iterations           | 48         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.19085418 |
# |    clip_fraction        | 0.481      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | 0.0896     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 99.1       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0339     |
# |    std                  | 1.06       |
# |    value_loss           | 7.88e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.4       |
# |    ep_rew_mean          | -99.9      |
# | time/                   |            |
# |    fps                  | 714        |
# |    iterations           | 49         |
# |    time_elapsed         | 140        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.04883549 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.45      |
# |    explained_variance   | 0.0758     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.34e+03   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0142     |
# |    std                  | 1.07       |
# |    value_loss           | 5.78e+03   |
# ----------------------------------------
# --- 141.8119523525238 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-127.86 +/- 334.15

# %%
model.save("zeppelin-v2.1-100000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.9     |
# |    ep_rew_mean     | -125     |
# | time/              |          |
# |    fps             | 1300     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.7        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017762413 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 239         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00246     |
# |    std                  | 1.07        |
# |    value_loss           | 1.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.6        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.049741663 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3e+03       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.0128      |
# |    std                  | 1.07        |
# |    value_loss           | 3.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.068582065 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.022       |
# |    std                  | 1.07        |
# |    value_loss           | 2.79e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 53.3      |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 771       |
# |    iterations           | 5         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.1479367 |
# |    clip_fraction        | 0.412     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.48     |
# |    explained_variance   | 0.00637   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.07e+03  |
# |    n_updates            | 530       |
# |    policy_gradient_loss | 0.0279    |
# |    std                  | 1.09      |
# |    value_loss           | 5.67e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 755        |
# |    iterations           | 6          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.20376271 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | -3.08      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.71       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.0406     |
# |    std                  | 1.1        |
# |    value_loss           | 16.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.041653924 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 724         |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.0133      |
# |    std                  | 1.1         |
# |    value_loss           | 5.77e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.4       |
# |    ep_rew_mean          | -110       |
# | time/                   |            |
# |    fps                  | 745        |
# |    iterations           | 8          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00702248 |
# |    clip_fraction        | 0.0928     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.55      |
# |    explained_variance   | 0.0121     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.61e+03   |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.00631   |
# |    std                  | 1.1        |
# |    value_loss           | 1.51e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 9           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012663268 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+03    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.000369   |
# |    std                  | 1.1         |
# |    value_loss           | 6.35e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.4         |
# |    ep_rew_mean          | -130         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 10           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0049561462 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.54        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.92e+03     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000259    |
# |    std                  | 1.1          |
# |    value_loss           | 9.41e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.7         |
# |    ep_rew_mean          | -120         |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 11           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0046713967 |
# |    clip_fraction        | 0.0827       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.54        |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.61e+03     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000238    |
# |    std                  | 1.1          |
# |    value_loss           | 8.64e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.1        |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 12          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.028692707 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.8        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.00211     |
# |    std                  | 1.1         |
# |    value_loss           | 7.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.8        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 13          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.030948449 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.309       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.39e+03    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.0124      |
# |    std                  | 1.1         |
# |    value_loss           | 7.67e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.5        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 14          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.027229398 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.52e+03    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00372     |
# |    std                  | 1.1         |
# |    value_loss           | 4.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.3        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 15          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.043633852 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.89e+03    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.00401     |
# |    std                  | 1.1         |
# |    value_loss           | 5.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.7        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 16          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.026550032 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | -0.425      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.02e+03    |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00797     |
# |    std                  | 1.11        |
# |    value_loss           | 1.68e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 54.7      |
# |    ep_rew_mean          | -79.9     |
# | time/                   |           |
# |    fps                  | 727       |
# |    iterations           | 17        |
# |    time_elapsed         | 47        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 2.7063484 |
# |    clip_fraction        | 0.444     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.0776    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.78e+03  |
# |    n_updates            | 650       |
# |    policy_gradient_loss | 0.135     |
# |    std                  | 1.11      |
# |    value_loss           | 5.08e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 59.4      |
# |    ep_rew_mean          | -110      |
# | time/                   |           |
# |    fps                  | 727       |
# |    iterations           | 18        |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 1.0450717 |
# |    clip_fraction        | 0.506     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.59     |
# |    explained_variance   | 0.161     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 55.9      |
# |    n_updates            | 660       |
# |    policy_gradient_loss | 0.0387    |
# |    std                  | 1.12      |
# |    value_loss           | 4.79e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 54.2     |
# |    ep_rew_mean          | -150     |
# | time/                   |          |
# |    fps                  | 726      |
# |    iterations           | 19       |
# |    time_elapsed         | 53       |
# |    total_timesteps      | 38912    |
# | train/                  |          |
# |    approx_kl            | 7.344697 |
# |    clip_fraction        | 0.767    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.6     |
# |    explained_variance   | 0.166    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 4.81     |
# |    n_updates            | 670      |
# |    policy_gradient_loss | 0.058    |
# |    std                  | 1.13     |
# |    value_loss           | 5.96e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 20          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011363319 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.92e+03    |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00218     |
# |    std                  | 1.13        |
# |    value_loss           | 1.15e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.5       |
# |    ep_rew_mean          | -99.8      |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 21         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.04758185 |
# |    clip_fraction        | 0.334      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.61      |
# |    explained_variance   | 0.509      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.8e+03    |
# |    n_updates            | 690        |
# |    policy_gradient_loss | 0.0134     |
# |    std                  | 1.13       |
# |    value_loss           | 3.44e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.2        |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 22          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013893384 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.03e+03    |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 1.13        |
# |    value_loss           | 8.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.2        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 23          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010600135 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.5e+03     |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.000214   |
# |    std                  | 1.13        |
# |    value_loss           | 8.56e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.8         |
# |    ep_rew_mean          | -140         |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 24           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0038565195 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.62        |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.07e+03     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | 0.00139      |
# |    std                  | 1.13         |
# |    value_loss           | 1.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.5         |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 25           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0098660225 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.62        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.02e+03     |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.00481     |
# |    std                  | 1.13         |
# |    value_loss           | 1.01e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.1        |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 26          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015057704 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.71e+03    |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.00132     |
# |    std                  | 1.13        |
# |    value_loss           | 8.25e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 47.2      |
# |    ep_rew_mean          | -99.9     |
# | time/                   |           |
# |    fps                  | 723       |
# |    iterations           | 27        |
# |    time_elapsed         | 76        |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.4213633 |
# |    clip_fraction        | 0.258     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.62     |
# |    explained_variance   | 0.322     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.92e+03  |
# |    n_updates            | 750       |
# |    policy_gradient_loss | 0.00359   |
# |    std                  | 1.13      |
# |    value_loss           | 1.05e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48          |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 28          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025775589 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 615         |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.00248     |
# |    std                  | 1.13        |
# |    value_loss           | 5.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 29          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.042583335 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81e+03    |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.000195   |
# |    std                  | 1.13        |
# |    value_loss           | 7.3e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.3       |
# |    ep_rew_mean          | -160       |
# | time/                   |            |
# |    fps                  | 723        |
# |    iterations           | 30         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.05573676 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.62      |
# |    explained_variance   | 0.592      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.34e+04   |
# |    n_updates            | 780        |
# |    policy_gradient_loss | 0.0223     |
# |    std                  | 1.13       |
# |    value_loss           | 7.83e+03   |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 41.1     |
# |    ep_rew_mean          | -180     |
# | time/                   |          |
# |    fps                  | 723      |
# |    iterations           | 31       |
# |    time_elapsed         | 87       |
# |    total_timesteps      | 63488    |
# | train/                  |          |
# |    approx_kl            | 0.663519 |
# |    clip_fraction        | 0.403    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.62    |
# |    explained_variance   | 0.37     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.91e+03 |
# |    n_updates            | 790      |
# |    policy_gradient_loss | 0.0202   |
# |    std                  | 1.13     |
# |    value_loss           | 7.96e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44          |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 32          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.015537402 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.38e+03    |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.0015      |
# |    std                  | 1.13        |
# |    value_loss           | 1.14e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.4       |
# |    ep_rew_mean          | -99.9      |
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 33         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.38182443 |
# |    clip_fraction        | 0.533      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.65      |
# |    explained_variance   | 0.386      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 331        |
# |    n_updates            | 810        |
# |    policy_gradient_loss | 0.0447     |
# |    std                  | 1.16       |
# |    value_loss           | 2.99e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46          |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 34          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.021807652 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | -0.173      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58e+03    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.0133      |
# |    std                  | 1.16        |
# |    value_loss           | 7.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 35          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.089555606 |
# |    clip_fraction        | 0.48        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 90.8        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | 0.0324      |
# |    std                  | 1.18        |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.1       |
# |    ep_rew_mean          | -180       |
# | time/                   |            |
# |    fps                  | 725        |
# |    iterations           | 36         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02755354 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.74      |
# |    explained_variance   | 0.272      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 61.7       |
# |    n_updates            | 840        |
# |    policy_gradient_loss | 0.00582    |
# |    std                  | 1.17       |
# |    value_loss           | 5.31e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.2         |
# |    ep_rew_mean          | -220         |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 37           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0019198677 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.74        |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12e+04     |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00074     |
# |    std                  | 1.17         |
# |    value_loss           | 2.25e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.2        |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 38          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.040725205 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.39e+03    |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.000193   |
# |    std                  | 1.17        |
# |    value_loss           | 1.2e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.3         |
# |    ep_rew_mean          | -140         |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 39           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0057650064 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.74        |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 534          |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00373     |
# |    std                  | 1.17         |
# |    value_loss           | 6.82e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.2       |
# |    ep_rew_mean          | -120       |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 40         |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.06699217 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.74      |
# |    explained_variance   | 0.312      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.72e+03   |
# |    n_updates            | 880        |
# |    policy_gradient_loss | 0.0105     |
# |    std                  | 1.17       |
# |    value_loss           | 7.61e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.9        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 41          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007482708 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.73e+03    |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00305    |
# |    std                  | 1.18        |
# |    value_loss           | 9.58e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.2       |
# |    ep_rew_mean          | -170       |
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 42         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.91873014 |
# |    clip_fraction        | 0.446      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.74      |
# |    explained_variance   | 0.184      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.5       |
# |    n_updates            | 900        |
# |    policy_gradient_loss | 0.0203     |
# |    std                  | 1.18       |
# |    value_loss           | 6.82e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 43          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.037876204 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.5        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.0067      |
# |    std                  | 1.18        |
# |    value_loss           | 1.47e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.2         |
# |    ep_rew_mean          | -120         |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 44           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0060382346 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.74        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.17e+03     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00345     |
# |    std                  | 1.18         |
# |    value_loss           | 1.38e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.8        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 45          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.045211833 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.39e+03    |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.00568     |
# |    std                  | 1.18        |
# |    value_loss           | 8.42e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 45.4      |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 46        |
# |    time_elapsed         | 130       |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 0.4392197 |
# |    clip_fraction        | 0.453     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.74     |
# |    explained_variance   | 0.221     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 160       |
# |    n_updates            | 940       |
# |    policy_gradient_loss | 0.0339    |
# |    std                  | 1.19      |
# |    value_loss           | 1.5e+03   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.8        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 47          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.082390025 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.77       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 431         |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00989     |
# |    std                  | 1.19        |
# |    value_loss           | 2.23e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 46.8      |
# |    ep_rew_mean          | -89.9     |
# | time/                   |           |
# |    fps                  | 718       |
# |    iterations           | 48        |
# |    time_elapsed         | 136       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 2.6349196 |
# |    clip_fraction        | 0.624     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.78     |
# |    explained_variance   | 0.801     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.1       |
# |    n_updates            | 960       |
# |    policy_gradient_loss | 0.057     |
# |    std                  | 1.2       |
# |    value_loss           | 578       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.1        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 49          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.123797804 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.43e+03    |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.0165      |
# |    std                  | 1.2         |
# |    value_loss           | 9.25e+03    |
# -----------------------------------------
# --- 140.9886302947998 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-85.86 +/- 280.41

# %%
model.save("zeppelin-v2.1-200000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.9     |
# |    ep_rew_mean     | -160     |
# | time/              |          |
# |    fps             | 1266     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.1       |
# |    ep_rew_mean          | -158       |
# | time/                   |            |
# |    fps                  | 897        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01258838 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.8       |
# |    explained_variance   | 0.426      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.35e+03   |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.00376   |
# |    std                  | 1.2        |
# |    value_loss           | 1.03e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.8       |
# |    ep_rew_mean          | -140       |
# | time/                   |            |
# |    fps                  | 806        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.04942543 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.8       |
# |    explained_variance   | 0.273      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.07e+03   |
# |    n_updates            | 1000       |
# |    policy_gradient_loss | 0.00487    |
# |    std                  | 1.2        |
# |    value_loss           | 8.27e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.7       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 776        |
# |    iterations           | 4          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.03335937 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.8       |
# |    explained_variance   | 0.0151     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12       |
# |    n_updates            | 1010       |
# |    policy_gradient_loss | 0.0103     |
# |    std                  | 1.2        |
# |    value_loss           | 7.15e+03   |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 43.9     |
# |    ep_rew_mean          | -79.9    |
# | time/                   |          |
# |    fps                  | 761      |
# |    iterations           | 5        |
# |    time_elapsed         | 13       |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 1.983045 |
# |    clip_fraction        | 0.538    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.81    |
# |    explained_variance   | 0.136    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 5.04e+03 |
# |    n_updates            | 1020     |
# |    policy_gradient_loss | 0.0438   |
# |    std                  | 1.21     |
# |    value_loss           | 5.54e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.059882674 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.95e+03    |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | 0.017       |
# |    std                  | 1.21        |
# |    value_loss           | 8.4e+03     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 46.6      |
# |    ep_rew_mean          | -110      |
# | time/                   |           |
# |    fps                  | 745       |
# |    iterations           | 7         |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.2750175 |
# |    clip_fraction        | 0.272     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.83     |
# |    explained_variance   | 0.182     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 220       |
# |    n_updates            | 1040      |
# |    policy_gradient_loss | 0.0169    |
# |    std                  | 1.21      |
# |    value_loss           | 5.44e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.2        |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.047713958 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 369         |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | 0.0152      |
# |    std                  | 1.21        |
# |    value_loss           | 3.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.1        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 9           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.043904684 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+03    |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | 0.000888    |
# |    std                  | 1.21        |
# |    value_loss           | 5.83e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.1       |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 10         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.41553968 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.83      |
# |    explained_variance   | 0.349      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 786        |
# |    n_updates            | 1070       |
# |    policy_gradient_loss | 0.0383     |
# |    std                  | 1.22       |
# |    value_loss           | 3.82e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 40.4      |
# |    ep_rew_mean          | -99.9     |
# | time/                   |           |
# |    fps                  | 723       |
# |    iterations           | 11        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 1.8616076 |
# |    clip_fraction        | 0.5       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.85     |
# |    explained_variance   | 0.44      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.3e+03   |
# |    n_updates            | 1080      |
# |    policy_gradient_loss | 0.0743    |
# |    std                  | 1.22      |
# |    value_loss           | 4.11e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009273771 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.6        |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.00319    |
# |    std                  | 1.22        |
# |    value_loss           | 7.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.3        |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 13          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007739033 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87e+03    |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00223    |
# |    std                  | 1.22        |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.7         |
# |    ep_rew_mean          | -180         |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 14           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0039475258 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.86        |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.0037      |
# |    std                  | 1.22         |
# |    value_loss           | 9.17e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.1       |
# |    ep_rew_mean          | -110       |
# | time/                   |            |
# |    fps                  | 719        |
# |    iterations           | 15         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.06157528 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.86      |
# |    explained_variance   | 0.568      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.56e+03   |
# |    n_updates            | 1120       |
# |    policy_gradient_loss | 0.00137    |
# |    std                  | 1.22       |
# |    value_loss           | 9.63e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 46.7      |
# |    ep_rew_mean          | -89.9     |
# | time/                   |           |
# |    fps                  | 716       |
# |    iterations           | 16        |
# |    time_elapsed         | 45        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 1.1766001 |
# |    clip_fraction        | 0.447     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.85     |
# |    explained_variance   | -1.46     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 199       |
# |    n_updates            | 1130      |
# |    policy_gradient_loss | 0.034     |
# |    std                  | 1.21      |
# |    value_loss           | 1.44e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.5        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 17          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022268485 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+03    |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | 0.00548     |
# |    std                  | 1.22        |
# |    value_loss           | 7.75e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.9       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 714        |
# |    iterations           | 18         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.10611282 |
# |    clip_fraction        | 0.363      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.84      |
# |    explained_variance   | 0.18       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.89       |
# |    n_updates            | 1150       |
# |    policy_gradient_loss | 0.0171     |
# |    std                  | 1.21       |
# |    value_loss           | 5.67e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.3       |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 713        |
# |    iterations           | 19         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.11255695 |
# |    clip_fraction        | 0.379      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.83      |
# |    explained_variance   | 0.608      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.97e+03   |
# |    n_updates            | 1160       |
# |    policy_gradient_loss | 0.0182     |
# |    std                  | 1.21       |
# |    value_loss           | 3.6e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 20          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015932586 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | 0.00632     |
# |    std                  | 1.21        |
# |    value_loss           | 7.23e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.2       |
# |    ep_rew_mean          | -160       |
# | time/                   |            |
# |    fps                  | 714        |
# |    iterations           | 21         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.39439213 |
# |    clip_fraction        | 0.481      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.84      |
# |    explained_variance   | 0.662      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 85.6       |
# |    n_updates            | 1180       |
# |    policy_gradient_loss | 0.0325     |
# |    std                  | 1.22       |
# |    value_loss           | 5.83e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.9       |
# |    ep_rew_mean          | -89.9      |
# | time/                   |            |
# |    fps                  | 715        |
# |    iterations           | 22         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.32861334 |
# |    clip_fraction        | 0.48       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.85      |
# |    explained_variance   | 0.407      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.5e+03    |
# |    n_updates            | 1190       |
# |    policy_gradient_loss | 0.0264     |
# |    std                  | 1.22       |
# |    value_loss           | 7.41e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 42.6      |
# |    ep_rew_mean          | -79.8     |
# | time/                   |           |
# |    fps                  | 714       |
# |    iterations           | 23        |
# |    time_elapsed         | 65        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.3604877 |
# |    clip_fraction        | 0.424     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.86     |
# |    explained_variance   | -0.224    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 67.7      |
# |    n_updates            | 1200      |
# |    policy_gradient_loss | 0.0308    |
# |    std                  | 1.22      |
# |    value_loss           | 2.23e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 44.3      |
# |    ep_rew_mean          | -69.8     |
# | time/                   |           |
# |    fps                  | 713       |
# |    iterations           | 24        |
# |    time_elapsed         | 68        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 1.6324892 |
# |    clip_fraction        | 0.502     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.86     |
# |    explained_variance   | 0.41      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 30        |
# |    n_updates            | 1210      |
# |    policy_gradient_loss | 0.0453    |
# |    std                  | 1.23      |
# |    value_loss           | 5.1e+03   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46         |
# |    ep_rew_mean          | -59.8      |
# | time/                   |            |
# |    fps                  | 714        |
# |    iterations           | 25         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.40322202 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.88      |
# |    explained_variance   | -1.53      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 986        |
# |    n_updates            | 1220       |
# |    policy_gradient_loss | 0.0258     |
# |    std                  | 1.23       |
# |    value_loss           | 3.28e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.9       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 712        |
# |    iterations           | 26         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.24859507 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.88      |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.52e+03   |
# |    n_updates            | 1230       |
# |    policy_gradient_loss | 0.0306     |
# |    std                  | 1.24       |
# |    value_loss           | 3.73e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.1       |
# |    ep_rew_mean          | -59.9      |
# | time/                   |            |
# |    fps                  | 712        |
# |    iterations           | 27         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03158204 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.9       |
# |    explained_variance   | 0.146      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.54e+03   |
# |    n_updates            | 1240       |
# |    policy_gradient_loss | 0.0145     |
# |    std                  | 1.24       |
# |    value_loss           | 8.06e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.1       |
# |    ep_rew_mean          | -39.8      |
# | time/                   |            |
# |    fps                  | 712        |
# |    iterations           | 28         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.14113648 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.89      |
# |    explained_variance   | 0.14       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.13e+03   |
# |    n_updates            | 1250       |
# |    policy_gradient_loss | 0.0128     |
# |    std                  | 1.23       |
# |    value_loss           | 3.31e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.9       |
# |    ep_rew_mean          | -69.8      |
# | time/                   |            |
# |    fps                  | 708        |
# |    iterations           | 29         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.06789954 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.87      |
# |    explained_variance   | -0.0322    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.12       |
# |    n_updates            | 1260       |
# |    policy_gradient_loss | 0.0345     |
# |    std                  | 1.23       |
# |    value_loss           | 3.71e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 55.9      |
# |    ep_rew_mean          | -79.8     |
# | time/                   |           |
# |    fps                  | 706       |
# |    iterations           | 30        |
# |    time_elapsed         | 87        |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.1194207 |
# |    clip_fraction        | 0.337     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.88     |
# |    explained_variance   | 0.43      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.61e+03  |
# |    n_updates            | 1270      |
# |    policy_gradient_loss | 0.0153    |
# |    std                  | 1.23      |
# |    value_loss           | 6.78e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 56.3      |
# |    ep_rew_mean          | -79.9     |
# | time/                   |           |
# |    fps                  | 706       |
# |    iterations           | 31        |
# |    time_elapsed         | 89        |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 3.6487286 |
# |    clip_fraction        | 0.561     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.89     |
# |    explained_variance   | -2.14     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 232       |
# |    n_updates            | 1280      |
# |    policy_gradient_loss | 0.0242    |
# |    std                  | 1.24      |
# |    value_loss           | 3.04e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.2       |
# |    ep_rew_mean          | -110       |
# | time/                   |            |
# |    fps                  | 705        |
# |    iterations           | 32         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.41557032 |
# |    clip_fraction        | 0.383      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.91      |
# |    explained_variance   | 0.81       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17       |
# |    n_updates            | 1290       |
# |    policy_gradient_loss | 0.0444     |
# |    std                  | 1.25       |
# |    value_loss           | 93.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 33          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.034471586 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.589       |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | 0.00927     |
# |    std                  | 1.25        |
# |    value_loss           | 7.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.8        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 34          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.032507226 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+03    |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | 0.0186      |
# |    std                  | 1.26        |
# |    value_loss           | 1.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.8        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 35          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.065350145 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44e+03    |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 1.26        |
# |    value_loss           | 5.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 36          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.045877345 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 118         |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | 0.00907     |
# |    std                  | 1.26        |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 47        |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 706       |
# |    iterations           | 37        |
# |    time_elapsed         | 107       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0545196 |
# |    clip_fraction        | 0.316     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.96     |
# |    explained_variance   | 0.114     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 987       |
# |    n_updates            | 1340      |
# |    policy_gradient_loss | 0.0267    |
# |    std                  | 1.26      |
# |    value_loss           | 4.46e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 46.8      |
# |    ep_rew_mean          | -59.9     |
# | time/                   |           |
# |    fps                  | 707       |
# |    iterations           | 38        |
# |    time_elapsed         | 109       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.1880775 |
# |    clip_fraction        | 0.264     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.96     |
# |    explained_variance   | 0.622     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 34.4      |
# |    n_updates            | 1350      |
# |    policy_gradient_loss | 0.00957   |
# |    std                  | 1.27      |
# |    value_loss           | 947       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.1        |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 39          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.041305553 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 153         |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | 0.00409     |
# |    std                  | 1.27        |
# |    value_loss           | 7.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.4        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 40          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.057950124 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.781       |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | 0.0114      |
# |    std                  | 1.27        |
# |    value_loss           | 4.48e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 53.3      |
# |    ep_rew_mean          | -89.9     |
# | time/                   |           |
# |    fps                  | 707       |
# |    iterations           | 41        |
# |    time_elapsed         | 118       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.3759762 |
# |    clip_fraction        | 0.473     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.96     |
# |    explained_variance   | 0.532     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.11e+03  |
# |    n_updates            | 1380      |
# |    policy_gradient_loss | 0.0255    |
# |    std                  | 1.27      |
# |    value_loss           | 2.24e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.9       |
# |    ep_rew_mean          | -110       |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 42         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.03235536 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | 0.571      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.07e+03   |
# |    n_updates            | 1390       |
# |    policy_gradient_loss | 0.00791    |
# |    std                  | 1.27       |
# |    value_loss           | 3.11e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.6         |
# |    ep_rew_mean          | -79.9        |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 43           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0047983173 |
# |    clip_fraction        | 0.0935       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 503          |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 1.27         |
# |    value_loss           | 1.15e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.9       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 705        |
# |    iterations           | 44         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.04564333 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.97      |
# |    explained_variance   | -0.079     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 150        |
# |    n_updates            | 1410       |
# |    policy_gradient_loss | 0.00627    |
# |    std                  | 1.27       |
# |    value_loss           | 1.8e+03    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.6         |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 45           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0050053643 |
# |    clip_fraction        | 0.0928       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.25e+03     |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | 0.000833     |
# |    std                  | 1.27         |
# |    value_loss           | 6.89e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47         |
# |    ep_rew_mean          | -130       |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 46         |
# |    time_elapsed         | 133        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03714101 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | 0.72       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.07e+03   |
# |    n_updates            | 1430       |
# |    policy_gradient_loss | 0.00229    |
# |    std                  | 1.27       |
# |    value_loss           | 4.99e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.5       |
# |    ep_rew_mean          | -150       |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 47         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.04264154 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | 0.437      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.6       |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | 0.00753    |
# |    std                  | 1.27       |
# |    value_loss           | 6.72e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.4       |
# |    ep_rew_mean          | -120       |
# | time/                   |            |
# |    fps                  | 705        |
# |    iterations           | 48         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.05459384 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.97      |
# |    explained_variance   | 0.573      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20.5       |
# |    n_updates            | 1450       |
# |    policy_gradient_loss | 0.00839    |
# |    std                  | 1.27       |
# |    value_loss           | 2.39e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.3       |
# |    ep_rew_mean          | -130       |
# | time/                   |            |
# |    fps                  | 705        |
# |    iterations           | 49         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.14211674 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.97      |
# |    explained_variance   | 0.638      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 55.7       |
# |    n_updates            | 1460       |
# |    policy_gradient_loss | 0.0174     |
# |    std                  | 1.27       |
# |    value_loss           | 4.35e+03   |
# ----------------------------------------
# --- 143.9128062725067 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-75.87 +/- 265.03

# %%
model.save("zeppelin-v2.1-300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.1     |
# |    ep_rew_mean     | -76.8    |
# | time/              |          |
# |    fps             | 1290     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51          |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.027719269 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.1        |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | 0.0128      |
# |    std                  | 1.27        |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.1        |
# |    ep_rew_mean          | -79.8       |
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.064686045 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | -0.376      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | 0.00946     |
# |    std                  | 1.27        |
# |    value_loss           | 4.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | -89.8       |
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016449071 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 798         |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | 0.00346     |
# |    std                  | 1.27        |
# |    value_loss           | 8.96e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.8      |
# |    ep_rew_mean          | -110      |
# | time/                   |           |
# |    fps                  | 783       |
# |    iterations           | 5         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 1.8529404 |
# |    clip_fraction        | 0.52      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.98     |
# |    explained_variance   | 0.742     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9         |
# |    n_updates            | 1510      |
# |    policy_gradient_loss | 0.0294    |
# |    std                  | 1.28      |
# |    value_loss           | 2.15e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.5        |
# |    ep_rew_mean          | -89.8       |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.050422437 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 1520        |
# |    policy_gradient_loss | 0.00915     |
# |    std                  | 1.28        |
# |    value_loss           | 5.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.5        |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.055659622 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 1530        |
# |    policy_gradient_loss | 0.0109      |
# |    std                  | 1.27        |
# |    value_loss           | 3.03e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 46.6      |
# |    ep_rew_mean          | -99.9     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 8         |
# |    time_elapsed         | 22        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.1920751 |
# |    clip_fraction        | 0.133     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.99     |
# |    explained_variance   | 0.511     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 30.3      |
# |    n_updates            | 1540      |
# |    policy_gradient_loss | 0.017     |
# |    std                  | 1.28      |
# |    value_loss           | 5.74e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.6       |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 731        |
# |    iterations           | 9          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.26282266 |
# |    clip_fraction        | 0.474      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.99      |
# |    explained_variance   | 0.58       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.83       |
# |    n_updates            | 1550       |
# |    policy_gradient_loss | 0.0242     |
# |    std                  | 1.28       |
# |    value_loss           | 7.04e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.2       |
# |    ep_rew_mean          | -59.9      |
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 10         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.13741884 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5         |
# |    explained_variance   | 0.571      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 189        |
# |    n_updates            | 1560       |
# |    policy_gradient_loss | 0.0284     |
# |    std                  | 1.28       |
# |    value_loss           | 2.05e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.5        |
# |    ep_rew_mean          | -69.8       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010505802 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 1570        |
# |    policy_gradient_loss | 0.00116     |
# |    std                  | 1.28        |
# |    value_loss           | 5.01e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 69.4       |
# |    ep_rew_mean          | -99.8      |
# | time/                   |            |
# |    fps                  | 723        |
# |    iterations           | 12         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.33528513 |
# |    clip_fraction        | 0.393      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.01      |
# |    explained_variance   | 0.501      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 276        |
# |    n_updates            | 1580       |
# |    policy_gradient_loss | 0.0165     |
# |    std                  | 1.29       |
# |    value_loss           | 4.06e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53         |
# |    ep_rew_mean          | -120       |
# | time/                   |            |
# |    fps                  | 723        |
# |    iterations           | 13         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.06253574 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5         |
# |    explained_variance   | 0.342      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.73e+03   |
# |    n_updates            | 1590       |
# |    policy_gradient_loss | 0.0133     |
# |    std                  | 1.28       |
# |    value_loss           | 4.93e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.3       |
# |    ep_rew_mean          | -110       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 14         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.07719056 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5         |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 238        |
# |    n_updates            | 1600       |
# |    policy_gradient_loss | 0.0157     |
# |    std                  | 1.28       |
# |    value_loss           | 1.84e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.5      |
# |    ep_rew_mean          | -110      |
# | time/                   |           |
# |    fps                  | 722       |
# |    iterations           | 15        |
# |    time_elapsed         | 42        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0801086 |
# |    clip_fraction        | 0.278     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5        |
# |    explained_variance   | 0.673     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.92e+03  |
# |    n_updates            | 1610      |
# |    policy_gradient_loss | 0.00742   |
# |    std                  | 1.28      |
# |    value_loss           | 3.55e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.2        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 16          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.070379525 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.517       |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | 0.0183      |
# |    std                  | 1.28        |
# |    value_loss           | 5.28e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 68.2      |
# |    ep_rew_mean          | -79.9     |
# | time/                   |           |
# |    fps                  | 723       |
# |    iterations           | 17        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.4485498 |
# |    clip_fraction        | 0.344     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.01     |
# |    explained_variance   | 0.255     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.22      |
# |    n_updates            | 1630      |
# |    policy_gradient_loss | 0.0328    |
# |    std                  | 1.29      |
# |    value_loss           | 4.09e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.3        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.025665758 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.381       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 773         |
# |    n_updates            | 1640        |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 1.3         |
# |    value_loss           | 3.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54          |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 19          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016844625 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+03     |
# |    n_updates            | 1650        |
# |    policy_gradient_loss | 0.00358     |
# |    std                  | 1.29        |
# |    value_loss           | 5.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 20          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.031387083 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | -25.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 1660        |
# |    policy_gradient_loss | 0.0186      |
# |    std                  | 1.29        |
# |    value_loss           | 211         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 21          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.036198005 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.506       |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | 0.00841     |
# |    std                  | 1.3         |
# |    value_loss           | 225         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.4       |
# |    ep_rew_mean          | -49.9      |
# | time/                   |            |
# |    fps                  | 720        |
# |    iterations           | 22         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.04806401 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.06      |
# |    explained_variance   | 0.802      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.254      |
# |    n_updates            | 1680       |
# |    policy_gradient_loss | 0.0113     |
# |    std                  | 1.31       |
# |    value_loss           | 645        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.8        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 23          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.030890375 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.72e+03    |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | 0.00304     |
# |    std                  | 1.32        |
# |    value_loss           | 1.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.1        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 24          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025443029 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 249         |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | 0.00756     |
# |    std                  | 1.32        |
# |    value_loss           | 2.72e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.8        |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 25          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.060334913 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.74e+03    |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | 0.00996     |
# |    std                  | 1.33        |
# |    value_loss           | 2.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.3        |
# |    ep_rew_mean          | -69.8       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 26          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.070356205 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.198       |
# |    n_updates            | 1720        |
# |    policy_gradient_loss | 0.0131      |
# |    std                  | 1.33        |
# |    value_loss           | 1.01e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60.2      |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 717       |
# |    iterations           | 27        |
# |    time_elapsed         | 77        |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.0535486 |
# |    clip_fraction        | 0.303     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.11     |
# |    explained_variance   | 0.23      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.9       |
# |    n_updates            | 1730      |
# |    policy_gradient_loss | 0.014     |
# |    std                  | 1.33      |
# |    value_loss           | 1.65e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.7        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 28          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.028855622 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | 0.00471     |
# |    std                  | 1.31        |
# |    value_loss           | 1.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.1        |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 29          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.043710813 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 299         |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | 0.0087      |
# |    std                  | 1.32        |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47         |
# |    ep_rew_mean          | -120       |
# | time/                   |            |
# |    fps                  | 713        |
# |    iterations           | 30         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.05031353 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.09      |
# |    explained_variance   | 0.414      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.8e+04    |
# |    n_updates            | 1760       |
# |    policy_gradient_loss | 0.0101     |
# |    std                  | 1.32       |
# |    value_loss           | 1.23e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.6        |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 31          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014546742 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 751         |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | 0.000636    |
# |    std                  | 1.32        |
# |    value_loss           | 8.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 32          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.029760314 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.00556     |
# |    std                  | 1.33        |
# |    value_loss           | 425         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 33          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011035796 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.00272     |
# |    std                  | 1.33        |
# |    value_loss           | 6.85e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.6       |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 711        |
# |    iterations           | 34         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.09343664 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.11      |
# |    explained_variance   | 0.585      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 43.6       |
# |    n_updates            | 1800       |
# |    policy_gradient_loss | 0.00944    |
# |    std                  | 1.33       |
# |    value_loss           | 2.19e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.2         |
# |    ep_rew_mean          | -49.9        |
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 35           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0070971306 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.11        |
# |    explained_variance   | -0.0927      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61e+03     |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | 0.00105      |
# |    std                  | 1.33         |
# |    value_loss           | 7.51e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.4        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 36          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.027952563 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.1        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.00924     |
# |    std                  | 1.32        |
# |    value_loss           | 1.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61.6       |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 711        |
# |    iterations           | 37         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02850523 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.09      |
# |    explained_variance   | -25.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.07       |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | 0.00768    |
# |    std                  | 1.32       |
# |    value_loss           | 331        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 38          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.022956742 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.662       |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.00763     |
# |    std                  | 1.32        |
# |    value_loss           | 1.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.9        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 39          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.037740476 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.191       |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | 0.0109      |
# |    std                  | 1.32        |
# |    value_loss           | 1.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.4        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 40          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.050641418 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.89e+03    |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.00942     |
# |    std                  | 1.32        |
# |    value_loss           | 5.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.9       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 714        |
# |    iterations           | 41         |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02667582 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.1       |
# |    explained_variance   | 0.119      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 104        |
# |    n_updates            | 1870       |
# |    policy_gradient_loss | 0.00851    |
# |    std                  | 1.33       |
# |    value_loss           | 5.79e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.8        |
# |    ep_rew_mean          | -9.89       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 42          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.030098373 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | -22.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.5        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.0108      |
# |    std                  | 1.33        |
# |    value_loss           | 23          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.2       |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 713        |
# |    iterations           | 43         |
# |    time_elapsed         | 123        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.02183612 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.08      |
# |    explained_variance   | -165       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.077      |
# |    n_updates            | 1890       |
# |    policy_gradient_loss | 0.00118    |
# |    std                  | 1.31       |
# |    value_loss           | 121        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.8         |
# |    ep_rew_mean          | -69.9        |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 44           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0065614358 |
# |    clip_fraction        | 0.193        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.06        |
# |    explained_variance   | 0.0906       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | 0.00403      |
# |    std                  | 1.31         |
# |    value_loss           | 6.59e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.4        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 45          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.019206272 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 308         |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.00638     |
# |    std                  | 1.31        |
# |    value_loss           | 4.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.9        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 46          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.106188804 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 284         |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.0135      |
# |    std                  | 1.31        |
# |    value_loss           | 5.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.2        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 47          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.034199424 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.00555     |
# |    std                  | 1.31        |
# |    value_loss           | 2.71e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.1       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 715        |
# |    iterations           | 48         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.35832053 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.07      |
# |    explained_variance   | 0.798      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.446      |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | 0.0163     |
# |    std                  | 1.31       |
# |    value_loss           | 1.54e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.4        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 49          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.059933312 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 1.31        |
# |    value_loss           | 3.36e+03    |
# -----------------------------------------
# --- 141.83863806724548 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-37.86 +/- 191.22

# %%
model.save("zeppelin-v2.1-400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.6     |
# |    ep_rew_mean     | -55.4    |
# | time/              |          |
# |    fps             | 1210     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51         |
# |    ep_rew_mean          | -62.3      |
# | time/                   |            |
# |    fps                  | 880        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.05975996 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.05      |
# |    explained_variance   | 0.56       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.73e+03   |
# |    n_updates            | 1970       |
# |    policy_gradient_loss | 0.0151     |
# |    std                  | 1.31       |
# |    value_loss           | 1.91e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.9       |
# |    ep_rew_mean          | -79.8      |
# | time/                   |            |
# |    fps                  | 823        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.05108822 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.06      |
# |    explained_variance   | 0.348      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.36e+03   |
# |    n_updates            | 1980       |
# |    policy_gradient_loss | 0.00707    |
# |    std                  | 1.31       |
# |    value_loss           | 5.42e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.2       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 4          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.05721669 |
# |    clip_fraction        | 0.35       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.07      |
# |    explained_variance   | 0.631      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.06e+03   |
# |    n_updates            | 1990       |
# |    policy_gradient_loss | 0.0183     |
# |    std                  | 1.31       |
# |    value_loss           | 3.5e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.1        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.040919837 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.3        |
# |    n_updates            | 2000        |
# |    policy_gradient_loss | 0.00684     |
# |    std                  | 1.31        |
# |    value_loss           | 6.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.025408484 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.07       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 568         |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | 0.00453     |
# |    std                  | 1.3         |
# |    value_loss           | 2.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.1        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.052887917 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.05       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | 0.0131      |
# |    std                  | 1.3         |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.6       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 696        |
# |    iterations           | 8          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.05381484 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.04      |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.391      |
# |    n_updates            | 2030       |
# |    policy_gradient_loss | 0.00894    |
# |    std                  | 1.3        |
# |    value_loss           | 4.87e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.6       |
# |    ep_rew_mean          | -79.8      |
# | time/                   |            |
# |    fps                  | 701        |
# |    iterations           | 9          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.14637578 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.04      |
# |    explained_variance   | 0.107      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.16e+03   |
# |    n_updates            | 2040       |
# |    policy_gradient_loss | 0.0181     |
# |    std                  | 1.3        |
# |    value_loss           | 6.15e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55.1         |
# |    ep_rew_mean          | -69.8        |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 10           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0048536314 |
# |    clip_fraction        | 0.0834       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.06e+03     |
# |    n_updates            | 2050         |
# |    policy_gradient_loss | 0.00138      |
# |    std                  | 1.3          |
# |    value_loss           | 5.69e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.6       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 11         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.04080869 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.04      |
# |    explained_variance   | 0.489      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.957      |
# |    n_updates            | 2060       |
# |    policy_gradient_loss | 0.00871    |
# |    std                  | 1.3        |
# |    value_loss           | 3.72e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.7        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.067922086 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.724       |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | 0.018       |
# |    std                  | 1.31        |
# |    value_loss           | 1.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.9        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032654934 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.293       |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | 0.00888     |
# |    std                  | 1.31        |
# |    value_loss           | 3.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | -59.8       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017489638 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | -0.302      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.17e+03    |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | 0.00223     |
# |    std                  | 1.31        |
# |    value_loss           | 8.42e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58         |
# |    ep_rew_mean          | -59.8      |
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 15         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.28562105 |
# |    clip_fraction        | 0.422      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.06      |
# |    explained_variance   | 0.76       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.228      |
# |    n_updates            | 2100       |
# |    policy_gradient_loss | 0.0196     |
# |    std                  | 1.31       |
# |    value_loss           | 900        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.9        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 16          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.026379172 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.07       |
# |    explained_variance   | -0.545      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 497         |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | 0.00914     |
# |    std                  | 1.31        |
# |    value_loss           | 7.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.9        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 17          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.045412257 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.229       |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 1.3         |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.4        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 18          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.031412784 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 257         |
# |    n_updates            | 2130        |
# |    policy_gradient_loss | 0.0057      |
# |    std                  | 1.31        |
# |    value_loss           | 4.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.4       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 697        |
# |    iterations           | 19         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.06713668 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.06      |
# |    explained_variance   | 0.0762     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.413      |
# |    n_updates            | 2140       |
# |    policy_gradient_loss | 0.00637    |
# |    std                  | 1.31       |
# |    value_loss           | 5.29e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.9       |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 694        |
# |    iterations           | 20         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01872395 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.08      |
# |    explained_variance   | -69.4      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.163      |
# |    n_updates            | 2150       |
# |    policy_gradient_loss | 0.0128     |
# |    std                  | 1.32       |
# |    value_loss           | 11.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52         |
# |    ep_rew_mean          | -49.9      |
# | time/                   |            |
# |    fps                  | 695        |
# |    iterations           | 21         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02844198 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.09      |
# |    explained_variance   | 0.525      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.8       |
# |    n_updates            | 2160       |
# |    policy_gradient_loss | 0.0125     |
# |    std                  | 1.32       |
# |    value_loss           | 2.75e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.2       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 696        |
# |    iterations           | 22         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.03122924 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.1       |
# |    explained_variance   | 0.724      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 716        |
# |    n_updates            | 2170       |
# |    policy_gradient_loss | 0.0074     |
# |    std                  | 1.33       |
# |    value_loss           | 2.22e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.2        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 23          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025281444 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | -46.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 123         |
# |    n_updates            | 2180        |
# |    policy_gradient_loss | 0.00422     |
# |    std                  | 1.32        |
# |    value_loss           | 225         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.2        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 24          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.038943708 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | -0.63       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.62        |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | 0.0131      |
# |    std                  | 1.32        |
# |    value_loss           | 1.83e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.9       |
# |    ep_rew_mean          | -69.8      |
# | time/                   |            |
# |    fps                  | 696        |
# |    iterations           | 25         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.08035882 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.08      |
# |    explained_variance   | 0.366      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.6e+03    |
# |    n_updates            | 2200       |
# |    policy_gradient_loss | 0.00965    |
# |    std                  | 1.32       |
# |    value_loss           | 3.85e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44          |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 26          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.021260945 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 2210        |
# |    policy_gradient_loss | 0.00633     |
# |    std                  | 1.32        |
# |    value_loss           | 5.01e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.3       |
# |    ep_rew_mean          | -49.9      |
# | time/                   |            |
# |    fps                  | 696        |
# |    iterations           | 27         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00383269 |
# |    clip_fraction        | 0.083      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.09      |
# |    explained_variance   | -0.0871    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.07       |
# |    n_updates            | 2220       |
# |    policy_gradient_loss | 0.00157    |
# |    std                  | 1.32       |
# |    value_loss           | 8.72e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.5        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 28          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.026863806 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.07       |
# |    explained_variance   | -0.0568     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.259       |
# |    n_updates            | 2230        |
# |    policy_gradient_loss | 0.00616     |
# |    std                  | 1.3         |
# |    value_loss           | 930         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 29          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.021638721 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+04    |
# |    n_updates            | 2240        |
# |    policy_gradient_loss | 0.00446     |
# |    std                  | 1.3         |
# |    value_loss           | 5.91e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.8        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 30          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.018045168 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | -0.0927     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.39e+03    |
# |    n_updates            | 2250        |
# |    policy_gradient_loss | 0.00597     |
# |    std                  | 1.3         |
# |    value_loss           | 3.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 31          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022613496 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+03     |
# |    n_updates            | 2260        |
# |    policy_gradient_loss | 0.0047      |
# |    std                  | 1.3         |
# |    value_loss           | 5.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 32          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.037991945 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.05       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | 0.00773     |
# |    std                  | 1.31        |
# |    value_loss           | 1.84e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.1       |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 699        |
# |    iterations           | 33         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.09804636 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.06      |
# |    explained_variance   | 0.42       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.2e+03    |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | 0.00432    |
# |    std                  | 1.31       |
# |    value_loss           | 3.57e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.1       |
# |    ep_rew_mean          | -89.9      |
# | time/                   |            |
# |    fps                  | 701        |
# |    iterations           | 34         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.06365745 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.06      |
# |    explained_variance   | 0.733      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.69e+03   |
# |    n_updates            | 2290       |
# |    policy_gradient_loss | 0.0108     |
# |    std                  | 1.31       |
# |    value_loss           | 2.79e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.5       |
# |    ep_rew_mean          | -99.9      |
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 35         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02649792 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.07      |
# |    explained_variance   | 0.607      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.2       |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | 0.0126     |
# |    std                  | 1.32       |
# |    value_loss           | 2.67e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.8       |
# |    ep_rew_mean          | -99.9      |
# | time/                   |            |
# |    fps                  | 703        |
# |    iterations           | 36         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.09616857 |
# |    clip_fraction        | 0.287      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.09      |
# |    explained_variance   | 0.796      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 77.4       |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | 0.0104     |
# |    std                  | 1.33       |
# |    value_loss           | 1.18e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47          |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 37          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.029996142 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26e+03    |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | 0.00424     |
# |    std                  | 1.33        |
# |    value_loss           | 5.23e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.8       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 704        |
# |    iterations           | 38         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.09696049 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.12      |
# |    explained_variance   | 0.582      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 104        |
# |    n_updates            | 2330       |
# |    policy_gradient_loss | 0.00346    |
# |    std                  | 1.33       |
# |    value_loss           | 2.35e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.3       |
# |    ep_rew_mean          | -69.9      |
# | time/                   |            |
# |    fps                  | 703        |
# |    iterations           | 39         |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.02012049 |
# |    clip_fraction        | 0.0389     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.12      |
# |    explained_variance   | 0.346      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 187        |
# |    n_updates            | 2340       |
# |    policy_gradient_loss | 0.00116    |
# |    std                  | 1.33       |
# |    value_loss           | 2.88e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.6        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 40          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015893247 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 649         |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.00352     |
# |    std                  | 1.33        |
# |    value_loss           | 1.48e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.7       |
# |    ep_rew_mean          | -69.8      |
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 41         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.08492975 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.12      |
# |    explained_variance   | 0.529      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.88e+03   |
# |    n_updates            | 2360       |
# |    policy_gradient_loss | 0.0101     |
# |    std                  | 1.34       |
# |    value_loss           | 6.29e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.8        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 42          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.050352167 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.13       |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.203       |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.0261      |
# |    std                  | 1.35        |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 43          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.080260396 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.15       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+03     |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00878     |
# |    std                  | 1.35        |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.4       |
# |    ep_rew_mean          | -89.9      |
# | time/                   |            |
# |    fps                  | 704        |
# |    iterations           | 44         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.07577856 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.16      |
# |    explained_variance   | 0.725      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.01e+04   |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | 0.00664    |
# |    std                  | 1.36       |
# |    value_loss           | 5.96e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.4       |
# |    ep_rew_mean          | -59.9      |
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 45         |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.04106807 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.18      |
# |    explained_variance   | 0.699      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 70         |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | 0.00856    |
# |    std                  | 1.36       |
# |    value_loss           | 449        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.6        |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 46          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.041948978 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+04    |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | 0.0148      |
# |    std                  | 1.36        |
# |    value_loss           | 5.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.4        |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 47          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.030276421 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | -0.368      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.98        |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | 0.00486     |
# |    std                  | 1.36        |
# |    value_loss           | 6.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.3        |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 48          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.032844942 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | 0.00827     |
# |    std                  | 1.37        |
# |    value_loss           | 3.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.9        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 49          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.034392297 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.43e+03    |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | 0.0135      |
# |    std                  | 1.36        |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------
# --- 143.7825803756714 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-30.87 +/- 173.34

# %%
model.save("zeppelin-v2.1-500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000,log_interval=10000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 720.6783912181854 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-9.85 +/- 99.51

# %%
model.save("zeppelin-v2.1-1000000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 778.6057074069977 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-7.85 +/- 89.10

# %%
model.save("zeppelin-v2.1-1500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1425.0840311050415 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-29.87 +/- 170.61

# %%
model.save("zeppelin-v2.1-2500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1421.8236010074615 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.14 +/- 0.19

# %%
model.save("zeppelin-v2.1-3500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1469.084046125412 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.14 +/- 0.19

# %%
model.save("zeppelin-v2.1-4500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1413.9804809093475 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.13 +/- 0.17

# %%
model.save("zeppelin-v2.1-5500000")

# %%
torch.manual_seed(43)
env.seed(43)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.14 +/- 0.20

# %% [markdown]
# Above ran while tab was closed...

# %%
model = PPO.load("zeppelin-v2-5500000")
model.set_env(env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-v2-400000")
model.set_env(env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-6500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1500000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1500000")
model.set_env(env)

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1600000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1700000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1800000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=1000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=4000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
print("hi")
for i_episode in range(5):
    observation = env.reset()
    env.unwrapped.state=[-5,110,50,22]
    total_reward=0
    for t in range(1000):
        action, _states = model.predict(observation)
        #x1_norm = observation[0]/np.sqrt(observation[0]**2+observation[1]**2)
        #x2_norm = observation[1]/np.sqrt(observation[0]**2+observation[1]**2)
        #f = 1.0 if (x2_norm) < 0 else -1.0
        #action = [f, f*(0-x1_norm)]
        observation, reward, done, info = env.step(action)
        print(observation)
        total_reward=0.99*total_reward+reward
        env.render()
        time.sleep(0.5)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            time.sleep(5.0)
            break
env.close()

# %%
env.close()

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-100000-0.5")
model.set_env(env)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
#env.init_polytopes(0.0,retrain_polytopes_certain)
for i_episode in range(10):
    observation = env.reset()
    observation = env.unwrapped.state
    total_reward=0
    for t in range(1000):
        #print(observation)
        x1,x2,c,w,g1,g2 = observation
        #action = [0.,0.,1.0]
        action, _states = model.predict(observation,deterministic=True)
        #print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        observation, reward, done, info = env.step(action)
        #assert reward >= 0, f"reward: {reward}"
        total_reward=0.99*total_reward+reward
        #env.render()
        if done:
            print(observation)
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            break
env.close()
