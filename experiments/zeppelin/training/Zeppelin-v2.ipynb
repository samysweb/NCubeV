# %% [markdown]
# This time we will train with a modified reward scheme...

# %%
import gym
import time

# %%
import numpy as np

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import torch
from torch import nn

# %%
import zeppelin_gym.env4
# Out:
# `polytope` failed to import `cvxopt.glpk`.
# will use `scipy.optimize.linprog`

# %%
torch.manual_seed(42)

# %%
env = gym.make('zeppelin-v4')
# Out:
# /root/miniconda3/envs/snnt/lib/python3.9/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
env.seed(42)

# %%
env.unwrapped.FUEL_RESTRAINT = False
env.unwrapped.OBSTACLE_REWARD = -1000.
env.unwrapped.NO_FUEL_REWARD = 0.1
# done reward = (FUEL_RESTRAINT) ? r+fuel*r : 2*r
env.unwrapped.DONE_REWARD = 0.5
env.unwrapped.TIME_STEP_REWARD = 0.
env.unwrapped.INCLUDE_UNWINNABLE = False

# %%
architecture = [dict(pi=[8,8], vf=[8,8])]
model = PPO("MlpPolicy", env, verbose=1,policy_kwargs={"activation_fn":nn.ReLU,"net_arch":architecture})
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /root/miniconda3/envs/snnt/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-283.88 +/- 451.01

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    fps             | 1336     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 574       |
# |    ep_rew_mean          | -286      |
# | time/                   |           |
# |    fps                  | 954       |
# |    iterations           | 2         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 13.202547 |
# |    clip_fraction        | 0.776     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.27     |
# |    explained_variance   | 0.978     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 70.4      |
# |    n_updates            | 10        |
# |    policy_gradient_loss | 0.17      |
# |    std                  | 1.01      |
# |    value_loss           | 220       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 625       |
# |    ep_rew_mean          | -222      |
# | time/                   |           |
# |    fps                  | 865       |
# |    iterations           | 3         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 2.3827477 |
# |    clip_fraction        | 0.203     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.28     |
# |    explained_variance   | 0.937     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.5e+03   |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.0276   |
# |    std                  | 1.01      |
# |    value_loss           | 5.89e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 668         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010566327 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00444     |
# |    std                  | 1.01        |
# |    value_loss           | 266         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 687          |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0067527583 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000572    |
# |    std                  | 1            |
# |    value_loss           | 103          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012477739 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0151      |
# |    std                  | 1.01        |
# |    value_loss           | 150         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 621        |
# |    ep_rew_mean          | -227       |
# | time/                   |            |
# |    fps                  | 784        |
# |    iterations           | 7          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.06242048 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.28      |
# |    explained_variance   | 0.637      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 140        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.000734  |
# |    std                  | 1.01       |
# |    value_loss           | 3.93e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 642         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 8           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.026812607 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.0196      |
# |    std                  | 1           |
# |    value_loss           | 40.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 632         |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 765         |
# |    iterations           | 9           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.035391003 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0121      |
# |    std                  | 0.989       |
# |    value_loss           | 72.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016844312 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0714      |
# |    std                  | 0.99        |
# |    value_loss           | 70.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 662          |
# |    ep_rew_mean          | -147         |
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 11           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0054295277 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.7          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00337      |
# |    std                  | 0.976        |
# |    value_loss           | 30.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 669          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 12           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0034787566 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.61         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00912      |
# |    std                  | 0.98         |
# |    value_loss           | 38           |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 679      |
# |    ep_rew_mean          | -128     |
# | time/                   |          |
# |    fps                  | 756      |
# |    iterations           | 13       |
# |    time_elapsed         | 35       |
# |    total_timesteps      | 26624    |
# | train/                  |          |
# |    approx_kl            | 68.02896 |
# |    clip_fraction        | 0.804    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.2     |
# |    explained_variance   | 0.972    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 40.6     |
# |    n_updates            | 120      |
# |    policy_gradient_loss | 0.39     |
# |    std                  | 0.985    |
# |    value_loss           | 243      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 685       |
# |    ep_rew_mean          | -122      |
# | time/                   |           |
# |    fps                  | 755       |
# |    iterations           | 14        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 38.026123 |
# |    clip_fraction        | 0.577     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.22     |
# |    explained_variance   | 0.973     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 29.9      |
# |    n_updates            | 130       |
# |    policy_gradient_loss | 0.28      |
# |    std                  | 0.987     |
# |    value_loss           | 246       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 693       |
# |    ep_rew_mean          | -114      |
# | time/                   |           |
# |    fps                  | 755       |
# |    iterations           | 15        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 4.5298615 |
# |    clip_fraction        | 0.592     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.23     |
# |    explained_variance   | 0.97      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.32      |
# |    n_updates            | 140       |
# |    policy_gradient_loss | 0.148     |
# |    std                  | 0.994     |
# |    value_loss           | 12.9      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 698      |
# |    ep_rew_mean          | -109     |
# | time/                   |          |
# |    fps                  | 755      |
# |    iterations           | 16       |
# |    time_elapsed         | 43       |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 17.96636 |
# |    clip_fraction        | 0.425    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.24    |
# |    explained_variance   | 0.971    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 8.57     |
# |    n_updates            | 150      |
# |    policy_gradient_loss | 0.149    |
# |    std                  | 0.994    |
# |    value_loss           | 94.5     |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 704        |
# |    ep_rew_mean          | -102       |
# | time/                   |            |
# |    fps                  | 755        |
# |    iterations           | 17         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.13869032 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.28      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.29       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0325     |
# |    std                  | 1.02       |
# |    value_loss           | 16.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | -97.9       |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 18          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016863994 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0288      |
# |    std                  | 1.01        |
# |    value_loss           | 21.8        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 700      |
# |    ep_rew_mean          | -109     |
# | time/                   |          |
# |    fps                  | 751      |
# |    iterations           | 19       |
# |    time_elapsed         | 51       |
# |    total_timesteps      | 38912    |
# | train/                  |          |
# |    approx_kl            | 42.25679 |
# |    clip_fraction        | 0.448    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.31    |
# |    explained_variance   | 0.974    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 73.7     |
# |    n_updates            | 180      |
# |    policy_gradient_loss | 0.313    |
# |    std                  | 1.02     |
# |    value_loss           | 92.2     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 705       |
# |    ep_rew_mean          | -103      |
# | time/                   |           |
# |    fps                  | 751       |
# |    iterations           | 20        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.2256815 |
# |    clip_fraction        | 0.0373    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.32     |
# |    explained_variance   | 0.804     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.47      |
# |    n_updates            | 190       |
# |    policy_gradient_loss | 0.0464    |
# |    std                  | 1.02      |
# |    value_loss           | 1.38e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 708       |
# |    ep_rew_mean          | -99.9     |
# | time/                   |           |
# |    fps                  | 751       |
# |    iterations           | 21        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0422306 |
# |    clip_fraction        | 0.19      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.972     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.66      |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.0594    |
# |    std                  | 1.01      |
# |    value_loss           | 17.9      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 702        |
# |    ep_rew_mean          | -93.6      |
# | time/                   |            |
# |    fps                  | 751        |
# |    iterations           | 22         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.03588283 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.3       |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0293     |
# |    std                  | 1.01       |
# |    value_loss           | 6.36       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 684         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 23          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008272446 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00219     |
# |    std                  | 1           |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 680         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 24          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004167933 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.453       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00264    |
# |    std                  | 1           |
# |    value_loss           | 1.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 25          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014960005 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.0215      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.51e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.015       |
# |    std                  | 1.01        |
# |    value_loss           | 3.02e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 679       |
# |    ep_rew_mean          | -102      |
# | time/                   |           |
# |    fps                  | 748       |
# |    iterations           | 26        |
# |    time_elapsed         | 71        |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.6648008 |
# |    clip_fraction        | 0.0967    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.29     |
# |    explained_variance   | 0.942     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.09      |
# |    n_updates            | 250       |
# |    policy_gradient_loss | 0.0236    |
# |    std                  | 1.01      |
# |    value_loss           | 7.96      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 682       |
# |    ep_rew_mean          | -99.9     |
# | time/                   |           |
# |    fps                  | 747       |
# |    iterations           | 27        |
# |    time_elapsed         | 73        |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 1.9686823 |
# |    clip_fraction        | 0.429     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.874     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.18      |
# |    n_updates            | 260       |
# |    policy_gradient_loss | 0.0347    |
# |    std                  | 1.02      |
# |    value_loss           | 3.77      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 655         |
# |    ep_rew_mean          | -126        |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 28          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002168328 |
# |    clip_fraction        | 0.00986     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00946     |
# |    std                  | 1.02        |
# |    value_loss           | 5.59        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 659        |
# |    ep_rew_mean          | -123       |
# | time/                   |            |
# |    fps                  | 744        |
# |    iterations           | 29         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.14021796 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.31      |
# |    explained_variance   | 0.224      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.4       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0105     |
# |    std                  | 1.02       |
# |    value_loss           | 6.83e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 663        |
# |    ep_rew_mean          | -119       |
# | time/                   |            |
# |    fps                  | 741        |
# |    iterations           | 30         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.09740276 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.3       |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.99       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0619     |
# |    std                  | 1.02       |
# |    value_loss           | 7.42       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 661       |
# |    ep_rew_mean          | -125      |
# | time/                   |           |
# |    fps                  | 740       |
# |    iterations           | 31        |
# |    time_elapsed         | 85        |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 7.9433665 |
# |    clip_fraction        | 0.528     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.87      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.88      |
# |    n_updates            | 300       |
# |    policy_gradient_loss | 0.146     |
# |    std                  | 1.02      |
# |    value_loss           | 17.3      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 664       |
# |    ep_rew_mean          | -122      |
# | time/                   |           |
# |    fps                  | 740       |
# |    iterations           | 32        |
# |    time_elapsed         | 88        |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.7137892 |
# |    clip_fraction        | 0.335     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.366     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.62      |
# |    n_updates            | 310       |
# |    policy_gradient_loss | 0.0728    |
# |    std                  | 1.02      |
# |    value_loss           | 1.06e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 666      |
# |    ep_rew_mean          | -120     |
# | time/                   |          |
# |    fps                  | 740      |
# |    iterations           | 33       |
# |    time_elapsed         | 91       |
# |    total_timesteps      | 67584    |
# | train/                  |          |
# |    approx_kl            | 26.60838 |
# |    clip_fraction        | 0.363    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.32    |
# |    explained_variance   | 0.866    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 4.23     |
# |    n_updates            | 320      |
# |    policy_gradient_loss | 0.173    |
# |    std                  | 1.02     |
# |    value_loss           | 31.6     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 666       |
# |    ep_rew_mean          | -120      |
# | time/                   |           |
# |    fps                  | 741       |
# |    iterations           | 34        |
# |    time_elapsed         | 93        |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 115.03374 |
# |    clip_fraction        | 0.732     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.32     |
# |    explained_variance   | 0.971     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 15.1      |
# |    n_updates            | 330       |
# |    policy_gradient_loss | 0.322     |
# |    std                  | 1.02      |
# |    value_loss           | 278       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 675       |
# |    ep_rew_mean          | -110      |
# | time/                   |           |
# |    fps                  | 741       |
# |    iterations           | 35        |
# |    time_elapsed         | 96        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 18.825922 |
# |    clip_fraction        | 0.523     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.988     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.03      |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.186     |
# |    std                  | 1.02      |
# |    value_loss           | 12.4      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 675      |
# |    ep_rew_mean          | -110     |
# | time/                   |          |
# |    fps                  | 741      |
# |    iterations           | 36       |
# |    time_elapsed         | 99       |
# |    total_timesteps      | 73728    |
# | train/                  |          |
# |    approx_kl            | 32.08716 |
# |    clip_fraction        | 0.375    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.31    |
# |    explained_variance   | 0.898    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 4.49e+03 |
# |    n_updates            | 350      |
# |    policy_gradient_loss | 0.205    |
# |    std                  | 1.02     |
# |    value_loss           | 2.76e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 675         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 37          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004731569 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00155     |
# |    std                  | 1           |
# |    value_loss           | 11.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 675          |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 38           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0050759036 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00188      |
# |    std                  | 0.998        |
# |    value_loss           | 75.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 39          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.025612079 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.42        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0117      |
# |    std                  | 0.996       |
# |    value_loss           | 34.3        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 683       |
# |    ep_rew_mean          | -89.9     |
# | time/                   |           |
# |    fps                  | 742       |
# |    iterations           | 40        |
# |    time_elapsed         | 110       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 1.2430382 |
# |    clip_fraction        | 0.255     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.25     |
# |    explained_variance   | 0.938     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.63      |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.0144    |
# |    std                  | 0.996     |
# |    value_loss           | 5.4       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 683       |
# |    ep_rew_mean          | -89.9     |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 41        |
# |    time_elapsed         | 112       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 64.474106 |
# |    clip_fraction        | 0.609     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.24     |
# |    explained_variance   | 0.898     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 31.9      |
# |    n_updates            | 400       |
# |    policy_gradient_loss | 0.336     |
# |    std                  | 0.992     |
# |    value_loss           | 1.36e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 691      |
# |    ep_rew_mean          | -89.9    |
# | time/                   |          |
# |    fps                  | 744      |
# |    iterations           | 42       |
# |    time_elapsed         | 115      |
# |    total_timesteps      | 86016    |
# | train/                  |          |
# |    approx_kl            | 7.996455 |
# |    clip_fraction        | 0.741    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.24    |
# |    explained_variance   | 0.966    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 13.8     |
# |    n_updates            | 410      |
# |    policy_gradient_loss | 0.129    |
# |    std                  | 0.995    |
# |    value_loss           | 26.7     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 691       |
# |    ep_rew_mean          | -89.9     |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 43        |
# |    time_elapsed         | 118       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 14.076063 |
# |    clip_fraction        | 0.708     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.24     |
# |    explained_variance   | 0.957     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.272     |
# |    n_updates            | 420       |
# |    policy_gradient_loss | 0.0593    |
# |    std                  | 0.993     |
# |    value_loss           | 13.2      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 691         |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 44          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.020641735 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.5         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0954      |
# |    std                  | 0.98        |
# |    value_loss           | 5.06        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 683       |
# |    ep_rew_mean          | -99.9     |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 45        |
# |    time_elapsed         | 123       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.5839346 |
# |    clip_fraction        | 0.312     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.19     |
# |    explained_variance   | 0.701     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.31      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | 0.0487    |
# |    std                  | 0.981     |
# |    value_loss           | 14.1      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 46          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004518494 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.46        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0159      |
# |    std                  | 0.981       |
# |    value_loss           | 910         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 47          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.015822133 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0147      |
# |    std                  | 0.984       |
# |    value_loss           | 8.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 48          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018765628 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | -0.02       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.113       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0146      |
# |    std                  | 0.985       |
# |    value_loss           | 8.16        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 683      |
# |    ep_rew_mean          | -99.9    |
# | time/                   |          |
# |    fps                  | 744      |
# |    iterations           | 49       |
# |    time_elapsed         | 134      |
# |    total_timesteps      | 100352   |
# | train/                  |          |
# |    approx_kl            | 7.955453 |
# |    clip_fraction        | 0.171    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.21    |
# |    explained_variance   | 0.792    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.75     |
# |    n_updates            | 480      |
# |    policy_gradient_loss | -0.0192  |
# |    std                  | 0.984    |
# |    value_loss           | 4.48     |
# --------------------------------------
# --- 136.04336738586426 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-9.84 +/- 99.52

# %%
model.save("zeppelin-v2-100000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    fps             | 1345     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 668       |
# |    ep_rew_mean          | 0.25      |
# | time/                   |           |
# |    fps                  | 953       |
# |    iterations           | 2         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 32.216133 |
# |    clip_fraction        | 0.398     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.21     |
# |    explained_variance   | 0.906     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.15      |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -0.0333   |
# |    std                  | 0.988     |
# |    value_loss           | 11.7      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 701       |
# |    ep_rew_mean          | 0.213     |
# | time/                   |           |
# |    fps                  | 847       |
# |    iterations           | 3         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.3431582 |
# |    clip_fraction        | 0.0402    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.22     |
# |    explained_variance   | 0.832     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.943     |
# |    n_updates            | 510       |
# |    policy_gradient_loss | 0.0447    |
# |    std                  | 0.992     |
# |    value_loss           | 2.73      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 728       |
# |    ep_rew_mean          | 0.182     |
# | time/                   |           |
# |    fps                  | 806       |
# |    iterations           | 4         |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 13.408429 |
# |    clip_fraction        | 0.655     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.24     |
# |    explained_variance   | 0.859     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.86      |
# |    n_updates            | 520       |
# |    policy_gradient_loss | 0.0904    |
# |    std                  | 0.996     |
# |    value_loss           | 3.47      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 739        |
# |    ep_rew_mean          | 0.169      |
# | time/                   |            |
# |    fps                  | 784        |
# |    iterations           | 5          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02762148 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.24      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.67       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0137     |
# |    std                  | 0.996      |
# |    value_loss           | 3.54       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 750      |
# |    ep_rew_mean          | 0.156    |
# | time/                   |          |
# |    fps                  | 766      |
# |    iterations           | 6        |
# |    time_elapsed         | 16       |
# |    total_timesteps      | 12288    |
# | train/                  |          |
# |    approx_kl            | 1.800241 |
# |    clip_fraction        | 0.551    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.26    |
# |    explained_variance   | 0.956    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.684    |
# |    n_updates            | 540      |
# |    policy_gradient_loss | 0.289    |
# |    std                  | 1.01     |
# |    value_loss           | 4.33     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 756      |
# |    ep_rew_mean          | 0.15     |
# | time/                   |          |
# |    fps                  | 766      |
# |    iterations           | 7        |
# |    time_elapsed         | 18       |
# |    total_timesteps      | 14336    |
# | train/                  |          |
# |    approx_kl            | 81.74837 |
# |    clip_fraction        | 0.781    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.28    |
# |    explained_variance   | 0.96     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.774    |
# |    n_updates            | 550      |
# |    policy_gradient_loss | 0.0999   |
# |    std                  | 1.01     |
# |    value_loss           | 3.69     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 762      |
# |    ep_rew_mean          | 0.143    |
# | time/                   |          |
# |    fps                  | 763      |
# |    iterations           | 8        |
# |    time_elapsed         | 21       |
# |    total_timesteps      | 16384    |
# | train/                  |          |
# |    approx_kl            | 46.25118 |
# |    clip_fraction        | 0.444    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.26    |
# |    explained_variance   | 0.863    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.39     |
# |    n_updates            | 560      |
# |    policy_gradient_loss | 0.0503   |
# |    std                  | 1        |
# |    value_loss           | 3.14     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 767       |
# |    ep_rew_mean          | 0.138     |
# | time/                   |           |
# |    fps                  | 761       |
# |    iterations           | 9         |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 25.257982 |
# |    clip_fraction        | 0.55      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.27     |
# |    explained_variance   | 0.793     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.39      |
# |    n_updates            | 570       |
# |    policy_gradient_loss | 0.00433   |
# |    std                  | 1.01      |
# |    value_loss           | 3.63      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 769       |
# |    ep_rew_mean          | 0.135     |
# | time/                   |           |
# |    fps                  | 758       |
# |    iterations           | 10        |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 56.100906 |
# |    clip_fraction        | 0.621     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.26     |
# |    explained_variance   | 0.907     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.412     |
# |    n_updates            | 580       |
# |    policy_gradient_loss | -0.000914 |
# |    std                  | 1         |
# |    value_loss           | 2.58      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 773         |
# |    ep_rew_mean          | 0.131       |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.043659057 |
# |    clip_fraction        | 0.505       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0826      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.086       |
# |    std                  | 1           |
# |    value_loss           | 0.524       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 774       |
# |    ep_rew_mean          | 0.129     |
# | time/                   |           |
# |    fps                  | 759       |
# |    iterations           | 12        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 11.576807 |
# |    clip_fraction        | 0.94      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.26     |
# |    explained_variance   | 0.614     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.584     |
# |    n_updates            | 600       |
# |    policy_gradient_loss | 0.084     |
# |    std                  | 1         |
# |    value_loss           | 3.14      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 777         |
# |    ep_rew_mean          | 0.126       |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 13          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.087411605 |
# |    clip_fraction        | 0.522       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.44        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.057       |
# |    std                  | 1.01        |
# |    value_loss           | 0.811       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 778      |
# |    ep_rew_mean          | 0.125    |
# | time/                   |          |
# |    fps                  | 756      |
# |    iterations           | 14       |
# |    time_elapsed         | 37       |
# |    total_timesteps      | 28672    |
# | train/                  |          |
# |    approx_kl            | 47.0841  |
# |    clip_fraction        | 0.718    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.27    |
# |    explained_variance   | 0.625    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.282    |
# |    n_updates            | 620      |
# |    policy_gradient_loss | 0.139    |
# |    std                  | 1.01     |
# |    value_loss           | 2.18     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 780       |
# |    ep_rew_mean          | 0.123     |
# | time/                   |           |
# |    fps                  | 756       |
# |    iterations           | 15        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 5.3491707 |
# |    clip_fraction        | 0.778     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.28     |
# |    explained_variance   | 0.069     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.576     |
# |    n_updates            | 630       |
# |    policy_gradient_loss | 0.127     |
# |    std                  | 1.01      |
# |    value_loss           | 1.59      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 781       |
# |    ep_rew_mean          | 0.122     |
# | time/                   |           |
# |    fps                  | 751       |
# |    iterations           | 16        |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 38.108887 |
# |    clip_fraction        | 0.832     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.29     |
# |    explained_variance   | -0.135    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.818     |
# |    n_updates            | 640       |
# |    policy_gradient_loss | 0.0838    |
# |    std                  | 1.01      |
# |    value_loss           | 2.62      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 782         |
# |    ep_rew_mean          | 0.12        |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 17          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016616814 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0795      |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.039       |
# |    std                  | 1.02        |
# |    value_loss           | 0.3         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 783       |
# |    ep_rew_mean          | 0.119     |
# | time/                   |           |
# |    fps                  | 750       |
# |    iterations           | 18        |
# |    time_elapsed         | 49        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 13.367407 |
# |    clip_fraction        | 0.692     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.376     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.577     |
# |    n_updates            | 660       |
# |    policy_gradient_loss | 0.161     |
# |    std                  | 1.02      |
# |    value_loss           | 3.1       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 784       |
# |    ep_rew_mean          | 0.118     |
# | time/                   |           |
# |    fps                  | 752       |
# |    iterations           | 19        |
# |    time_elapsed         | 51        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 56.577835 |
# |    clip_fraction        | 0.93      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.31     |
# |    explained_variance   | 0.501     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.49      |
# |    n_updates            | 670       |
# |    policy_gradient_loss | 0.138     |
# |    std                  | 1.02      |
# |    value_loss           | 10.5      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 785       |
# |    ep_rew_mean          | 0.117     |
# | time/                   |           |
# |    fps                  | 752       |
# |    iterations           | 20        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 12.147775 |
# |    clip_fraction        | 0.932     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.32     |
# |    explained_variance   | 0.803     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.25      |
# |    n_updates            | 680       |
# |    policy_gradient_loss | 0.153     |
# |    std                  | 1.03      |
# |    value_loss           | 1.85      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 785      |
# |    ep_rew_mean          | 0.117    |
# | time/                   |          |
# |    fps                  | 751      |
# |    iterations           | 21       |
# |    time_elapsed         | 57       |
# |    total_timesteps      | 43008    |
# | train/                  |          |
# |    approx_kl            | 5.705905 |
# |    clip_fraction        | 0.884    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.33    |
# |    explained_variance   | 0.673    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.928    |
# |    n_updates            | 690      |
# |    policy_gradient_loss | 0.132    |
# |    std                  | 1.03     |
# |    value_loss           | 2.8      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 786       |
# |    ep_rew_mean          | 0.116     |
# | time/                   |           |
# |    fps                  | 750       |
# |    iterations           | 22        |
# |    time_elapsed         | 60        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 34.827106 |
# |    clip_fraction        | 0.775     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.33     |
# |    explained_variance   | 0.884     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.105     |
# |    n_updates            | 700       |
# |    policy_gradient_loss | 0.0757    |
# |    std                  | 1.02      |
# |    value_loss           | 0.642     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 787      |
# |    ep_rew_mean          | 0.115    |
# | time/                   |          |
# |    fps                  | 748      |
# |    iterations           | 23       |
# |    time_elapsed         | 62       |
# |    total_timesteps      | 47104    |
# | train/                  |          |
# |    approx_kl            | 2.411305 |
# |    clip_fraction        | 0.503    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.32    |
# |    explained_variance   | 0.926    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.283    |
# |    n_updates            | 710      |
# |    policy_gradient_loss | 0.0994   |
# |    std                  | 1.02     |
# |    value_loss           | 1.43     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 764       |
# |    ep_rew_mean          | 0.142     |
# | time/                   |           |
# |    fps                  | 749       |
# |    iterations           | 24        |
# |    time_elapsed         | 65        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 18.930832 |
# |    clip_fraction        | 0.667     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.32     |
# |    explained_variance   | 0.783     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.816     |
# |    n_updates            | 720       |
# |    policy_gradient_loss | 0.091     |
# |    std                  | 1.02      |
# |    value_loss           | 2.3       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 765       |
# |    ep_rew_mean          | 0.141     |
# | time/                   |           |
# |    fps                  | 748       |
# |    iterations           | 25        |
# |    time_elapsed         | 68        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 237.53743 |
# |    clip_fraction        | 0.818     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.33     |
# |    explained_variance   | 0.958     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.48      |
# |    n_updates            | 730       |
# |    policy_gradient_loss | 0.12      |
# |    std                  | 1.03      |
# |    value_loss           | 2.77      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 767      |
# |    ep_rew_mean          | 0.139    |
# | time/                   |          |
# |    fps                  | 747      |
# |    iterations           | 26       |
# |    time_elapsed         | 71       |
# |    total_timesteps      | 53248    |
# | train/                  |          |
# |    approx_kl            | 93.27114 |
# |    clip_fraction        | 0.845    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.33    |
# |    explained_variance   | 0.406    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.353    |
# |    n_updates            | 740      |
# |    policy_gradient_loss | 0.119    |
# |    std                  | 1.02     |
# |    value_loss           | 1.26     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 768      |
# |    ep_rew_mean          | 0.138    |
# | time/                   |          |
# |    fps                  | 745      |
# |    iterations           | 27       |
# |    time_elapsed         | 74       |
# |    total_timesteps      | 55296    |
# | train/                  |          |
# |    approx_kl            | 68.97566 |
# |    clip_fraction        | 0.731    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.33    |
# |    explained_variance   | 0.269    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.194    |
# |    n_updates            | 750      |
# |    policy_gradient_loss | 0.124    |
# |    std                  | 1.03     |
# |    value_loss           | 1.13     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 759         |
# |    ep_rew_mean          | 0.148       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 28          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.023439102 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | -1.86       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.373       |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.0279      |
# |    std                  | 1.03        |
# |    value_loss           | 0.978       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 761       |
# |    ep_rew_mean          | 0.146     |
# | time/                   |           |
# |    fps                  | 741       |
# |    iterations           | 29        |
# |    time_elapsed         | 80        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 21.070559 |
# |    clip_fraction        | 0.808     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.35     |
# |    explained_variance   | 0.829     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.408     |
# |    n_updates            | 770       |
# |    policy_gradient_loss | 0.148     |
# |    std                  | 1.04      |
# |    value_loss           | 1.05      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 753        |
# |    ep_rew_mean          | 0.156      |
# | time/                   |            |
# |    fps                  | 741        |
# |    iterations           | 30         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02388485 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.35      |
# |    explained_variance   | 0.768      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.173      |
# |    n_updates            | 780        |
# |    policy_gradient_loss | 0.00764    |
# |    std                  | 1.03       |
# |    value_loss           | 0.593      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 754       |
# |    ep_rew_mean          | 0.154     |
# | time/                   |           |
# |    fps                  | 741       |
# |    iterations           | 31        |
# |    time_elapsed         | 85        |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 56.692528 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.35     |
# |    explained_variance   | 0.958     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.655     |
# |    n_updates            | 790       |
# |    policy_gradient_loss | 0.0164    |
# |    std                  | 1.03      |
# |    value_loss           | 1.4       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 755        |
# |    ep_rew_mean          | 0.152      |
# | time/                   |            |
# |    fps                  | 741        |
# |    iterations           | 32         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.30735523 |
# |    clip_fraction        | 0.376      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.35      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.503      |
# |    n_updates            | 800        |
# |    policy_gradient_loss | 0.137      |
# |    std                  | 1.03       |
# |    value_loss           | 0.67       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 757       |
# |    ep_rew_mean          | 0.151     |
# | time/                   |           |
# |    fps                  | 740       |
# |    iterations           | 33        |
# |    time_elapsed         | 91        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 22.829222 |
# |    clip_fraction        | 0.815     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.36     |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00134  |
# |    n_updates            | 810       |
# |    policy_gradient_loss | 0.038     |
# |    std                  | 1.03      |
# |    value_loss           | 0.248     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 758      |
# |    ep_rew_mean          | 0.149    |
# | time/                   |          |
# |    fps                  | 739      |
# |    iterations           | 34       |
# |    time_elapsed         | 94       |
# |    total_timesteps      | 69632    |
# | train/                  |          |
# |    approx_kl            | 25.14373 |
# |    clip_fraction        | 0.94     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.34    |
# |    explained_variance   | 0.839    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.255    |
# |    n_updates            | 820      |
# |    policy_gradient_loss | 0.204    |
# |    std                  | 1.03     |
# |    value_loss           | 0.838    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 759        |
# |    ep_rew_mean          | 0.148      |
# | time/                   |            |
# |    fps                  | 739        |
# |    iterations           | 35         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.04278738 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.34      |
# |    explained_variance   | 0.149      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.33       |
# |    n_updates            | 830        |
# |    policy_gradient_loss | 0.00132    |
# |    std                  | 1.03       |
# |    value_loss           | 1.85       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 746         |
# |    ep_rew_mean          | 0.164       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 36          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.060828604 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.153       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.053       |
# |    std                  | 1.03        |
# |    value_loss           | 0.388       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 739         |
# |    ep_rew_mean          | 0.172       |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 37          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.049159918 |
# |    clip_fraction        | 0.474       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.28        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.0341      |
# |    std                  | 1.03        |
# |    value_loss           | 0.494       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 747       |
# |    ep_rew_mean          | 0.163     |
# | time/                   |           |
# |    fps                  | 738       |
# |    iterations           | 38        |
# |    time_elapsed         | 105       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 101.40561 |
# |    clip_fraction        | 0.654     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.35     |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.183     |
# |    n_updates            | 860       |
# |    policy_gradient_loss | 0.0268    |
# |    std                  | 1.03      |
# |    value_loss           | 0.42      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 747       |
# |    ep_rew_mean          | 0.163     |
# | time/                   |           |
# |    fps                  | 738       |
# |    iterations           | 39        |
# |    time_elapsed         | 108       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 163.30914 |
# |    clip_fraction        | 0.861     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.35     |
# |    explained_variance   | 0.87      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.376     |
# |    n_updates            | 870       |
# |    policy_gradient_loss | 0.219     |
# |    std                  | 1.03      |
# |    value_loss           | 1.37      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 747        |
# |    ep_rew_mean          | 0.163      |
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 40         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03491765 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.38      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.23       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | 0.0469     |
# |    std                  | 1.04       |
# |    value_loss           | 0.608      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 747      |
# |    ep_rew_mean          | 0.163    |
# | time/                   |          |
# |    fps                  | 738      |
# |    iterations           | 41       |
# |    time_elapsed         | 113      |
# |    total_timesteps      | 83968    |
# | train/                  |          |
# |    approx_kl            | 31.3609  |
# |    clip_fraction        | 0.61     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.39    |
# |    explained_variance   | 0.937    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.332    |
# |    n_updates            | 890      |
# |    policy_gradient_loss | 0.21     |
# |    std                  | 1.05     |
# |    value_loss           | 0.507    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 747       |
# |    ep_rew_mean          | 0.163     |
# | time/                   |           |
# |    fps                  | 738       |
# |    iterations           | 42        |
# |    time_elapsed         | 116       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 51.718597 |
# |    clip_fraction        | 0.702     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.42     |
# |    explained_variance   | 0.788     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.907     |
# |    n_updates            | 900       |
# |    policy_gradient_loss | 0.129     |
# |    std                  | 1.06      |
# |    value_loss           | 0.822     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 747        |
# |    ep_rew_mean          | 0.163      |
# | time/                   |            |
# |    fps                  | 739        |
# |    iterations           | 43         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.03245495 |
# |    clip_fraction        | 0.303      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.197      |
# |    n_updates            | 910        |
# |    policy_gradient_loss | 0.0191     |
# |    std                  | 1.06       |
# |    value_loss           | 0.729      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 747        |
# |    ep_rew_mean          | 0.163      |
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 44         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 15.8585005 |
# |    clip_fraction        | 0.683      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.46      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.109      |
# |    n_updates            | 920        |
# |    policy_gradient_loss | 0.238      |
# |    std                  | 1.09       |
# |    value_loss           | 0.151      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 747         |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 45          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.016682755 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0665      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 1.09        |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 724         |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 46          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.033728164 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | 0.0518      |
# |    std                  | 1.1         |
# |    value_loss           | 0.236       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 724        |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 47         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.04866698 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.55      |
# |    explained_variance   | -0.00945   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.7e+03    |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.00238   |
# |    std                  | 1.1        |
# |    value_loss           | 6.36e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 716        |
# |    ep_rew_mean          | -29.8      |
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 48         |
# |    time_elapsed         | 133        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.12413701 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.52      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.292      |
# |    n_updates            | 960        |
# |    policy_gradient_loss | 0.0197     |
# |    std                  | 1.08       |
# |    value_loss           | 1.42       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 716        |
# |    ep_rew_mean          | -29.8      |
# | time/                   |            |
# |    fps                  | 737        |
# |    iterations           | 49         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.19359656 |
# |    clip_fraction        | 0.478      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.48      |
# |    explained_variance   | 0.213      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.67       |
# |    n_updates            | 970        |
# |    policy_gradient_loss | 0.0275     |
# |    std                  | 1.08       |
# |    value_loss           | 2.9e+03    |
# ----------------------------------------
# --- 137.33978652954102 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-61.86 +/- 241.19

# %%
model.save("zeppelin-v2-200000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    fps             | 1374     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 673       |
# |    ep_rew_mean          | -167      |
# | time/                   |           |
# |    fps                  | 957       |
# |    iterations           | 2         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 21.651817 |
# |    clip_fraction        | 0.765     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.49     |
# |    explained_variance   | 0.221     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.15      |
# |    n_updates            | 990       |
# |    policy_gradient_loss | 0.0369    |
# |    std                  | 1.08      |
# |    value_loss           | 56.2      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 627      |
# |    ep_rew_mean          | -222     |
# | time/                   |          |
# |    fps                  | 862      |
# |    iterations           | 3        |
# |    time_elapsed         | 7        |
# |    total_timesteps      | 6144     |
# | train/                  |          |
# |    approx_kl            | 50.40146 |
# |    clip_fraction        | 0.63     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.49    |
# |    explained_variance   | 0.469    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 4.43     |
# |    n_updates            | 1000     |
# |    policy_gradient_loss | 0.0702   |
# |    std                  | 1.08     |
# |    value_loss           | 1.91e+03 |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 670      |
# |    ep_rew_mean          | -167     |
# | time/                   |          |
# |    fps                  | 812      |
# |    iterations           | 4        |
# |    time_elapsed         | 10       |
# |    total_timesteps      | 8192     |
# | train/                  |          |
# |    approx_kl            | 47.41777 |
# |    clip_fraction        | 0.8      |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.51    |
# |    explained_variance   | 0.201    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.728    |
# |    n_updates            | 1010     |
# |    policy_gradient_loss | 0.182    |
# |    std                  | 1.09     |
# |    value_loss           | 1.63e+03 |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 689       |
# |    ep_rew_mean          | -143      |
# | time/                   |           |
# |    fps                  | 788       |
# |    iterations           | 5         |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 12.813275 |
# |    clip_fraction        | 0.863     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.52     |
# |    explained_variance   | 0.099     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 11        |
# |    n_updates            | 1020      |
# |    policy_gradient_loss | 0.0556    |
# |    std                  | 1.09      |
# |    value_loss           | 107       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 672      |
# |    ep_rew_mean          | -167     |
# | time/                   |          |
# |    fps                  | 769      |
# |    iterations           | 6        |
# |    time_elapsed         | 15       |
# |    total_timesteps      | 12288    |
# | train/                  |          |
# |    approx_kl            | 61.81743 |
# |    clip_fraction        | 0.629    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.52    |
# |    explained_variance   | 0.976    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 4.06     |
# |    n_updates            | 1030     |
# |    policy_gradient_loss | 0.252    |
# |    std                  | 1.09     |
# |    value_loss           | 50.8     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 684       |
# |    ep_rew_mean          | -150      |
# | time/                   |           |
# |    fps                  | 757       |
# |    iterations           | 7         |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 38.445156 |
# |    clip_fraction        | 0.777     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.52     |
# |    explained_variance   | 0.83      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 88.6      |
# |    n_updates            | 1040      |
# |    policy_gradient_loss | 0.104     |
# |    std                  | 1.09      |
# |    value_loss           | 3.26e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 699      |
# |    ep_rew_mean          | -130     |
# | time/                   |          |
# |    fps                  | 752      |
# |    iterations           | 8        |
# |    time_elapsed         | 21       |
# |    total_timesteps      | 16384    |
# | train/                  |          |
# |    approx_kl            | 8.638369 |
# |    clip_fraction        | 0.883    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.54    |
# |    explained_variance   | 0.962    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.719    |
# |    n_updates            | 1050     |
# |    policy_gradient_loss | 0.215    |
# |    std                  | 1.11     |
# |    value_loss           | 2.43     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 708       |
# |    ep_rew_mean          | -120      |
# | time/                   |           |
# |    fps                  | 748       |
# |    iterations           | 9         |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 53.552128 |
# |    clip_fraction        | 0.807     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.56     |
# |    explained_variance   | 0.97      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.13      |
# |    n_updates            | 1060      |
# |    policy_gradient_loss | 0.228     |
# |    std                  | 1.11      |
# |    value_loss           | 45.8      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -107      |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 10        |
# |    time_elapsed         | 27        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 19.218334 |
# |    clip_fraction        | 0.794     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.31      |
# |    n_updates            | 1070      |
# |    policy_gradient_loss | 0.0628    |
# |    std                  | 1.11      |
# |    value_loss           | 4         |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 725       |
# |    ep_rew_mean          | -96.7     |
# | time/                   |           |
# |    fps                  | 742       |
# |    iterations           | 11        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 18.342651 |
# |    clip_fraction        | 0.562     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.784     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.6       |
# |    n_updates            | 1080      |
# |    policy_gradient_loss | 0.00581   |
# |    std                  | 1.11      |
# |    value_loss           | 21.4      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 730      |
# |    ep_rew_mean          | -90.8    |
# | time/                   |          |
# |    fps                  | 741      |
# |    iterations           | 12       |
# |    time_elapsed         | 33       |
# |    total_timesteps      | 24576    |
# | train/                  |          |
# |    approx_kl            | 96.91762 |
# |    clip_fraction        | 0.688    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.58    |
# |    explained_variance   | 0.976    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.43     |
# |    n_updates            | 1090     |
# |    policy_gradient_loss | -0.0353  |
# |    std                  | 1.11     |
# |    value_loss           | 4.19     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -81       |
# | time/                   |           |
# |    fps                  | 740       |
# |    iterations           | 13        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 14.782772 |
# |    clip_fraction        | 0.816     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.567     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.8       |
# |    n_updates            | 1100      |
# |    policy_gradient_loss | 0.0348    |
# |    std                  | 1.11      |
# |    value_loss           | 4.17      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 705       |
# |    ep_rew_mean          | -74.9     |
# | time/                   |           |
# |    fps                  | 741       |
# |    iterations           | 14        |
# |    time_elapsed         | 38        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 131.24548 |
# |    clip_fraction        | 0.734     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.56     |
# |    explained_variance   | 0.896     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.11      |
# |    n_updates            | 1110      |
# |    policy_gradient_loss | 0.0762    |
# |    std                  | 1.11      |
# |    value_loss           | 2.71      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 711      |
# |    ep_rew_mean          | -69.6    |
# | time/                   |          |
# |    fps                  | 740      |
# |    iterations           | 15       |
# |    time_elapsed         | 41       |
# |    total_timesteps      | 30720    |
# | train/                  |          |
# |    approx_kl            | 65.54477 |
# |    clip_fraction        | 0.929    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.58    |
# |    explained_variance   | 0.974    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.6      |
# |    n_updates            | 1120     |
# |    policy_gradient_loss | 0.4      |
# |    std                  | 1.12     |
# |    value_loss           | 15.8     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 700      |
# |    ep_rew_mean          | -86.8    |
# | time/                   |          |
# |    fps                  | 740      |
# |    iterations           | 16       |
# |    time_elapsed         | 44       |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 99.56865 |
# |    clip_fraction        | 0.912    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.58    |
# |    explained_variance   | -1.46    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 9.81     |
# |    n_updates            | 1130     |
# |    policy_gradient_loss | 0.0326   |
# |    std                  | 1.11     |
# |    value_loss           | 32.3     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 706       |
# |    ep_rew_mean          | -81.5     |
# | time/                   |           |
# |    fps                  | 738       |
# |    iterations           | 17        |
# |    time_elapsed         | 47        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 72.536896 |
# |    clip_fraction        | 0.638     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.452     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 345       |
# |    n_updates            | 1140      |
# |    policy_gradient_loss | 0.0137    |
# |    std                  | 1.11      |
# |    value_loss           | 2.09e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 710       |
# |    ep_rew_mean          | -78.3     |
# | time/                   |           |
# |    fps                  | 739       |
# |    iterations           | 18        |
# |    time_elapsed         | 49        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 49.378754 |
# |    clip_fraction        | 0.914     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.946     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.49      |
# |    n_updates            | 1150      |
# |    policy_gradient_loss | 0.124     |
# |    std                  | 1.11      |
# |    value_loss           | 4.2       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 702       |
# |    ep_rew_mean          | -90.8     |
# | time/                   |           |
# |    fps                  | 738       |
# |    iterations           | 19        |
# |    time_elapsed         | 52        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 156.48586 |
# |    clip_fraction        | 0.943     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.59     |
# |    explained_variance   | 0.686     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.422     |
# |    n_updates            | 1160      |
# |    policy_gradient_loss | 0.208     |
# |    std                  | 1.12      |
# |    value_loss           | 0.685     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 705       |
# |    ep_rew_mean          | -87.6     |
# | time/                   |           |
# |    fps                  | 740       |
# |    iterations           | 20        |
# |    time_elapsed         | 55        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 17.460917 |
# |    clip_fraction        | 0.861     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.59     |
# |    explained_variance   | 0.0828    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 60.7      |
# |    n_updates            | 1170      |
# |    policy_gradient_loss | 0.0965    |
# |    std                  | 1.12      |
# |    value_loss           | 2.55e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 710       |
# |    ep_rew_mean          | -83.2     |
# | time/                   |           |
# |    fps                  | 740       |
# |    iterations           | 21        |
# |    time_elapsed         | 58        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 99.555664 |
# |    clip_fraction        | 0.959     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.59     |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.573     |
# |    n_updates            | 1180      |
# |    policy_gradient_loss | 0.299     |
# |    std                  | 1.12      |
# |    value_loss           | 3.01      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 714         |
# |    ep_rew_mean          | -79.2       |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 22          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.037417855 |
# |    clip_fraction        | 0.47        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.947       |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | 0.0901      |
# |    std                  | 1.13        |
# |    value_loss           | 3.63        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -76.8     |
# | time/                   |           |
# |    fps                  | 737       |
# |    iterations           | 23        |
# |    time_elapsed         | 63        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 34.321884 |
# |    clip_fraction        | 0.538     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.62     |
# |    explained_variance   | 0.814     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1         |
# |    n_updates            | 1200      |
# |    policy_gradient_loss | 0.131     |
# |    std                  | 1.13      |
# |    value_loss           | 14.6      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 721      |
# |    ep_rew_mean          | -73.4    |
# | time/                   |          |
# |    fps                  | 737      |
# |    iterations           | 24       |
# |    time_elapsed         | 66       |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 11.02717 |
# |    clip_fraction        | 0.431    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.62    |
# |    explained_variance   | 0.61     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.72     |
# |    n_updates            | 1210     |
# |    policy_gradient_loss | 0.0215   |
# |    std                  | 1.13     |
# |    value_loss           | 30.9     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 723         |
# |    ep_rew_mean          | -71.3       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 25          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.022298746 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | 0.0283      |
# |    std                  | 1.13        |
# |    value_loss           | 3.5         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 726      |
# |    ep_rew_mean          | -68.4    |
# | time/                   |          |
# |    fps                  | 735      |
# |    iterations           | 26       |
# |    time_elapsed         | 72       |
# |    total_timesteps      | 53248    |
# | train/                  |          |
# |    approx_kl            | 76.33036 |
# |    clip_fraction        | 0.501    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.62    |
# |    explained_variance   | -1.09    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.8      |
# |    n_updates            | 1230     |
# |    policy_gradient_loss | 0.0227   |
# |    std                  | 1.13     |
# |    value_loss           | 15.4     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 728      |
# |    ep_rew_mean          | -66.5    |
# | time/                   |          |
# |    fps                  | 735      |
# |    iterations           | 27       |
# |    time_elapsed         | 75       |
# |    total_timesteps      | 55296    |
# | train/                  |          |
# |    approx_kl            | 3.158834 |
# |    clip_fraction        | 0.452    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.62    |
# |    explained_variance   | 0.948    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.64     |
# |    n_updates            | 1240     |
# |    policy_gradient_loss | 0.00716  |
# |    std                  | 1.13     |
# |    value_loss           | 9.47     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 723       |
# |    ep_rew_mean          | -63.2     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 28        |
# |    time_elapsed         | 78        |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 31.918781 |
# |    clip_fraction        | 0.529     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.61     |
# |    explained_variance   | 0.971     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.53      |
# |    n_updates            | 1250      |
# |    policy_gradient_loss | -0.0412   |
# |    std                  | 1.12      |
# |    value_loss           | 6.31      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 725      |
# |    ep_rew_mean          | -61.6    |
# | time/                   |          |
# |    fps                  | 733      |
# |    iterations           | 29       |
# |    time_elapsed         | 80       |
# |    total_timesteps      | 59392    |
# | train/                  |          |
# |    approx_kl            | 4.248294 |
# |    clip_fraction        | 0.4      |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.6     |
# |    explained_variance   | 0.951    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 9.79     |
# |    n_updates            | 1260     |
# |    policy_gradient_loss | -0.0203  |
# |    std                  | 1.12     |
# |    value_loss           | 7.78     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 727       |
# |    ep_rew_mean          | -59.4     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 30        |
# |    time_elapsed         | 83        |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 39.401688 |
# |    clip_fraction        | 0.327     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.62     |
# |    explained_variance   | 0.875     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.124     |
# |    n_updates            | 1270      |
# |    policy_gradient_loss | -0.0112   |
# |    std                  | 1.14      |
# |    value_loss           | 0.532     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 729       |
# |    ep_rew_mean          | -58       |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 31        |
# |    time_elapsed         | 86        |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 100.51567 |
# |    clip_fraction        | 0.818     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.63     |
# |    explained_variance   | 0.933     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0666    |
# |    n_updates            | 1280      |
# |    policy_gradient_loss | 0.125     |
# |    std                  | 1.13      |
# |    value_loss           | 0.632     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | -54.8       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 32          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.033751614 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.472       |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | 0.0336      |
# |    std                  | 1.13        |
# |    value_loss           | 6.08        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 712       |
# |    ep_rew_mean          | -63.7     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 33        |
# |    time_elapsed         | 91        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 17.573288 |
# |    clip_fraction        | 0.474     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.62     |
# |    explained_variance   | 0.79      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.205     |
# |    n_updates            | 1300      |
# |    policy_gradient_loss | -0.0203   |
# |    std                  | 1.13      |
# |    value_loss           | 0.896     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 715       |
# |    ep_rew_mean          | -61.7     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 34        |
# |    time_elapsed         | 94        |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 19.593693 |
# |    clip_fraction        | 0.376     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.63     |
# |    explained_variance   | 0.0177    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.86      |
# |    n_updates            | 1310      |
# |    policy_gradient_loss | -0.00257  |
# |    std                  | 1.14      |
# |    value_loss           | 3.1e+03   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 717      |
# |    ep_rew_mean          | -60.5    |
# | time/                   |          |
# |    fps                  | 736      |
# |    iterations           | 35       |
# |    time_elapsed         | 97       |
# |    total_timesteps      | 71680    |
# | train/                  |          |
# |    approx_kl            | 46.39254 |
# |    clip_fraction        | 0.764    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.63    |
# |    explained_variance   | 0.97     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.45     |
# |    n_updates            | 1320     |
# |    policy_gradient_loss | 0.0457   |
# |    std                  | 1.14     |
# |    value_loss           | 3.9      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 718      |
# |    ep_rew_mean          | -59.9    |
# | time/                   |          |
# |    fps                  | 736      |
# |    iterations           | 36       |
# |    time_elapsed         | 100      |
# |    total_timesteps      | 73728    |
# | train/                  |          |
# |    approx_kl            | 32.95542 |
# |    clip_fraction        | 0.412    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.63    |
# |    explained_variance   | 0.913    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.393    |
# |    n_updates            | 1330     |
# |    policy_gradient_loss | 0.00851  |
# |    std                  | 1.13     |
# |    value_loss           | 2.88     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 717         |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 37          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.027506957 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.83        |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | 0.0243      |
# |    std                  | 1.13        |
# |    value_loss           | 3.08        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -49.9     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 38        |
# |    time_elapsed         | 105       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.6212374 |
# |    clip_fraction        | 0.628     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.64     |
# |    explained_variance   | 0.113     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.3e+03   |
# |    n_updates            | 1350      |
# |    policy_gradient_loss | 0.332     |
# |    std                  | 1.14      |
# |    value_loss           | 1.54e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -49.9     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 39        |
# |    time_elapsed         | 108       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 2.6223032 |
# |    clip_fraction        | 0.296     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.66     |
# |    explained_variance   | 0.948     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.957     |
# |    n_updates            | 1360      |
# |    policy_gradient_loss | -0.0296   |
# |    std                  | 1.14      |
# |    value_loss           | 2.52      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -49.9     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 40        |
# |    time_elapsed         | 111       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 24.314995 |
# |    clip_fraction        | 0.593     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.65     |
# |    explained_variance   | 0.943     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.42      |
# |    n_updates            | 1370      |
# |    policy_gradient_loss | -0.00967  |
# |    std                  | 1.14      |
# |    value_loss           | 3.85      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 725        |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 732        |
# |    iterations           | 41         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.14238876 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.63      |
# |    explained_variance   | 0.278      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.455      |
# |    n_updates            | 1380       |
# |    policy_gradient_loss | -0.00138   |
# |    std                  | 1.13       |
# |    value_loss           | 2.19       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 725       |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 732       |
# |    iterations           | 42        |
# |    time_elapsed         | 117       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 23.406118 |
# |    clip_fraction        | 0.475     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.62     |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.731     |
# |    n_updates            | 1390      |
# |    policy_gradient_loss | -0.0434   |
# |    std                  | 1.13      |
# |    value_loss           | 1.27      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -39.8     |
# | time/                   |           |
# |    fps                  | 732       |
# |    iterations           | 43        |
# |    time_elapsed         | 120       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.1107944 |
# |    clip_fraction        | 0.405     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.61     |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.354     |
# |    n_updates            | 1400      |
# |    policy_gradient_loss | 0.157     |
# |    std                  | 1.13      |
# |    value_loss           | 1.41      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 717         |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 44          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002334918 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.4         |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | 6.49e-06    |
# |    std                  | 1.13        |
# |    value_loss           | 8.94        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 717          |
# |    ep_rew_mean          | -39.8        |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 45           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0009188203 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.61        |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.181        |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00357     |
# |    std                  | 1.12         |
# |    value_loss           | 0.62         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 717       |
# |    ep_rew_mean          | -39.8     |
# | time/                   |           |
# |    fps                  | 730       |
# |    iterations           | 46        |
# |    time_elapsed         | 129       |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 23.950352 |
# |    clip_fraction        | 0.442     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.6      |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.529     |
# |    n_updates            | 1430      |
# |    policy_gradient_loss | -0.0135   |
# |    std                  | 1.13      |
# |    value_loss           | 1.97      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 717          |
# |    ep_rew_mean          | -39.8        |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 47           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0008330939 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.39         |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.000668    |
# |    std                  | 1.12         |
# |    value_loss           | 0.743        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 717      |
# |    ep_rew_mean          | -39.8    |
# | time/                   |          |
# |    fps                  | 729      |
# |    iterations           | 48       |
# |    time_elapsed         | 134      |
# |    total_timesteps      | 98304    |
# | train/                  |          |
# |    approx_kl            | 27.24731 |
# |    clip_fraction        | 0.505    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.61    |
# |    explained_variance   | 0.957    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.223    |
# |    n_updates            | 1450     |
# |    policy_gradient_loss | -0.00997 |
# |    std                  | 1.13     |
# |    value_loss           | 0.904    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 724        |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 728        |
# |    iterations           | 49         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.21877068 |
# |    clip_fraction        | 0.0712     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.63      |
# |    explained_variance   | 0.495      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.905      |
# |    n_updates            | 1460       |
# |    policy_gradient_loss | -0.00559   |
# |    std                  | 1.13       |
# |    value_loss           | 2.53       |
# ----------------------------------------
# --- 139.53898882865906 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-39.85 +/- 195.99

# %%
model.save("zeppelin-v2-300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    fps             | 1318     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 800       |
# |    ep_rew_mean          | 0.1       |
# | time/                   |           |
# |    fps                  | 953       |
# |    iterations           | 2         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 11.290543 |
# |    clip_fraction        | 0.51      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.61     |
# |    explained_variance   | -0.112    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.204     |
# |    n_updates            | 1480      |
# |    policy_gradient_loss | 0.0234    |
# |    std                  | 1.13      |
# |    value_loss           | 1.49      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 800      |
# |    ep_rew_mean          | 0.1      |
# | time/                   |          |
# |    fps                  | 878      |
# |    iterations           | 3        |
# |    time_elapsed         | 6        |
# |    total_timesteps      | 6144     |
# | train/                  |          |
# |    approx_kl            | 20.8405  |
# |    clip_fraction        | 0.413    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.6     |
# |    explained_variance   | 0.679    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.599    |
# |    n_updates            | 1490     |
# |    policy_gradient_loss | 0.0622   |
# |    std                  | 1.12     |
# |    value_loss           | 1.32     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 800       |
# |    ep_rew_mean          | 0.1       |
# | time/                   |           |
# |    fps                  | 839       |
# |    iterations           | 4         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 54.034794 |
# |    clip_fraction        | 0.441     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.59     |
# |    explained_variance   | 0.969     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.437     |
# |    n_updates            | 1500      |
# |    policy_gradient_loss | 0.0309    |
# |    std                  | 1.12      |
# |    value_loss           | 1.36      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 800      |
# |    ep_rew_mean          | 0.1      |
# | time/                   |          |
# |    fps                  | 821      |
# |    iterations           | 5        |
# |    time_elapsed         | 12       |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 7.003463 |
# |    clip_fraction        | 0.435    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.59    |
# |    explained_variance   | 0.818    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.801    |
# |    n_updates            | 1510     |
# |    policy_gradient_loss | 0.0307   |
# |    std                  | 1.12     |
# |    value_loss           | 1.92     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 800       |
# |    ep_rew_mean          | 0.1       |
# | time/                   |           |
# |    fps                  | 804       |
# |    iterations           | 6         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 3.3437152 |
# |    clip_fraction        | 0.532     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.6      |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.112     |
# |    n_updates            | 1520      |
# |    policy_gradient_loss | 0.0197    |
# |    std                  | 1.12      |
# |    value_loss           | 0.478     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 800      |
# |    ep_rew_mean          | 0.1      |
# | time/                   |          |
# |    fps                  | 783      |
# |    iterations           | 7        |
# |    time_elapsed         | 18       |
# |    total_timesteps      | 14336    |
# | train/                  |          |
# |    approx_kl            | 2.387889 |
# |    clip_fraction        | 0.136    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.6     |
# |    explained_variance   | 0.958    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0253   |
# |    n_updates            | 1530     |
# |    policy_gradient_loss | -0.0298  |
# |    std                  | 1.12     |
# |    value_loss           | 0.943    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 762      |
# |    ep_rew_mean          | -47.5    |
# | time/                   |          |
# |    fps                  | 776      |
# |    iterations           | 8        |
# |    time_elapsed         | 21       |
# |    total_timesteps      | 16384    |
# | train/                  |          |
# |    approx_kl            | 19.96474 |
# |    clip_fraction        | 0.383    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.59    |
# |    explained_variance   | 0.974    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.244    |
# |    n_updates            | 1540     |
# |    policy_gradient_loss | -0.019   |
# |    std                  | 1.12     |
# |    value_loss           | 0.465    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 767      |
# |    ep_rew_mean          | -41.6    |
# | time/                   |          |
# |    fps                  | 772      |
# |    iterations           | 9        |
# |    time_elapsed         | 23       |
# |    total_timesteps      | 18432    |
# | train/                  |          |
# |    approx_kl            | 69.02893 |
# |    clip_fraction        | 0.72     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.59    |
# |    explained_variance   | 0.0586   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.04     |
# |    n_updates            | 1550     |
# |    policy_gradient_loss | 0.178    |
# |    std                  | 1.12     |
# |    value_loss           | 1.24e+03 |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 741       |
# |    ep_rew_mean          | -74       |
# | time/                   |           |
# |    fps                  | 768       |
# |    iterations           | 10        |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 25.820417 |
# |    clip_fraction        | 0.568     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.973     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0906    |
# |    n_updates            | 1560      |
# |    policy_gradient_loss | -0.0601   |
# |    std                  | 1.1       |
# |    value_loss           | 0.539     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 747       |
# |    ep_rew_mean          | -66.6     |
# | time/                   |           |
# |    fps                  | 764       |
# |    iterations           | 11        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 166.35771 |
# |    clip_fraction        | 0.815     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.54     |
# |    explained_variance   | 0.0769    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.637     |
# |    n_updates            | 1570      |
# |    policy_gradient_loss | 0.168     |
# |    std                  | 1.1       |
# |    value_loss           | 2.02e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 750      |
# |    ep_rew_mean          | -62.4    |
# | time/                   |          |
# |    fps                  | 757      |
# |    iterations           | 12       |
# |    time_elapsed         | 32       |
# |    total_timesteps      | 24576    |
# | train/                  |          |
# |    approx_kl            | 4.139163 |
# |    clip_fraction        | 0.172    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.54    |
# |    explained_variance   | 0.894    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.68     |
# |    n_updates            | 1580     |
# |    policy_gradient_loss | 0.0398   |
# |    std                  | 1.1      |
# |    value_loss           | 7.28     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 755       |
# |    ep_rew_mean          | -57       |
# | time/                   |           |
# |    fps                  | 757       |
# |    iterations           | 13        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.6536019 |
# |    clip_fraction        | 0.122     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.55     |
# |    explained_variance   | 0.901     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.37      |
# |    n_updates            | 1590      |
# |    policy_gradient_loss | 0.0164    |
# |    std                  | 1.11      |
# |    value_loss           | 7.34      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 738       |
# |    ep_rew_mean          | -52.5     |
# | time/                   |           |
# |    fps                  | 757       |
# |    iterations           | 14        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 29.976435 |
# |    clip_fraction        | 0.446     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.55     |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.854     |
# |    n_updates            | 1600      |
# |    policy_gradient_loss | -0.0331   |
# |    std                  | 1.1       |
# |    value_loss           | 2.67      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 742       |
# |    ep_rew_mean          | -48.7     |
# | time/                   |           |
# |    fps                  | 757       |
# |    iterations           | 15        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 10.604866 |
# |    clip_fraction        | 0.318     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.54     |
# |    explained_variance   | 0.935     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.35      |
# |    n_updates            | 1610      |
# |    policy_gradient_loss | 0.00388   |
# |    std                  | 1.1       |
# |    value_loss           | 1.63      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 729      |
# |    ep_rew_mean          | -45.3    |
# | time/                   |          |
# |    fps                  | 755      |
# |    iterations           | 16       |
# |    time_elapsed         | 43       |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 2.058722 |
# |    clip_fraction        | 0.179    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.55    |
# |    explained_variance   | 0.933    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.91     |
# |    n_updates            | 1620     |
# |    policy_gradient_loss | 0.029    |
# |    std                  | 1.11     |
# |    value_loss           | 4.36     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 734       |
# |    ep_rew_mean          | -42.4     |
# | time/                   |           |
# |    fps                  | 752       |
# |    iterations           | 17        |
# |    time_elapsed         | 46        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 1.0793498 |
# |    clip_fraction        | 0.094     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.57     |
# |    explained_variance   | 0.873     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.347     |
# |    n_updates            | 1630      |
# |    policy_gradient_loss | -0.0105   |
# |    std                  | 1.12      |
# |    value_loss           | 2.21      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 736       |
# |    ep_rew_mean          | -40.7     |
# | time/                   |           |
# |    fps                  | 750       |
# |    iterations           | 18        |
# |    time_elapsed         | 49        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.5721502 |
# |    clip_fraction        | 0.112     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.58     |
# |    explained_variance   | 0.849     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.729     |
# |    n_updates            | 1640      |
# |    policy_gradient_loss | 0.00512   |
# |    std                  | 1.12      |
# |    value_loss           | 1.15      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 740          |
# |    ep_rew_mean          | -38.3        |
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 19           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0009244457 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.312        |
# |    n_updates            | 1650         |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 1.12         |
# |    value_loss           | 2.64         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 743       |
# |    ep_rew_mean          | -36.2     |
# | time/                   |           |
# |    fps                  | 749       |
# |    iterations           | 20        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 34.306976 |
# |    clip_fraction        | 0.424     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.58     |
# |    explained_variance   | 0.892     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.277     |
# |    n_updates            | 1660      |
# |    policy_gradient_loss | 0.198     |
# |    std                  | 1.12      |
# |    value_loss           | 1.54      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 745       |
# |    ep_rew_mean          | -35       |
# | time/                   |           |
# |    fps                  | 749       |
# |    iterations           | 21        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 8.5086975 |
# |    clip_fraction        | 0.215     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.58     |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.11      |
# |    n_updates            | 1670      |
# |    policy_gradient_loss | -0.0408   |
# |    std                  | 1.12      |
# |    value_loss           | 1.21      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 737       |
# |    ep_rew_mean          | -32.6     |
# | time/                   |           |
# |    fps                  | 749       |
# |    iterations           | 22        |
# |    time_elapsed         | 60        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 17.512331 |
# |    clip_fraction        | 0.4       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.59     |
# |    explained_variance   | 0.943     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.268     |
# |    n_updates            | 1680      |
# |    policy_gradient_loss | 0.135     |
# |    std                  | 1.12      |
# |    value_loss           | 0.558     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 739       |
# |    ep_rew_mean          | -31.6     |
# | time/                   |           |
# |    fps                  | 749       |
# |    iterations           | 23        |
# |    time_elapsed         | 62        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 1.8555201 |
# |    clip_fraction        | 0.219     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.58     |
# |    explained_variance   | 0.907     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.308     |
# |    n_updates            | 1690      |
# |    policy_gradient_loss | -0.0021   |
# |    std                  | 1.12      |
# |    value_loss           | 1.32      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 742       |
# |    ep_rew_mean          | -30.2     |
# | time/                   |           |
# |    fps                  | 747       |
# |    iterations           | 24        |
# |    time_elapsed         | 65        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.1254145 |
# |    clip_fraction        | 0.309     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.58     |
# |    explained_variance   | 0.929     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0293    |
# |    n_updates            | 1700      |
# |    policy_gradient_loss | 0.0594    |
# |    std                  | 1.12      |
# |    value_loss           | 0.282     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 743        |
# |    ep_rew_mean          | -29.3      |
# | time/                   |            |
# |    fps                  | 746        |
# |    iterations           | 25         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.48010546 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.57      |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.1        |
# |    n_updates            | 1710       |
# |    policy_gradient_loss | 0.0078     |
# |    std                  | 1.11       |
# |    value_loss           | 2.13       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 736          |
# |    ep_rew_mean          | -27.6        |
# | time/                   |              |
# |    fps                  | 745          |
# |    iterations           | 26           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0015770451 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.254        |
# |    n_updates            | 1720         |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 1.12         |
# |    value_loss           | 1.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 737         |
# |    ep_rew_mean          | -26.9       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 27          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.021367874 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.188       |
# |    n_updates            | 1730        |
# |    policy_gradient_loss | 0.0166      |
# |    std                  | 1.11        |
# |    value_loss           | 1.17        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 740       |
# |    ep_rew_mean          | -25.8     |
# | time/                   |           |
# |    fps                  | 738       |
# |    iterations           | 28        |
# |    time_elapsed         | 77        |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 51.481743 |
# |    clip_fraction        | 0.425     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.58     |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.172     |
# |    n_updates            | 1740      |
# |    policy_gradient_loss | 0.0192    |
# |    std                  | 1.12      |
# |    value_loss           | 0.668     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 742          |
# |    ep_rew_mean          | -24.9        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 29           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0045525855 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0.338        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.353        |
# |    n_updates            | 1750         |
# |    policy_gradient_loss | -0.00239     |
# |    std                  | 1.12         |
# |    value_loss           | 1.21         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 743        |
# |    ep_rew_mean          | -24.2      |
# | time/                   |            |
# |    fps                  | 734        |
# |    iterations           | 30         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.15961179 |
# |    clip_fraction        | 0.0437     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.59      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0811     |
# |    n_updates            | 1760       |
# |    policy_gradient_loss | 0.00845    |
# |    std                  | 1.12       |
# |    value_loss           | 0.375      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 745       |
# |    ep_rew_mean          | -23.4     |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 31        |
# |    time_elapsed         | 86        |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 43.649315 |
# |    clip_fraction        | 0.385     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.59     |
# |    explained_variance   | 0.971     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0437    |
# |    n_updates            | 1770      |
# |    policy_gradient_loss | -0.0726   |
# |    std                  | 1.12      |
# |    value_loss           | 0.367     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 747          |
# |    ep_rew_mean          | -22.8        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 32           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0009982511 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.272        |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 1.12         |
# |    value_loss           | 0.373        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 748           |
# |    ep_rew_mean          | -22.1         |
# | time/                   |               |
# |    fps                  | 735           |
# |    iterations           | 33            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00033239936 |
# |    clip_fraction        | 0.00327       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.6          |
# |    explained_variance   | 0.745         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0817        |
# |    n_updates            | 1790          |
# |    policy_gradient_loss | 0.0001        |
# |    std                  | 1.12          |
# |    value_loss           | 0.332         |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 750       |
# |    ep_rew_mean          | -21.6     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 34        |
# |    time_elapsed         | 94        |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 159.10638 |
# |    clip_fraction        | 0.413     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.61     |
# |    explained_variance   | 0.958     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.343     |
# |    n_updates            | 1800      |
# |    policy_gradient_loss | 0.0881    |
# |    std                  | 1.12      |
# |    value_loss           | 1.38      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 751          |
# |    ep_rew_mean          | -20.9        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 35           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0012248771 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.199        |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00315     |
# |    std                  | 1.12         |
# |    value_loss           | 0.786        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 752       |
# |    ep_rew_mean          | -20.5     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 36        |
# |    time_elapsed         | 100       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.7838785 |
# |    clip_fraction        | 0.126     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.58     |
# |    explained_variance   | 0.834     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0212    |
# |    n_updates            | 1820      |
# |    policy_gradient_loss | 0.0165    |
# |    std                  | 1.11      |
# |    value_loss           | 0.179     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 37          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004091554 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0919      |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.00715     |
# |    std                  | 1.11        |
# |    value_loss           | 0.655       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 38          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.059490446 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.331       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0243      |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.0245      |
# |    std                  | 1.1         |
# |    value_loss           | 1.11        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 754       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 39        |
# |    time_elapsed         | 108       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 1.2710551 |
# |    clip_fraction        | 0.129     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.54     |
# |    explained_variance   | 0.778     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0303   |
# |    n_updates            | 1850      |
# |    policy_gradient_loss | 0.00631   |
# |    std                  | 1.1       |
# |    value_loss           | 0.0897    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 754       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 40        |
# |    time_elapsed         | 111       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 18.952679 |
# |    clip_fraction        | 0.353     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.54     |
# |    explained_variance   | 0.947     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0902    |
# |    n_updates            | 1860      |
# |    policy_gradient_loss | -0.0533   |
# |    std                  | 1.1       |
# |    value_loss           | 0.9       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 41          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007987943 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.074       |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | 0.0161      |
# |    std                  | 1.1         |
# |    value_loss           | 0.314       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 754       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 42        |
# |    time_elapsed         | 117       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 32.556675 |
# |    clip_fraction        | 0.334     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.54     |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0262    |
# |    n_updates            | 1880      |
# |    policy_gradient_loss | -0.0727   |
# |    std                  | 1.11      |
# |    value_loss           | 0.404     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 754       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 43        |
# |    time_elapsed         | 119       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 1.1010559 |
# |    clip_fraction        | 0.166     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.55     |
# |    explained_variance   | 0.826     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.109     |
# |    n_updates            | 1890      |
# |    policy_gradient_loss | 0.0251    |
# |    std                  | 1.11      |
# |    value_loss           | 0.185     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 754       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 44        |
# |    time_elapsed         | 122       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 43.607147 |
# |    clip_fraction        | 0.349     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.56     |
# |    explained_variance   | 0.969     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.166     |
# |    n_updates            | 1900      |
# |    policy_gradient_loss | -0.0538   |
# |    std                  | 1.11      |
# |    value_loss           | 0.545     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 754      |
# |    ep_rew_mean          | -19.9    |
# | time/                   |          |
# |    fps                  | 735      |
# |    iterations           | 45       |
# |    time_elapsed         | 125      |
# |    total_timesteps      | 92160    |
# | train/                  |          |
# |    approx_kl            | 77.26425 |
# |    clip_fraction        | 0.36     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.56    |
# |    explained_variance   | 0.925    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.528    |
# |    n_updates            | 1910     |
# |    policy_gradient_loss | 0.00719  |
# |    std                  | 1.11     |
# |    value_loss           | 0.782    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 762         |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 46          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006671184 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.66        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 1.09        |
# |    value_loss           | 0.983       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 770       |
# |    ep_rew_mean          | 0.136     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 47        |
# |    time_elapsed         | 130       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 2.5424507 |
# |    clip_fraction        | 0.207     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.53     |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.263     |
# |    n_updates            | 1930      |
# |    policy_gradient_loss | -0.00334  |
# |    std                  | 1.1       |
# |    value_loss           | 0.453     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 770       |
# |    ep_rew_mean          | 0.136     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 48        |
# |    time_elapsed         | 133       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 28.746933 |
# |    clip_fraction        | 0.3       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.53     |
# |    explained_variance   | 0.853     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0283   |
# |    n_updates            | 1940      |
# |    policy_gradient_loss | -0.0275   |
# |    std                  | 1.1       |
# |    value_loss           | 0.272     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 770        |
# |    ep_rew_mean          | 0.136      |
# | time/                   |            |
# |    fps                  | 735        |
# |    iterations           | 49         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.25157425 |
# |    clip_fraction        | 0.0335     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | -0.648     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.27       |
# |    n_updates            | 1950       |
# |    policy_gradient_loss | 0.0345     |
# |    std                  | 1.1        |
# |    value_loss           | 1.22       |
# ----------------------------------------
# --- 137.82847380638123 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-3.84 +/- 63.13

# %%
model.save("zeppelin-v2-400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    fps             | 1316     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 800         |
# |    ep_rew_mean          | 0.1         |
# | time/                   |             |
# |    fps                  | 933         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005376435 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.543       |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | 0.00887     |
# |    std                  | 1.1         |
# |    value_loss           | 1.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 800         |
# |    ep_rew_mean          | 0.1         |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010031981 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.404       |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | 0.00155     |
# |    std                  | 1.1         |
# |    value_loss           | 0.778       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 800       |
# |    ep_rew_mean          | 0.1       |
# | time/                   |           |
# |    fps                  | 810       |
# |    iterations           | 4         |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 63.906677 |
# |    clip_fraction        | 0.347     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.53     |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0851    |
# |    n_updates            | 1990      |
# |    policy_gradient_loss | -0.082    |
# |    std                  | 1.1       |
# |    value_loss           | 0.609     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 800        |
# |    ep_rew_mean          | 0.1        |
# | time/                   |            |
# |    fps                  | 751        |
# |    iterations           | 5          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.24714126 |
# |    clip_fraction        | 0.0894     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | 0.599      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.09       |
# |    n_updates            | 2000       |
# |    policy_gradient_loss | 0.0468     |
# |    std                  | 1.1        |
# |    value_loss           | 2.04       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 753        |
# |    ep_rew_mean          | 0.156      |
# | time/                   |            |
# |    fps                  | 729        |
# |    iterations           | 6          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.15900975 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.56      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.921      |
# |    n_updates            | 2010       |
# |    policy_gradient_loss | 0.0558     |
# |    std                  | 1.12       |
# |    value_loss           | 0.487      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 719      |
# |    ep_rew_mean          | 0.195    |
# | time/                   |          |
# |    fps                  | 715      |
# |    iterations           | 7        |
# |    time_elapsed         | 20       |
# |    total_timesteps      | 14336    |
# | train/                  |          |
# |    approx_kl            | 39.29216 |
# |    clip_fraction        | 0.403    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.59    |
# |    explained_variance   | 0.954    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0158  |
# |    n_updates            | 2020     |
# |    policy_gradient_loss | -0.0255  |
# |    std                  | 1.12     |
# |    value_loss           | 0.29     |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 730          |
# |    ep_rew_mean          | 0.182        |
# | time/                   |              |
# |    fps                  | 692          |
# |    iterations           | 8            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0044093765 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0702       |
# |    n_updates            | 2030         |
# |    policy_gradient_loss | 0.0315       |
# |    std                  | 1.13         |
# |    value_loss           | 0.24         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 736         |
# |    ep_rew_mean          | 0.175       |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 9           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004520067 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 2040        |
# |    policy_gradient_loss | 0.00495     |
# |    std                  | 1.12        |
# |    value_loss           | 0.475       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 743      |
# |    ep_rew_mean          | 0.167    |
# | time/                   |          |
# |    fps                  | 689      |
# |    iterations           | 10       |
# |    time_elapsed         | 29       |
# |    total_timesteps      | 20480    |
# | train/                  |          |
# |    approx_kl            | 0.629351 |
# |    clip_fraction        | 0.0883   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.59    |
# |    explained_variance   | 0.0617   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.46     |
# |    n_updates            | 2050     |
# |    policy_gradient_loss | 0.0977   |
# |    std                  | 1.12     |
# |    value_loss           | 1.1      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 703        |
# |    ep_rew_mean          | 0.213      |
# | time/                   |            |
# |    fps                  | 692        |
# |    iterations           | 11         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03548592 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.6       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.226      |
# |    n_updates            | 2060       |
# |    policy_gradient_loss | 0.106      |
# |    std                  | 1.12       |
# |    value_loss           | 0.527      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | 0.206       |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 12          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015298934 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0819      |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 1.12        |
# |    value_loss           | 0.199       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 716          |
# |    ep_rew_mean          | 0.197        |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 13           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0045994595 |
# |    clip_fraction        | 0.0793       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0385       |
# |    n_updates            | 2080         |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 1.12         |
# |    value_loss           | 0.145        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 720      |
# |    ep_rew_mean          | 0.192    |
# | time/                   |          |
# |    fps                  | 689      |
# |    iterations           | 14       |
# |    time_elapsed         | 41       |
# |    total_timesteps      | 28672    |
# | train/                  |          |
# |    approx_kl            | 1.811443 |
# |    clip_fraction        | 0.507    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.62    |
# |    explained_variance   | 0.911    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0957   |
# |    n_updates            | 2090     |
# |    policy_gradient_loss | 0.148    |
# |    std                  | 1.14     |
# |    value_loss           | 0.22     |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 726          |
# |    ep_rew_mean          | 0.186        |
# | time/                   |              |
# |    fps                  | 690          |
# |    iterations           | 15           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0028240043 |
# |    clip_fraction        | 0.0762       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0929       |
# |    n_updates            | 2100         |
# |    policy_gradient_loss | 0.0236       |
# |    std                  | 1.13         |
# |    value_loss           | 0.355        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 729      |
# |    ep_rew_mean          | 0.182    |
# | time/                   |          |
# |    fps                  | 691      |
# |    iterations           | 16       |
# |    time_elapsed         | 47       |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 18.80892 |
# |    clip_fraction        | 0.407    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.63    |
# |    explained_variance   | 0.867    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.279    |
# |    n_updates            | 2110     |
# |    policy_gradient_loss | 0.195    |
# |    std                  | 1.13     |
# |    value_loss           | 0.61     |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 734          |
# |    ep_rew_mean          | 0.177        |
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 17           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0050919047 |
# |    clip_fraction        | 0.0957       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.62        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.196        |
# |    n_updates            | 2120         |
# |    policy_gradient_loss | 0.0225       |
# |    std                  | 1.13         |
# |    value_loss           | 0.305        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 736       |
# |    ep_rew_mean          | 0.173     |
# | time/                   |           |
# |    fps                  | 692       |
# |    iterations           | 18        |
# |    time_elapsed         | 53        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 25.364418 |
# |    clip_fraction        | 0.488     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.61     |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.123     |
# |    n_updates            | 2130      |
# |    policy_gradient_loss | -0.0449   |
# |    std                  | 1.12      |
# |    value_loss           | 0.273     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 740          |
# |    ep_rew_mean          | 0.169        |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 19           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0067481073 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 0.367        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00739      |
# |    n_updates            | 2140         |
# |    policy_gradient_loss | 0.00809      |
# |    std                  | 1.13         |
# |    value_loss           | 1.08         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 743       |
# |    ep_rew_mean          | 0.165     |
# | time/                   |           |
# |    fps                  | 693       |
# |    iterations           | 20        |
# |    time_elapsed         | 59        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 2.0445275 |
# |    clip_fraction        | 0.183     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.62     |
# |    explained_variance   | -0.821    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.563     |
# |    n_updates            | 2150      |
# |    policy_gradient_loss | 0.0484    |
# |    std                  | 1.13      |
# |    value_loss           | 0.868     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 745         |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 21          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.031853784 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.596       |
# |    n_updates            | 2160        |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 1.13        |
# |    value_loss           | 2.1         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 748      |
# |    ep_rew_mean          | 0.16     |
# | time/                   |          |
# |    fps                  | 688      |
# |    iterations           | 22       |
# |    time_elapsed         | 65       |
# |    total_timesteps      | 45056    |
# | train/                  |          |
# |    approx_kl            | 7.611553 |
# |    clip_fraction        | 0.626    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.63    |
# |    explained_variance   | 0.955    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0446  |
# |    n_updates            | 2170     |
# |    policy_gradient_loss | 0.0247   |
# |    std                  | 1.13     |
# |    value_loss           | 0.162    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 738       |
# |    ep_rew_mean          | 0.171     |
# | time/                   |           |
# |    fps                  | 688       |
# |    iterations           | 23        |
# |    time_elapsed         | 68        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 3.4041371 |
# |    clip_fraction        | 0.178     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.63     |
# |    explained_variance   | 0.714     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.166     |
# |    n_updates            | 2180      |
# |    policy_gradient_loss | 0.0116    |
# |    std                  | 1.13      |
# |    value_loss           | 0.541     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 741         |
# |    ep_rew_mean          | 0.168       |
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 24          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005038878 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0284      |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | -0.00562    |
# |    std                  | 1.13        |
# |    value_loss           | 0.548       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 743       |
# |    ep_rew_mean          | 0.166     |
# | time/                   |           |
# |    fps                  | 688       |
# |    iterations           | 25        |
# |    time_elapsed         | 74        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 3.9236093 |
# |    clip_fraction        | 0.132     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.61     |
# |    explained_variance   | 0.909     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.566     |
# |    n_updates            | 2200      |
# |    policy_gradient_loss | 0.00451   |
# |    std                  | 1.13      |
# |    value_loss           | 0.61      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 689          |
# |    iterations           | 26           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0073113726 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.61        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 2210         |
# |    policy_gradient_loss | 0.0163       |
# |    std                  | 1.13         |
# |    value_loss           | 0.301        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 747        |
# |    ep_rew_mean          | 0.161      |
# | time/                   |            |
# |    fps                  | 689        |
# |    iterations           | 27         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.28918946 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.61      |
# |    explained_variance   | 0.362      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.11       |
# |    n_updates            | 2220       |
# |    policy_gradient_loss | 0.0101     |
# |    std                  | 1.13       |
# |    value_loss           | 0.401      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 749        |
# |    ep_rew_mean          | 0.159      |
# | time/                   |            |
# |    fps                  | 689        |
# |    iterations           | 28         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.05858023 |
# |    clip_fraction        | 0.0292     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.62      |
# |    explained_variance   | 0.673      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00913    |
# |    n_updates            | 2230       |
# |    policy_gradient_loss | 0.0318     |
# |    std                  | 1.13       |
# |    value_loss           | 0.332      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 751         |
# |    ep_rew_mean          | 0.157       |
# | time/                   |             |
# |    fps                  | 690         |
# |    iterations           | 29          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.062156424 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.173       |
# |    n_updates            | 2240        |
# |    policy_gradient_loss | 0.172       |
# |    std                  | 1.14        |
# |    value_loss           | 0.678       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 752        |
# |    ep_rew_mean          | 0.156      |
# | time/                   |            |
# |    fps                  | 691        |
# |    iterations           | 30         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.53381276 |
# |    clip_fraction        | 0.0702     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.66      |
# |    explained_variance   | -1.76      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.226      |
# |    n_updates            | 2250       |
# |    policy_gradient_loss | 0.0336     |
# |    std                  | 1.15       |
# |    value_loss           | 0.884      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 753      |
# |    ep_rew_mean          | 0.154    |
# | time/                   |          |
# |    fps                  | 692      |
# |    iterations           | 31       |
# |    time_elapsed         | 91       |
# |    total_timesteps      | 63488    |
# | train/                  |          |
# |    approx_kl            | 3.258174 |
# |    clip_fraction        | 0.166    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.68    |
# |    explained_variance   | 0.473    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0177   |
# |    n_updates            | 2260     |
# |    policy_gradient_loss | 0.0193   |
# |    std                  | 1.16     |
# |    value_loss           | 0.491    |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 0.152        |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 32           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0012697865 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.68        |
# |    explained_variance   | -0.0585      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0299       |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 1.16         |
# |    value_loss           | 0.131        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 756       |
# |    ep_rew_mean          | 0.151     |
# | time/                   |           |
# |    fps                  | 694       |
# |    iterations           | 33        |
# |    time_elapsed         | 97        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 10.746969 |
# |    clip_fraction        | 0.403     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.67     |
# |    explained_variance   | 0.939     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0401    |
# |    n_updates            | 2280      |
# |    policy_gradient_loss | 0.00524   |
# |    std                  | 1.15      |
# |    value_loss           | 0.188     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 757         |
# |    ep_rew_mean          | 0.149       |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 34          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.002474756 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | -1.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | 0.0192      |
# |    std                  | 1.14        |
# |    value_loss           | 0.269       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 0.148        |
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 35           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0009812538 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.64        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0873       |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.000863    |
# |    std                  | 1.14         |
# |    value_loss           | 0.171        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 760          |
# |    ep_rew_mean          | 0.146        |
# | time/                   |              |
# |    fps                  | 695          |
# |    iterations           | 36           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0011753531 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 0.396        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.00239     |
# |    std                  | 1.13         |
# |    value_loss           | 0.222        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 761          |
# |    ep_rew_mean          | 0.145        |
# | time/                   |              |
# |    fps                  | 696          |
# |    iterations           | 37           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0021434857 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0282       |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | 0.00584      |
# |    std                  | 1.14         |
# |    value_loss           | 0.138        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 761          |
# |    ep_rew_mean          | 0.145        |
# | time/                   |              |
# |    fps                  | 696          |
# |    iterations           | 38           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0023601148 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.64        |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0568       |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | 0.00171      |
# |    std                  | 1.14         |
# |    value_loss           | 0.145        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 761          |
# |    ep_rew_mean          | 0.145        |
# | time/                   |              |
# |    fps                  | 697          |
# |    iterations           | 39           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0069669057 |
# |    clip_fraction        | 0.0896       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.64        |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0949       |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | 0.00152      |
# |    std                  | 1.14         |
# |    value_loss           | 0.203        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 761        |
# |    ep_rew_mean          | 0.145      |
# | time/                   |            |
# |    fps                  | 698        |
# |    iterations           | 40         |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.16058879 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.66      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.242      |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | 0.115      |
# |    std                  | 1.16       |
# |    value_loss           | 0.4        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 761         |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 41          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010515141 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.117       |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.00972     |
# |    std                  | 1.15        |
# |    value_loss           | 0.172       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 761       |
# |    ep_rew_mean          | 0.145     |
# | time/                   |           |
# |    fps                  | 698       |
# |    iterations           | 42        |
# |    time_elapsed         | 123       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 2.1110454 |
# |    clip_fraction        | 0.431     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.68     |
# |    explained_variance   | 0.975     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.197     |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | 0.0713    |
# |    std                  | 1.15      |
# |    value_loss           | 0.229     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 761        |
# |    ep_rew_mean          | 0.145      |
# | time/                   |            |
# |    fps                  | 699        |
# |    iterations           | 43         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.02334763 |
# |    clip_fraction        | 0.0539     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.66      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.125      |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | 0.0596     |
# |    std                  | 1.14       |
# |    value_loss           | 0.52       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 768       |
# |    ep_rew_mean          | 0.136     |
# | time/                   |           |
# |    fps                  | 700       |
# |    iterations           | 44        |
# |    time_elapsed         | 128       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 2.4205933 |
# |    clip_fraction        | 0.32      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.66     |
# |    explained_variance   | 0.746     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.155     |
# |    n_updates            | 2390      |
# |    policy_gradient_loss | 0.139     |
# |    std                  | 1.15      |
# |    value_loss           | 0.176     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 768        |
# |    ep_rew_mean          | 0.136      |
# | time/                   |            |
# |    fps                  | 700        |
# |    iterations           | 45         |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.14215155 |
# |    clip_fraction        | 0.0977     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.67      |
# |    explained_variance   | 0.0597     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0139     |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | 0.00767    |
# |    std                  | 1.15       |
# |    value_loss           | 0.105      |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 768           |
# |    ep_rew_mean          | 0.136         |
# | time/                   |               |
# |    fps                  | 699           |
# |    iterations           | 46            |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00076797634 |
# |    clip_fraction        | 0.0103        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.67         |
# |    explained_variance   | 0.145         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0582        |
# |    n_updates            | 2410          |
# |    policy_gradient_loss | -0.00605      |
# |    std                  | 1.15          |
# |    value_loss           | 0.153         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 760         |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 47          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014086228 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0652      |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | 0.00328     |
# |    std                  | 1.14        |
# |    value_loss           | 0.117       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 760      |
# |    ep_rew_mean          | 0.145    |
# | time/                   |          |
# |    fps                  | 700      |
# |    iterations           | 48       |
# |    time_elapsed         | 140      |
# |    total_timesteps      | 98304    |
# | train/                  |          |
# |    approx_kl            | 6.088501 |
# |    clip_fraction        | 0.377    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.64    |
# |    explained_variance   | 0.975    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0156  |
# |    n_updates            | 2430     |
# |    policy_gradient_loss | 0.0865   |
# |    std                  | 1.13     |
# |    value_loss           | 0.429    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 776        |
# |    ep_rew_mean          | 0.127      |
# | time/                   |            |
# |    fps                  | 700        |
# |    iterations           | 49         |
# |    time_elapsed         | 143        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.17024967 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.63      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.421      |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | 0.108      |
# |    std                  | 1.14       |
# |    value_loss           | 0.241      |
# ----------------------------------------
# --- 144.50485229492188 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-11.85 +/- 108.90

# %%
model.save("zeppelin-v2-500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    fps             | 1222     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 800      |
# |    ep_rew_mean          | 0.1      |
# | time/                   |          |
# |    fps                  | 929      |
# |    iterations           | 2        |
# |    time_elapsed         | 4        |
# |    total_timesteps      | 4096     |
# | train/                  |          |
# |    approx_kl            | 1115.965 |
# |    clip_fraction        | 0.508    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.64    |
# |    explained_variance   | 0.802    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.203    |
# |    n_updates            | 2460     |
# |    policy_gradient_loss | 0.119    |
# |    std                  | 1.14     |
# |    value_loss           | 0.803    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 800        |
# |    ep_rew_mean          | 0.1        |
# | time/                   |            |
# |    fps                  | 865        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.46889627 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.67      |
# |    explained_variance   | 0.427      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.212      |
# |    n_updates            | 2470       |
# |    policy_gradient_loss | 0.0331     |
# |    std                  | 1.16       |
# |    value_loss           | 0.355      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 800       |
# |    ep_rew_mean          | 0.1       |
# | time/                   |           |
# |    fps                  | 835       |
# |    iterations           | 4         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.7122393 |
# |    clip_fraction        | 0.357     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.7      |
# |    explained_variance   | 0.977     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.187     |
# |    n_updates            | 2480      |
# |    policy_gradient_loss | 0.109     |
# |    std                  | 1.16      |
# |    value_loss           | 0.249     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 739        |
# |    ep_rew_mean          | 0.169      |
# | time/                   |            |
# |    fps                  | 813        |
# |    iterations           | 5          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.18541424 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.7       |
# |    explained_variance   | 0.233      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.434      |
# |    n_updates            | 2490       |
# |    policy_gradient_loss | 0.0637     |
# |    std                  | 1.16       |
# |    value_loss           | 0.86       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 750       |
# |    ep_rew_mean          | 0.156     |
# | time/                   |           |
# |    fps                  | 803       |
# |    iterations           | 6         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 2.0647397 |
# |    clip_fraction        | 0.182     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.71     |
# |    explained_variance   | 0.766     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.322     |
# |    n_updates            | 2500      |
# |    policy_gradient_loss | 0.0205    |
# |    std                  | 1.16      |
# |    value_loss           | 0.985     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 718      |
# |    ep_rew_mean          | 0.195    |
# | time/                   |          |
# |    fps                  | 793      |
# |    iterations           | 7        |
# |    time_elapsed         | 18       |
# |    total_timesteps      | 14336    |
# | train/                  |          |
# |    approx_kl            | 5.087098 |
# |    clip_fraction        | 0.229    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.71    |
# |    explained_variance   | 0.64     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.106    |
# |    n_updates            | 2510     |
# |    policy_gradient_loss | 0.0102   |
# |    std                  | 1.16     |
# |    value_loss           | 0.333    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 698        |
# |    ep_rew_mean          | -43.3      |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 8          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.09641152 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.71      |
# |    explained_variance   | 0.479      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.67       |
# |    n_updates            | 2520       |
# |    policy_gradient_loss | 0.0292     |
# |    std                  | 1.17       |
# |    value_loss           | 1.29       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 706      |
# |    ep_rew_mean          | -39.8    |
# | time/                   |          |
# |    fps                  | 779      |
# |    iterations           | 9        |
# |    time_elapsed         | 23       |
# |    total_timesteps      | 18432    |
# | train/                  |          |
# |    approx_kl            | 38.10755 |
# |    clip_fraction        | 0.604    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.73    |
# |    explained_variance   | 0.00648  |
# |    learning_rate        | 0.0003   |
# |    loss                 | 5.43     |
# |    n_updates            | 2530     |
# |    policy_gradient_loss | 0.117    |
# |    std                  | 1.17     |
# |    value_loss           | 2.4e+03  |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 716          |
# |    ep_rew_mean          | -35.6        |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 10           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0047931205 |
# |    clip_fraction        | 0.0765       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.73        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.2          |
# |    n_updates            | 2540         |
# |    policy_gradient_loss | 0.00412      |
# |    std                  | 1.17         |
# |    value_loss           | 3.64         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 724        |
# |    ep_rew_mean          | -32.1      |
# | time/                   |            |
# |    fps                  | 763        |
# |    iterations           | 11         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.21895903 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.73      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.442      |
# |    n_updates            | 2550       |
# |    policy_gradient_loss | 0.0226     |
# |    std                  | 1.17       |
# |    value_loss           | 1.83       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 729       |
# |    ep_rew_mean          | -30.2     |
# | time/                   |           |
# |    fps                  | 755       |
# |    iterations           | 12        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 3.1498065 |
# |    clip_fraction        | 0.126     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.73     |
# |    explained_variance   | 0.957     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.361     |
# |    n_updates            | 2560      |
# |    policy_gradient_loss | 0.00102   |
# |    std                  | 1.17      |
# |    value_loss           | 2.1       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 715       |
# |    ep_rew_mean          | -26.9     |
# | time/                   |           |
# |    fps                  | 749       |
# |    iterations           | 13        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 25.261845 |
# |    clip_fraction        | 0.407     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.74     |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00167   |
# |    n_updates            | 2570      |
# |    policy_gradient_loss | -0.0772   |
# |    std                  | 1.18      |
# |    value_loss           | 0.679     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 720       |
# |    ep_rew_mean          | -25.5     |
# | time/                   |           |
# |    fps                  | 747       |
# |    iterations           | 14        |
# |    time_elapsed         | 38        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 29.048588 |
# |    clip_fraction        | 0.373     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.75     |
# |    explained_variance   | 0.946     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.1       |
# |    n_updates            | 2580      |
# |    policy_gradient_loss | -0.0345   |
# |    std                  | 1.18      |
# |    value_loss           | 2.91      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 725         |
# |    ep_rew_mean          | -23.6       |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 15          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009064276 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | 0.0163      |
# |    std                  | 1.17        |
# |    value_loss           | 1.22        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 729       |
# |    ep_rew_mean          | -22.6     |
# | time/                   |           |
# |    fps                  | 746       |
# |    iterations           | 16        |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 29.175072 |
# |    clip_fraction        | 0.346     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.74     |
# |    explained_variance   | 0.86      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.801     |
# |    n_updates            | 2600      |
# |    policy_gradient_loss | -0.00189  |
# |    std                  | 1.18      |
# |    value_loss           | 1.04      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 733      |
# |    ep_rew_mean          | -21.1    |
# | time/                   |          |
# |    fps                  | 746      |
# |    iterations           | 17       |
# |    time_elapsed         | 46       |
# |    total_timesteps      | 34816    |
# | train/                  |          |
# |    approx_kl            | 7.088504 |
# |    clip_fraction        | 0.335    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.75    |
# |    explained_variance   | 0.944    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.207    |
# |    n_updates            | 2610     |
# |    policy_gradient_loss | -0.0168  |
# |    std                  | 1.18     |
# |    value_loss           | 1.73     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 737         |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 18          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.043449517 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 2620        |
# |    policy_gradient_loss | 0.000281    |
# |    std                  | 1.18        |
# |    value_loss           | 2.4         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 740        |
# |    ep_rew_mean          | -19.1      |
# | time/                   |            |
# |    fps                  | 745        |
# |    iterations           | 19         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00920265 |
# |    clip_fraction        | 0.0101     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.75      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.414      |
# |    n_updates            | 2630       |
# |    policy_gradient_loss | 0.00126    |
# |    std                  | 1.18       |
# |    value_loss           | 1.26       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 743       |
# |    ep_rew_mean          | -18       |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 20        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 158.70555 |
# |    clip_fraction        | 0.403     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.76     |
# |    explained_variance   | 0.957     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.755     |
# |    n_updates            | 2640      |
# |    policy_gradient_loss | 0.243     |
# |    std                  | 1.18      |
# |    value_loss           | 1.97      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 745        |
# |    ep_rew_mean          | -17.4      |
# | time/                   |            |
# |    fps                  | 744        |
# |    iterations           | 21         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.27346385 |
# |    clip_fraction        | 0.0479     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.77      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0628     |
# |    n_updates            | 2650       |
# |    policy_gradient_loss | 0.00345    |
# |    std                  | 1.19       |
# |    value_loss           | 2.01       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 748      |
# |    ep_rew_mean          | -16.5    |
# | time/                   |          |
# |    fps                  | 741      |
# |    iterations           | 22       |
# |    time_elapsed         | 60       |
# |    total_timesteps      | 45056    |
# | train/                  |          |
# |    approx_kl            | 9.850939 |
# |    clip_fraction        | 0.297    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.78    |
# |    explained_variance   | 0.865    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.408    |
# |    n_updates            | 2660     |
# |    policy_gradient_loss | 0.0857   |
# |    std                  | 1.19     |
# |    value_loss           | 0.731    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 749        |
# |    ep_rew_mean          | -16        |
# | time/                   |            |
# |    fps                  | 739        |
# |    iterations           | 23         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.21859172 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.79      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.435      |
# |    n_updates            | 2670       |
# |    policy_gradient_loss | 0.0909     |
# |    std                  | 1.2        |
# |    value_loss           | 0.589      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 752         |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 24          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.092137285 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.349       |
# |    n_updates            | 2680        |
# |    policy_gradient_loss | 0.0918      |
# |    std                  | 1.2         |
# |    value_loss           | 0.224       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 753       |
# |    ep_rew_mean          | -14.8     |
# | time/                   |           |
# |    fps                  | 737       |
# |    iterations           | 25        |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.8746439 |
# |    clip_fraction        | 0.369     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.81     |
# |    explained_variance   | 0.972     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.218     |
# |    n_updates            | 2690      |
# |    policy_gradient_loss | 0.0908    |
# |    std                  | 1.2       |
# |    value_loss           | 0.55      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 26           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0037241727 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.8         |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.181        |
# |    n_updates            | 2700         |
# |    policy_gradient_loss | 0.000404     |
# |    std                  | 1.19         |
# |    value_loss           | 1.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 757         |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 27          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.053105116 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.17        |
# |    n_updates            | 2710        |
# |    policy_gradient_loss | -0.00163    |
# |    std                  | 1.19        |
# |    value_loss           | 0.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 758        |
# |    ep_rew_mean          | -13.2      |
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 28         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.78992444 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.79      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.393      |
# |    n_updates            | 2720       |
# |    policy_gradient_loss | 0.133      |
# |    std                  | 1.2        |
# |    value_loss           | 0.446      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 750         |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 29          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.033732798 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0652      |
# |    n_updates            | 2730        |
# |    policy_gradient_loss | 0.0295      |
# |    std                  | 1.2         |
# |    value_loss           | 0.138       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 752          |
# |    ep_rew_mean          | -12.2        |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 30           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0029783729 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.81        |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.212        |
# |    n_updates            | 2740         |
# |    policy_gradient_loss | -0.00026     |
# |    std                  | 1.2          |
# |    value_loss           | 0.723        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | -11.8        |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 31           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0115925055 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.8         |
# |    explained_variance   | 0.608        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 2750         |
# |    policy_gradient_loss | 0.00374      |
# |    std                  | 1.2          |
# |    value_loss           | 0.317        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | -11.5       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 32          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009181016 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 2760        |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 1.2         |
# |    value_loss           | 0.324       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 748          |
# |    ep_rew_mean          | -11          |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 33           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0016376914 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.77        |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.326        |
# |    n_updates            | 2770         |
# |    policy_gradient_loss | -0.00306     |
# |    std                  | 1.18         |
# |    value_loss           | 0.363        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | -10.7       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 34          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.046112016 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.013       |
# |    n_updates            | 2780        |
# |    policy_gradient_loss | 0.0189      |
# |    std                  | 1.19        |
# |    value_loss           | 0.0992      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 751       |
# |    ep_rew_mean          | -10.4     |
# | time/                   |           |
# |    fps                  | 739       |
# |    iterations           | 35        |
# |    time_elapsed         | 96        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 25.447523 |
# |    clip_fraction        | 0.469     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.8      |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.108     |
# |    n_updates            | 2790      |
# |    policy_gradient_loss | 0.0717    |
# |    std                  | 1.2       |
# |    value_loss           | 0.124     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 752         |
# |    ep_rew_mean          | -10.1       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 36          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013782389 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0598      |
# |    n_updates            | 2800        |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 1.2         |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 37          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.002632155 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | -0.114      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0797      |
# |    n_updates            | 2810        |
# |    policy_gradient_loss | -0.00369    |
# |    std                  | 1.2         |
# |    value_loss           | 0.193       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 38          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009338976 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0482      |
# |    n_updates            | 2820        |
# |    policy_gradient_loss | 0.00164     |
# |    std                  | 1.2         |
# |    value_loss           | 0.148       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 745         |
# |    ep_rew_mean          | -9.85       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 39          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011051312 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0431      |
# |    n_updates            | 2830        |
# |    policy_gradient_loss | 0.00964     |
# |    std                  | 1.21        |
# |    value_loss           | 0.194       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 745      |
# |    ep_rew_mean          | -9.85    |
# | time/                   |          |
# |    fps                  | 737      |
# |    iterations           | 40       |
# |    time_elapsed         | 111      |
# |    total_timesteps      | 81920    |
# | train/                  |          |
# |    approx_kl            | 77.04422 |
# |    clip_fraction        | 0.591    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.82    |
# |    explained_variance   | 0.894    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.082    |
# |    n_updates            | 2840     |
# |    policy_gradient_loss | 0.0716   |
# |    std                  | 1.21     |
# |    value_loss           | 0.185    |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | -9.85        |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 41           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0024498357 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.82        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51         |
# |    n_updates            | 2850         |
# |    policy_gradient_loss | 0.00769      |
# |    std                  | 1.2          |
# |    value_loss           | 2.92         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | -9.86        |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 42           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0011353795 |
# |    clip_fraction        | 0.00747      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.81        |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 2860         |
# |    policy_gradient_loss | -0.00178     |
# |    std                  | 1.21         |
# |    value_loss           | 3.57         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 738          |
# |    ep_rew_mean          | -9.84        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 43           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0123093445 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.81        |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38         |
# |    n_updates            | 2870         |
# |    policy_gradient_loss | 0.00113      |
# |    std                  | 1.2          |
# |    value_loss           | 2.41         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 746       |
# |    ep_rew_mean          | 0.163     |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 44        |
# |    time_elapsed         | 122       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 16.358881 |
# |    clip_fraction        | 0.33      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.81     |
# |    explained_variance   | 0.709     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.234     |
# |    n_updates            | 2880      |
# |    policy_gradient_loss | 0.0816    |
# |    std                  | 1.21      |
# |    value_loss           | 0.506     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 746        |
# |    ep_rew_mean          | 0.163      |
# | time/                   |            |
# |    fps                  | 734        |
# |    iterations           | 45         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.04633662 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.84      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.66       |
# |    n_updates            | 2890       |
# |    policy_gradient_loss | 0.14       |
# |    std                  | 1.22       |
# |    value_loss           | 1.49       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 46           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0034626485 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.83        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.181        |
# |    n_updates            | 2900         |
# |    policy_gradient_loss | 0.000449     |
# |    std                  | 1.21         |
# |    value_loss           | 0.498        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 746      |
# |    ep_rew_mean          | 0.163    |
# | time/                   |          |
# |    fps                  | 734      |
# |    iterations           | 47       |
# |    time_elapsed         | 130      |
# |    total_timesteps      | 96256    |
# | train/                  |          |
# |    approx_kl            | 1.071278 |
# |    clip_fraction        | 0.508    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.87    |
# |    explained_variance   | 0.972    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.102    |
# |    n_updates            | 2910     |
# |    policy_gradient_loss | 0.112    |
# |    std                  | 1.23     |
# |    value_loss           | 0.279    |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 48           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0018587278 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.9         |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.15         |
# |    n_updates            | 2920         |
# |    policy_gradient_loss | -0.00434     |
# |    std                  | 1.25         |
# |    value_loss           | 0.151        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 49           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0038332012 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.92        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0655       |
# |    n_updates            | 2930         |
# |    policy_gradient_loss | 0.00145      |
# |    std                  | 1.25         |
# |    value_loss           | 0.126        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | -9.85        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 50           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0018892323 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.92        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0579       |
# |    n_updates            | 2940         |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 1.24         |
# |    value_loss           | 0.0853       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | -9.85        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 51           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0020657866 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | 0.00449      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.4         |
# |    n_updates            | 2950         |
# |    policy_gradient_loss | -0.00152     |
# |    std                  | 1.25         |
# |    value_loss           | 3.25e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 746       |
# |    ep_rew_mean          | -9.85     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 52        |
# |    time_elapsed         | 144       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 2.6410356 |
# |    clip_fraction        | 0.342     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.92     |
# |    explained_variance   | 0.977     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.85      |
# |    n_updates            | 2960      |
# |    policy_gradient_loss | 0.0825    |
# |    std                  | 1.25      |
# |    value_loss           | 68.9      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 746       |
# |    ep_rew_mean          | -9.85     |
# | time/                   |           |
# |    fps                  | 735       |
# |    iterations           | 53        |
# |    time_elapsed         | 147       |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 12.853173 |
# |    clip_fraction        | 0.276     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.92     |
# |    explained_variance   | 0.774     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.67      |
# |    n_updates            | 2970      |
# |    policy_gradient_loss | -0.0214   |
# |    std                  | 1.25      |
# |    value_loss           | 16        |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 746        |
# |    ep_rew_mean          | -9.85      |
# | time/                   |            |
# |    fps                  | 736        |
# |    iterations           | 54         |
# |    time_elapsed         | 150        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.63956916 |
# |    clip_fraction        | 0.22       |
# ...
# |    explained_variance   | 0.843     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.907     |
# |    n_updates            | 4720      |
# |    policy_gradient_loss | 0.0241    |
# |    std                  | 1.69      |
# |    value_loss           | 0.952     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 761      |
# |    ep_rew_mean          | -9.86    |
# | time/                   |          |
# |    fps                  | 735      |
# |    iterations           | 229      |
# |    time_elapsed         | 638      |
# |    total_timesteps      | 468992   |
# | train/                  |          |
# |    approx_kl            | 1.536804 |
# |    clip_fraction        | 0.134    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.83    |
# |    explained_variance   | 0.957    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0978   |
# |    n_updates            | 4730     |
# |    policy_gradient_loss | 0.00456  |
# |    std                  | 1.69     |
# |    value_loss           | 0.261    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 761         |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 230         |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.060179584 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.168       |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | 0.035       |
# |    std                  | 1.68        |
# |    value_loss           | 0.917       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 769          |
# |    ep_rew_mean          | -9.87        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 231          |
# |    time_elapsed         | 643          |
# |    total_timesteps      | 473088       |
# | train/                  |              |
# |    approx_kl            | 0.0036944516 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.8         |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | 0.00158      |
# |    std                  | 1.67         |
# |    value_loss           | 2.84         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | -9.88        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 232          |
# |    time_elapsed         | 646          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0040520127 |
# |    clip_fraction        | 0.0892       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.8         |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.081        |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | 0.0143       |
# |    std                  | 1.68         |
# |    value_loss           | 0.317        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 777        |
# |    ep_rew_mean          | -9.88      |
# | time/                   |            |
# |    fps                  | 735        |
# |    iterations           | 233        |
# |    time_elapsed         | 649        |
# |    total_timesteps      | 477184     |
# | train/                  |            |
# |    approx_kl            | 0.09819512 |
# |    clip_fraction        | 0.288      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.8       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0459     |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | 0.054      |
# |    std                  | 1.68       |
# |    value_loss           | 0.233      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | -9.88        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 234          |
# |    time_elapsed         | 651          |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0022097195 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.79        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000658     |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.000962    |
# |    std                  | 1.66         |
# |    value_loss           | 0.598        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 784         |
# |    ep_rew_mean          | -9.89       |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 235         |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.010022899 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | 0.0128      |
# |    std                  | 1.65        |
# |    value_loss           | 0.723       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 784        |
# |    ep_rew_mean          | -9.89      |
# | time/                   |            |
# |    fps                  | 734        |
# |    iterations           | 236        |
# |    time_elapsed         | 657        |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.21307993 |
# |    clip_fraction        | 0.0575     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.75      |
# |    explained_variance   | 0.704      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.379      |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | 0.0399     |
# |    std                  | 1.64       |
# |    value_loss           | 0.957      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | -9.89        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 237          |
# |    time_elapsed         | 660          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0012820645 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.75        |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.211        |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | 0.0154       |
# |    std                  | 1.65         |
# |    value_loss           | 0.493        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 784      |
# |    ep_rew_mean          | -9.89    |
# | time/                   |          |
# |    fps                  | 734      |
# |    iterations           | 238      |
# |    time_elapsed         | 663      |
# |    total_timesteps      | 487424   |
# | train/                  |          |
# |    approx_kl            | 5.116003 |
# |    clip_fraction        | 0.344    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.74    |
# |    explained_variance   | 0.945    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.144    |
# |    n_updates            | 4820     |
# |    policy_gradient_loss | -0.00492 |
# |    std                  | 1.64     |
# |    value_loss           | 0.325    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 784        |
# |    ep_rew_mean          | -9.89      |
# | time/                   |            |
# |    fps                  | 734        |
# |    iterations           | 239        |
# |    time_elapsed         | 666        |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.95261765 |
# |    clip_fraction        | 0.0527     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.74      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0423     |
# |    n_updates            | 4830       |
# |    policy_gradient_loss | -0.0163    |
# |    std                  | 1.64       |
# |    value_loss           | 0.188      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | -9.89        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 240          |
# |    time_elapsed         | 669          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0022218053 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.74        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0882       |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | 0.000182     |
# |    std                  | 1.64         |
# |    value_loss           | 0.19         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 784         |
# |    ep_rew_mean          | -9.89       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 241         |
# |    time_elapsed         | 671         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.008600259 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0462      |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | 0.00134     |
# |    std                  | 1.63        |
# |    value_loss           | 0.0969      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | -9.89        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 242          |
# |    time_elapsed         | 674          |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0017087087 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0238       |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00516     |
# |    std                  | 1.63         |
# |    value_loss           | 0.0873       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 784        |
# |    ep_rew_mean          | -9.89      |
# | time/                   |            |
# |    fps                  | 734        |
# |    iterations           | 243        |
# |    time_elapsed         | 677        |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.04473128 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.71      |
# |    explained_variance   | 0.853      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.152      |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | 0.0177     |
# |    std                  | 1.63       |
# |    value_loss           | 0.101      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | -9.89        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 244          |
# |    time_elapsed         | 680          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0015672087 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0238       |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00387     |
# |    std                  | 1.63         |
# |    value_loss           | 0.102        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 784        |
# |    ep_rew_mean          | -9.89      |
# | time/                   |            |
# |    fps                  | 734        |
# |    iterations           | 245        |
# |    time_elapsed         | 682        |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.03209825 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.72      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0741     |
# |    n_updates            | 4890       |
# |    policy_gradient_loss | 0.0289     |
# |    std                  | 1.63       |
# |    value_loss           | 0.0888     |
# ----------------------------------------
# --- 684.1702446937561 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-1.85 +/- 44.68

# %%
model.save("zeppelin-v2-1000000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 536      |
# |    ep_rew_mean     | 0.4      |
# | time/              |          |
# |    fps             | 1373     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 668       |
# |    ep_rew_mean          | 0.25      |
# | time/                   |           |
# |    fps                  | 972       |
# |    iterations           | 2         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 14.913584 |
# |    clip_fraction        | 0.23      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.957     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.119     |
# |    n_updates            | 4910      |
# |    policy_gradient_loss | -0.00179  |
# |    std                  | 1.63      |
# |    value_loss           | 0.437     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 701       |
# |    ep_rew_mean          | 0.213     |
# | time/                   |           |
# |    fps                  | 875       |
# |    iterations           | 3         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 24.818333 |
# |    clip_fraction        | 0.526     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.97      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0354    |
# |    n_updates            | 4920      |
# |    policy_gradient_loss | -0.0704   |
# |    std                  | 1.63      |
# |    value_loss           | 0.191     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 728         |
# |    ep_rew_mean          | 0.182       |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.002512747 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | -1.96       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0251      |
# |    n_updates            | 4930        |
# |    policy_gradient_loss | -0.00323    |
# |    std                  | 1.62        |
# |    value_loss           | 0.184       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 739       |
# |    ep_rew_mean          | 0.169     |
# | time/                   |           |
# |    fps                  | 813       |
# |    iterations           | 5         |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 15.296835 |
# |    clip_fraction        | 0.211     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.296     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0303    |
# |    n_updates            | 4940      |
# |    policy_gradient_loss | -0.00924  |
# |    std                  | 1.63      |
# |    value_loss           | 0.0912    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 750       |
# |    ep_rew_mean          | 0.156     |
# | time/                   |           |
# |    fps                  | 800       |
# |    iterations           | 6         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 2.0774274 |
# |    clip_fraction        | 0.174     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.73     |
# |    explained_variance   | 0.342     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00879   |
# |    n_updates            | 4950      |
# |    policy_gradient_loss | -0.000919 |
# |    std                  | 1.64      |
# |    value_loss           | 0.0966    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 756       |
# |    ep_rew_mean          | 0.15      |
# | time/                   |           |
# |    fps                  | 791       |
# |    iterations           | 7         |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 7.6113186 |
# |    clip_fraction        | 0.427     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.74     |
# |    explained_variance   | 0.972     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0153   |
# |    n_updates            | 4960      |
# |    policy_gradient_loss | -0.064    |
# |    std                  | 1.64      |
# |    value_loss           | 0.246     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 762         |
# |    ep_rew_mean          | 0.143       |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.045136455 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.321       |
# |    n_updates            | 4970        |
# |    policy_gradient_loss | 0.015       |
# |    std                  | 1.63        |
# |    value_loss           | 1.46        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 767      |
# |    ep_rew_mean          | 0.138    |
# | time/                   |          |
# |    fps                  | 774      |
# |    iterations           | 9        |
# |    time_elapsed         | 23       |
# |    total_timesteps      | 18432    |
# | train/                  |          |
# |    approx_kl            | 6.239726 |
# |    clip_fraction        | 0.193    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.73    |
# |    explained_variance   | 0.971    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.183    |
# |    n_updates            | 4980     |
# |    policy_gradient_loss | 0.0502   |
# |    std                  | 1.64     |
# |    value_loss           | 0.712    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 742       |
# |    ep_rew_mean          | 0.167     |
# | time/                   |           |
# |    fps                  | 768       |
# |    iterations           | 10        |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 10.254271 |
# |    clip_fraction        | 0.312     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.942     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0509    |
# |    n_updates            | 4990      |
# |    policy_gradient_loss | 0.0166    |
# |    std                  | 1.63      |
# |    value_loss           | 0.36      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 724         |
# |    ep_rew_mean          | 0.187       |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.031041957 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.476       |
# |    n_updates            | 5000        |
# |    policy_gradient_loss | 0.0822      |
# |    std                  | 1.63        |
# |    value_loss           | 0.701       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 0.182       |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.058741968 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 5010        |
# |    policy_gradient_loss | -0.000166   |
# |    std                  | 1.63        |
# |    value_loss           | 0.332       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 735       |
# |    ep_rew_mean          | 0.175     |
# | time/                   |           |
# |    fps                  | 757       |
# |    iterations           | 13        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 10.847673 |
# |    clip_fraction        | 0.435     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.789     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.133     |
# |    n_updates            | 5020      |
# |    policy_gradient_loss | 0.0293    |
# |    std                  | 1.64      |
# |    value_loss           | 0.21      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 738         |
# |    ep_rew_mean          | 0.171       |
# | time/                   |             |
# |    fps                  | 756         |
# |    iterations           | 14          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020572444 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.217       |
# |    n_updates            | 5030        |
# |    policy_gradient_loss | 0.0114      |
# |    std                  | 1.64        |
# |    value_loss           | 0.333       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 743      |
# |    ep_rew_mean          | 0.166    |
# | time/                   |          |
# |    fps                  | 755      |
# |    iterations           | 15       |
# |    time_elapsed         | 40       |
# |    total_timesteps      | 30720    |
# | train/                  |          |
# |    approx_kl            | 6.747206 |
# |    clip_fraction        | 0.335    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.75    |
# |    explained_variance   | 0.837    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.508    |
# |    n_updates            | 5040     |
# |    policy_gradient_loss | 0.262    |
# |    std                  | 1.65     |
# |    value_loss           | 0.32     |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 16           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0015190972 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.75        |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.011        |
# |    n_updates            | 5050         |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 1.64         |
# |    value_loss           | 0.044        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 749       |
# |    ep_rew_mean          | 0.159     |
# | time/                   |           |
# |    fps                  | 752       |
# |    iterations           | 17        |
# |    time_elapsed         | 46        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.5051574 |
# |    clip_fraction        | 0.108     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.73     |
# |    explained_variance   | -0.159    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.56      |
# |    n_updates            | 5060      |
# |    policy_gradient_loss | 0.0267    |
# |    std                  | 1.64      |
# |    value_loss           | 1.29      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 752          |
# |    ep_rew_mean          | 0.155        |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 18           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0019527682 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.807        |
# |    n_updates            | 5070         |
# |    policy_gradient_loss | 0.0103       |
# |    std                  | 1.63         |
# |    value_loss           | 0.792        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 19          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004373635 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.571       |
# |    n_updates            | 5080        |
# |    policy_gradient_loss | -0.00157    |
# |    std                  | 1.63        |
# |    value_loss           | 1.13        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 757          |
# |    ep_rew_mean          | 0.15         |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 20           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0016046201 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.635        |
# |    n_updates            | 5090         |
# |    policy_gradient_loss | -0.000611    |
# |    std                  | 1.63         |
# |    value_loss           | 1.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 0.148        |
# | time/                   |              |
# |    fps                  | 751          |
# |    iterations           | 21           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0012512312 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.617        |
# |    n_updates            | 5100         |
# |    policy_gradient_loss | 0.00192      |
# |    std                  | 1.63         |
# |    value_loss           | 1.56         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 760         |
# |    ep_rew_mean          | 0.146       |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 22          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019870522 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.581       |
# |    n_updates            | 5110        |
# |    policy_gradient_loss | 0.00844     |
# |    std                  | 1.63        |
# |    value_loss           | 0.808       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 762         |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 23          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008294902 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.547       |
# |    n_updates            | 5120        |
# |    policy_gradient_loss | 0.0064      |
# |    std                  | 1.63        |
# |    value_loss           | 1.27        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 752          |
# |    ep_rew_mean          | 0.155        |
# | time/                   |              |
# |    fps                  | 751          |
# |    iterations           | 24           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0032858746 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.47         |
# |    n_updates            | 5130         |
# |    policy_gradient_loss | 0.00111      |
# |    std                  | 1.63         |
# |    value_loss           | 0.798        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 753       |
# |    ep_rew_mean          | 0.154     |
# | time/                   |           |
# |    fps                  | 750       |
# |    iterations           | 25        |
# |    time_elapsed         | 68        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 28.639706 |
# |    clip_fraction        | 0.431     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.71     |
# |    explained_variance   | 0.92      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0635    |
# |    n_updates            | 5140      |
# |    policy_gradient_loss | 0.122     |
# |    std                  | 1.61      |
# |    value_loss           | 0.244     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 0.151        |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 26           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0014771825 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0678       |
# |    n_updates            | 5150         |
# |    policy_gradient_loss | -0.00231     |
# |    std                  | 1.61         |
# |    value_loss           | 0.154        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 757         |
# |    ep_rew_mean          | 0.149       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 27          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006427752 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0454      |
# |    n_updates            | 5160        |
# |    policy_gradient_loss | 0.00826     |
# |    std                  | 1.62        |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 0.148        |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 28           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0032747062 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.917        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.151        |
# |    n_updates            | 5170         |
# |    policy_gradient_loss | 0.00526      |
# |    std                  | 1.61         |
# |    value_loss           | 0.168        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 751       |
# |    ep_rew_mean          | 0.157     |
# | time/                   |           |
# |    fps                  | 747       |
# |    iterations           | 29        |
# |    time_elapsed         | 79        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 26.752163 |
# |    clip_fraction        | 0.333     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.7      |
# |    explained_variance   | 0.945     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.177     |
# |    n_updates            | 5180      |
# |    policy_gradient_loss | 0.225     |
# |    std                  | 1.62      |
# |    value_loss           | 0.0914    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 752      |
# |    ep_rew_mean          | 0.156    |
# | time/                   |          |
# |    fps                  | 746      |
# |    iterations           | 30       |
# |    time_elapsed         | 82       |
# |    total_timesteps      | 61440    |
# | train/                  |          |
# |    approx_kl            | 2.218648 |
# |    clip_fraction        | 0.197    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.72    |
# |    explained_variance   | 0.943    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.208    |
# |    n_updates            | 5190     |
# |    policy_gradient_loss | 0.108    |
# |    std                  | 1.63     |
# |    value_loss           | 0.207    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 745         |
# |    ep_rew_mean          | 0.164       |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 31          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014807231 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.053       |
# |    n_updates            | 5200        |
# |    policy_gradient_loss | 0.0664      |
# |    std                  | 1.62        |
# |    value_loss           | 0.128       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 746        |
# |    ep_rew_mean          | 0.162      |
# | time/                   |            |
# |    fps                  | 746        |
# |    iterations           | 32         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.08453466 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.71      |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.076      |
# |    n_updates            | 5210       |
# |    policy_gradient_loss | 0.0502     |
# |    std                  | 1.62       |
# |    value_loss           | 0.259      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | 0.16        |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 33          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.043139666 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.5         |
# |    n_updates            | 5220        |
# |    policy_gradient_loss | 0.0677      |
# |    std                  | 1.62        |
# |    value_loss           | 0.564       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | 0.159       |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 34          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.033463866 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0548      |
# |    n_updates            | 5230        |
# |    policy_gradient_loss | 0.00848     |
# |    std                  | 1.62        |
# |    value_loss           | 0.26        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 751       |
# |    ep_rew_mean          | 0.157     |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 35        |
# |    time_elapsed         | 96        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 224.45294 |
# |    clip_fraction        | 0.158     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.7      |
# |    explained_variance   | 0.918     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.405     |
# |    n_updates            | 5240      |
# |    policy_gradient_loss | 0.00746   |
# |    std                  | 1.62      |
# |    value_loss           | 0.364     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 745      |
# |    ep_rew_mean          | 0.164    |
# | time/                   |          |
# |    fps                  | 744      |
# |    iterations           | 36       |
# |    time_elapsed         | 99       |
# |    total_timesteps      | 73728    |
# | train/                  |          |
# |    approx_kl            | 28.57375 |
# |    clip_fraction        | 0.137    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.7     |
# |    explained_variance   | 0.742    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.639    |
# |    n_updates            | 5250     |
# |    policy_gradient_loss | 0.00908  |
# |    std                  | 1.61     |
# |    value_loss           | 0.934    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 745       |
# |    ep_rew_mean          | 0.163     |
# | time/                   |           |
# |    fps                  | 742       |
# |    iterations           | 37        |
# |    time_elapsed         | 102       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 2.3371553 |
# |    clip_fraction        | 0.211     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.7      |
# |    explained_variance   | -0.365    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.285     |
# |    n_updates            | 5260      |
# |    policy_gradient_loss | 0.039     |
# |    std                  | 1.62      |
# |    value_loss           | 1.99      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 737         |
# |    ep_rew_mean          | 0.172       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 38          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.059743147 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.346       |
# |    n_updates            | 5270        |
# |    policy_gradient_loss | 0.076       |
# |    std                  | 1.62        |
# |    value_loss           | 0.85        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 737          |
# |    ep_rew_mean          | 0.172        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 39           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0045758416 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.144        |
# |    n_updates            | 5280         |
# |    policy_gradient_loss | 0.0201       |
# |    std                  | 1.62         |
# |    value_loss           | 0.193        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 737       |
# |    ep_rew_mean          | 0.172     |
# | time/                   |           |
# |    fps                  | 742       |
# |    iterations           | 40        |
# |    time_elapsed         | 110       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 24.483677 |
# |    clip_fraction        | 0.364     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.71     |
# |    explained_variance   | 0.795     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0605    |
# |    n_updates            | 5290      |
# |    policy_gradient_loss | 0.0423    |
# |    std                  | 1.62      |
# |    value_loss           | 0.302     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 737       |
# |    ep_rew_mean          | 0.172     |
# | time/                   |           |
# |    fps                  | 742       |
# |    iterations           | 41        |
# |    time_elapsed         | 113       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 22.816257 |
# |    clip_fraction        | 0.512     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.775     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0114   |
# |    n_updates            | 5300      |
# |    policy_gradient_loss | -0.029    |
# |    std                  | 1.63      |
# |    value_loss           | 0.133     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 737          |
# |    ep_rew_mean          | 0.172        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 42           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0025893184 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0399       |
# |    n_updates            | 5310         |
# |    policy_gradient_loss | -0.000774    |
# |    std                  | 1.62         |
# |    value_loss           | 0.12         |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 737      |
# |    ep_rew_mean          | 0.172    |
# | time/                   |          |
# |    fps                  | 743      |
# |    iterations           | 43       |
# |    time_elapsed         | 118      |
# |    total_timesteps      | 88064    |
# | train/                  |          |
# |    approx_kl            | 56.45488 |
# |    clip_fraction        | 0.355    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.69    |
# |    explained_variance   | 0.879    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.189    |
# |    n_updates            | 5320     |
# |    policy_gradient_loss | 0.0564   |
# |    std                  | 1.61     |
# |    value_loss           | 0.438    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 737      |
# |    ep_rew_mean          | 0.172    |
# | time/                   |          |
# |    fps                  | 743      |
# |    iterations           | 44       |
# |    time_elapsed         | 121      |
# |    total_timesteps      | 90112    |
# | train/                  |          |
# |    approx_kl            | 5.587176 |
# |    clip_fraction        | 0.484    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.68    |
# |    explained_variance   | 0.951    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 5.98     |
# |    n_updates            | 5330     |
# |    policy_gradient_loss | 0.0435   |
# |    std                  | 1.61     |
# |    value_loss           | 0.287    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 737       |
# |    ep_rew_mean          | 0.172     |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 45        |
# |    time_elapsed         | 123       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 3.8253393 |
# |    clip_fraction        | 0.197     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.68     |
# |    explained_variance   | 0.917     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.124     |
# |    n_updates            | 5340      |
# |    policy_gradient_loss | 0.0105    |
# |    std                  | 1.6       |
# |    value_loss           | 0.695     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 745       |
# |    ep_rew_mean          | 0.163     |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 46        |
# |    time_elapsed         | 126       |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 33.139553 |
# |    clip_fraction        | 0.723     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.68     |
# |    explained_variance   | 0.681     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0507    |
# |    n_updates            | 5350      |
# |    policy_gradient_loss | 0.0551    |
# |    std                  | 1.61      |
# |    value_loss           | 0.906     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 753      |
# |    ep_rew_mean          | 0.154    |
# | time/                   |          |
# |    fps                  | 744      |
# |    iterations           | 47       |
# |    time_elapsed         | 129      |
# |    total_timesteps      | 96256    |
# | train/                  |          |
# |    approx_kl            | 12.39196 |
# |    clip_fraction        | 0.53     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.67    |
# |    explained_variance   | 0.969    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.188    |
# |    n_updates            | 5360     |
# |    policy_gradient_loss | -0.0277  |
# |    std                  | 1.6      |
# |    value_loss           | 0.405    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 753       |
# |    ep_rew_mean          | 0.154     |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 48        |
# |    time_elapsed         | 132       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 2.8014166 |
# |    clip_fraction        | 0.434     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.66     |
# |    explained_variance   | 0.857     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.173     |
# |    n_updates            | 5370      |
# |    policy_gradient_loss | 0.109     |
# |    std                  | 1.6       |
# |    value_loss           | 0.393     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | 0.154        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 49           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0010426048 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00472      |
# |    n_updates            | 5380         |
# |    policy_gradient_loss | 0.000875     |
# |    std                  | 1.59         |
# |    value_loss           | 0.219        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 50          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.024538163 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00845     |
# |    n_updates            | 5390        |
# |    policy_gradient_loss | 0.0239      |
# |    std                  | 1.59        |
# |    value_loss           | 0.155       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 753       |
# |    ep_rew_mean          | 0.154     |
# | time/                   |           |
# |    fps                  | 742       |
# |    iterations           | 51        |
# |    time_elapsed         | 140       |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 17.519855 |
# |    clip_fraction        | 0.416     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.65     |
# |    explained_variance   | 0.96      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0288   |
# |    n_updates            | 5400      |
# |    policy_gradient_loss | -0.0381   |
# |    std                  | 1.59      |
# |    value_loss           | 0.0661    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 753      |
# |    ep_rew_mean          | 0.154    |
# | time/                   |          |
# |    fps                  | 742      |
# |    iterations           | 52       |
# |    time_elapsed         | 143      |
# |    total_timesteps      | 106496   |
# | train/                  |          |
# |    approx_kl            | 8.207424 |
# |    clip_fraction        | 0.358    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.65    |
# |    explained_variance   | 0.898    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.255    |
# |    n_updates            | 5410     |
# |    policy_gradient_loss | -0.0123  |
# |    std                  | 1.59     |
# |    value_loss           | 0.372    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 753      |
# |    ep_rew_mean          | 0.154    |
# | time/                   |          |
# |    fps                  | 742      |
# |    iterations           | 53       |
# |    time_elapsed         | 146      |
# |    total_timesteps      | 108544   |
# | train/                  |          |
# |    approx_kl            | 4.116228 |
# |    clip_fraction        | 0.226    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.65    |
# |    explained_variance   | 0.958    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0328  |
# |    n_updates            | 5420     |
# |    policy_gradient_loss | -0.0243  |
# |    std                  | 1.6      |
# |    value_loss           | 0.726    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 753       |
# |    ep_rew_mean          | 0.154     |
# | time/                   |           |
# |    fps                  | 742       |
# |    iterations           | 54        |
# |    time_elapsed         | 149       |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 1614.7349 |
# |    clip_fraction        | 0.599     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.65     |
# |    explained_variance   | 0.971     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.129     |
# |    n_updates            | 5430      |
# |    policy_gradient_loss | 0.0266    |
# |    std                  | 1.59      |
# ...
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.74        |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0136       |
# |    n_updates            | 7170         |
# |    policy_gradient_loss | -0.00235     |
# |    std                  | 1.65         |
# |    value_loss           | 0.216        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 792          |
# |    ep_rew_mean          | -9.9         |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 229          |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 0.0052239886 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.74        |
# |    explained_variance   | 0.685        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.426        |
# |    n_updates            | 7180         |
# |    policy_gradient_loss | 0.0048       |
# |    std                  | 1.64         |
# |    value_loss           | 0.317        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | -19.9        |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 230          |
# |    time_elapsed         | 642          |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 0.0036204641 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.74        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.209        |
# |    n_updates            | 7190         |
# |    policy_gradient_loss | 0.00519      |
# |    std                  | 1.65         |
# |    value_loss           | 0.335        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 784         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 231         |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.018749489 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.00622     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.1e+03     |
# |    n_updates            | 7200        |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 1.65        |
# |    value_loss           | 2.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 784         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 232         |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.021448668 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.142       |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | 0.00559     |
# |    std                  | 1.65        |
# |    value_loss           | 5.92        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 769      |
# |    ep_rew_mean          | -19.9    |
# | time/                   |          |
# |    fps                  | 733      |
# |    iterations           | 233      |
# |    time_elapsed         | 650      |
# |    total_timesteps      | 477184   |
# | train/                  |          |
# |    approx_kl            | 6.857025 |
# |    clip_fraction        | 0.214    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.74    |
# |    explained_variance   | 0.898    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.511    |
# |    n_updates            | 7220     |
# |    policy_gradient_loss | 0.0936   |
# |    std                  | 1.65     |
# |    value_loss           | 1.52     |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 769        |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 733        |
# |    iterations           | 234        |
# |    time_elapsed         | 653        |
# |    total_timesteps      | 479232     |
# | train/                  |            |
# |    approx_kl            | 0.06351787 |
# |    clip_fraction        | 0.0789     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.72      |
# |    explained_variance   | 0.68       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.43       |
# |    n_updates            | 7230       |
# |    policy_gradient_loss | -0.00382   |
# |    std                  | 1.63       |
# |    value_loss           | 3.5        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 753       |
# |    ep_rew_mean          | -29.9     |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 235       |
# |    time_elapsed         | 656       |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 0.1892975 |
# |    clip_fraction        | 0.0372    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.71     |
# |    explained_variance   | 0.671     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.561     |
# |    n_updates            | 7240      |
# |    policy_gradient_loss | 0.0145    |
# |    std                  | 1.64      |
# |    value_loss           | 1.62      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 236         |
# |    time_elapsed         | 659         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.011457146 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.0756      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.38e+03    |
# |    n_updates            | 7250        |
# |    policy_gradient_loss | 0.00243     |
# |    std                  | 1.64        |
# |    value_loss           | 1.67e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 237         |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.000874864 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.325       |
# |    n_updates            | 7260        |
# |    policy_gradient_loss | -0.00232    |
# |    std                  | 1.64        |
# |    value_loss           | 2.39        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | -29.9        |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 238          |
# |    time_elapsed         | 664          |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0018391333 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | -0.115       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.873        |
# |    n_updates            | 7270         |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 1.64         |
# |    value_loss           | 4.39         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 745       |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 239       |
# |    time_elapsed         | 667       |
# |    total_timesteps      | 489472    |
# | train/                  |           |
# |    approx_kl            | 3.2011216 |
# |    clip_fraction        | 0.126     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.71     |
# |    explained_variance   | 0.579     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.909     |
# |    n_updates            | 7280      |
# |    policy_gradient_loss | 0.0247    |
# |    std                  | 1.63      |
# |    value_loss           | 3.6       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | -39.9        |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 240          |
# |    time_elapsed         | 670          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0005800555 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.0913       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3            |
# |    n_updates            | 7290         |
# |    policy_gradient_loss | 0.00204      |
# |    std                  | 1.63         |
# |    value_loss           | 1.12e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 745       |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 241       |
# |    time_elapsed         | 672       |
# |    total_timesteps      | 493568    |
# | train/                  |           |
# |    approx_kl            | 30.710552 |
# |    clip_fraction        | 0.423     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.7      |
# |    explained_variance   | 0.976     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.499     |
# |    n_updates            | 7300      |
# |    policy_gradient_loss | 0.326     |
# |    std                  | 1.63      |
# |    value_loss           | 2.45      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 745      |
# |    ep_rew_mean          | -39.9    |
# | time/                   |          |
# |    fps                  | 733      |
# |    iterations           | 242      |
# |    time_elapsed         | 675      |
# |    total_timesteps      | 495616   |
# | train/                  |          |
# |    approx_kl            | 3.787235 |
# |    clip_fraction        | 0.383    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.72    |
# |    explained_variance   | 0.965    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.291    |
# |    n_updates            | 7310     |
# |    policy_gradient_loss | 0.093    |
# |    std                  | 1.65     |
# |    value_loss           | 1.88     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 745       |
# |    ep_rew_mean          | -39.9     |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 243       |
# |    time_elapsed         | 678       |
# |    total_timesteps      | 497664    |
# | train/                  |           |
# |    approx_kl            | 0.0207777 |
# |    clip_fraction        | 0.05      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.73     |
# |    explained_variance   | 0.962     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.209     |
# |    n_updates            | 7320      |
# |    policy_gradient_loss | 0.0025    |
# |    std                  | 1.64      |
# |    value_loss           | 0.773     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 745        |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 733        |
# |    iterations           | 244        |
# |    time_elapsed         | 681        |
# |    total_timesteps      | 499712     |
# | train/                  |            |
# |    approx_kl            | 0.04880701 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.75      |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.223      |
# |    n_updates            | 7330       |
# |    policy_gradient_loss | 0.0954     |
# |    std                  | 1.66       |
# |    value_loss           | 1.95       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | -39.9        |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 245          |
# |    time_elapsed         | 684          |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0005810184 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.77        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 7340         |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 1.66         |
# |    value_loss           | 2.66         |
# ------------------------------------------
# --- 685.3655922412872 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-35.86 +/- 186.32

# %%
model.save("zeppelin-v2-1500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 534      |
# |    ep_rew_mean     | -333     |
# | time/              |          |
# |    fps             | 1278     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 575         |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.028475234 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0925      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.276       |
# |    n_updates            | 7360        |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 1.65        |
# |    value_loss           | 860         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 625      |
# |    ep_rew_mean          | -111     |
# | time/                   |          |
# |    fps                  | 868      |
# |    iterations           | 3        |
# |    time_elapsed         | 7        |
# |    total_timesteps      | 6144     |
# | train/                  |          |
# |    approx_kl            | 1.887318 |
# |    clip_fraction        | 0.116    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.75    |
# |    explained_variance   | 0.92     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0303   |
# |    n_updates            | 7370     |
# |    policy_gradient_loss | -0.0117  |
# |    std                  | 1.65     |
# |    value_loss           | 0.575    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 669       |
# |    ep_rew_mean          | -83.2     |
# | time/                   |           |
# |    fps                  | 834       |
# |    iterations           | 4         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.4633434 |
# |    clip_fraction        | 0.0731    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.73     |
# |    explained_variance   | 0.904     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0101    |
# |    n_updates            | 7380      |
# |    policy_gradient_loss | 0.000324  |
# |    std                  | 1.63      |
# |    value_loss           | 0.299     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 643         |
# |    ep_rew_mean          | -66.5       |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.024274755 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.215       |
# |    n_updates            | 7390        |
# |    policy_gradient_loss | 0.0282      |
# |    std                  | 1.61        |
# |    value_loss           | 0.832       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 634           |
# |    ep_rew_mean          | -52.4         |
# | time/                   |               |
# |    fps                  | 797           |
# |    iterations           | 6             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00053429324 |
# |    clip_fraction        | 0.00396       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.68         |
# |    explained_variance   | 0.913         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.18          |
# |    n_updates            | 7400          |
# |    policy_gradient_loss | -0.00238      |
# |    std                  | 1.61          |
# |    value_loss           | 1.88          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 650         |
# |    ep_rew_mean          | -47.4       |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016599137 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.0404      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.699       |
# |    n_updates            | 7410        |
# |    policy_gradient_loss | 0.00631     |
# |    std                  | 1.61        |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 669           |
# |    ep_rew_mean          | -41.5         |
# | time/                   |               |
# |    fps                  | 780           |
# |    iterations           | 8             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00048169133 |
# |    clip_fraction        | 0.00425       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.68         |
# |    explained_variance   | -1.35         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.751         |
# |    n_updates            | 7420          |
# |    policy_gradient_loss | -0.00295      |
# |    std                  | 1.61          |
# |    value_loss           | 0.907         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 679          |
# |    ep_rew_mean          | -38.3        |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 9            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0034718276 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.161        |
# |    n_updates            | 7430         |
# |    policy_gradient_loss | 0.00396      |
# |    std                  | 1.61         |
# |    value_loss           | 0.437        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 692         |
# |    ep_rew_mean          | -34.3       |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.025719948 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.165       |
# |    n_updates            | 7440        |
# |    policy_gradient_loss | 0.073       |
# |    std                  | 1.62        |
# |    value_loss           | 0.583       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 702       |
# |    ep_rew_mean          | -31.1     |
# | time/                   |           |
# |    fps                  | 769       |
# |    iterations           | 11        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 2.3767686 |
# |    clip_fraction        | 0.288     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.7      |
# |    explained_variance   | 0.974     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.123     |
# |    n_updates            | 7450      |
# |    policy_gradient_loss | 0.0491    |
# |    std                  | 1.63      |
# |    value_loss           | 0.566     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 707         |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012498954 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0594      |
# |    n_updates            | 7460        |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 1.6         |
# |    value_loss           | 0.287       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 715          |
# |    ep_rew_mean          | -26.9        |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 13           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0014638834 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0962       |
# |    n_updates            | 7470         |
# |    policy_gradient_loss | -0.00213     |
# |    std                  | 1.61         |
# |    value_loss           | 0.164        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 719      |
# |    ep_rew_mean          | -25.5    |
# | time/                   |          |
# |    fps                  | 763      |
# |    iterations           | 14       |
# |    time_elapsed         | 37       |
# |    total_timesteps      | 28672    |
# | train/                  |          |
# |    approx_kl            | 9.772688 |
# |    clip_fraction        | 0.393    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.68    |
# |    explained_variance   | 0.67     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.367    |
# |    n_updates            | 7480     |
# |    policy_gradient_loss | 0.137    |
# |    std                  | 1.61     |
# |    value_loss           | 0.879    |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | -23.6        |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 15           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0005119152 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.336        |
# |    n_updates            | 7490         |
# |    policy_gradient_loss | 0.00424      |
# |    std                  | 1.61         |
# |    value_loss           | 0.934        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 713      |
# |    ep_rew_mean          | -22      |
# | time/                   |          |
# |    fps                  | 760      |
# |    iterations           | 16       |
# |    time_elapsed         | 43       |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 2.988133 |
# |    clip_fraction        | 0.219    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.68    |
# |    explained_variance   | 0.742    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0139   |
# |    n_updates            | 7500     |
# |    policy_gradient_loss | -0.00184 |
# |    std                  | 1.61     |
# |    value_loss           | 0.313    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 718       |
# |    ep_rew_mean          | -20.7     |
# | time/                   |           |
# |    fps                  | 761       |
# |    iterations           | 17        |
# |    time_elapsed         | 45        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 1.2596939 |
# |    clip_fraction        | 0.445     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.976     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0979    |
# |    n_updates            | 7510      |
# |    policy_gradient_loss | 0.0679    |
# |    std                  | 1.65      |
# |    value_loss           | 0.206     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 721         |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 18          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007882738 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0583      |
# |    n_updates            | 7520        |
# |    policy_gradient_loss | 0.0015      |
# |    std                  | 1.65        |
# |    value_loss           | 0.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 726          |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 761          |
# |    iterations           | 19           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0046503143 |
# |    clip_fraction        | 0.0543       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.74        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.156        |
# |    n_updates            | 7530         |
# |    policy_gradient_loss | 0.00788      |
# |    std                  | 1.64         |
# |    value_loss           | 0.944        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 730          |
# |    ep_rew_mean          | -17.7        |
# | time/                   |              |
# |    fps                  | 761          |
# |    iterations           | 20           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0064677997 |
# |    clip_fraction        | 0.0839       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.74        |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0406       |
# |    n_updates            | 7540         |
# |    policy_gradient_loss | 0.00815      |
# |    std                  | 1.65         |
# |    value_loss           | 0.137        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 732       |
# |    ep_rew_mean          | -17.1     |
# | time/                   |           |
# |    fps                  | 760       |
# |    iterations           | 21        |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 182.51062 |
# |    clip_fraction        | 0.532     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.73     |
# |    explained_variance   | 0.881     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.095     |
# |    n_updates            | 7550      |
# |    policy_gradient_loss | 0.0422    |
# |    std                  | 1.64      |
# |    value_loss           | 0.352     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 736          |
# |    ep_rew_mean          | -16.2        |
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 22           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0010844736 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.184        |
# |    n_updates            | 7560         |
# |    policy_gradient_loss | -0.00408     |
# |    std                  | 1.64         |
# |    value_loss           | 0.286        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 738        |
# |    ep_rew_mean          | -15.7      |
# | time/                   |            |
# |    fps                  | 758        |
# |    iterations           | 23         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.04036727 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.71      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0516     |
# |    n_updates            | 7570       |
# |    policy_gradient_loss | 0.0364     |
# |    std                  | 1.61       |
# |    value_loss           | 0.139      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 741      |
# |    ep_rew_mean          | -15      |
# | time/                   |          |
# |    fps                  | 758      |
# |    iterations           | 24       |
# |    time_elapsed         | 64       |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 7.371233 |
# |    clip_fraction        | 0.165    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.7     |
# |    explained_variance   | 0.861    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.042    |
# |    n_updates            | 7580     |
# |    policy_gradient_loss | 0.00948  |
# |    std                  | 1.63     |
# |    value_loss           | 0.0801   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 742       |
# |    ep_rew_mean          | -14.6     |
# | time/                   |           |
# |    fps                  | 756       |
# |    iterations           | 25        |
# |    time_elapsed         | 67        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 11.095167 |
# |    clip_fraction        | 0.255     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.7      |
# |    explained_variance   | 0.629     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0167    |
# |    n_updates            | 7590      |
# |    policy_gradient_loss | 0.0202    |
# |    std                  | 1.62      |
# |    value_loss           | 0.182     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | -13.9        |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 26           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0011980174 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | -0.361       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0571       |
# |    n_updates            | 7600         |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 1.62         |
# |    value_loss           | 0.924        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 747       |
# |    ep_rew_mean          | -13.4     |
# | time/                   |           |
# |    fps                  | 756       |
# |    iterations           | 27        |
# |    time_elapsed         | 73        |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.5557341 |
# |    clip_fraction        | 0.158     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.69     |
# |    explained_variance   | 0.28      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.11      |
# |    n_updates            | 7610      |
# |    policy_gradient_loss | 0.0525    |
# |    std                  | 1.62      |
# |    value_loss           | 0.309     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 748        |
# |    ep_rew_mean          | -13        |
# | time/                   |            |
# |    fps                  | 756        |
# |    iterations           | 28         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.41917783 |
# |    clip_fraction        | 0.055      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.68      |
# |    explained_variance   | -0.984     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.228      |
# |    n_updates            | 7620       |
# |    policy_gradient_loss | 0.0158     |
# |    std                  | 1.61       |
# |    value_loss           | 0.458      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 750         |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 756         |
# |    iterations           | 29          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.060160898 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 7630        |
# |    policy_gradient_loss | 0.027       |
# |    std                  | 1.61        |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 752         |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 30          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010030983 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.064       |
# |    n_updates            | 7640        |
# |    policy_gradient_loss | 0.0723      |
# |    std                  | 1.61        |
# |    value_loss           | 0.274       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 753      |
# |    ep_rew_mean          | -11.8    |
# | time/                   |          |
# |    fps                  | 751      |
# |    iterations           | 31       |
# |    time_elapsed         | 84       |
# |    total_timesteps      | 63488    |
# | train/                  |          |
# |    approx_kl            | 0.550563 |
# |    clip_fraction        | 0.0666   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.7     |
# |    explained_variance   | -0.605   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0124   |
# |    n_updates            | 7650     |
# |    policy_gradient_loss | 0.0607   |
# |    std                  | 1.63     |
# |    value_loss           | 0.285    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 754       |
# |    ep_rew_mean          | -11.5     |
# | time/                   |           |
# |    fps                  | 751       |
# |    iterations           | 32        |
# |    time_elapsed         | 87        |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 6.0633593 |
# |    clip_fraction        | 0.226     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | -0.0535   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0295    |
# |    n_updates            | 7660      |
# |    policy_gradient_loss | 0.0386    |
# |    std                  | 1.64      |
# |    value_loss           | 0.669     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 756         |
# |    ep_rew_mean          | -11.1       |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 33          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010176012 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | -0.556      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 7670        |
# |    policy_gradient_loss | -0.000282   |
# |    std                  | 1.64        |
# |    value_loss           | 1.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | -10.7       |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 34          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018317653 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | -0.314      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.47        |
# |    n_updates            | 7680        |
# |    policy_gradient_loss | 0.0102      |
# |    std                  | 1.65        |
# |    value_loss           | 0.891       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 751         |
# |    ep_rew_mean          | -10.4       |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 35          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008773232 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.482       |
# |    n_updates            | 7690        |
# |    policy_gradient_loss | 0.0179      |
# |    std                  | 1.65        |
# |    value_loss           | 0.808       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 752          |
# |    ep_rew_mean          | -10.1        |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 36           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0040330985 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.75        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.295        |
# |    n_updates            | 7700         |
# |    policy_gradient_loss | 0.000953     |
# |    std                  | 1.65         |
# |    value_loss           | 0.445        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 753        |
# |    ep_rew_mean          | -9.86      |
# | time/                   |            |
# |    fps                  | 749        |
# |    iterations           | 37         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.11548875 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.74      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0498     |
# |    n_updates            | 7710       |
# |    policy_gradient_loss | 0.0359     |
# |    std                  | 1.65       |
# |    value_loss           | 0.112      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 38          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009877485 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | -1.99       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 7720        |
# |    policy_gradient_loss | -0.00335    |
# |    std                  | 1.65        |
# |    value_loss           | 0.393       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 39          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009170217 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.00109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39        |
# |    n_updates            | 7730        |
# |    policy_gradient_loss | -0.000194   |
# |    std                  | 1.65        |
# |    value_loss           | 2.8e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 40          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.027931083 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.34        |
# |    n_updates            | 7740        |
# |    policy_gradient_loss | -0.000378   |
# |    std                  | 1.64        |
# |    value_loss           | 1.53        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 753      |
# |    ep_rew_mean          | -19.9    |
# | time/                   |          |
# |    fps                  | 748      |
# |    iterations           | 41       |
# |    time_elapsed         | 112      |
# |    total_timesteps      | 83968    |
# | train/                  |          |
# |    approx_kl            | 27.48621 |
# |    clip_fraction        | 0.405    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.72    |
# |    explained_variance   | 0.23     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 8.33     |
# |    n_updates            | 7750     |
# |    policy_gradient_loss | 0.0241   |
# |    std                  | 1.64     |
# |    value_loss           | 2.62e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 761         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 42          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011422796 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.09        |
# |    n_updates            | 7760        |
# |    policy_gradient_loss | 0.0234      |
# |    std                  | 1.64        |
# |    value_loss           | 9.35        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 761        |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 747        |
# |    iterations           | 43         |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.33474937 |
# |    clip_fraction        | 0.0482     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.72      |
# |    explained_variance   | 0.28       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.06       |
# |    n_updates            | 7770       |
# |    policy_gradient_loss | -0.00548   |
# |    std                  | 1.64       |
# |    value_loss           | 8.06       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 769         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 44          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.058777407 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 7780        |
# |    policy_gradient_loss | 0.0292      |
# |    std                  | 1.64        |
# |    value_loss           | 3.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 769         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 45          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006646959 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0619      |
# |    n_updates            | 7790        |
# |    policy_gradient_loss | 0.00159     |
# |    std                  | 1.64        |
# |    value_loss           | 2.02        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 769      |
# |    ep_rew_mean          | -19.9    |
# | time/                   |          |
# |    fps                  | 746      |
# |    iterations           | 46       |
# |    time_elapsed         | 126      |
# |    total_timesteps      | 94208    |
# | train/                  |          |
# |    approx_kl            | 32.69012 |
# |    clip_fraction        | 0.325    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.72    |
# |    explained_variance   | 0.839    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.19     |
# |    n_updates            | 7800     |
# |    policy_gradient_loss | 0.0892   |
# |    std                  | 1.64     |
# |    value_loss           | 2.14     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 769      |
# |    ep_rew_mean          | -19.9    |
# | time/                   |          |
# |    fps                  | 746      |
# |    iterations           | 47       |
# |    time_elapsed         | 128      |
# |    total_timesteps      | 96256    |
# | train/                  |          |
# |    approx_kl            | 2.450588 |
# |    clip_fraction        | 0.258    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.72    |
# |    explained_variance   | 0.963    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.769    |
# |    n_updates            | 7810     |
# |    policy_gradient_loss | -0.00524 |
# |    std                  | 1.64     |
# |    value_loss           | 2.18     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 769       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 745       |
# |    iterations           | 48        |
# |    time_elapsed         | 131       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 176.17133 |
# |    clip_fraction        | 0.88      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.72     |
# |    explained_variance   | 0.845     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.278     |
# |    n_updates            | 7820      |
# |    policy_gradient_loss | 0.182     |
# |    std                  | 1.65      |
# |    value_loss           | 0.668     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 761         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 49          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.060834844 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 7830        |
# |    policy_gradient_loss | 0.0195      |
# |    std                  | 1.65        |
# |    value_loss           | 1.88        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 761       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 745       |
# |    iterations           | 50        |
# |    time_elapsed         | 137       |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 3.2545414 |
# |    clip_fraction        | 0.317     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.74     |
# |    explained_variance   | 0.217     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.167     |
# |    n_updates            | 7840      |
# |    policy_gradient_loss | 0.0573    |
# |    std                  | 1.66      |
# |    value_loss           | 3.03      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 761        |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 743        |
# |    iterations           | 51         |
# |    time_elapsed         | 140        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.26928627 |
# |    clip_fraction        | 0.524      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.75      |
# |    explained_variance   | 0.151      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.972      |
# |    n_updates            | 7850       |
# |    policy_gradient_loss | 0.0861     |
# |    std                  | 1.66       |
# |    value_loss           | 1.13       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 753       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 52        |
# |    time_elapsed         | 143       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 35.265415 |
# |    clip_fraction        | 0.502     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.76     |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.28      |
# |    n_updates            | 7860      |
# |    policy_gradient_loss | 0.101     |
# |    std                  | 1.67      |
# |    value_loss           | 2.82      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 761       |
# |    ep_rew_mean          | -19.9     |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 53        |
# |    time_elapsed         | 145       |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 39.831493 |
# |    clip_fraction        | 0.348     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.77     |
# |    explained_variance   | -0.159    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.777     |
# |    n_updates            | 7870      |
# |    policy_gradient_loss | 0.0468    |
# |    std                  | 1.66      |
# |    value_loss           | 1.6       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 761        |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 744        |
# |    iterations           | 54         |
# |    time_elapsed         | 148        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.11888153 |
# ...
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.56        |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04         |
# |    n_updates            | 12060        |
# |    policy_gradient_loss | 0.00333      |
# |    std                  | 1.57         |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 642        |
# |    ep_rew_mean          | -170       |
# | time/                   |            |
# |    fps                  | 720        |
# |    iterations           | 473        |
# |    time_elapsed         | 1343       |
# |    total_timesteps      | 968704     |
# | train/                  |            |
# |    approx_kl            | 0.02121364 |
# |    clip_fraction        | 0.0388     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.54      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.775      |
# |    n_updates            | 12070      |
# |    policy_gradient_loss | 0.00983    |
# |    std                  | 1.55       |
# |    value_loss           | 7.39       |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 627           |
# |    ep_rew_mean          | -190          |
# | time/                   |               |
# |    fps                  | 720           |
# |    iterations           | 474           |
# |    time_elapsed         | 1346          |
# |    total_timesteps      | 970752        |
# | train/                  |               |
# |    approx_kl            | 0.00041269642 |
# |    clip_fraction        | 0.0149        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.52         |
# |    explained_variance   | 0.826         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.528         |
# |    n_updates            | 12080         |
# |    policy_gradient_loss | 0.0017        |
# |    std                  | 1.54          |
# |    value_loss           | 7.04          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 627          |
# |    ep_rew_mean          | -190         |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 475          |
# |    time_elapsed         | 1349         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0009829944 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.354        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 772          |
# |    n_updates            | 12090        |
# |    policy_gradient_loss | -0.0051      |
# |    std                  | 1.54         |
# |    value_loss           | 2.95e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 627         |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 476         |
# |    time_elapsed         | 1352        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.002625452 |
# |    clip_fraction        | 0.01        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.83        |
# |    n_updates            | 12100       |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 1.54        |
# |    value_loss           | 158         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 627       |
# |    ep_rew_mean          | -190      |
# | time/                   |           |
# |    fps                  | 720       |
# |    iterations           | 477       |
# |    time_elapsed         | 1354      |
# |    total_timesteps      | 976896    |
# | train/                  |           |
# |    approx_kl            | 10.671125 |
# |    clip_fraction        | 0.333     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.5      |
# |    explained_variance   | 0.764     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.96      |
# |    n_updates            | 12110     |
# |    policy_gradient_loss | 0.203     |
# |    std                  | 1.54      |
# |    value_loss           | 581       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 627         |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 478         |
# |    time_elapsed         | 1357        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.037276506 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.91        |
# |    n_updates            | 12120       |
# |    policy_gradient_loss | 0.00614     |
# |    std                  | 1.53        |
# |    value_loss           | 29.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 642         |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 479         |
# |    time_elapsed         | 1360        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.017027782 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 12130       |
# |    policy_gradient_loss | 0.0158      |
# |    std                  | 1.54        |
# |    value_loss           | 116         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 642          |
# |    ep_rew_mean          | -170         |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 480          |
# |    time_elapsed         | 1363         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0014980165 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.5         |
# |    n_updates            | 12140        |
# |    policy_gradient_loss | -7.49e-05    |
# |    std                  | 1.52         |
# |    value_loss           | 99.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 650         |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 481         |
# |    time_elapsed         | 1366        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.027020074 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.222       |
# |    n_updates            | 12150       |
# |    policy_gradient_loss | 0.00211     |
# |    std                  | 1.51        |
# |    value_loss           | 7.01        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 650       |
# |    ep_rew_mean          | -150      |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 482       |
# |    time_elapsed         | 1369      |
# |    total_timesteps      | 987136    |
# | train/                  |           |
# |    approx_kl            | 2.0477066 |
# |    clip_fraction        | 0.188     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.45     |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.35      |
# |    n_updates            | 12160     |
# |    policy_gradient_loss | 0.187     |
# |    std                  | 1.51      |
# |    value_loss           | 58.1      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 651        |
# |    ep_rew_mean          | -140       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 483        |
# |    time_elapsed         | 1371       |
# |    total_timesteps      | 989184     |
# | train/                  |            |
# |    approx_kl            | 0.18760478 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.45      |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.1       |
# |    n_updates            | 12170      |
# |    policy_gradient_loss | 0.00275    |
# |    std                  | 1.51       |
# |    value_loss           | 64.5       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 651      |
# |    ep_rew_mean          | -140     |
# | time/                   |          |
# |    fps                  | 721      |
# |    iterations           | 484      |
# |    time_elapsed         | 1374     |
# |    total_timesteps      | 991232   |
# | train/                  |          |
# |    approx_kl            | 327.5802 |
# |    clip_fraction        | 0.389    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.44    |
# |    explained_variance   | 0.918    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 18.9     |
# |    n_updates            | 12180    |
# |    policy_gradient_loss | 0.286    |
# |    std                  | 1.51     |
# |    value_loss           | 90.5     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 643       |
# |    ep_rew_mean          | -150      |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 485       |
# |    time_elapsed         | 1377      |
# |    total_timesteps      | 993280    |
# | train/                  |           |
# |    approx_kl            | 0.5109992 |
# |    clip_fraction        | 0.0573    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.45     |
# |    explained_variance   | 0.521     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.7       |
# |    n_updates            | 12190     |
# |    policy_gradient_loss | 0.0142    |
# |    std                  | 1.51      |
# |    value_loss           | 14.7      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 651          |
# |    ep_rew_mean          | -140         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 486          |
# |    time_elapsed         | 1380         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0018584254 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.46        |
# |    explained_variance   | 0.0421       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.89         |
# |    n_updates            | 12200        |
# |    policy_gradient_loss | 0.00148      |
# |    std                  | 1.51         |
# |    value_loss           | 2.27e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 658         |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 487         |
# |    time_elapsed         | 1383        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.049054995 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 12210       |
# |    policy_gradient_loss | 0.06        |
# |    std                  | 1.51        |
# |    value_loss           | 19.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 658       |
# |    ep_rew_mean          | -130      |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 488       |
# |    time_elapsed         | 1385      |
# |    total_timesteps      | 999424    |
# | train/                  |           |
# |    approx_kl            | 118.23126 |
# |    clip_fraction        | 0.309     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.45     |
# |    explained_variance   | 0.983     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 13.5      |
# |    n_updates            | 12220     |
# |    policy_gradient_loss | 0.336     |
# |    std                  | 1.51      |
# |    value_loss           | 25.1      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 651      |
# |    ep_rew_mean          | -130     |
# | time/                   |          |
# |    fps                  | 721      |
# |    iterations           | 489      |
# |    time_elapsed         | 1388     |
# |    total_timesteps      | 1001472  |
# | train/                  |          |
# |    approx_kl            | 39.30333 |
# |    clip_fraction        | 0.083    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.45    |
# |    explained_variance   | 0.966    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 16.1     |
# |    n_updates            | 12230    |
# |    policy_gradient_loss | 0.248    |
# |    std                  | 1.51     |
# |    value_loss           | 26.8     |
# --------------------------------------
# --- 1389.8266339302063 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-133.87 +/- 340.70

# %%
model.save("zeppelin-v2-2500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    fps             | 1338     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 576         |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004321849 |
# |    clip_fraction        | 0.00737     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.324       |
# |    n_updates            | 12250       |
# |    policy_gradient_loss | -0.00107    |
# |    std                  | 1.52        |
# |    value_loss           | 2.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 566         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 857         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.022089742 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.7        |
# |    n_updates            | 12260       |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 1.53        |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 577         |
# |    ep_rew_mean          | -214        |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003076924 |
# |    clip_fraction        | 0.0216      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 12270       |
# |    policy_gradient_loss | 0.000707    |
# |    std                  | 1.53        |
# |    value_loss           | 1.63e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | -187         |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 5            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0027770349 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.49        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.25         |
# |    n_updates            | 12280        |
# |    policy_gradient_loss | -0.000873    |
# |    std                  | 1.52         |
# |    value_loss           | 445          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 604         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.002115351 |
# |    clip_fraction        | 0.00786     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | -3.25       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.298       |
# |    n_updates            | 12290       |
# |    policy_gradient_loss | 0.000781    |
# |    std                  | 1.53        |
# |    value_loss           | 23.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 595         |
# |    ep_rew_mean          | -217        |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.047039717 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 12300       |
# |    policy_gradient_loss | 0.0379      |
# |    std                  | 1.53        |
# |    value_loss           | 985         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 619        |
# |    ep_rew_mean          | -192       |
# | time/                   |            |
# |    fps                  | 761        |
# |    iterations           | 8          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.04592082 |
# |    clip_fraction        | 0.014      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.5       |
# |    explained_variance   | -0.143     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.2       |
# |    n_updates            | 12310      |
# |    policy_gradient_loss | 0.0129     |
# |    std                  | 1.54       |
# |    value_loss           | 2.99e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 632       |
# |    ep_rew_mean          | -178      |
# | time/                   |           |
# |    fps                  | 754       |
# |    iterations           | 9         |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 2.2814102 |
# |    clip_fraction        | 0.14      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.5      |
# |    explained_variance   | 0.805     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.19      |
# |    n_updates            | 12320     |
# |    policy_gradient_loss | 0.129     |
# |    std                  | 1.54      |
# |    value_loss           | 33.9      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 648       |
# |    ep_rew_mean          | -161      |
# | time/                   |           |
# |    fps                  | 751       |
# |    iterations           | 10        |
# |    time_elapsed         | 27        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 1.7629335 |
# |    clip_fraction        | 0.215     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.51     |
# |    explained_variance   | -0.104    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 24.2      |
# |    n_updates            | 12330     |
# |    policy_gradient_loss | 0.105     |
# |    std                  | 1.54      |
# |    value_loss           | 25.3      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 661         |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 11          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017868806 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18        |
# |    n_updates            | 12340       |
# |    policy_gradient_loss | 0.00798     |
# |    std                  | 1.52        |
# |    value_loss           | 3.68        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 635          |
# |    ep_rew_mean          | -158         |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 12           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0066529643 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 12350        |
# |    policy_gradient_loss | -0.000243    |
# |    std                  | 1.53         |
# |    value_loss           | 4.82         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 632        |
# |    ep_rew_mean          | -143       |
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 13         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.18785392 |
# |    clip_fraction        | 0.0754     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.49      |
# |    explained_variance   | -0.0277    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.9       |
# |    n_updates            | 12360      |
# |    policy_gradient_loss | 0.0265     |
# |    std                  | 1.53       |
# |    value_loss           | 484        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 640         |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 14          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006480732 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.716       |
# |    n_updates            | 12370       |
# |    policy_gradient_loss | 0.0114      |
# |    std                  | 1.53        |
# |    value_loss           | 3.05        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 637        |
# |    ep_rew_mean          | -125       |
# | time/                   |            |
# |    fps                  | 735        |
# |    iterations           | 15         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.16489571 |
# |    clip_fraction        | 0.0287     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.49      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.118      |
# |    n_updates            | 12380      |
# |    policy_gradient_loss | 0.0136     |
# |    std                  | 1.53       |
# |    value_loss           | 0.472      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 643       |
# |    ep_rew_mean          | -120      |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 16        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.3712942 |
# |    clip_fraction        | 0.0813    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.49     |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.76      |
# |    n_updates            | 12390     |
# |    policy_gradient_loss | 0.0639    |
# |    std                  | 1.53      |
# |    value_loss           | 4.81      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 652         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 17          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.040642142 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2           |
# |    n_updates            | 12400       |
# |    policy_gradient_loss | 0.0601      |
# |    std                  | 1.53        |
# |    value_loss           | 4.91        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 646          |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 18           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0033978675 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.49        |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.38         |
# |    n_updates            | 12410        |
# |    policy_gradient_loss | 0.00203      |
# |    std                  | 1.53         |
# |    value_loss           | 0.989        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 633        |
# |    ep_rew_mean          | -131       |
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 19         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.10260865 |
# |    clip_fraction        | 0.0274     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.49      |
# |    explained_variance   | 0.0241     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.37       |
# |    n_updates            | 12420      |
# |    policy_gradient_loss | 0.0112     |
# |    std                  | 1.53       |
# |    value_loss           | 2.95e+03   |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 629      |
# |    ep_rew_mean          | -140     |
# | time/                   |          |
# |    fps                  | 725      |
# |    iterations           | 20       |
# |    time_elapsed         | 56       |
# |    total_timesteps      | 40960    |
# | train/                  |          |
# |    approx_kl            | 5.587037 |
# |    clip_fraction        | 0.149    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.5     |
# |    explained_variance   | 0.13     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 477      |
# |    n_updates            | 12430    |
# |    policy_gradient_loss | 0.0379   |
# |    std                  | 1.53     |
# |    value_loss           | 3.04e+03 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 593        |
# |    ep_rew_mean          | -194       |
# | time/                   |            |
# |    fps                  | 725        |
# |    iterations           | 21         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.39113533 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.5       |
# |    explained_variance   | 0.53       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 394        |
# |    n_updates            | 12440      |
# |    policy_gradient_loss | 0.0579     |
# |    std                  | 1.53       |
# |    value_loss           | 1.05e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 599         |
# |    ep_rew_mean          | -189        |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 22          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.002985306 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98e+03    |
# |    n_updates            | 12450       |
# |    policy_gradient_loss | -0.00493    |
# |    std                  | 1.53        |
# |    value_loss           | 7.23e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 607          |
# |    ep_rew_mean          | -182         |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 23           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0012253636 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.8         |
# |    n_updates            | 12460        |
# |    policy_gradient_loss | 0.00155      |
# |    std                  | 1.54         |
# |    value_loss           | 12.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 614          |
# |    ep_rew_mean          | -175         |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 24           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0017626442 |
# |    clip_fraction        | 0.00347      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.52        |
# |    explained_variance   | -3.52        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.2         |
# |    n_updates            | 12470        |
# |    policy_gradient_loss | 0.000349     |
# |    std                  | 1.54         |
# |    value_loss           | 218          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 597          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 25           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0030530817 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.52        |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.16         |
# |    n_updates            | 12480        |
# |    policy_gradient_loss | 1.14e-05     |
# |    std                  | 1.54         |
# |    value_loss           | 43.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | -193         |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 26           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024035147 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.7         |
# |    n_updates            | 12490        |
# |    policy_gradient_loss | 2.9e-05      |
# |    std                  | 1.54         |
# |    value_loss           | 4.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 609          |
# |    ep_rew_mean          | -189         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 27           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0017545138 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | -0.117       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.4         |
# |    n_updates            | 12500        |
# |    policy_gradient_loss | 0.00107      |
# |    std                  | 1.54         |
# |    value_loss           | 153          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 596           |
# |    ep_rew_mean          | -198          |
# | time/                   |               |
# |    fps                  | 724           |
# |    iterations           | 28            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00081286876 |
# |    clip_fraction        | 0.00542       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.51         |
# |    explained_variance   | -1.93         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.81          |
# |    n_updates            | 12510         |
# |    policy_gradient_loss | -0.00254      |
# |    std                  | 1.53          |
# |    value_loss           | 90.6          |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 594       |
# |    ep_rew_mean          | -202      |
# | time/                   |           |
# |    fps                  | 722       |
# |    iterations           | 29        |
# |    time_elapsed         | 82        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.4260637 |
# |    clip_fraction        | 0.311     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.5      |
# |    explained_variance   | 0.738     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 10.6      |
# |    n_updates            | 12520     |
# |    policy_gradient_loss | 0.144     |
# |    std                  | 1.54      |
# |    value_loss           | 1.7e+03   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 30          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013217968 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 12530       |
# |    policy_gradient_loss | 0.00788     |
# |    std                  | 1.54        |
# |    value_loss           | 885         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 31           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0032175477 |
# |    clip_fraction        | 0.00444      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.982        |
# |    n_updates            | 12540        |
# |    policy_gradient_loss | 0.00262      |
# |    std                  | 1.55         |
# |    value_loss           | 23.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 604         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 32          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.088527836 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | -0.0784     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.307       |
# |    n_updates            | 12550       |
# |    policy_gradient_loss | 0.018       |
# |    std                  | 1.55        |
# |    value_loss           | 37.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 612         |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 33          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004150441 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.8        |
# |    n_updates            | 12560       |
# |    policy_gradient_loss | 0.00511     |
# |    std                  | 1.55        |
# |    value_loss           | 566         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | -210        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 34          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.029698897 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 12570       |
# |    policy_gradient_loss | 0.0288      |
# |    std                  | 1.55        |
# |    value_loss           | 165         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 596          |
# |    ep_rew_mean          | -210         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 35           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0015126598 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.52         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 537          |
# |    n_updates            | 12580        |
# |    policy_gradient_loss | 0.000662     |
# |    std                  | 1.55         |
# |    value_loss           | 4.47e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 604         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 36          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.001230335 |
# |    clip_fraction        | 0.00527     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | -0.124      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 12590       |
# |    policy_gradient_loss | -0.00499    |
# |    std                  | 1.55        |
# |    value_loss           | 105         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 605        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 37         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.12784806 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.52      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.83       |
# |    n_updates            | 12600      |
# |    policy_gradient_loss | 0.0215     |
# |    std                  | 1.54       |
# |    value_loss           | 87.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 597         |
# |    ep_rew_mean          | -210        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 38          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007568871 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 12610       |
# |    policy_gradient_loss | 0.00356     |
# |    std                  | 1.54        |
# |    value_loss           | 2.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 581         |
# |    ep_rew_mean          | -230        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 39          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010755039 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+03    |
# |    n_updates            | 12620       |
# |    policy_gradient_loss | 0.00372     |
# |    std                  | 1.53        |
# |    value_loss           | 2.48e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 581          |
# |    ep_rew_mean          | -230         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 40           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0012234675 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 414          |
# |    n_updates            | 12630        |
# |    policy_gradient_loss | -0.00368     |
# |    std                  | 1.54         |
# |    value_loss           | 1.9e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 589         |
# |    ep_rew_mean          | -230        |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 41          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010403077 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.39        |
# |    n_updates            | 12640       |
# |    policy_gradient_loss | 0.00972     |
# |    std                  | 1.53        |
# |    value_loss           | 244         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 589         |
# |    ep_rew_mean          | -230        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 42          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.036388338 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.76e+03    |
# |    n_updates            | 12650       |
# |    policy_gradient_loss | 0.0211      |
# |    std                  | 1.54        |
# |    value_loss           | 775         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 589          |
# |    ep_rew_mean          | -240         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 43           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0007066404 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | -0.69        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01         |
# |    n_updates            | 12660        |
# |    policy_gradient_loss | 0.00671      |
# |    std                  | 1.54         |
# |    value_loss           | 34.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 588        |
# |    ep_rew_mean          | -250       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 44         |
# |    time_elapsed         | 124        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.10750246 |
# |    clip_fraction        | 0.0725     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.51      |
# |    explained_variance   | 0.233      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.59e+03   |
# |    n_updates            | 12670      |
# |    policy_gradient_loss | 0.0136     |
# |    std                  | 1.55       |
# |    value_loss           | 1.75e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 588          |
# |    ep_rew_mean          | -250         |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 45           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0015483083 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51         |
# |    n_updates            | 12680        |
# |    policy_gradient_loss | -0.00235     |
# |    std                  | 1.55         |
# |    value_loss           | 905          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 588        |
# |    ep_rew_mean          | -250       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 46         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.43803474 |
# |    clip_fraction        | 0.0704     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.53      |
# |    explained_variance   | -0.581     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.9       |
# |    n_updates            | 12690      |
# |    policy_gradient_loss | 0.00229    |
# |    std                  | 1.55       |
# |    value_loss           | 66.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 596        |
# |    ep_rew_mean          | -240       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 47         |
# |    time_elapsed         | 133        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.04398364 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.53      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14         |
# |    n_updates            | 12700      |
# |    policy_gradient_loss | 0.0807     |
# |    std                  | 1.55       |
# |    value_loss           | 93.3       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 589       |
# |    ep_rew_mean          | -250      |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 48        |
# |    time_elapsed         | 136       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 24.054548 |
# |    clip_fraction        | 0.372     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.53     |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.59      |
# |    n_updates            | 12710     |
# |    policy_gradient_loss | 0.36      |
# |    std                  | 1.56      |
# |    value_loss           | 29.1      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | -240        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 49          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.069901586 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.39        |
# |    n_updates            | 12720       |
# |    policy_gradient_loss | 9.77e-05    |
# |    std                  | 1.56        |
# |    value_loss           | 787         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | -230         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 50           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0034208144 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.52        |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95         |
# |    n_updates            | 12730        |
# |    policy_gradient_loss | 0.0081       |
# |    std                  | 1.54         |
# |    value_loss           | 14.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 612          |
# |    ep_rew_mean          | -220         |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 51           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0011155666 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 12740        |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 1.55         |
# |    value_loss           | 1.58e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | -230         |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 52           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0012485043 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.61         |
# |    n_updates            | 12750        |
# |    policy_gradient_loss | -0.00173     |
# |    std                  | 1.54         |
# |    value_loss           | 2.1e+03      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 604        |
# |    ep_rew_mean          | -230       |
# | time/                   |            |
# |    fps                  | 722        |
# |    iterations           | 53         |
# |    time_elapsed         | 150        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.31574827 |
# |    clip_fraction        | 0.0796     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.5       |
# |    explained_variance   | 0.744      |
# ...
# |    entropy_loss         | -5.45        |
# |    explained_variance   | 0.608        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.33e+03     |
# |    n_updates            | 13220        |
# |    policy_gradient_loss | -0.00297     |
# |    std                  | 1.51         |
# |    value_loss           | 2.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 533          |
# |    ep_rew_mean          | -290         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 100          |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0066557033 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.45        |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01         |
# |    n_updates            | 13230        |
# |    policy_gradient_loss | -0.00826     |
# |    std                  | 1.51         |
# |    value_loss           | 1.4e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 533         |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 101         |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 206848      |
# | train/                  |             |
# |    approx_kl            | 0.048617467 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.93e+03    |
# |    n_updates            | 13240       |
# |    policy_gradient_loss | 0.00515     |
# |    std                  | 1.51        |
# |    value_loss           | 945         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 541          |
# |    ep_rew_mean          | -280         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 102          |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0017918834 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.45        |
# |    explained_variance   | -0.194       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25         |
# |    n_updates            | 13250        |
# |    policy_gradient_loss | 0.00117      |
# |    std                  | 1.51         |
# |    value_loss           | 163          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 548          |
# |    ep_rew_mean          | -290         |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 103          |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 210944       |
# | train/                  |              |
# |    approx_kl            | 0.0067249173 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.45        |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+03      |
# |    n_updates            | 13260        |
# |    policy_gradient_loss | 0.00121      |
# |    std                  | 1.51         |
# |    value_loss           | 1.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 556          |
# |    ep_rew_mean          | -270         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 104          |
# |    time_elapsed         | 295          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0047642444 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.43        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.9          |
# |    n_updates            | 13270        |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 1.49         |
# |    value_loss           | 157          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 556       |
# |    ep_rew_mean          | -270      |
# | time/                   |           |
# |    fps                  | 721       |
# |    iterations           | 105       |
# |    time_elapsed         | 298       |
# |    total_timesteps      | 215040    |
# | train/                  |           |
# |    approx_kl            | 1.5003941 |
# |    clip_fraction        | 0.0747    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.41     |
# |    explained_variance   | -7.05     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.95      |
# |    n_updates            | 13280     |
# |    policy_gradient_loss | 0.0013    |
# |    std                  | 1.49      |
# |    value_loss           | 166       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 556         |
# |    ep_rew_mean          | -260        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 106         |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.008504877 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | -1.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.565       |
# |    n_updates            | 13290       |
# |    policy_gradient_loss | 0.00958     |
# |    std                  | 1.48        |
# |    value_loss           | 32.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 107         |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 219136      |
# | train/                  |             |
# |    approx_kl            | 0.014263814 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 196         |
# |    n_updates            | 13300       |
# |    policy_gradient_loss | 0.00717     |
# |    std                  | 1.47        |
# |    value_loss           | 473         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 572      |
# |    ep_rew_mean          | -240     |
# | time/                   |          |
# |    fps                  | 721      |
# |    iterations           | 108      |
# |    time_elapsed         | 306      |
# |    total_timesteps      | 221184   |
# | train/                  |          |
# |    approx_kl            | 5.374856 |
# |    clip_fraction        | 0.123    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.39    |
# |    explained_variance   | 0.466    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.67e+03 |
# |    n_updates            | 13310    |
# |    policy_gradient_loss | 0.0722   |
# |    std                  | 1.47     |
# |    value_loss           | 2.13e+03 |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 564      |
# |    ep_rew_mean          | -260     |
# | time/                   |          |
# |    fps                  | 721      |
# |    iterations           | 109      |
# |    time_elapsed         | 309      |
# |    total_timesteps      | 223232   |
# | train/                  |          |
# |    approx_kl            | 1.735586 |
# |    clip_fraction        | 0.361    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.39    |
# |    explained_variance   | 0.961    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 13.7     |
# |    n_updates            | 13320    |
# |    policy_gradient_loss | 0.305    |
# |    std                  | 1.48     |
# |    value_loss           | 50.2     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 564      |
# |    ep_rew_mean          | -260     |
# | time/                   |          |
# |    fps                  | 721      |
# |    iterations           | 110      |
# |    time_elapsed         | 312      |
# |    total_timesteps      | 225280   |
# | train/                  |          |
# |    approx_kl            | 41.12026 |
# |    clip_fraction        | 0.379    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.41    |
# |    explained_variance   | 0.896    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.75e+03 |
# |    n_updates            | 13330    |
# |    policy_gradient_loss | 0.232    |
# |    std                  | 1.49     |
# |    value_loss           | 4.24e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | -270        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 111         |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 227328      |
# | train/                  |             |
# |    approx_kl            | 0.009495417 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 13340       |
# |    policy_gradient_loss | -0.00206    |
# |    std                  | 1.48        |
# |    value_loss           | 22.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 572          |
# |    ep_rew_mean          | -260         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 112          |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0049327924 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.4         |
# |    explained_variance   | 0.343        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38e+03     |
# |    n_updates            | 13350        |
# |    policy_gradient_loss | 0.0032       |
# |    std                  | 1.48         |
# |    value_loss           | 2.56e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 580        |
# |    ep_rew_mean          | -250       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 113        |
# |    time_elapsed         | 320        |
# |    total_timesteps      | 231424     |
# | train/                  |            |
# |    approx_kl            | 0.46238422 |
# |    clip_fraction        | 0.0755     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.4       |
# |    explained_variance   | 0.802      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.05       |
# |    n_updates            | 13360      |
# |    policy_gradient_loss | 0.00857    |
# |    std                  | 1.48       |
# |    value_loss           | 8.77       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 580         |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 114         |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.009386678 |
# |    clip_fraction        | 0.00962     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | -0.00256    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74        |
# |    n_updates            | 13370       |
# |    policy_gradient_loss | 0.0127      |
# |    std                  | 1.48        |
# |    value_loss           | 51.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 564          |
# |    ep_rew_mean          | -260         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 115          |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0011210664 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.00326      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 397          |
# |    n_updates            | 13380        |
# |    policy_gradient_loss | 0.00368      |
# |    std                  | 1.48         |
# |    value_loss           | 2.58e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 556         |
# |    ep_rew_mean          | -260        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 116         |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.006717829 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 13390       |
# |    policy_gradient_loss | 0.0117      |
# |    std                  | 1.48        |
# |    value_loss           | 295         |
# -----------------------------------------

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2-3500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2-4500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2-5500000")

# %% [markdown]
# Above ran while tab was closed...

# %%
model = PPO.load("zeppelin-v2-5500000")
model.set_env(env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-161.87 +/- 368.51

# %%
model = PPO.load("zeppelin-v2-400000")
model.set_env(env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-5.84 +/- 77.24

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-6500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1500000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1500000")
model.set_env(env)

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1600000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1700000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1800000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=1000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=4000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
print("hi")
for i_episode in range(5):
    observation = env.reset()
    env.unwrapped.state=[-5,110,50,22]
    total_reward=0
    for t in range(1000):
        action, _states = model.predict(observation)
        #x1_norm = observation[0]/np.sqrt(observation[0]**2+observation[1]**2)
        #x2_norm = observation[1]/np.sqrt(observation[0]**2+observation[1]**2)
        #f = 1.0 if (x2_norm) < 0 else -1.0
        #action = [f, f*(0-x1_norm)]
        observation, reward, done, info = env.step(action)
        print(observation)
        total_reward=0.99*total_reward+reward
        env.render()
        time.sleep(0.5)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            time.sleep(5.0)
            break
env.close()

# %%
env.close()

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-100000-0.5")
model.set_env(env)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
#env.init_polytopes(0.0,retrain_polytopes_certain)
for i_episode in range(10):
    observation = env.reset()
    observation = env.unwrapped.state
    total_reward=0
    for t in range(1000):
        #print(observation)
        x1,x2,c,w,g1,g2 = observation
        #action = [0.,0.,1.0]
        action, _states = model.predict(observation,deterministic=True)
        #print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        observation, reward, done, info = env.step(action)
        #assert reward >= 0, f"reward: {reward}"
        total_reward=0.99*total_reward+reward
        #env.render()
        if done:
            print(observation)
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            break
env.close()
