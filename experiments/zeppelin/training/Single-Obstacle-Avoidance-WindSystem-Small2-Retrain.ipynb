# %% [markdown]
# # Retraining after first attempt to prove correct
# **Important note:**
# In the process of initiating the retraining we found a bug in the environment:
# Essentially, the area which now turned out to be buggy has not been trained on originally as it never occurred in the training samples due to a buggy bounds check (mixup between obstacle size `c` and wind speed `w` in `is_in_bounds`

# %%
import gym
import time

# %%
import pickle
import numpy as np
import polytope as pc

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import torch
from torch import nn

# %%
import zeppelin_gym.env3

# %%
torch.manual_seed(42)

# %%
env = gym.make('zeppelin-v3')
# Out:
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/gym/logger.py:34: UserWarning: WARN: Environment '<class 'zeppelin_gym.env3.ZeppelinEnv'>' has deprecated methods '_step' and '_reset' rather than 'step' and 'reset'. Compatibility code invoked. Set _gym_disable_underscore_compat = True to disable this behavior.
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
env.unwrapped.FUEL_RESTRAINT = False
env.unwrapped.OBSTACLE_REWARD = -1000.
env.unwrapped.NO_FUEL_REWARD = 0.
# done reward = (FUEL_RESTRAINT) ? r+fuel*r : 2*r
env.unwrapped.DONE_REWARD = 0.5
env.unwrapped.TIME_STEP_REWARD = 0.
env.unwrapped.INCLUDE_UNWINNABLE = False

# %%
env.seed(42)
# Out:
# [42]

# %%
retrain_polytopes = None
with open("zeppelin-small2-polytopes.pickle","rb") as f:
    retrain_polytopes = pickle.load(f)

# %%
poly_region = pc.Region(retrain_polytopes)
poly_region.contains(np.array([[72.],[131.],[80.],[30.]]),abs_tol=20)
# Out:
# array([False])

# %%
# Total volume of polytopes?
# Share of instances usually (i.e. without "focus polytopes")

# Volume of state space:
N = 100000
n=4
l_b = np.array([env.unwrapped.MIN_X,env.unwrapped.MIN_Y,env.unwrapped.MIN_C,env.unwrapped.MAX_VELOCITY-env.unwrapped.MAX_TURBULENCE+0.1])
u_b = np.array([env.unwrapped.MAX_X,env.unwrapped.MAX_Y,env.unwrapped.MAX_C,env.unwrapped.MAX_WIND_SPEED])
xs = env.unwrapped.np_random.uniform(low=l_b,high=u_b,size=(N,n))
s = 0
for x in xs:
    if not env.unwrapped.is_crash(x) and not env.unwrapped.reached_goal(x) and env.unwrapped.is_in_bounds(x):
        s+=1
print("s: ",s)
total_vol = np.prod(u_b - l_b) * (s / N)
print("total volume: ", total_vol)

poly_region = pc.Region(retrain_polytopes)
l_b, u_b = poly_region.bounding_box
l_b = l_b.flatten()
u_b = u_b.flatten()
print(l_b,",",u_b)
xs = env.unwrapped.np_random.uniform(low=l_b,high=u_b,size=(N,n))
s = 0
for x in xs:
    if x in poly_region:
        if not env.unwrapped.is_crash(x) and not env.unwrapped.reached_goal(x) and env.unwrapped.is_in_bounds(x):
                s+=1
poly_vol = np.prod(u_b - l_b) * (s / N)
print("poly volume: ", poly_vol)

# We only have an upper bound for the share, since polytopes may be partially outside the state space of interest
poly_share = poly_vol/total_vol
print("max share: ", poly_share)
# Out:
# s:  4512
# total volume:  50332262.4
# [-268.98618  -97.5       10.         5.     ] , [400. 400.  80.  30.]
# poly volume:  16197547.64683712
# max share:  0.32181242953301303

# %%
eval_episode_length=30000
training_episode_length=100000

# %%
env.seed(42)
torch.manual_seed(42)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

env.init_polytopes(1.0,[])
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# mean_reward:0.97 +/- 5.78

# %%
env.init_polytopes(0.0,retrain_polytopes)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.03 +/- 31.11

# %%
results_overall = {}
results_polys = {}

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    env.unwrapped.INCLUDE_UNWINNABLE = False
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-100000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.21     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 365      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.027606804 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.121       |
# |    explained_variance   | 0.000141    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0304      |
# |    n_updates            | 6870        |
# |    policy_gradient_loss | 0.0078      |
# |    std                  | 0.228       |
# |    value_loss           | 978         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.028665677 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.116       |
# |    explained_variance   | 0.00142     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0446      |
# |    n_updates            | 6880        |
# |    policy_gradient_loss | 0.00609     |
# |    std                  | 0.229       |
# |    value_loss           | 977         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015294209 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.105       |
# |    explained_variance   | -182        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000866   |
# |    n_updates            | 6890        |
# |    policy_gradient_loss | 0.00924     |
# |    std                  | 0.23        |
# |    value_loss           | 0.0568      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018092182 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.116       |
# |    explained_variance   | -88.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00672    |
# |    n_updates            | 6900        |
# |    policy_gradient_loss | 0.00568     |
# |    std                  | 0.228       |
# |    value_loss           | 0.031       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 6           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020622402 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.12        |
# |    explained_variance   | -46.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0227      |
# |    n_updates            | 6910        |
# |    policy_gradient_loss | 0.00553     |
# |    std                  | 0.229       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 7           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019429766 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.113       |
# |    explained_variance   | -36.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0261     |
# |    n_updates            | 6920        |
# |    policy_gradient_loss | 0.00464     |
# |    std                  | 0.23        |
# |    value_loss           | 0.00867     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.31       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 288        |
# |    iterations           | 8          |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02411413 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0951     |
# |    explained_variance   | 0.00112    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00725   |
# |    n_updates            | 6930       |
# |    policy_gradient_loss | 0.00782    |
# |    std                  | 0.233      |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 9           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.035275333 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0661      |
# |    explained_variance   | -39.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0313      |
# |    n_updates            | 6940        |
# |    policy_gradient_loss | 0.00226     |
# |    std                  | 0.236       |
# |    value_loss           | 0.00623     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 10          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017511778 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0491      |
# |    explained_variance   | -27.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.011      |
# |    n_updates            | 6950        |
# |    policy_gradient_loss | 0.00383     |
# |    std                  | 0.237       |
# |    value_loss           | 0.00545     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.1        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 286        |
# |    iterations           | 11         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02297163 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0456     |
# |    explained_variance   | 0.00217    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0218     |
# |    n_updates            | 6960       |
# |    policy_gradient_loss | 0.00489    |
# |    std                  | 0.238      |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 12          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025246033 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0424      |
# |    explained_variance   | 0.0022      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 6970        |
# |    policy_gradient_loss | 0.00366     |
# |    std                  | 0.238       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 13          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.029489912 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0478      |
# |    explained_variance   | 0.00126     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00375    |
# |    n_updates            | 6980        |
# |    policy_gradient_loss | 0.00463     |
# |    std                  | 0.237       |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 14          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.026763227 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0683      |
# |    explained_variance   | -121        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0506      |
# |    n_updates            | 6990        |
# |    policy_gradient_loss | 0.00808     |
# |    std                  | 0.233       |
# |    value_loss           | 0.0603      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 15          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018519795 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0913      |
# |    explained_variance   | -43.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0464      |
# |    n_updates            | 7000        |
# |    policy_gradient_loss | 0.00504     |
# |    std                  | 0.231       |
# |    value_loss           | 0.0182      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 16          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018526781 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.105       |
# |    explained_variance   | -43.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00276     |
# |    n_updates            | 7010        |
# |    policy_gradient_loss | 0.00576     |
# |    std                  | 0.23        |
# |    value_loss           | 0.0159      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 17          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015670424 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.115       |
# |    explained_variance   | -38.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0117      |
# |    n_updates            | 7020        |
# |    policy_gradient_loss | 0.00345     |
# |    std                  | 0.228       |
# |    value_loss           | 0.00704     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | -9.01      |
# | time/                   |            |
# |    fps                  | 281        |
# |    iterations           | 18         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02199512 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.118      |
# |    explained_variance   | 0.00269    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0233     |
# |    n_updates            | 7030       |
# |    policy_gradient_loss | 0.004      |
# |    std                  | 0.229      |
# |    value_loss           | 974        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 19          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014576544 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.104       |
# |    explained_variance   | 0.0049      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85e+03    |
# |    n_updates            | 7040        |
# |    policy_gradient_loss | 0.00858     |
# |    std                  | 0.231       |
# |    value_loss           | 1.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 20          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020620484 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0967      |
# |    explained_variance   | 0.00664     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.027       |
# |    n_updates            | 7050        |
# |    policy_gradient_loss | 0.00687     |
# |    std                  | 0.231       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 21          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.019931287 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0782      |
# |    explained_variance   | -68.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 7060        |
# |    policy_gradient_loss | 0.00357     |
# |    std                  | 0.235       |
# |    value_loss           | 0.0629      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 22          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020374142 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.078       |
# |    explained_variance   | -304        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0412      |
# |    n_updates            | 7070        |
# |    policy_gradient_loss | 0.00604     |
# |    std                  | 0.232       |
# |    value_loss           | 0.0478      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.02       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 279        |
# |    iterations           | 23         |
# |    time_elapsed         | 168        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02235685 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.093      |
# |    explained_variance   | -4.83e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0081    |
# |    n_updates            | 7080       |
# |    policy_gradient_loss | 0.00764    |
# |    std                  | 0.231      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 24          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022300798 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0854      |
# |    explained_variance   | 0.00309     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0128      |
# |    n_updates            | 7090        |
# |    policy_gradient_loss | 0.00688     |
# |    std                  | 0.232       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 25          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.047643315 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0721      |
# |    explained_variance   | 0.00687     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0601      |
# |    n_updates            | 7100        |
# |    policy_gradient_loss | 0.00852     |
# |    std                  | 0.235       |
# |    value_loss           | 1.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 26          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.029811032 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0571      |
# |    explained_variance   | -319        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0196      |
# |    n_updates            | 7110        |
# |    policy_gradient_loss | 0.00417     |
# |    std                  | 0.235       |
# |    value_loss           | 0.147       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 27          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.024601124 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0789      |
# |    explained_variance   | -132        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00638    |
# |    n_updates            | 7120        |
# |    policy_gradient_loss | 0.00134     |
# |    std                  | 0.231       |
# |    value_loss           | 0.0473      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 28          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.027750086 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0976      |
# |    explained_variance   | 0.00275     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0987      |
# |    n_updates            | 7130        |
# |    policy_gradient_loss | 0.00575     |
# |    std                  | 0.231       |
# |    value_loss           | 976         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 29          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.018757604 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0906      |
# |    explained_variance   | 0.00462     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0197     |
# |    n_updates            | 7140        |
# |    policy_gradient_loss | 0.0052      |
# |    std                  | 0.233       |
# |    value_loss           | 972         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 30          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.026126072 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0738      |
# |    explained_variance   | -50.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0336     |
# |    n_updates            | 7150        |
# |    policy_gradient_loss | 0.0074      |
# |    std                  | 0.234       |
# |    value_loss           | 0.00548     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.27       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 270        |
# |    iterations           | 31         |
# |    time_elapsed         | 234        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02874463 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0677     |
# |    explained_variance   | -302       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0377     |
# |    n_updates            | 7160       |
# |    policy_gradient_loss | 0.00163    |
# |    std                  | 0.234      |
# |    value_loss           | 0.075      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 32          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.027465686 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0732      |
# |    explained_variance   | -249        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0277      |
# |    n_updates            | 7170        |
# |    policy_gradient_loss | 0.00821     |
# |    std                  | 0.234       |
# |    value_loss           | 0.0274      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.08       |
# |    ep_rew_mean          | -9.01      |
# | time/                   |            |
# |    fps                  | 270        |
# |    iterations           | 33         |
# |    time_elapsed         | 249        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02933396 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0767     |
# |    explained_variance   | 0.00439    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.038     |
# |    n_updates            | 7180       |
# |    policy_gradient_loss | -0.00285   |
# |    std                  | 0.233      |
# |    value_loss           | 487        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 34          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014202321 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0701      |
# |    explained_variance   | 0.00433     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0651      |
# |    n_updates            | 7190        |
# |    policy_gradient_loss | 0.00724     |
# |    std                  | 0.235       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 269        |
# |    iterations           | 35         |
# |    time_elapsed         | 265        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.04196916 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0669     |
# |    explained_variance   | 0.00964    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.391      |
# |    n_updates            | 7200       |
# |    policy_gradient_loss | 0.00336    |
# |    std                  | 0.234      |
# |    value_loss           | 1.88e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 36          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023501147 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0637      |
# |    explained_variance   | -257        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0374      |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | 0.0018      |
# |    std                  | 0.236       |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.39        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 37          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.019184392 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0667      |
# |    explained_variance   | 0.00976     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 7220        |
# |    policy_gradient_loss | 0.00571     |
# |    std                  | 0.234       |
# |    value_loss           | 484         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 269        |
# |    iterations           | 38         |
# |    time_elapsed         | 288        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01393988 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0843     |
# |    explained_variance   | 0.00512    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0107     |
# |    n_updates            | 7230       |
# |    policy_gradient_loss | 0.00334    |
# |    std                  | 0.231      |
# |    value_loss           | 918        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 39          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.027007312 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0954      |
# |    explained_variance   | 4.47e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00137     |
# |    n_updates            | 7240        |
# |    policy_gradient_loss | 0.00763     |
# |    std                  | 0.232       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 40          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.026607579 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0862      |
# |    explained_variance   | 0.0045      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0205      |
# |    n_updates            | 7250        |
# |    policy_gradient_loss | 0.00309     |
# |    std                  | 0.233       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 41          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028597124 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0717      |
# |    explained_variance   | -163        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0844      |
# |    n_updates            | 7260        |
# |    policy_gradient_loss | 0.00224     |
# |    std                  | 0.236       |
# |    value_loss           | 0.0382      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 42          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013779789 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0582      |
# |    explained_variance   | 0.00215     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.023       |
# |    n_updates            | 7270        |
# |    policy_gradient_loss | 0.00584     |
# |    std                  | 0.236       |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 269        |
# |    iterations           | 43         |
# |    time_elapsed         | 326        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.02238559 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0693     |
# |    explained_variance   | -153       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0373     |
# |    n_updates            | 7280       |
# |    policy_gradient_loss | 0.00725    |
# |    std                  | 0.233      |
# |    value_loss           | 0.0357     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.12      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 269       |
# |    iterations           | 44        |
# |    time_elapsed         | 334       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0246307 |
# |    clip_fraction        | 0.236     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.0768    |
# |    explained_variance   | -204      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0102   |
# |    n_updates            | 7290      |
# |    policy_gradient_loss | 0.00393   |
# |    std                  | 0.234     |
# |    value_loss           | 0.0248    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 45          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013892362 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0754      |
# |    explained_variance   | 0.00551     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.77e+03    |
# |    n_updates            | 7300        |
# |    policy_gradient_loss | -0.000756   |
# |    std                  | 0.233       |
# |    value_loss           | 486         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 46          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.028406134 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0738      |
# |    explained_variance   | -62.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 7310        |
# |    policy_gradient_loss | 0.00935     |
# |    std                  | 0.234       |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 47          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.034710873 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0567      |
# |    explained_variance   | 7.82e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00374     |
# |    n_updates            | 7320        |
# |    policy_gradient_loss | 0.0142      |
# |    std                  | 0.237       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 48          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.029124457 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0182      |
# |    explained_variance   | 0.00317     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00858     |
# |    n_updates            | 7330        |
# |    policy_gradient_loss | 0.00431     |
# |    std                  | 0.243       |
# |    value_loss           | 919         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 49          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.018213505 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.00833     |
# |    explained_variance   | -102        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.02        |
# |    n_updates            | 7340        |
# |    policy_gradient_loss | 0.00442     |
# |    std                  | 0.24        |
# |    value_loss           | 0.0345      |
# -----------------------------------------
# --- 374.14886021614075 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.25     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 371      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.030785363 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.122       |
# |    explained_variance   | 0.000125    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0278      |
# |    n_updates            | 6870        |
# |    policy_gradient_loss | 0.00974     |
# |    std                  | 0.228       |
# |    value_loss           | 978         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017325643 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.119       |
# |    explained_variance   | 0.00129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0235      |
# |    n_updates            | 6880        |
# |    policy_gradient_loss | 0.0047      |
# |    std                  | 0.228       |
# |    value_loss           | 977         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.034468036 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.107       |
# |    explained_variance   | 0.00248     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.037       |
# |    n_updates            | 6890        |
# |    policy_gradient_loss | 0.0074      |
# |    std                  | 0.23        |
# |    value_loss           | 1.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# ...
# |    entropy_loss         | 0.117       |
# |    explained_variance   | -84.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0449      |
# |    n_updates            | 7170        |
# |    policy_gradient_loss | 0.00725     |
# |    std                  | 0.227       |
# |    value_loss           | 0.459       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.34      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 367       |
# |    iterations           | 33        |
# |    time_elapsed         | 184       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0577729 |
# |    clip_fraction        | 0.275     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.132     |
# |    explained_variance   | -110      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0127    |
# |    n_updates            | 7180      |
# |    policy_gradient_loss | 0.00834   |
# |    std                  | 0.227     |
# |    value_loss           | 0.0122    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.24       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 365        |
# |    iterations           | 34         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.03372774 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.122      |
# |    explained_variance   | 0.00884    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0954     |
# |    n_updates            | 7190       |
# |    policy_gradient_loss | 0.00517    |
# |    std                  | 0.228      |
# |    value_loss           | 897        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.8         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 35          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.044441506 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.111       |
# |    explained_variance   | -220        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0441      |
# |    n_updates            | 7200        |
# |    policy_gradient_loss | 0.0158      |
# |    std                  | 0.229       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.37        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 36          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.047764264 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.116       |
# |    explained_variance   | -45.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0476      |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 0.227       |
# |    value_loss           | 0.00493     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 37          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022241946 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.12        |
# |    explained_variance   | -25.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0173      |
# |    n_updates            | 7220        |
# |    policy_gradient_loss | 0.00641     |
# |    std                  | 0.228       |
# |    value_loss           | 0.00856     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 38          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.029986652 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.119       |
# |    explained_variance   | -60.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0199     |
# |    n_updates            | 7230        |
# |    policy_gradient_loss | 0.00866     |
# |    std                  | 0.228       |
# |    value_loss           | 0.00825     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 39          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.018537655 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.132       |
# |    explained_variance   | -27.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00324    |
# |    n_updates            | 7240        |
# |    policy_gradient_loss | 0.0101      |
# |    std                  | 0.226       |
# |    value_loss           | 0.00587     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 351        |
# |    iterations           | 40         |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03511833 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.138      |
# |    explained_variance   | -99        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000456   |
# |    n_updates            | 7250       |
# |    policy_gradient_loss | 0.0147     |
# |    std                  | 0.226      |
# |    value_loss           | 0.0109     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.32      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 349       |
# |    iterations           | 41        |
# |    time_elapsed         | 240       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0419226 |
# |    clip_fraction        | 0.284     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.125     |
# |    explained_variance   | -108      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.15      |
# |    n_updates            | 7260      |
# |    policy_gradient_loss | 0.0225    |
# |    std                  | 0.228     |
# |    value_loss           | 0.00957   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 42          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.022863545 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.115       |
# |    explained_variance   | -386        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0526      |
# |    n_updates            | 7270        |
# |    policy_gradient_loss | 0.00676     |
# |    std                  | 0.229       |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 43          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.022892784 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.124       |
# |    explained_variance   | -197        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.029      |
# |    n_updates            | 7280        |
# |    policy_gradient_loss | 0.00781     |
# |    std                  | 0.226       |
# |    value_loss           | 0.0164      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 44          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.049038205 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.13        |
# |    explained_variance   | -58.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.034       |
# |    n_updates            | 7290        |
# |    policy_gradient_loss | 0.00817     |
# |    std                  | 0.227       |
# |    value_loss           | 0.00845     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.37       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 352        |
# |    iterations           | 45         |
# |    time_elapsed         | 261        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02418377 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.118      |
# |    explained_variance   | -21.7      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0455     |
# |    n_updates            | 7300       |
# |    policy_gradient_loss | 0.00484    |
# |    std                  | 0.229      |
# |    value_loss           | 0.00486    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 46          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.032426506 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.108       |
# |    explained_variance   | -103        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0895      |
# |    n_updates            | 7310        |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.23        |
# |    value_loss           | 0.00582     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 47          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.029293707 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0914      |
# |    explained_variance   | -302        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0624      |
# |    n_updates            | 7320        |
# |    policy_gradient_loss | 0.0143      |
# |    std                  | 0.232       |
# |    value_loss           | 0.026       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 48          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022292517 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0955      |
# |    explained_variance   | -63.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.022       |
# |    n_updates            | 7330        |
# |    policy_gradient_loss | 0.0077      |
# |    std                  | 0.23        |
# |    value_loss           | 0.00885     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 49          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.020423686 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.1         |
# |    explained_variance   | -73.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00871     |
# |    n_updates            | 7340        |
# |    policy_gradient_loss | 0.0126      |
# |    std                  | 0.231       |
# |    value_loss           | 0.00873     |
# -----------------------------------------
# --- 282.8767776489258 seconds ---

# %%
eval_episode_length=100000
training_episode_length=100000

# %%
env.seed(42)
torch.manual_seed(42)

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    results_overall[p]=[]
    results_polys[p]=[]
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-100000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.94 +/- 7.75
# Focus Polytopes:
# mean_reward:0.58 +/- 20.51
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.97 +/- 5.48
# Focus Polytopes:
# mean_reward:0.58 +/- 20.51
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.94 +/- 7.75
# Focus Polytopes:
# mean_reward:0.72 +/- 16.75
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.98 +/- 4.48
# Focus Polytopes:
# mean_reward:0.80 +/- 14.15
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.98 +/- 4.48
# Focus Polytopes:
# mean_reward:0.48 +/- 22.82
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.97 +/- 5.48
# Focus Polytopes:
# mean_reward:-0.29 +/- 35.93

# %%
results_overall = {0.:[(0.94,7.75)],0.05:[(0.97,5.48)],0.1:[(0.94,7.75)],0.5:[(0.98,4.48)],0.9:[(0.97,5.48)],1.0:[(0.97,5.48)]}
results_polys = {0.:[(0.58,20.51)],0.05:[(0.58,20.51)],0.1:[(0.72,16.75)],0.5:[(0.8,14.15)],0.9:[(0.48,22.82)],1.0:[(-0.29,35.93)]}

# %%
env.seed(43)
torch.manual_seed(43)

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-100000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-200000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.96     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 330      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.028366089 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00363    |
# |    explained_variance   | -343        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00405     |
# |    n_updates            | 7360        |
# |    policy_gradient_loss | -0.00339    |
# |    std                  | 0.244       |
# |    value_loss           | 0.0449      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 3           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.022209033 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0177     |
# |    explained_variance   | 1.26e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00378    |
# |    n_updates            | 7370        |
# |    policy_gradient_loss | 0.0073      |
# |    std                  | 0.245       |
# |    value_loss           | 978         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.025914244 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0351     |
# |    explained_variance   | -69.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0541      |
# |    n_updates            | 7380        |
# |    policy_gradient_loss | 0.00678     |
# |    std                  | 0.248       |
# |    value_loss           | 0.0447      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.07       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 215        |
# |    iterations           | 5          |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01680317 |
# |    clip_fraction        | 0.198      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0387    |
# |    explained_variance   | 0.000448   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0357     |
# |    n_updates            | 7390       |
# |    policy_gradient_loss | 0.00483    |
# |    std                  | 0.247      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 6           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.039170526 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0304     |
# |    explained_variance   | 0.00223     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.432       |
# |    n_updates            | 7400        |
# |    policy_gradient_loss | 0.00532     |
# |    std                  | 0.246       |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 7           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016575724 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0263     |
# |    explained_variance   | -233        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0394      |
# |    n_updates            | 7410        |
# |    policy_gradient_loss | 0.00754     |
# |    std                  | 0.246       |
# |    value_loss           | 0.0617      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.11       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 214        |
# |    iterations           | 8          |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.03431449 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0448    |
# |    explained_variance   | 0.00404    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0376     |
# |    n_updates            | 7420       |
# |    policy_gradient_loss | -0.00014   |
# |    std                  | 0.25       |
# |    value_loss           | 973        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 9           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022040289 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0499     |
# |    explained_variance   | -238        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0395      |
# |    n_updates            | 7430        |
# |    policy_gradient_loss | 0.000388    |
# |    std                  | 0.248       |
# |    value_loss           | 0.0498      |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 2.07     |
# |    ep_rew_mean          | 1        |
# | time/                   |          |
# |    fps                  | 218      |
# |    iterations           | 10       |
# |    time_elapsed         | 93       |
# |    total_timesteps      | 20480    |
# | train/                  |          |
# |    approx_kl            | 0.043462 |
# |    clip_fraction        | 0.249    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.045   |
# |    explained_variance   | -198     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0302   |
# |    n_updates            | 7440     |
# |    policy_gradient_loss | 0.00624  |
# |    std                  | 0.249    |
# |    value_loss           | 0.0184   |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 11          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.016817104 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0688     |
# |    explained_variance   | 0.00316     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0171     |
# |    n_updates            | 7450        |
# |    policy_gradient_loss | 0.00404     |
# |    std                  | 0.254       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 12          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.019552127 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0822     |
# |    explained_variance   | -83.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 7460        |
# |    policy_gradient_loss | 0.00403     |
# |    std                  | 0.252       |
# |    value_loss           | 0.0156      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 13          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021389905 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.075      |
# |    explained_variance   | 0.00341     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 7470        |
# |    policy_gradient_loss | 0.00247     |
# |    std                  | 0.252       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 14          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.028398216 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0651     |
# |    explained_variance   | 0.00284     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0351      |
# |    n_updates            | 7480        |
# |    policy_gradient_loss | 0.00702     |
# |    std                  | 0.249       |
# |    value_loss           | 975         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 223         |
# |    iterations           | 15          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.019991865 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0472     |
# |    explained_variance   | -85.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00235     |
# |    n_updates            | 7490        |
# |    policy_gradient_loss | 0.00591     |
# |    std                  | 0.248       |
# |    value_loss           | 0.0181      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 16          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014191605 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0469     |
# |    explained_variance   | -43.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00194    |
# |    n_updates            | 7500        |
# |    policy_gradient_loss | 0.0042      |
# |    std                  | 0.249       |
# |    value_loss           | 0.00817     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 17          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017821189 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.029      |
# |    explained_variance   | -73.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 7510        |
# |    policy_gradient_loss | 0.00487     |
# |    std                  | 0.244       |
# |    value_loss           | 0.00855     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 18          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016571445 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0188     |
# |    explained_variance   | -28.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0229     |
# |    n_updates            | 7520        |
# |    policy_gradient_loss | 0.00512     |
# |    std                  | 0.246       |
# |    value_loss           | 0.00511     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 19          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017246464 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0251     |
# |    explained_variance   | 0.00202     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0392      |
# |    n_updates            | 7530        |
# |    policy_gradient_loss | 0.00203     |
# |    std                  | 0.246       |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 20          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.019194994 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00611    |
# |    explained_variance   | -115        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000295    |
# |    n_updates            | 7540        |
# |    policy_gradient_loss | 0.00501     |
# |    std                  | 0.241       |
# |    value_loss           | 0.052       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 220        |
# |    iterations           | 21         |
# |    time_elapsed         | 194        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02168284 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0244     |
# |    explained_variance   | 0.00638    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0068    |
# |    n_updates            | 7550       |
# |    policy_gradient_loss | -0.00115   |
# |    std                  | 0.239      |
# |    value_loss           | 486        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 22          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020571727 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0449      |
# |    explained_variance   | -160        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00257    |
# |    n_updates            | 7560        |
# |    policy_gradient_loss | 0.00354     |
# |    std                  | 0.236       |
# |    value_loss           | 0.0241      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.01       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 219        |
# |    iterations           | 23         |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02550821 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0352     |
# |    explained_variance   | -69.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0174    |
# |    n_updates            | 7570       |
# |    policy_gradient_loss | 0.00382    |
# |    std                  | 0.241      |
# |    value_loss           | 0.0109     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 24          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023042187 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0215      |
# |    explained_variance   | 0.00498     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 7580        |
# |    policy_gradient_loss | 0.00135     |
# |    std                  | 0.24        |
# |    value_loss           | 971         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 25          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.029764153 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0304      |
# |    explained_variance   | 0.00703     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0743      |
# |    n_updates            | 7590        |
# |    policy_gradient_loss | 0.00755     |
# |    std                  | 0.239       |
# |    value_loss           | 1.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 26          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.031884238 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0301      |
# |    explained_variance   | -599        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0152      |
# |    n_updates            | 7600        |
# |    policy_gradient_loss | 0.0026      |
# |    std                  | 0.239       |
# |    value_loss           | 0.263       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 27         |
# |    time_elapsed         | 252        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.02957162 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0403     |
# |    explained_variance   | -0.000287  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00898   |
# |    n_updates            | 7610       |
# |    policy_gradient_loss | 0.00419    |
# |    std                  | 0.238      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 28          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025160424 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.042       |
# |    explained_variance   | -346        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00102    |
# |    n_updates            | 7620        |
# |    policy_gradient_loss | 0.00142     |
# |    std                  | 0.238       |
# |    value_loss           | 0.0291      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 29         |
# |    time_elapsed         | 271        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02382049 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0424     |
# |    explained_variance   | -201       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00492    |
# |    n_updates            | 7630       |
# |    policy_gradient_loss | 0.012      |
# |    std                  | 0.238      |
# |    value_loss           | 0.0223     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 30          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020752076 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0454      |
# |    explained_variance   | 0.00264     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 7640        |
# |    policy_gradient_loss | 0.00968     |
# |    std                  | 0.238       |
# |    value_loss           | 975         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 31          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.028234912 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0434      |
# |    explained_variance   | -497        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 7650        |
# |    policy_gradient_loss | 0.0138      |
# |    std                  | 0.238       |
# |    value_loss           | 0.0454      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 32          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.031676337 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0524      |
# |    explained_variance   | -185        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.046       |
# |    n_updates            | 7660        |
# |    policy_gradient_loss | -0.000592   |
# |    std                  | 0.236       |
# |    value_loss           | 0.0371      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 33          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.023399994 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0536      |
# |    explained_variance   | -176        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 7670        |
# |    policy_gradient_loss | 0.00415     |
# |    std                  | 0.238       |
# |    value_loss           | 0.014       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 34          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.021636218 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0478      |
# |    explained_variance   | 0.00325     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0376      |
# |    n_updates            | 7680        |
# |    policy_gradient_loss | -0.00119    |
# |    std                  | 0.237       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 35          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.033776868 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0538      |
# |    explained_variance   | 0.00616     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.016       |
# |    n_updates            | 7690        |
# |    policy_gradient_loss | 0.00815     |
# |    std                  | 0.237       |
# |    value_loss           | 486         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 36          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.035776943 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0499      |
# |    explained_variance   | -195        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0157     |
# |    n_updates            | 7700        |
# |    policy_gradient_loss | 0.00211     |
# |    std                  | 0.238       |
# |    value_loss           | 0.0293      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 37          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.017618857 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.047       |
# |    explained_variance   | -218        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0587      |
# |    n_updates            | 7710        |
# |    policy_gradient_loss | 0.00567     |
# |    std                  | 0.237       |
# |    value_loss           | 0.0241      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.23       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 221        |
# |    iterations           | 38         |
# |    time_elapsed         | 351        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02809542 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0572     |
# |    explained_variance   | 0.00162    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00751    |
# |    n_updates            | 7720       |
# |    policy_gradient_loss | 0.00332    |
# |    std                  | 0.236      |
# |    value_loss           | 920        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 39          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.017931234 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0672      |
# |    explained_variance   | 0.00623     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 7730        |
# |    policy_gradient_loss | 0.0059      |
# |    std                  | 0.235       |
# |    value_loss           | 486         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.28        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 40          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.021455873 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0852      |
# |    explained_variance   | -158        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0421      |
# |    n_updates            | 7740        |
# |    policy_gradient_loss | 0.0028      |
# |    std                  | 0.231       |
# |    value_loss           | 0.0242      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 41          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.025101475 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.107       |
# |    explained_variance   | -122        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | 0.00119     |
# |    std                  | 0.23        |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 42          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.022451535 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.116       |
# |    explained_variance   | -0.000129   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0391      |
# |    n_updates            | 7760        |
# |    policy_gradient_loss | 0.00333     |
# |    std                  | 0.23        |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 43          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.019850815 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.11        |
# |    explained_variance   | 0.00385     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 7770        |
# |    policy_gradient_loss | 0.00639     |
# |    std                  | 0.231       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 44          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.019433353 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0983      |
# |    explained_variance   | -1.55e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0337      |
# |    n_updates            | 7780        |
# |    policy_gradient_loss | 0.00257     |
# |    std                  | 0.232       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 45          |
# |    time_elapsed         | 414         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018249081 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0919      |
# |    explained_variance   | 0.0038      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0579      |
# |    n_updates            | 7790        |
# |    policy_gradient_loss | 0.00917     |
# |    std                  | 0.233       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 46          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018916877 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0849      |
# |    explained_variance   | 0.00501     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00229    |
# |    n_updates            | 7800        |
# |    policy_gradient_loss | 0.00626     |
# |    std                  | 0.234       |
# |    value_loss           | 486         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 47          |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.023829147 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0803      |
# |    explained_variance   | -9.31e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 7810        |
# |    policy_gradient_loss | 0.00532     |
# |    std                  | 0.234       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 48          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022038653 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0829      |
# |    explained_variance   | -72.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00366     |
# |    n_updates            | 7820        |
# |    policy_gradient_loss | 0.00493     |
# |    std                  | 0.234       |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 49          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.016901962 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0894      |
# |    explained_variance   | 0.00369     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0259      |
# |    n_updates            | 7830        |
# |    policy_gradient_loss | 0.00691     |
# |    std                  | 0.233       |
# |    value_loss           | 487         |
# -----------------------------------------
# --- 452.5310261249542 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.24     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 275      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 260        |
# |    iterations           | 2          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.11437802 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0333    |
# |    explained_variance   | 0.000106   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0207    |
# |    n_updates            | 7360       |
# |    policy_gradient_loss | 0.00681    |
# |    std                  | 0.248      |
# |    value_loss           | 978        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017778022 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0563     |
# |    explained_variance   | 0.000102    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.83e+03    |
# |    n_updates            | 7370        |
# |    policy_gradient_loss | 0.00286     |
# |    std                  | 0.25        |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016192505 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0756     |
# |    explained_variance   | 0.00271     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0287      |
# |    n_updates            | 7380        |
# |    policy_gradient_loss | 0.00535     |
# |    std                  | 0.252       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# ...
# |    explained_variance   | -0.000917   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0152      |
# |    n_updates            | 7660        |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 0.232       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 33          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.042420946 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0846      |
# |    explained_variance   | -46.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0631      |
# |    n_updates            | 7670        |
# |    policy_gradient_loss | 0.00354     |
# |    std                  | 0.232       |
# |    value_loss           | 0.0775      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.42        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 34          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.026271265 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.086       |
# |    explained_variance   | -21         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0154      |
# |    n_updates            | 7680        |
# |    policy_gradient_loss | 0.00658     |
# |    std                  | 0.232       |
# |    value_loss           | 0.00849     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 35          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013920635 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0706      |
# |    explained_variance   | -235        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0436      |
# |    n_updates            | 7690        |
# |    policy_gradient_loss | 0.0156      |
# |    std                  | 0.235       |
# |    value_loss           | 0.0226      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 36          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023876116 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0619      |
# |    explained_variance   | -81.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -4.7e-05    |
# |    n_updates            | 7700        |
# |    policy_gradient_loss | 0.00612     |
# |    std                  | 0.235       |
# |    value_loss           | 0.0198      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.27       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 37         |
# |    time_elapsed         | 210        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01410487 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.08       |
# |    explained_variance   | -114       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0127     |
# |    n_updates            | 7710       |
# |    policy_gradient_loss | 0.00316    |
# |    std                  | 0.231      |
# |    value_loss           | 0.0113     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 38          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.024007898 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0854      |
# |    explained_variance   | -114        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0197      |
# |    n_updates            | 7720        |
# |    policy_gradient_loss | 0.0238      |
# |    std                  | 0.232       |
# |    value_loss           | 0.00505     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 361        |
# |    iterations           | 39         |
# |    time_elapsed         | 221        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01725765 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0782     |
# |    explained_variance   | -18.7      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0115     |
# |    n_updates            | 7730       |
# |    policy_gradient_loss | 0.0066     |
# |    std                  | 0.233      |
# |    value_loss           | 0.00471    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 362        |
# |    iterations           | 40         |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02293804 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0751     |
# |    explained_variance   | -14.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0157     |
# |    n_updates            | 7740       |
# |    policy_gradient_loss | 0.00565    |
# |    std                  | 0.233      |
# |    value_loss           | 0.00393    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.29        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 41          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015401417 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0679      |
# |    explained_variance   | -130        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0638      |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | 0.00295     |
# |    std                  | 0.234       |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 42          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019846363 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0651      |
# |    explained_variance   | -551        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00655    |
# |    n_updates            | 7760        |
# |    policy_gradient_loss | -0.000486   |
# |    std                  | 0.234       |
# |    value_loss           | 0.0273      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.37        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 43          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.022731867 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0641      |
# |    explained_variance   | -56.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0085     |
# |    n_updates            | 7770        |
# |    policy_gradient_loss | 0.00381     |
# |    std                  | 0.235       |
# |    value_loss           | 0.00818     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 44          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015025366 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0626      |
# |    explained_variance   | -35.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 7780        |
# |    policy_gradient_loss | 0.00592     |
# |    std                  | 0.234       |
# |    value_loss           | 0.00617     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 45          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009772107 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0622      |
# |    explained_variance   | -52.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000172   |
# |    n_updates            | 7790        |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.235       |
# |    value_loss           | 0.00697     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 361        |
# |    iterations           | 46         |
# |    time_elapsed         | 260        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01554841 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0533     |
# |    explained_variance   | -16.2      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00566   |
# |    n_updates            | 7800       |
# |    policy_gradient_loss | 0.00566    |
# |    std                  | 0.236      |
# |    value_loss           | 0.00635    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 47         |
# |    time_elapsed         | 267        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.05569713 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0469     |
# |    explained_variance   | -86        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0357    |
# |    n_updates            | 7810       |
# |    policy_gradient_loss | 0.0174     |
# |    std                  | 0.237      |
# |    value_loss           | 0.00749    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 48          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020749617 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0209      |
# |    explained_variance   | -65.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 7820        |
# |    policy_gradient_loss | 0.00799     |
# |    std                  | 0.242       |
# |    value_loss           | 0.00588     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 49          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013403375 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00733    |
# |    explained_variance   | -43.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 7830        |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 0.243       |
# |    value_loss           | 0.00419     |
# -----------------------------------------
# --- 284.0840952396393 seconds ---

# %%
env.seed(1997)
torch.manual_seed(1997)

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-200000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.98 +/- 4.48
# Focus Polytopes:
# mean_reward:0.88 +/- 10.96
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.68 +/- 17.90
# Focus Polytopes:
# mean_reward:0.78 +/- 14.85
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.87 +/- 11.41
# Focus Polytopes:
# mean_reward:0.78 +/- 14.85
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.96 +/- 6.33
# Focus Polytopes:
# mean_reward:0.81 +/- 13.80
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.97 +/- 5.48
# Focus Polytopes:
# mean_reward:0.41 +/- 24.31
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.95 +/- 7.08
# Focus Polytopes:
# mean_reward:0.66 +/- 18.45

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-200000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-300000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 331      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.029406453 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.104       |
# |    explained_variance   | -88.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0322     |
# |    n_updates            | 7850        |
# |    policy_gradient_loss | 0.000194    |
# |    std                  | 0.232       |
# |    value_loss           | 0.00986     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.025641121 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0929      |
# |    explained_variance   | -126        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0261     |
# |    n_updates            | 7860        |
# |    policy_gradient_loss | -0.000578   |
# |    std                  | 0.234       |
# |    value_loss           | 0.00844     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.3        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 264        |
# |    iterations           | 4          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02627952 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0586     |
# |    explained_variance   | -51.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0209    |
# |    n_updates            | 7870       |
# |    policy_gradient_loss | 0.00285    |
# |    std                  | 0.239      |
# |    value_loss           | 0.0102     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 5           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016121482 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0223      |
# |    explained_variance   | -0.000112   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0198     |
# |    n_updates            | 7880        |
# |    policy_gradient_loss | 0.00513     |
# |    std                  | 0.243       |
# |    value_loss           | 489         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.8        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 259        |
# |    iterations           | 6          |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01948466 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0069    |
# |    explained_variance   | 0.000585   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0293    |
# |    n_updates            | 7890       |
# |    policy_gradient_loss | 0.00122    |
# |    std                  | 0.247      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 7           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.021060046 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0347     |
# |    explained_variance   | 0.000406    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0272      |
# |    n_updates            | 7900        |
# |    policy_gradient_loss | 0.00401     |
# |    std                  | 0.249       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 8           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019138603 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0427     |
# |    explained_variance   | 0.000221    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0211      |
# |    n_updates            | 7910        |
# |    policy_gradient_loss | 0.0102      |
# |    std                  | 0.249       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 9           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026817665 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0405     |
# |    explained_variance   | -182        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0506      |
# |    n_updates            | 7920        |
# |    policy_gradient_loss | 0.00969     |
# |    std                  | 0.248       |
# |    value_loss           | 0.0411      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 10          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.028745268 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0366     |
# |    explained_variance   | -87.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0086      |
# |    n_updates            | 7930        |
# |    policy_gradient_loss | 0.0116      |
# |    std                  | 0.248       |
# |    value_loss           | 0.00529     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 11          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021458711 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0373     |
# |    explained_variance   | -44.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0266      |
# |    n_updates            | 7940        |
# |    policy_gradient_loss | 0.00509     |
# |    std                  | 0.249       |
# |    value_loss           | 0.00513     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 12          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.020577244 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0364     |
# |    explained_variance   | -0.000249   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0067      |
# |    n_updates            | 7950        |
# |    policy_gradient_loss | 0.00471     |
# |    std                  | 0.248       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 13          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021601819 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0439     |
# |    explained_variance   | 0.00106     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00331     |
# |    n_updates            | 7960        |
# |    policy_gradient_loss | 0.00302     |
# |    std                  | 0.25        |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 14          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.050479755 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0681     |
# |    explained_variance   | -197        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00255     |
# |    n_updates            | 7970        |
# |    policy_gradient_loss | 0.00156     |
# |    std                  | 0.254       |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 15          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.037510008 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0943     |
# |    explained_variance   | -8.82e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0218      |
# |    n_updates            | 7980        |
# |    policy_gradient_loss | 0.00105     |
# |    std                  | 0.256       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 16          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.029915847 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0931     |
# |    explained_variance   | -25.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 7990        |
# |    policy_gradient_loss | 0.00261     |
# |    std                  | 0.253       |
# |    value_loss           | 0.0197      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 17          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.019909864 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0884     |
# |    explained_variance   | 0.000108    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0169      |
# |    n_updates            | 8000        |
# |    policy_gradient_loss | 0.003       |
# |    std                  | 0.255       |
# |    value_loss           | 489         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 252        |
# |    iterations           | 18         |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01910727 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.106     |
# |    explained_variance   | -48.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00104    |
# |    n_updates            | 8010       |
# |    policy_gradient_loss | 0.00263    |
# |    std                  | 0.258      |
# |    value_loss           | 0.0455     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 19          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.040420566 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.121      |
# |    explained_variance   | 0.00101     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0259     |
# |    n_updates            | 8020        |
# |    policy_gradient_loss | 0.00446     |
# |    std                  | 0.258       |
# |    value_loss           | 976         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 20          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029649748 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.124      |
# |    explained_variance   | 0.000557    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00854     |
# |    n_updates            | 8030        |
# |    policy_gradient_loss | 0.00273     |
# |    std                  | 0.258       |
# |    value_loss           | 489         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.35       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 21         |
# |    time_elapsed         | 170        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01175979 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.117     |
# |    explained_variance   | 0.000906   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0211     |
# |    n_updates            | 8040       |
# |    policy_gradient_loss | 0.00378    |
# |    std                  | 0.256      |
# |    value_loss           | 918        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 22         |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02780522 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.103     |
# |    explained_variance   | 0.000215   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.018      |
# |    n_updates            | 8050       |
# |    policy_gradient_loss | -0.00616   |
# |    std                  | 0.255      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 23          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.023021236 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.00453     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.019       |
# |    n_updates            | 8060        |
# |    policy_gradient_loss | 0.00971     |
# |    std                  | 0.256       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 24          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017995533 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | -159        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00344     |
# |    n_updates            | 8070        |
# |    policy_gradient_loss | 0.0023      |
# |    std                  | 0.255       |
# |    value_loss           | 0.0303      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2        |
# |    ep_rew_mean          | -9.01      |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 25         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01540309 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0904    |
# |    explained_variance   | -74.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00702    |
# |    n_updates            | 8080       |
# |    policy_gradient_loss | 0.00696    |
# |    std                  | 0.252      |
# |    value_loss           | 0.00924    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 26          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.025199145 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0777     |
# |    explained_variance   | 0.00131     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0441      |
# |    n_updates            | 8090        |
# |    policy_gradient_loss | 0.00681     |
# |    std                  | 0.251       |
# |    value_loss           | 976         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 27          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.021765577 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0664     |
# |    explained_variance   | -192        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 8100        |
# |    policy_gradient_loss | 0.00196     |
# |    std                  | 0.249       |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 28          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.034438163 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0595     |
# |    explained_variance   | -51.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 8110        |
# |    policy_gradient_loss | 0.0054      |
# |    std                  | 0.25        |
# |    value_loss           | 0.0195      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 29          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.020380562 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0651     |
# |    explained_variance   | -39.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0166      |
# |    n_updates            | 8120        |
# |    policy_gradient_loss | 0.00691     |
# |    std                  | 0.252       |
# |    value_loss           | 0.00636     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 30          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.026364548 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0741     |
# |    explained_variance   | 0.00114     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0628      |
# |    n_updates            | 8130        |
# |    policy_gradient_loss | 0.0042      |
# |    std                  | 0.251       |
# |    value_loss           | 488         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.29       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 31         |
# |    time_elapsed         | 252        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01589904 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0705    |
# |    explained_variance   | 0.0047     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00971    |
# |    n_updates            | 8140       |
# |    policy_gradient_loss | 0.00684    |
# |    std                  | 0.25       |
# |    value_loss           | 487        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 32          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.064952575 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0738     |
# |    explained_variance   | -59.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0977      |
# |    n_updates            | 8150        |
# |    policy_gradient_loss | 0.00616     |
# |    std                  | 0.253       |
# |    value_loss           | 0.0595      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 33          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014721574 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0872     |
# |    explained_variance   | 0.00394     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00802    |
# |    n_updates            | 8160        |
# |    policy_gradient_loss | 0.00536     |
# |    std                  | 0.253       |
# |    value_loss           | 487         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 34         |
# |    time_elapsed         | 277        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.03332206 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.087     |
# |    explained_variance   | -44.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0609     |
# |    n_updates            | 8170       |
# |    policy_gradient_loss | 0.00986    |
# |    std                  | 0.253      |
# |    value_loss           | 0.00614    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.03       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 35         |
# |    time_elapsed         | 285        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.03175141 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0749    |
# |    explained_variance   | -178       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0237    |
# |    n_updates            | 8180       |
# |    policy_gradient_loss | 0.00425    |
# |    std                  | 0.25       |
# |    value_loss           | 0.0156     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 36          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.028279345 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.055      |
# |    explained_variance   | -118        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00367     |
# |    n_updates            | 8190        |
# |    policy_gradient_loss | 0.00732     |
# |    std                  | 0.247       |
# |    value_loss           | 0.0398      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 37          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.029908128 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.034      |
# |    explained_variance   | -48.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 8200        |
# |    policy_gradient_loss | 0.00362     |
# |    std                  | 0.245       |
# |    value_loss           | 0.0184      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 38          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.023252608 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0284     |
# |    explained_variance   | -77.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.004       |
# |    n_updates            | 8210        |
# |    policy_gradient_loss | 0.00534     |
# |    std                  | 0.245       |
# |    value_loss           | 0.00678     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.1        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 39         |
# |    time_elapsed         | 318        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01498946 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0158    |
# |    explained_variance   | 0.00155    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0126    |
# |    n_updates            | 8220       |
# |    policy_gradient_loss | 0.00168    |
# |    std                  | 0.243      |
# |    value_loss           | 487        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 40          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.052938826 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.00201     |
# |    explained_variance   | -255        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00427    |
# |    n_updates            | 8230        |
# |    policy_gradient_loss | 0.00479     |
# |    std                  | 0.241       |
# |    value_loss           | 0.0264      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 41          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.056657076 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0113      |
# |    explained_variance   | -28.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 8240        |
# |    policy_gradient_loss | -0.0021     |
# |    std                  | 0.24        |
# |    value_loss           | 0.013       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 42         |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.02699421 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0277     |
# |    explained_variance   | -21.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0337     |
# |    n_updates            | 8250       |
# |    policy_gradient_loss | 0.0049     |
# |    std                  | 0.238      |
# |    value_loss           | 0.00459    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 43         |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01577508 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0372     |
# |    explained_variance   | 0.000877   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00507   |
# |    n_updates            | 8260       |
# |    policy_gradient_loss | 0.00524    |
# |    std                  | 0.238      |
# |    value_loss           | 488        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.9        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 44         |
# |    time_elapsed         | 359        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.02392926 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0516     |
# |    explained_variance   | -7.31e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0276     |
# |    n_updates            | 8270       |
# |    policy_gradient_loss | 0.00425    |
# |    std                  | 0.235      |
# |    value_loss           | 489        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.25       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 45         |
# |    time_elapsed         | 367        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02033027 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0627     |
# |    explained_variance   | -30.7      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00378    |
# |    n_updates            | 8280       |
# |    policy_gradient_loss | 0.0126     |
# |    std                  | 0.235      |
# |    value_loss           | 0.0218     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 46          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.024311062 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0589      |
# |    explained_variance   | -32.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00407     |
# |    n_updates            | 8290        |
# |    policy_gradient_loss | 0.00801     |
# |    std                  | 0.236       |
# |    value_loss           | 0.00951     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 47          |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011802739 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0558      |
# |    explained_variance   | -34.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00681    |
# |    n_updates            | 8300        |
# |    policy_gradient_loss | 0.00923     |
# |    std                  | 0.236       |
# |    value_loss           | 0.00656     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 48          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020926367 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0345      |
# |    explained_variance   | 0.000938    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.9e-05    |
# |    n_updates            | 8310        |
# |    policy_gradient_loss | 0.000792    |
# |    std                  | 0.241       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.76        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 49          |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.026959147 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0177      |
# |    explained_variance   | -122        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 8320        |
# |    policy_gradient_loss | 0.0128      |
# |    std                  | 0.24        |
# |    value_loss           | 0.0204      |
# -----------------------------------------
# --- 403.1137857437134 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.32     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 340      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14       |
# |    ep_rew_mean          | -9.01      |
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 2          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.06163502 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0741    |
# |    explained_variance   | -29.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00977   |
# |    n_updates            | 7850       |
# |    policy_gradient_loss | 0.00213    |
# |    std                  | 0.251      |
# |    value_loss           | 0.00444    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013226865 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.103      |
# |    explained_variance   | 0.00161     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00841    |
# |    n_updates            | 7860        |
# |    policy_gradient_loss | 0.00469     |
# |    std                  | 0.257       |
# |    value_loss           | 977         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 4            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0146826375 |
# |    clip_fraction        | 0.183        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0.00421      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0106      |
# |    n_updates            | 7870         |
# |    policy_gradient_loss | 0.00418      |
# |    std                  | 0.252        |
# |    value_loss           | 487          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.32       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 265        |
# |    iterations           | 5          |
# ...
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00392    |
# |    n_updates            | 8150       |
# |    policy_gradient_loss | 0.00441    |
# |    std                  | 0.253      |
# |    value_loss           | 0.0159     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.38        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 33          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.017500516 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0806     |
# |    explained_variance   | -167        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0119      |
# |    n_updates            | 8160        |
# |    policy_gradient_loss | 0.0062      |
# |    std                  | 0.252       |
# |    value_loss           | 0.029       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 34          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.023293719 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0816     |
# |    explained_variance   | -374        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0089      |
# |    n_updates            | 8170        |
# |    policy_gradient_loss | 0.00109     |
# |    std                  | 0.253       |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 35          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013442117 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0829     |
# |    explained_variance   | -196        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 8180        |
# |    policy_gradient_loss | 0.00838     |
# |    std                  | 0.253       |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 36          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017712925 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0727     |
# |    explained_variance   | -49.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 8190        |
# |    policy_gradient_loss | 0.00241     |
# |    std                  | 0.251       |
# |    value_loss           | 0.00955     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 37          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.024862083 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0814     |
# |    explained_variance   | -23.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0258     |
# |    n_updates            | 8200        |
# |    policy_gradient_loss | 0.00913     |
# |    std                  | 0.254       |
# |    value_loss           | 0.00813     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 38          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016554879 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.095      |
# |    explained_variance   | -23.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.412       |
# |    n_updates            | 8210        |
# |    policy_gradient_loss | 0.00543     |
# |    std                  | 0.255       |
# |    value_loss           | 0.165       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 39          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.031041412 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0927     |
# |    explained_variance   | -69         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 8220        |
# |    policy_gradient_loss | 0.000983    |
# |    std                  | 0.253       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.04      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 375       |
# |    iterations           | 40        |
# |    time_elapsed         | 218       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0291157 |
# |    clip_fraction        | 0.181     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0826   |
# |    explained_variance   | 2.74e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.129     |
# |    n_updates            | 8230      |
# |    policy_gradient_loss | 0.0105    |
# |    std                  | 0.253     |
# |    value_loss           | 921       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 41          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.025798582 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0706     |
# |    explained_variance   | -190        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0383      |
# |    n_updates            | 8240        |
# |    policy_gradient_loss | 0.0119      |
# |    std                  | 0.25        |
# |    value_loss           | 0.0085      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.28        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 42          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019807873 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.06       |
# |    explained_variance   | -63.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00481     |
# |    n_updates            | 8250        |
# |    policy_gradient_loss | 0.0151      |
# |    std                  | 0.25        |
# |    value_loss           | 0.00563     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 43          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.026059186 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0432     |
# |    explained_variance   | -27.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 8260        |
# |    policy_gradient_loss | 0.00608     |
# |    std                  | 0.246       |
# |    value_loss           | 0.00494     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 44          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.028287793 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.022      |
# |    explained_variance   | -11.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00861     |
# |    n_updates            | 8270        |
# |    policy_gradient_loss | 0.0115      |
# |    std                  | 0.245       |
# |    value_loss           | 0.00423     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.48        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 45          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.022208363 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0191     |
# |    explained_variance   | -10.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000905    |
# |    n_updates            | 8280        |
# |    policy_gradient_loss | -0.00302    |
# |    std                  | 0.245       |
# |    value_loss           | 0.00929     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.36        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 46          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.031770952 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.000482   |
# |    explained_variance   | -30.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0261     |
# |    n_updates            | 8290        |
# |    policy_gradient_loss | 0.00613     |
# |    std                  | 0.241       |
# |    value_loss           | 0.00423     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 47          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.015718266 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.00455     |
# |    explained_variance   | -12.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 8300        |
# |    policy_gradient_loss | 0.00189     |
# |    std                  | 0.243       |
# |    value_loss           | 0.00672     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 48          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014906895 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00754    |
# |    explained_variance   | -49.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000211    |
# |    n_updates            | 8310        |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.244       |
# |    value_loss           | 0.00561     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 49          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.027271966 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.006      |
# |    explained_variance   | -26.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.022       |
# |    n_updates            | 8320        |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 0.243       |
# |    value_loss           | 0.00625     |
# -----------------------------------------
# --- 270.33099722862244 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-300000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean_reward:0.94 +/- 7.75
# Focus Polytopes:
# mean_reward:0.90 +/- 10.01
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.68 +/- 17.90
# Focus Polytopes:
# mean_reward:-0.83 +/- 42.78
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.98 +/- 4.48
# Focus Polytopes:
# mean_reward:0.85 +/- 12.26
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.96 +/- 6.33
# Focus Polytopes:
# mean_reward:0.90 +/- 10.01
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.60 +/- 20.02
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.97 +/- 5.48
# Focus Polytopes:
# mean_reward:0.86 +/- 11.84

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-300000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-400000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.12     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 337      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 2          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.02039217 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0368     |
# |    explained_variance   | 0.00294    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0165     |
# |    n_updates            | 8340       |
# |    policy_gradient_loss | 0.00627    |
# |    std                  | 0.237      |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015878504 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0458      |
# |    explained_variance   | 0.000125    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 8350        |
# |    policy_gradient_loss | 0.0114      |
# |    std                  | 0.237       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018227803 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0465      |
# |    explained_variance   | -65.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00593     |
# |    n_updates            | 8360        |
# |    policy_gradient_loss | 0.00516     |
# |    std                  | 0.237       |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019340074 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0371      |
# |    explained_variance   | -27.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 8370        |
# |    policy_gradient_loss | 0.0108      |
# |    std                  | 0.239       |
# |    value_loss           | 0.00552     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 6           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.022672452 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0558      |
# |    explained_variance   | -24.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00745    |
# |    n_updates            | 8380        |
# |    policy_gradient_loss | 0.00283     |
# |    std                  | 0.234       |
# |    value_loss           | 0.00572     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 7           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.031136721 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0797      |
# |    explained_variance   | -19.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00396    |
# |    n_updates            | 8390        |
# |    policy_gradient_loss | 0.0135      |
# |    std                  | 0.233       |
# |    value_loss           | 0.0198      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.28        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 8           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012959836 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0904      |
# |    explained_variance   | 0.00161     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0186      |
# |    n_updates            | 8400        |
# |    policy_gradient_loss | 0.005       |
# |    std                  | 0.231       |
# |    value_loss           | 488         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.09      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 257       |
# |    iterations           | 9         |
# |    time_elapsed         | 71        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0219284 |
# |    clip_fraction        | 0.204     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.0918    |
# |    explained_variance   | -105      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000628  |
# |    n_updates            | 8410      |
# |    policy_gradient_loss | 0.00569   |
# |    std                  | 0.233     |
# |    value_loss           | 0.00587   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 10          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.023195203 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0845      |
# |    explained_variance   | -27.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0159      |
# |    n_updates            | 8420        |
# |    policy_gradient_loss | 0.00656     |
# |    std                  | 0.233       |
# |    value_loss           | 0.00859     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 11          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020480003 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.077       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00664     |
# |    n_updates            | 8430        |
# |    policy_gradient_loss | 0.00565     |
# |    std                  | 0.234       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.29        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 12          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.026878582 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0768      |
# |    explained_variance   | -86         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 8440        |
# |    policy_gradient_loss | 0.00127     |
# |    std                  | 0.233       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 13          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017175501 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0892      |
# |    explained_variance   | -27.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0024     |
# |    n_updates            | 8450        |
# |    policy_gradient_loss | 0.00458     |
# |    std                  | 0.23        |
# |    value_loss           | 0.00283     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 14          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.022477586 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0914      |
# |    explained_variance   | -14.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 8460        |
# |    policy_gradient_loss | 0.00341     |
# |    std                  | 0.233       |
# |    value_loss           | 0.00316     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 15          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.026042897 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.077       |
# |    explained_variance   | -5.46       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0401     |
# |    n_updates            | 8470        |
# |    policy_gradient_loss | 0.00665     |
# |    std                  | 0.234       |
# |    value_loss           | 0.000898    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.28        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 16          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.023961227 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0725      |
# |    explained_variance   | -8.97       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.016       |
# |    n_updates            | 8480        |
# |    policy_gradient_loss | 0.00344     |
# |    std                  | 0.234       |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 17          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.020140454 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0649      |
# |    explained_variance   | -7.4        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00343     |
# |    n_updates            | 8490        |
# |    policy_gradient_loss | 0.00474     |
# |    std                  | 0.236       |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 18          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.038599446 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0516      |
# |    explained_variance   | -17.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00496     |
# |    n_updates            | 8500        |
# |    policy_gradient_loss | 0.00657     |
# |    std                  | 0.237       |
# |    value_loss           | 0.00331     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.37        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 19          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024463044 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0408      |
# |    explained_variance   | 0.000449    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 8510        |
# |    policy_gradient_loss | -0.000551   |
# |    std                  | 0.237       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 20          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021611203 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0502      |
# |    explained_variance   | -73.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00696    |
# |    n_updates            | 8520        |
# |    policy_gradient_loss | 0.00511     |
# |    std                  | 0.236       |
# |    value_loss           | 0.00792     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 21          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021530218 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0313      |
# |    explained_variance   | -72         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000105   |
# |    n_updates            | 8530        |
# |    policy_gradient_loss | 0.00769     |
# |    std                  | 0.241       |
# |    value_loss           | 0.00448     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 22          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020633325 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0151      |
# |    explained_variance   | 7.72e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00932     |
# |    n_updates            | 8540        |
# |    policy_gradient_loss | 0.00463     |
# |    std                  | 0.241       |
# |    value_loss           | 489         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.89       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 252        |
# |    iterations           | 23         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02956901 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.00848    |
# |    explained_variance   | -39        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.014     |
# |    n_updates            | 8550       |
# |    policy_gradient_loss | 0.00873    |
# |    std                  | 0.242      |
# |    value_loss           | 0.00426    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 24          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022151686 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.00499     |
# |    explained_variance   | 0.000637    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00601    |
# |    n_updates            | 8560        |
# |    policy_gradient_loss | 0.00308     |
# |    std                  | 0.242       |
# |    value_loss           | 1.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 25          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.022509048 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0215      |
# |    explained_variance   | -86.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0176      |
# |    n_updates            | 8570        |
# |    policy_gradient_loss | 0.00246     |
# |    std                  | 0.237       |
# |    value_loss           | 0.0146      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 26          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.026524756 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0343      |
# |    explained_variance   | -69.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00887     |
# |    n_updates            | 8580        |
# |    policy_gradient_loss | 0.00424     |
# |    std                  | 0.239       |
# |    value_loss           | 0.00714     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 27          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.038406186 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0285      |
# |    explained_variance   | -12         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00932     |
# |    n_updates            | 8590        |
# |    policy_gradient_loss | 0.00277     |
# |    std                  | 0.239       |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 28          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016997298 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.027       |
# |    explained_variance   | -13.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0378      |
# |    n_updates            | 8600        |
# |    policy_gradient_loss | 0.0113      |
# |    std                  | 0.239       |
# |    value_loss           | 0.00431     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 29          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.017580792 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0391      |
# |    explained_variance   | -23         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0277     |
# |    n_updates            | 8610        |
# |    policy_gradient_loss | 0.00516     |
# |    std                  | 0.236       |
# |    value_loss           | 0.00322     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 30          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020863686 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0481      |
# |    explained_variance   | 0.000645    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.035       |
# |    n_updates            | 8620        |
# |    policy_gradient_loss | 0.00475     |
# |    std                  | 0.237       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 31          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.023952808 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0547      |
# |    explained_variance   | -111        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0124      |
# |    n_updates            | 8630        |
# |    policy_gradient_loss | 0.00771     |
# |    std                  | 0.235       |
# |    value_loss           | 0.0206      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 32          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.029192023 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0699      |
# |    explained_variance   | -22.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00881    |
# |    n_updates            | 8640        |
# |    policy_gradient_loss | 0.00941     |
# |    std                  | 0.234       |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 33          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.018665144 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0861      |
# |    explained_variance   | -29.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0261      |
# |    n_updates            | 8650        |
# |    policy_gradient_loss | 0.00184     |
# |    std                  | 0.231       |
# |    value_loss           | 0.0055      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 34          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.030856257 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0856      |
# |    explained_variance   | -11.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0198     |
# |    n_updates            | 8660        |
# |    policy_gradient_loss | 0.00485     |
# |    std                  | 0.233       |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.36        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 35          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.021509597 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0791      |
# |    explained_variance   | -11.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00168     |
# |    n_updates            | 8670        |
# |    policy_gradient_loss | 0.00613     |
# |    std                  | 0.233       |
# |    value_loss           | 0.00653     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 36          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016157655 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0897      |
# |    explained_variance   | -29.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00239     |
# |    n_updates            | 8680        |
# |    policy_gradient_loss | 0.0101      |
# |    std                  | 0.231       |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 37          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022344802 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0924      |
# |    explained_variance   | 0.000681    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00298    |
# |    n_updates            | 8690        |
# |    policy_gradient_loss | 0.00536     |
# |    std                  | 0.232       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 38          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.023746502 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0888      |
# |    explained_variance   | -136        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00279    |
# |    n_updates            | 8700        |
# |    policy_gradient_loss | 0.00202     |
# |    std                  | 0.232       |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 39          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.031557284 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0884      |
# |    explained_variance   | -10.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 8710        |
# |    policy_gradient_loss | 0.00572     |
# |    std                  | 0.232       |
# |    value_loss           | 0.0015      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 40         |
# |    time_elapsed         | 327        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02286221 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.094      |
# |    explained_variance   | -10.4      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0155    |
# |    n_updates            | 8720       |
# |    policy_gradient_loss | 0.00512    |
# |    std                  | 0.23       |
# |    value_loss           | 0.00306    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.3        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 41         |
# |    time_elapsed         | 335        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02018888 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0977     |
# |    explained_variance   | 0.000925   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0066     |
# |    n_updates            | 8730       |
# |    policy_gradient_loss | 0.0052     |
# |    std                  | 0.231      |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 42          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.030496947 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.105       |
# |    explained_variance   | -118        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0171      |
# |    n_updates            | 8740        |
# |    policy_gradient_loss | -0.000155   |
# |    std                  | 0.229       |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 43          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020570952 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.101       |
# |    explained_variance   | -21.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0208      |
# |    n_updates            | 8750        |
# |    policy_gradient_loss | 0.00669     |
# |    std                  | 0.231       |
# |    value_loss           | 0.00705     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 44          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.026291337 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0852      |
# |    explained_variance   | -28.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 8760        |
# |    policy_gradient_loss | 0.00342     |
# |    std                  | 0.232       |
# |    value_loss           | 0.00753     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 45          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.016581649 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0926      |
# |    explained_variance   | -96.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0211      |
# |    n_updates            | 8770        |
# |    policy_gradient_loss | 0.00894     |
# |    std                  | 0.23        |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 46          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.023127045 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.102       |
# |    explained_variance   | -22.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00192     |
# |    n_updates            | 8780        |
# |    policy_gradient_loss | 0.00416     |
# |    std                  | 0.23        |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 47          |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.034547545 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0968      |
# |    explained_variance   | -54.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00752    |
# |    n_updates            | 8790        |
# |    policy_gradient_loss | -0.000789   |
# |    std                  | 0.231       |
# |    value_loss           | 0.00952     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 48          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020604035 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.11        |
# |    explained_variance   | -11         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 8800        |
# |    policy_gradient_loss | 0.00648     |
# |    std                  | 0.228       |
# |    value_loss           | 0.00135     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 49         |
# |    time_elapsed         | 401        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.03966865 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.114      |
# |    explained_variance   | 0.00089    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0372     |
# |    n_updates            | 8810       |
# |    policy_gradient_loss | 0.00441    |
# |    std                  | 0.229      |
# |    value_loss           | 488        |
# ----------------------------------------
# --- 403.2861502170563 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.37     |
# |    ep_rew_mean     | -9.01    |
# | time/              |          |
# |    fps             | 312      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020344984 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.144      |
# |    explained_variance   | 0.000469    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0268      |
# |    n_updates            | 8340        |
# |    policy_gradient_loss | 0.00311     |
# |    std                  | 0.26        |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.021357935 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.137      |
# |    explained_variance   | 0.00134     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0533      |
# |    n_updates            | 8350        |
# |    policy_gradient_loss | 0.00355     |
# |    std                  | 0.26        |
# |    value_loss           | 1.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.037920758 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.122      |
# |    explained_variance   | 0.00208     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 8360        |
# |    policy_gradient_loss | 0.00223     |
# |    std                  | 0.256       |
# |    value_loss           | 977         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.37        |
# ...
# |    explained_variance   | -714        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0869      |
# |    n_updates            | 8640        |
# |    policy_gradient_loss | 0.0064      |
# |    std                  | 0.23        |
# |    value_loss           | 0.0837      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.27       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 33         |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02434638 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.118      |
# |    explained_variance   | 0.0455     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.142      |
# |    n_updates            | 8650       |
# |    policy_gradient_loss | 0.00584    |
# |    std                  | 0.228      |
# |    value_loss           | 873        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 34          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.024171568 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.139       |
# |    explained_variance   | -287        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000825    |
# |    n_updates            | 8660        |
# |    policy_gradient_loss | 0.00621     |
# |    std                  | 0.225       |
# |    value_loss           | 0.0242      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.37        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 35          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.033073176 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.151       |
# |    explained_variance   | -128        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0182      |
# |    n_updates            | 8670        |
# |    policy_gradient_loss | 0.0076      |
# |    std                  | 0.225       |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 36         |
# |    time_elapsed         | 195        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02183719 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.15       |
# |    explained_variance   | -57.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0129     |
# |    n_updates            | 8680       |
# |    policy_gradient_loss | 0.00459    |
# |    std                  | 0.226      |
# |    value_loss           | 0.011      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 37          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011496982 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.151       |
# |    explained_variance   | -135        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 8690        |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.225       |
# |    value_loss           | 0.0236      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 38          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.026531752 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.157       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.246       |
# |    n_updates            | 8700        |
# |    policy_gradient_loss | 0.00318     |
# |    std                  | 0.224       |
# |    value_loss           | 785         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.02       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 39         |
# |    time_elapsed         | 212        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.02768479 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.159      |
# |    explained_variance   | -0.00123   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00986   |
# |    n_updates            | 8710       |
# |    policy_gradient_loss | 0.000878   |
# |    std                  | 0.224      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 40          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018340088 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.16        |
# |    explained_variance   | -71.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0136      |
# |    n_updates            | 8720        |
# |    policy_gradient_loss | 0.0104      |
# |    std                  | 0.224       |
# |    value_loss           | 0.0292      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 41          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021087792 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.175       |
# |    explained_variance   | -17.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.334       |
# |    n_updates            | 8730        |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.221       |
# |    value_loss           | 0.627       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 42          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.027067333 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.182       |
# |    explained_variance   | -111        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0557      |
# |    n_updates            | 8740        |
# |    policy_gradient_loss | 0.00106     |
# |    std                  | 0.222       |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 43          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017208628 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.169       |
# |    explained_variance   | -145        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0609      |
# |    n_updates            | 8750        |
# |    policy_gradient_loss | 0.00271     |
# |    std                  | 0.223       |
# |    value_loss           | 0.196       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.33       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 44         |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01271979 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.171      |
# |    explained_variance   | -260       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00269   |
# |    n_updates            | 8760       |
# |    policy_gradient_loss | 0.000914   |
# |    std                  | 0.223      |
# |    value_loss           | 0.0515     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 45          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.029710472 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.177       |
# |    explained_variance   | -233        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0467      |
# |    n_updates            | 8770        |
# |    policy_gradient_loss | 0.00828     |
# |    std                  | 0.221       |
# |    value_loss           | 0.0212      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.39       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 46         |
# |    time_elapsed         | 250        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.02359312 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.2        |
# |    explained_variance   | -102       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0194    |
# |    n_updates            | 8780       |
# |    policy_gradient_loss | 0.00179    |
# |    std                  | 0.218      |
# |    value_loss           | 0.0167     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 47          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018858396 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.213       |
# |    explained_variance   | -69.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0199      |
# |    n_updates            | 8790        |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.218       |
# |    value_loss           | 0.00901     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 48          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022806136 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.228       |
# |    explained_variance   | -35.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0267      |
# |    n_updates            | 8800        |
# |    policy_gradient_loss | 0.00853     |
# |    std                  | 0.215       |
# |    value_loss           | 0.0067      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.36        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 49          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.026958635 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.251       |
# |    explained_variance   | -58         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0158      |
# |    n_updates            | 8810        |
# |    policy_gradient_loss | -0.00152    |
# |    std                  | 0.214       |
# |    value_loss           | 0.0129      |
# -----------------------------------------
# --- 268.57478427886963 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-400000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.98 +/- 4.48
# Focus Polytopes:
# mean_reward:0.96 +/- 6.33
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.85 +/- 12.26
# Focus Polytopes:
# mean_reward:0.71 +/- 17.04
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:1.00 +/- 0.00
# Focus Polytopes:
# mean_reward:0.90 +/- 10.01
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.95 +/- 7.08
# Focus Polytopes:
# mean_reward:-0.39 +/- 37.29
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.43 +/- 23.89
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.96 +/- 6.33
# Focus Polytopes:
# mean_reward:0.55 +/- 21.23

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-400000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-500000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.33     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 342      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.041977957 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.115       |
# |    explained_variance   | 0.00427     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0197      |
# |    n_updates            | 8830        |
# |    policy_gradient_loss | 0.00745     |
# |    std                  | 0.228       |
# |    value_loss           | 487         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 277        |
# |    iterations           | 3          |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.06412484 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.122      |
# |    explained_variance   | -192       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0128     |
# |    n_updates            | 8840       |
# |    policy_gradient_loss | 0.0058     |
# |    std                  | 0.228      |
# |    value_loss           | 0.0129     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 269        |
# |    iterations           | 4          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.05355718 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.124      |
# |    explained_variance   | -3.28e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00391    |
# |    n_updates            | 8850       |
# |    policy_gradient_loss | -0.00572   |
# |    std                  | 0.227      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.024466781 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.122       |
# |    explained_variance   | -88.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00539     |
# |    n_updates            | 8860        |
# |    policy_gradient_loss | 0.0043      |
# |    std                  | 0.229       |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.13      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 264       |
# |    iterations           | 6         |
# |    time_elapsed         | 46        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0195898 |
# |    clip_fraction        | 0.202     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.116     |
# |    explained_variance   | -31.1     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0311    |
# |    n_updates            | 8870      |
# |    policy_gradient_loss | 0.0051    |
# |    std                  | 0.229     |
# |    value_loss           | 0.0021    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 7           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.025699593 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.12        |
# |    explained_variance   | -22.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0545      |
# |    n_updates            | 8880        |
# |    policy_gradient_loss | 0.00584     |
# |    std                  | 0.227       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 8           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020401768 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.129       |
# |    explained_variance   | -34.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00807     |
# |    n_updates            | 8890        |
# |    policy_gradient_loss | 0.0061      |
# |    std                  | 0.227       |
# |    value_loss           | 0.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 9           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026426326 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.134       |
# |    explained_variance   | 7.69e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00514     |
# |    n_updates            | 8900        |
# |    policy_gradient_loss | 0.0142      |
# |    std                  | 0.226       |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 10          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.027719684 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.139       |
# |    explained_variance   | -104        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 8910        |
# |    policy_gradient_loss | 0.00536     |
# |    std                  | 0.226       |
# |    value_loss           | 0.00293     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 11          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017999526 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.14        |
# |    explained_variance   | -125        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00859     |
# |    n_updates            | 8920        |
# |    policy_gradient_loss | 0.00759     |
# |    std                  | 0.226       |
# |    value_loss           | 0.00566     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.25      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 12        |
# |    time_elapsed         | 95        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0389119 |
# |    clip_fraction        | 0.26      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.134     |
# |    explained_variance   | -26       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0488    |
# |    n_updates            | 8930      |
# |    policy_gradient_loss | 0.00763   |
# |    std                  | 0.227     |
# |    value_loss           | 0.00212   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 13          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.031266816 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.135       |
# |    explained_variance   | -5.03       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00755     |
# |    n_updates            | 8940        |
# |    policy_gradient_loss | 0.0029      |
# |    std                  | 0.226       |
# |    value_loss           | 0.00428     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 256        |
# |    iterations           | 14         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01556618 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.137      |
# |    explained_variance   | -1.84      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00339   |
# |    n_updates            | 8950       |
# |    policy_gradient_loss | 0.00458    |
# |    std                  | 0.227      |
# |    value_loss           | 0.000715   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 15          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016256608 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.133       |
# |    explained_variance   | -27.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 8960        |
# |    policy_gradient_loss | 0.00628     |
# |    std                  | 0.227       |
# |    value_loss           | 0.0031      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 16         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.04386665 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.129      |
# |    explained_variance   | -8.09      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.042     |
# |    n_updates            | 8970       |
# |    policy_gradient_loss | -0.00299   |
# |    std                  | 0.228      |
# |    value_loss           | 0.005      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 17          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.031309314 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.129       |
# |    explained_variance   | -14.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 8980        |
# |    policy_gradient_loss | 0.00591     |
# |    std                  | 0.228       |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 18          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.030473117 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.145       |
# |    explained_variance   | -9.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0178      |
# |    n_updates            | 8990        |
# |    policy_gradient_loss | 0.00181     |
# |    std                  | 0.225       |
# |    value_loss           | 0.00364     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 19          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019128373 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.152       |
# |    explained_variance   | -6.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 9000        |
# |    policy_gradient_loss | 0.0038      |
# |    std                  | 0.226       |
# |    value_loss           | 0.00257     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 20          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.027323823 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.157       |
# |    explained_variance   | -18.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0312      |
# |    n_updates            | 9010        |
# |    policy_gradient_loss | 0.00508     |
# |    std                  | 0.224       |
# |    value_loss           | 0.0033      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 21          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016990531 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.162       |
# |    explained_variance   | -25.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0353      |
# |    n_updates            | 9020        |
# |    policy_gradient_loss | 0.00703     |
# |    std                  | 0.224       |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 22          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020427965 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.158       |
# |    explained_variance   | -10.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.011       |
# |    n_updates            | 9030        |
# |    policy_gradient_loss | 0.00379     |
# |    std                  | 0.225       |
# |    value_loss           | 0.0022      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 23          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011308318 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.166       |
# |    explained_variance   | -7.81       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0049     |
# |    n_updates            | 9040        |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.222       |
# |    value_loss           | 0.0091      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 24          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.030166768 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.185       |
# |    explained_variance   | -7.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00539    |
# |    n_updates            | 9050        |
# |    policy_gradient_loss | 0.0095      |
# |    std                  | 0.221       |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 25          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023378503 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.189       |
# |    explained_variance   | -1.86       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0198      |
# |    n_updates            | 9060        |
# |    policy_gradient_loss | 0.0103      |
# |    std                  | 0.221       |
# |    value_loss           | 0.00275     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.47        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 26          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.021166861 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.205       |
# |    explained_variance   | -14.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00772    |
# |    n_updates            | 9070        |
# |    policy_gradient_loss | 0.00622     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00161     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.92       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 254        |
# |    iterations           | 27         |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03743106 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.216      |
# |    explained_variance   | -11.2      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0047     |
# |    n_updates            | 9080       |
# |    policy_gradient_loss | 0.00262    |
# |    std                  | 0.217      |
# |    value_loss           | 0.00769    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 28          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016569592 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.219       |
# |    explained_variance   | -30.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0322      |
# |    n_updates            | 9090        |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 0.217       |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 29          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.019866224 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.218       |
# |    explained_variance   | -1.9        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0343      |
# |    n_updates            | 9100        |
# |    policy_gradient_loss | 0.00783     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00512     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 30          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.028684083 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.215       |
# |    explained_variance   | -1.96       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0165      |
# |    n_updates            | 9110        |
# |    policy_gradient_loss | 0.00534     |
# |    std                  | 0.218       |
# |    value_loss           | 0.000344    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 254        |
# |    iterations           | 31         |
# |    time_elapsed         | 249        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02358795 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.196      |
# |    explained_variance   | -2.1       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0062    |
# |    n_updates            | 9120       |
# |    policy_gradient_loss | 0.00572    |
# |    std                  | 0.221      |
# |    value_loss           | 0.00103    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 32          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.024721209 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.176       |
# |    explained_variance   | -9.48       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000149   |
# |    n_updates            | 9130        |
# |    policy_gradient_loss | 0.00924     |
# |    std                  | 0.222       |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 33          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.022972059 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.191       |
# |    explained_variance   | -7.25       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00793    |
# |    n_updates            | 9140        |
# |    policy_gradient_loss | 0.0025      |
# |    std                  | 0.219       |
# |    value_loss           | 0.00506     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 34          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016320834 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.213       |
# |    explained_variance   | -24.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0252      |
# |    n_updates            | 9150        |
# |    policy_gradient_loss | 0.00967     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00195     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 35          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.027963381 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.227       |
# |    explained_variance   | -8.54       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00136    |
# |    n_updates            | 9160        |
# |    policy_gradient_loss | 0.00194     |
# |    std                  | 0.215       |
# |    value_loss           | 0.000996    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 36          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.019686338 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.234       |
# |    explained_variance   | -1.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 9170        |
# |    policy_gradient_loss | 0.00877     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00365     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.29        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 37          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.018371498 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.253       |
# |    explained_variance   | -17.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0063     |
# |    n_updates            | 9180        |
# |    policy_gradient_loss | 0.00636     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00125     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 254        |
# |    iterations           | 38         |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02664064 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.265      |
# |    explained_variance   | -1.65      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0248    |
# |    n_updates            | 9190       |
# |    policy_gradient_loss | 0.00536    |
# |    std                  | 0.212      |
# |    value_loss           | 0.0104     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 39          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015590014 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.279       |
# |    explained_variance   | -5.1        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00771    |
# |    n_updates            | 9200        |
# |    policy_gradient_loss | 0.00415     |
# |    std                  | 0.21        |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 40         |
# |    time_elapsed         | 322        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.04701656 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.268      |
# |    explained_variance   | -0.643     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0324    |
# |    n_updates            | 9210       |
# |    policy_gradient_loss | 0.00261    |
# |    std                  | 0.213      |
# |    value_loss           | 0.00458    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 41         |
# |    time_elapsed         | 330        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.09590175 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.248      |
# |    explained_variance   | -18.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00727   |
# |    n_updates            | 9220       |
# |    policy_gradient_loss | 0.00193    |
# |    std                  | 0.214      |
# |    value_loss           | 0.00198    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 42          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.035971813 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.248       |
# |    explained_variance   | -5.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0134      |
# |    n_updates            | 9230        |
# |    policy_gradient_loss | 0.0139      |
# |    std                  | 0.213       |
# |    value_loss           | 0.00312     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 43          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017509693 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.243       |
# |    explained_variance   | 0.00031     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00168    |
# |    n_updates            | 9240        |
# |    policy_gradient_loss | 0.00935     |
# |    std                  | 0.216       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 44          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011202292 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.238       |
# |    explained_variance   | -349        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0197      |
# |    n_updates            | 9250        |
# |    policy_gradient_loss | 0.00886     |
# |    std                  | 0.215       |
# |    value_loss           | 0.0225      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 45          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018640336 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.263       |
# |    explained_variance   | -37.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0099     |
# |    n_updates            | 9260        |
# |    policy_gradient_loss | 0.00426     |
# |    std                  | 0.211       |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.36        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 46          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.030872246 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.271       |
# |    explained_variance   | -10.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.052       |
# |    n_updates            | 9270        |
# |    policy_gradient_loss | 0.00936     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00557     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.33      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 253       |
# |    iterations           | 47        |
# |    time_elapsed         | 379       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0256267 |
# |    clip_fraction        | 0.187     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.26      |
# |    explained_variance   | -118      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00254  |
# |    n_updates            | 9280      |
# |    policy_gradient_loss | 0.00535   |
# |    std                  | 0.213     |
# |    value_loss           | 0.00244   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 48          |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.027717743 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.263       |
# |    explained_variance   | -9.63       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000777    |
# |    n_updates            | 9290        |
# |    policy_gradient_loss | 0.00419     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 49          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.022977408 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.258       |
# |    explained_variance   | -56.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0284      |
# |    n_updates            | 9300        |
# |    policy_gradient_loss | 0.00939     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00656     |
# -----------------------------------------
# --- 398.60524439811707 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.22     |
# |    ep_rew_mean     | -9.01    |
# | time/              |          |
# |    fps             | 341      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.023667846 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.235       |
# |    explained_variance   | 0.00196     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0263      |
# |    n_updates            | 8830        |
# |    policy_gradient_loss | 0.00258     |
# |    std                  | 0.214       |
# |    value_loss           | 1.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.035253488 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.272       |
# |    explained_variance   | 0.00257     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0578      |
# |    n_updates            | 8840        |
# |    policy_gradient_loss | 0.00267     |
# |    std                  | 0.21        |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.025652703 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.294       |
# |    explained_variance   | 0.000884    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0063      |
# |    n_updates            | 8850        |
# |    policy_gradient_loss | 0.000466    |
# |    std                  | 0.209       |
# |    value_loss           | 489         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.33      |
# |    ep_rew_mean          | -9.01     |
# | time/                   |           |
# |    fps                  | 270       |
# |    iterations           | 5         |
# |    time_elapsed         | 37        |
# ...
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.311      |
# |    explained_variance   | -19.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00493    |
# |    n_updates            | 9130       |
# |    policy_gradient_loss | 0.012      |
# |    std                  | 0.209      |
# |    value_loss           | 0.0037     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 33         |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02010658 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.319      |
# |    explained_variance   | -6.07      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0204    |
# |    n_updates            | 9140       |
# |    policy_gradient_loss | 0.012      |
# |    std                  | 0.21       |
# |    value_loss           | 0.00207    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 34          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.024628788 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.316       |
# |    explained_variance   | -6.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 9150        |
# |    policy_gradient_loss | 0.0103      |
# |    std                  | 0.21        |
# |    value_loss           | 0.00582     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 35          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017800663 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.326       |
# |    explained_variance   | -26.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0218      |
# |    n_updates            | 9160        |
# |    policy_gradient_loss | 0.0129      |
# |    std                  | 0.208       |
# |    value_loss           | 0.00787     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 36          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023534195 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.319       |
# |    explained_variance   | -40.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0278      |
# |    n_updates            | 9170        |
# |    policy_gradient_loss | 0.00723     |
# |    std                  | 0.21        |
# |    value_loss           | 0.00963     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 382        |
# |    iterations           | 37         |
# |    time_elapsed         | 198        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.03567908 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.313      |
# |    explained_variance   | -6.63      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.019      |
# |    n_updates            | 9180       |
# |    policy_gradient_loss | 0.0123     |
# |    std                  | 0.209      |
# |    value_loss           | 0.00474    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.1        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 382        |
# |    iterations           | 38         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02288324 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.325      |
# |    explained_variance   | -21.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00331   |
# |    n_updates            | 9190       |
# |    policy_gradient_loss | 0.011      |
# |    std                  | 0.208      |
# |    value_loss           | 0.00305    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 39          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.021924516 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.332       |
# |    explained_variance   | -9.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0327      |
# |    n_updates            | 9200        |
# |    policy_gradient_loss | 0.0117      |
# |    std                  | 0.208       |
# |    value_loss           | 0.00362     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 40          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.024361573 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.316       |
# |    explained_variance   | -19.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 9210        |
# |    policy_gradient_loss | 0.0119      |
# |    std                  | 0.211       |
# |    value_loss           | 0.00891     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 41          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015564425 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.293       |
# |    explained_variance   | -50.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0208      |
# |    n_updates            | 9220        |
# |    policy_gradient_loss | 0.0147      |
# |    std                  | 0.213       |
# |    value_loss           | 0.00616     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.26       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 42         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.02449837 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.295      |
# |    explained_variance   | -6.55      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0107    |
# |    n_updates            | 9230       |
# |    policy_gradient_loss | 0.0123     |
# |    std                  | 0.212      |
# |    value_loss           | 0.00408    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 43          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.022897048 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.314       |
# |    explained_variance   | -3.43       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 9240        |
# |    policy_gradient_loss | 0.00516     |
# |    std                  | 0.209       |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.09       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 44         |
# |    time_elapsed         | 236        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.39475143 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.324      |
# |    explained_variance   | -13.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0682    |
# |    n_updates            | 9250       |
# |    policy_gradient_loss | 0.022      |
# |    std                  | 0.208      |
# |    value_loss           | 0.00694    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 45          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.016800765 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.337       |
# |    explained_variance   | -26.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 9260        |
# |    policy_gradient_loss | 0.0103      |
# |    std                  | 0.206       |
# |    value_loss           | 0.00238     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 46          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015992498 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.344       |
# |    explained_variance   | -3.79       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 9270        |
# |    policy_gradient_loss | 0.00862     |
# |    std                  | 0.206       |
# |    value_loss           | 0.00702     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 47          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017516037 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.352       |
# |    explained_variance   | -19.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 9280        |
# |    policy_gradient_loss | 0.00948     |
# |    std                  | 0.204       |
# |    value_loss           | 0.00375     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.24       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 48         |
# |    time_elapsed         | 257        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.03712555 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.369      |
# |    explained_variance   | -8.19      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0164    |
# |    n_updates            | 9290       |
# |    policy_gradient_loss | 0.0128     |
# |    std                  | 0.203      |
# |    value_loss           | 0.00326    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 380        |
# |    iterations           | 49         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.03622806 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.362      |
# |    explained_variance   | -8.95      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0193     |
# |    n_updates            | 9300       |
# |    policy_gradient_loss | 0.00441    |
# |    std                  | 0.205      |
# |    value_loss           | 0.00484    |
# ----------------------------------------
# --- 265.49797797203064 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-500000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.92 +/- 8.95
# Focus Polytopes:
# mean_reward:1.00 +/- 0.00
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.81 +/- 13.80
# Focus Polytopes:
# mean_reward:0.58 +/- 20.51
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:1.00 +/- 0.00
# Focus Polytopes:
# mean_reward:0.96 +/- 6.33
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:1.00 +/- 0.00
# Focus Polytopes:
# mean_reward:0.92 +/- 8.95
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:1.00 +/- 0.00
# Focus Polytopes:
# mean_reward:0.59 +/- 20.26
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.97 +/- 5.48
# Focus Polytopes:
# mean_reward:0.67 +/- 18.18

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-500000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-600000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.19     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 318      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.034706473 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.271       |
# |    explained_variance   | -4.64       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0249     |
# |    n_updates            | 9320        |
# |    policy_gradient_loss | 0.0042      |
# |    std                  | 0.212       |
# |    value_loss           | 0.00173     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017001864 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.263       |
# |    explained_variance   | -19.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00193     |
# |    n_updates            | 9330        |
# |    policy_gradient_loss | 0.0128      |
# |    std                  | 0.212       |
# |    value_loss           | 0.000597    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.050486304 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.256       |
# |    explained_variance   | -0.271      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00818     |
# |    n_updates            | 9340        |
# |    policy_gradient_loss | 0.00396     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 2.18     |
# |    ep_rew_mean          | 1        |
# | time/                   |          |
# |    fps                  | 264      |
# |    iterations           | 5        |
# |    time_elapsed         | 38       |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 0.091482 |
# |    clip_fraction        | 0.206    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0.243    |
# |    explained_variance   | -9.23    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00414  |
# |    n_updates            | 9350     |
# |    policy_gradient_loss | 0.00665  |
# |    std                  | 0.215    |
# |    value_loss           | 0.00321  |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.92       |
# |    ep_rew_mean          | -9.01      |
# | time/                   |            |
# |    fps                  | 263        |
# |    iterations           | 6          |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.03236936 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.231      |
# |    explained_variance   | -15.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00568    |
# |    n_updates            | 9360       |
# |    policy_gradient_loss | -0.0014    |
# |    std                  | 0.216      |
# |    value_loss           | 0.00442    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 7           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024418477 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.222       |
# |    explained_variance   | 0.000481    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 9370        |
# |    policy_gradient_loss | 0.00188     |
# |    std                  | 0.217       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 8           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023875345 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.212       |
# |    explained_variance   | -111        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 9380        |
# |    policy_gradient_loss | 0.000574    |
# |    std                  | 0.218       |
# |    value_loss           | 0.00736     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 9           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022671513 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.213       |
# |    explained_variance   | -11.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00602     |
# |    n_updates            | 9390        |
# |    policy_gradient_loss | 0.00955     |
# |    std                  | 0.217       |
# |    value_loss           | 0.000507    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.15       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 260        |
# |    iterations           | 10         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.03647225 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.225      |
# |    explained_variance   | -2.45      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0161    |
# |    n_updates            | 9400       |
# |    policy_gradient_loss | 0.0049     |
# |    std                  | 0.215      |
# |    value_loss           | 0.00376    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 11          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.018063655 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.219       |
# |    explained_variance   | -7.88       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0334      |
# |    n_updates            | 9410        |
# |    policy_gradient_loss | 0.00571     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 12          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015136128 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.202       |
# |    explained_variance   | -35.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0259     |
# |    n_updates            | 9420        |
# |    policy_gradient_loss | 0.0136      |
# |    std                  | 0.219       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 13          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018986812 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.222       |
# |    explained_variance   | -17         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 9430        |
# |    policy_gradient_loss | 0.00585     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 14          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.024207752 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.229       |
# |    explained_variance   | -15         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00971    |
# |    n_updates            | 9440        |
# |    policy_gradient_loss | 0.00215     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 258        |
# |    iterations           | 15         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02072052 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.201      |
# |    explained_variance   | -30.2      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0167    |
# |    n_updates            | 9450       |
# |    policy_gradient_loss | 0.00417    |
# |    std                  | 0.22       |
# |    value_loss           | 0.00464    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 16          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022334393 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.186       |
# |    explained_variance   | -12.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0191      |
# |    n_updates            | 9460        |
# |    policy_gradient_loss | 0.00368     |
# |    std                  | 0.221       |
# |    value_loss           | 0.00164     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 17          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.038165703 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.192       |
# |    explained_variance   | -0.501      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.037       |
# |    n_updates            | 9470        |
# |    policy_gradient_loss | 0.0129      |
# |    std                  | 0.22        |
# |    value_loss           | 0.000242    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 18          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017183904 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.181       |
# |    explained_variance   | -7.87       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 9480        |
# |    policy_gradient_loss | 0.000865    |
# |    std                  | 0.222       |
# |    value_loss           | 0.00415     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 19         |
# |    time_elapsed         | 150        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03103595 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.166      |
# |    explained_variance   | -25.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00357    |
# |    n_updates            | 9490       |
# |    policy_gradient_loss | 0.00946    |
# |    std                  | 0.223      |
# |    value_loss           | 0.00145    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 20          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.032392494 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.171       |
# |    explained_variance   | -54.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0108      |
# |    n_updates            | 9500        |
# |    policy_gradient_loss | 0.0014      |
# |    std                  | 0.221       |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 21          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.026962418 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.176       |
# |    explained_variance   | -22.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00163    |
# |    n_updates            | 9510        |
# |    policy_gradient_loss | 0.00651     |
# |    std                  | 0.222       |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 22          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019998772 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.164       |
# |    explained_variance   | -6.88       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 9520        |
# |    policy_gradient_loss | 0.00292     |
# |    std                  | 0.223       |
# |    value_loss           | 0.000908    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 23         |
# |    time_elapsed         | 183        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.05216545 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.166      |
# |    explained_variance   | -1.01      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0194    |
# |    n_updates            | 9530       |
# |    policy_gradient_loss | 0.0109     |
# |    std                  | 0.223      |
# |    value_loss           | 0.000547   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 24          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.024481941 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.17        |
# |    explained_variance   | -4.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0524      |
# |    n_updates            | 9540        |
# |    policy_gradient_loss | 0.00273     |
# |    std                  | 0.222       |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 25          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.030125111 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.168       |
# |    explained_variance   | 0.00019     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000506   |
# |    n_updates            | 9550        |
# |    policy_gradient_loss | 0.016       |
# |    std                  | 0.223       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 26          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.017746141 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.19        |
# |    explained_variance   | -96.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000654    |
# |    n_updates            | 9560        |
# |    policy_gradient_loss | 0.00432     |
# |    std                  | 0.218       |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.76        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 27          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.025642436 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.212       |
# |    explained_variance   | -35.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00641     |
# |    n_updates            | 9570        |
# |    policy_gradient_loss | 0.000921    |
# |    std                  | 0.217       |
# |    value_loss           | 0.00494     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 28          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016563576 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.225       |
# |    explained_variance   | -31.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0572      |
# |    n_updates            | 9580        |
# |    policy_gradient_loss | 0.00299     |
# |    std                  | 0.215       |
# |    value_loss           | 0.0015      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 29          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.019535381 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.245       |
# |    explained_variance   | 0.00174     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0753      |
# |    n_updates            | 9590        |
# |    policy_gradient_loss | 0.006       |
# |    std                  | 0.213       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 30          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020059738 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.251       |
# |    explained_variance   | 0.00563     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0588      |
# |    n_updates            | 9600        |
# |    policy_gradient_loss | 0.00179     |
# |    std                  | 0.213       |
# |    value_loss           | 486         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.28        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 31          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.025935628 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.252       |
# |    explained_variance   | -288        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00645     |
# |    n_updates            | 9610        |
# |    policy_gradient_loss | 0.00573     |
# |    std                  | 0.214       |
# |    value_loss           | 0.021       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 256        |
# |    iterations           | 32         |
# |    time_elapsed         | 255        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.04090335 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.251      |
# |    explained_variance   | -57.4      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0769     |
# |    n_updates            | 9620       |
# |    policy_gradient_loss | 0.00606    |
# |    std                  | 0.213      |
# |    value_loss           | 0.00506    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 33          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016984822 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.253       |
# |    explained_variance   | -20.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.098       |
# |    n_updates            | 9630        |
# |    policy_gradient_loss | 0.00857     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00243     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 34          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.031220816 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.251       |
# |    explained_variance   | -118        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0134      |
# |    n_updates            | 9640        |
# |    policy_gradient_loss | 0.00591     |
# |    std                  | 0.213       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.87       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 35         |
# |    time_elapsed         | 280        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01533405 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.257      |
# |    explained_variance   | -150       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00125   |
# |    n_updates            | 9650       |
# |    policy_gradient_loss | 0.00496    |
# |    std                  | 0.213      |
# |    value_loss           | 0.00845    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 36          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.027254108 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.263       |
# |    explained_variance   | -25.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0423      |
# |    n_updates            | 9660        |
# |    policy_gradient_loss | 0.00194     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00349     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 37          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.026478589 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.254       |
# |    explained_variance   | -19.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | 0.0104      |
# |    std                  | 0.214       |
# |    value_loss           | 0.00143     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 38          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.019477373 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.236       |
# |    explained_variance   | -6.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0439     |
# |    n_updates            | 9680        |
# |    policy_gradient_loss | 0.00761     |
# |    std                  | 0.216       |
# |    value_loss           | 0.000208    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.87       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 39         |
# |    time_elapsed         | 312        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.05901786 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.225      |
# |    explained_variance   | -1.43      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00208    |
# |    n_updates            | 9690       |
# |    policy_gradient_loss | -0.00324   |
# |    std                  | 0.216      |
# |    value_loss           | 0.0127     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.88       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 40         |
# |    time_elapsed         | 320        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03955041 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.213      |
# |    explained_variance   | -90.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0289     |
# |    n_updates            | 9700       |
# |    policy_gradient_loss | 0.0105     |
# |    std                  | 0.219      |
# |    value_loss           | 0.00507    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 41          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.024600197 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.199       |
# |    explained_variance   | -8.3        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0137      |
# |    n_updates            | 9710        |
# |    policy_gradient_loss | 0.0108      |
# |    std                  | 0.219       |
# |    value_loss           | 0.00117     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.07       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 42         |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.08147816 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.193      |
# |    explained_variance   | -4.04      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00622   |
# |    n_updates            | 9720       |
# |    policy_gradient_loss | 0.00612    |
# |    std                  | 0.22       |
# |    value_loss           | 0.00136    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 43         |
# |    time_elapsed         | 345        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.03813364 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.207      |
# |    explained_variance   | -3.68      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0327     |
# |    n_updates            | 9730       |
# |    policy_gradient_loss | 0.00648    |
# |    std                  | 0.217      |
# |    value_loss           | 0.000906   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 44         |
# |    time_elapsed         | 353        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.04278139 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.212      |
# |    explained_variance   | -4.34      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0345    |
# |    n_updates            | 9740       |
# |    policy_gradient_loss | 0.00746    |
# |    std                  | 0.218      |
# |    value_loss           | 0.00076    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 45          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.034779392 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.213       |
# |    explained_variance   | -1.3        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | 0.00847     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00227     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 254        |
# |    iterations           | 46         |
# |    time_elapsed         | 369        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.02920603 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.195      |
# |    explained_variance   | -41.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0577    |
# |    n_updates            | 9760       |
# |    policy_gradient_loss | 0.00568    |
# |    std                  | 0.221      |
# |    value_loss           | 0.00318    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 47          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014707113 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.176       |
# |    explained_variance   | -2.77       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0182     |
# |    n_updates            | 9770        |
# |    policy_gradient_loss | 0.0035      |
# |    std                  | 0.222       |
# |    value_loss           | 0.0056      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 254        |
# |    iterations           | 48         |
# |    time_elapsed         | 385        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02282644 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.185      |
# |    explained_variance   | -88.2      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0134     |
# |    n_updates            | 9780       |
# |    policy_gradient_loss | 0.0103     |
# |    std                  | 0.22       |
# |    value_loss           | 0.00106    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 254        |
# |    iterations           | 49         |
# |    time_elapsed         | 393        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.02347922 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.202      |
# |    explained_variance   | -0.697     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00312    |
# |    n_updates            | 9790       |
# |    policy_gradient_loss | 0.00349    |
# |    std                  | 0.218      |
# |    value_loss           | 0.00362    |
# ----------------------------------------
# --- 395.7523684501648 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.87     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 331      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.95      |
# |    ep_rew_mean          | -9.01     |
# | time/                   |           |
# |    fps                  | 288       |
# |    iterations           | 2         |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0568275 |
# |    clip_fraction        | 0.299     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.8       |
# |    explained_variance   | 0.00151   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.159     |
# |    n_updates            | 9320      |
# |    policy_gradient_loss | 0.00616   |
# |    std                  | 0.161     |
# |    value_loss           | 1.46e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.026283689 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.831       |
# |    explained_variance   | 0.000237    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0495      |
# |    n_updates            | 9330        |
# |    policy_gradient_loss | 0.00903     |
# |    std                  | 0.159       |
# |    value_loss           | 977         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 274        |
# |    iterations           | 4          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.15338609 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.84       |
# |    explained_variance   | 0.00166    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0216     |
# |    n_updates            | 9340       |
# |    policy_gradient_loss | -0.0019    |
# |    std                  | 0.16       |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# ...
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.32        |
# |    explained_variance   | -3.08       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00746     |
# |    n_updates            | 9620        |
# |    policy_gradient_loss | 0.00154     |
# |    std                  | 0.209       |
# |    value_loss           | 0.00378     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.28        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 33          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.051589742 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.318       |
# |    explained_variance   | -4.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 9630        |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.211       |
# |    value_loss           | 0.00678     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.49       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 34         |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.04630292 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.318      |
# |    explained_variance   | -6.09      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0063    |
# |    n_updates            | 9640       |
# |    policy_gradient_loss | 0.0029     |
# |    std                  | 0.208      |
# |    value_loss           | 0.00265    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 35          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.033545382 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.313       |
# |    explained_variance   | -31.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00279     |
# |    n_updates            | 9650        |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.212       |
# |    value_loss           | 0.0054      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.07      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 387       |
# |    iterations           | 36        |
# |    time_elapsed         | 190       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 1.4274476 |
# |    clip_fraction        | 0.374     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.285     |
# |    explained_variance   | -66.6     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00372  |
# |    n_updates            | 9660      |
# |    policy_gradient_loss | 0.0387    |
# |    std                  | 0.213     |
# |    value_loss           | 0.0166    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 37          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.019441111 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.289       |
# |    explained_variance   | 1.34e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00195     |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | 0.00738     |
# |    std                  | 0.212       |
# |    value_loss           | 1.9e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 38          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020705821 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.296       |
# |    explained_variance   | -101        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0473      |
# |    n_updates            | 9680        |
# |    policy_gradient_loss | 0.00338     |
# |    std                  | 0.211       |
# |    value_loss           | 0.0672      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 39          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.033061158 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.304       |
# |    explained_variance   | -146        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00761    |
# |    n_updates            | 9690        |
# |    policy_gradient_loss | 0.0171      |
# |    std                  | 0.21        |
# |    value_loss           | 0.00959     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 40          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015900705 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.329       |
# |    explained_variance   | -130        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0301     |
# |    n_updates            | 9700        |
# |    policy_gradient_loss | 0.00223     |
# |    std                  | 0.206       |
# |    value_loss           | 0.00946     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 41          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.018742524 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.361       |
# |    explained_variance   | -28.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0133     |
# |    n_updates            | 9710        |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.203       |
# |    value_loss           | 0.00357     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.15       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 386        |
# |    iterations           | 42         |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01724914 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.382      |
# |    explained_variance   | 9.18e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0104     |
# |    n_updates            | 9720       |
# |    policy_gradient_loss | 0.00453    |
# |    std                  | 0.202      |
# |    value_loss           | 489        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.28      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 387       |
# |    iterations           | 43        |
# |    time_elapsed         | 227       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.0677608 |
# |    clip_fraction        | 0.269     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.381     |
# |    explained_variance   | -158      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0128    |
# |    n_updates            | 9730      |
# |    policy_gradient_loss | 0.0199    |
# |    std                  | 0.203     |
# |    value_loss           | 0.00654   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 44         |
# |    time_elapsed         | 232        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.05752319 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.388      |
# |    explained_variance   | -13.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0148     |
# |    n_updates            | 9740       |
# |    policy_gradient_loss | 0.0118     |
# |    std                  | 0.201      |
# |    value_loss           | 0.00272    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.96       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 45         |
# |    time_elapsed         | 238        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.03973954 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.381      |
# |    explained_variance   | -9.05      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0193    |
# |    n_updates            | 9750       |
# |    policy_gradient_loss | 0.0017     |
# |    std                  | 0.203      |
# |    value_loss           | 0.00785    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 46         |
# |    time_elapsed         | 243        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.02793212 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.383      |
# |    explained_variance   | -12        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0078     |
# |    n_updates            | 9760       |
# |    policy_gradient_loss | 0.00581    |
# |    std                  | 0.201      |
# |    value_loss           | 0.00706    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 47         |
# |    time_elapsed         | 248        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.04279556 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.377      |
# |    explained_variance   | 0.000317   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.314      |
# |    n_updates            | 9770       |
# |    policy_gradient_loss | 0.00775    |
# |    std                  | 0.204      |
# |    value_loss           | 1.62e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.29       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 48         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02299913 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.371      |
# |    explained_variance   | -167       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0336     |
# |    n_updates            | 9780       |
# |    policy_gradient_loss | 0.00544    |
# |    std                  | 0.202      |
# |    value_loss           | 0.0789     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 49          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.031318273 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.374       |
# |    explained_variance   | -51.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0075     |
# |    n_updates            | 9790        |
# |    policy_gradient_loss | 0.00907     |
# |    std                  | 0.202       |
# |    value_loss           | 0.0092      |
# -----------------------------------------
# --- 261.4639239311218 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-600000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:1.00 +/- 0.00
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.04 +/- 31.00
# Focus Polytopes:
# mean_reward:0.70 +/- 17.34
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.98 +/- 4.48
# Focus Polytopes:
# mean_reward:0.90 +/- 10.01
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.95 +/- 7.08
# Focus Polytopes:
# mean_reward:0.71 +/- 17.04
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:1.00 +/- 0.00
# Focus Polytopes:
# mean_reward:0.82 +/- 13.43
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.90 +/- 10.01
# Focus Polytopes:
# mean_reward:0.47 +/- 23.04

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-600000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-700000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.83     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 337      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.023266051 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.195       |
# |    explained_variance   | -7.95       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0292      |
# |    n_updates            | 9810        |
# |    policy_gradient_loss | 0.00742     |
# |    std                  | 0.219       |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016262338 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.2         |
# |    explained_variance   | -0.486      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0356     |
# |    n_updates            | 9820        |
# |    policy_gradient_loss | 0.00676     |
# |    std                  | 0.219       |
# |    value_loss           | 0.0033      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 271        |
# |    iterations           | 4          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02257466 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.204      |
# |    explained_variance   | -6.13      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.058      |
# |    n_updates            | 9830       |
# |    policy_gradient_loss | 0.0102     |
# |    std                  | 0.217      |
# |    value_loss           | 0.00813    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018720798 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.217       |
# |    explained_variance   | -16.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0189      |
# |    n_updates            | 9840        |
# |    policy_gradient_loss | 0.00894     |
# |    std                  | 0.217       |
# |    value_loss           | 0.000462    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 6           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.029730413 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.222       |
# |    explained_variance   | -8.74       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0175      |
# |    n_updates            | 9850        |
# |    policy_gradient_loss | 0.0052      |
# |    std                  | 0.216       |
# |    value_loss           | 0.00422     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 7           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017128034 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.229       |
# |    explained_variance   | -7.34       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0258      |
# |    n_updates            | 9860        |
# |    policy_gradient_loss | 0.00455     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 259        |
# |    iterations           | 8          |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.03286188 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.231      |
# |    explained_variance   | -5.07      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00715   |
# |    n_updates            | 9870       |
# |    policy_gradient_loss | 0.00216    |
# |    std                  | 0.216      |
# |    value_loss           | 0.00431    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 9           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.030433817 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.234       |
# |    explained_variance   | -3.17       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0433      |
# |    n_updates            | 9880        |
# |    policy_gradient_loss | 0.00438     |
# |    std                  | 0.215       |
# |    value_loss           | 0.000641    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 10          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.023324898 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.244       |
# |    explained_variance   | -12.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00997    |
# |    n_updates            | 9890        |
# |    policy_gradient_loss | 0.00775     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00571     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 11          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.024024628 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.249       |
# |    explained_variance   | -12         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0381      |
# |    n_updates            | 9900        |
# |    policy_gradient_loss | 0.0151      |
# |    std                  | 0.213       |
# |    value_loss           | 0.00275     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.76        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 12          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.024700046 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.251       |
# |    explained_variance   | -13.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00509    |
# |    n_updates            | 9910        |
# |    policy_gradient_loss | 0.00585     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 13          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013635492 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.246       |
# |    explained_variance   | -2.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0356      |
# |    n_updates            | 9920        |
# |    policy_gradient_loss | 0.00578     |
# |    std                  | 0.215       |
# |    value_loss           | 0.000813    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2          |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 14         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01966709 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.228      |
# |    explained_variance   | -4.74      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00287   |
# |    n_updates            | 9930       |
# |    policy_gradient_loss | 0.00867    |
# |    std                  | 0.217      |
# |    value_loss           | 0.0198     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 15         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02969036 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.207      |
# |    explained_variance   | -12.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.087      |
# |    n_updates            | 9940       |
# |    policy_gradient_loss | 0.0112     |
# |    std                  | 0.218      |
# |    value_loss           | 0.000359   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.69        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 16          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.023880199 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.209       |
# |    explained_variance   | -1          |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0141      |
# |    n_updates            | 9950        |
# |    policy_gradient_loss | 0.00774     |
# |    std                  | 0.217       |
# |    value_loss           | 0.000963    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 17          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.032006573 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.224       |
# |    explained_variance   | -10.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00391    |
# |    n_updates            | 9960        |
# |    policy_gradient_loss | 0.00672     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 18          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026231928 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.234       |
# |    explained_variance   | -0.442      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00705     |
# |    n_updates            | 9970        |
# |    policy_gradient_loss | 0.00273     |
# |    std                  | 0.216       |
# |    value_loss           | 0.0015      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 19          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017529096 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.218       |
# |    explained_variance   | -65.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.035       |
# |    n_updates            | 9980        |
# |    policy_gradient_loss | 0.00598     |
# |    std                  | 0.219       |
# |    value_loss           | 0.000741    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 256        |
# |    iterations           | 20         |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.04065465 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.204      |
# |    explained_variance   | -0.827     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0596     |
# |    n_updates            | 9990       |
# |    policy_gradient_loss | 0.00734    |
# |    std                  | 0.218      |
# |    value_loss           | 0.00182    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.03       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 256        |
# |    iterations           | 21         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02458422 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.212      |
# |    explained_variance   | -3.32      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0244    |
# |    n_updates            | 10000      |
# |    policy_gradient_loss | 0.00703    |
# |    std                  | 0.217      |
# |    value_loss           | 0.0205     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 22         |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02490452 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.208      |
# |    explained_variance   | -7.48      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0146     |
# |    n_updates            | 10010      |
# |    policy_gradient_loss | 0.00897    |
# |    std                  | 0.219      |
# |    value_loss           | 0.00158    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.83        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 23          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.016440425 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.207       |
# |    explained_variance   | -8.86       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00253    |
# |    n_updates            | 10020       |
# |    policy_gradient_loss | 0.0066      |
# |    std                  | 0.218       |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 24          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.024697177 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.224       |
# |    explained_variance   | -2.2        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0295      |
# |    n_updates            | 10030       |
# |    policy_gradient_loss | 0.00811     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 25          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.020154305 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.24        |
# |    explained_variance   | -3.28       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 10040       |
# |    policy_gradient_loss | 0.00102     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00359     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 26          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022090174 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.249       |
# |    explained_variance   | -30.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0252      |
# |    n_updates            | 10050       |
# |    policy_gradient_loss | 0.00696     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 27          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.027279057 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.263       |
# |    explained_variance   | -2.24       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00979    |
# |    n_updates            | 10060       |
# |    policy_gradient_loss | 0.00552     |
# |    std                  | 0.211       |
# |    value_loss           | 0.00233     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 28          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017910318 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.264       |
# |    explained_variance   | -14.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0045      |
# |    n_updates            | 10070       |
# |    policy_gradient_loss | 0.00632     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.8         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 29          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.021637075 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.26        |
# |    explained_variance   | -0.498      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0418      |
# |    n_updates            | 10080       |
# |    policy_gradient_loss | 0.00949     |
# |    std                  | 0.213       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 30          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.019305978 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.256       |
# |    explained_variance   | -20.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 10090       |
# |    policy_gradient_loss | 0.00679     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00732     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 252        |
# |    iterations           | 31         |
# |    time_elapsed         | 251        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.03350791 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.251      |
# |    explained_variance   | -9.09      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0102    |
# |    n_updates            | 10100      |
# |    policy_gradient_loss | 0.00504    |
# |    std                  | 0.214      |
# |    value_loss           | 0.0117     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 32           |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0153576955 |
# |    clip_fraction        | 0.207        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.261        |
# |    explained_variance   | -16.6        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00598      |
# |    n_updates            | 10110        |
# |    policy_gradient_loss | 0.00555      |
# |    std                  | 0.211        |
# |    value_loss           | 0.0026       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 33         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.20982882 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.278      |
# |    explained_variance   | -5.57      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00367   |
# |    n_updates            | 10120      |
# |    policy_gradient_loss | 0.0179     |
# |    std                  | 0.211      |
# |    value_loss           | 0.00318    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 34          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.029486917 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.291       |
# |    explained_variance   | -0.75       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 10130       |
# |    policy_gradient_loss | 0.00671     |
# |    std                  | 0.209       |
# |    value_loss           | 0.000269    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 35          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.021158673 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.292       |
# |    explained_variance   | -1.54       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00918     |
# |    n_updates            | 10140       |
# |    policy_gradient_loss | 0.0116      |
# |    std                  | 0.21        |
# |    value_loss           | 0.00194     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.09       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 36         |
# |    time_elapsed         | 291        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02402803 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.298      |
# |    explained_variance   | -0.743     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0512     |
# |    n_updates            | 10150      |
# |    policy_gradient_loss | 0.0092     |
# |    std                  | 0.208      |
# |    value_loss           | 0.00116    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 37          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.035639636 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.308       |
# |    explained_variance   | -10.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00725    |
# |    n_updates            | 10160       |
# |    policy_gradient_loss | 0.0123      |
# |    std                  | 0.207       |
# |    value_loss           | 0.00444     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 38         |
# |    time_elapsed         | 307        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01387507 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.307      |
# |    explained_variance   | -0.000104  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0541     |
# |    n_updates            | 10170      |
# |    policy_gradient_loss | 0.00439    |
# |    std                  | 0.209      |
# |    value_loss           | 488        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.09       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 39         |
# |    time_elapsed         | 315        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03402836 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.298      |
# |    explained_variance   | 0.00452    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0298     |
# |    n_updates            | 10180      |
# |    policy_gradient_loss | 0.00491    |
# |    std                  | 0.209      |
# |    value_loss           | 487        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 40          |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.021941727 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.303       |
# |    explained_variance   | 0.00366     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0474      |
# |    n_updates            | 10190       |
# |    policy_gradient_loss | 0.00883     |
# |    std                  | 0.208       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 41          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015661865 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.326       |
# |    explained_variance   | -84.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00385    |
# |    n_updates            | 10200       |
# |    policy_gradient_loss | 0.00644     |
# |    std                  | 0.205       |
# |    value_loss           | 0.00665     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 42          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.031572286 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.338       |
# |    explained_variance   | -13.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0406      |
# |    n_updates            | 10210       |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.205       |
# |    value_loss           | 0.00266     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.85       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 43         |
# |    time_elapsed         | 347        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01778971 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.335      |
# |    explained_variance   | -140       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00611   |
# |    n_updates            | 10220      |
# |    policy_gradient_loss | 0.0096     |
# |    std                  | 0.205      |
# |    value_loss           | 0.00706    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 44          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.024825517 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.32        |
# |    explained_variance   | -57.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00838     |
# |    n_updates            | 10230       |
# |    policy_gradient_loss | 0.00298     |
# |    std                  | 0.209       |
# |    value_loss           | 0.0059      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.92       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 45         |
# |    time_elapsed         | 363        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02088055 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.286      |
# |    explained_variance   | -36.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.032      |
# |    n_updates            | 10240      |
# |    policy_gradient_loss | 0.00756    |
# |    std                  | 0.211      |
# |    value_loss           | 0.00438    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 46          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.026193498 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.268       |
# |    explained_variance   | -18.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00155     |
# |    n_updates            | 10250       |
# |    policy_gradient_loss | 0.00232     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00337     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 47          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.040521964 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.263       |
# |    explained_variance   | -8.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0613      |
# |    n_updates            | 10260       |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.212       |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 48         |
# |    time_elapsed         | 387        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01746624 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.257      |
# |    explained_variance   | -8.08      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00927    |
# |    n_updates            | 10270      |
# |    policy_gradient_loss | 0.00581    |
# |    std                  | 0.213      |
# |    value_loss           | 0.00498    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 49          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019584574 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.235       |
# |    explained_variance   | -73.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.037       |
# |    n_updates            | 10280       |
# |    policy_gradient_loss | 0.00504     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00347     |
# -----------------------------------------
# --- 397.6115822792053 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.05     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 346      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.045884572 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.966       |
# |    explained_variance   | -137        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0223      |
# |    n_updates            | 9810        |
# |    policy_gradient_loss | 0.00233     |
# |    std                  | 0.149       |
# |    value_loss           | 0.0252      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.96       |
# |    ep_rew_mean          | -9.01      |
# | time/                   |            |
# |    fps                  | 287        |
# |    iterations           | 3          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.14532053 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.969      |
# |    explained_variance   | 0.000609   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.1e+03    |
# |    n_updates            | 9820       |
# |    policy_gradient_loss | 0.0136     |
# |    std                  | 0.149      |
# |    value_loss           | 2.2e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.025415331 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.968       |
# |    explained_variance   | 0.00254     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.141       |
# |    n_updates            | 9830        |
# |    policy_gradient_loss | 0.00875     |
# |    std                  | 0.15        |
# |    value_loss           | 975         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 276        |
# |    iterations           | 5          |
# ...
# |    explained_variance   | -55.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 10110       |
# |    policy_gradient_loss | 0.0163      |
# |    std                  | 0.205       |
# |    value_loss           | 0.00527     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.09       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 389        |
# |    iterations           | 33         |
# |    time_elapsed         | 173        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01858197 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.374      |
# |    explained_variance   | -19.4      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0238    |
# |    n_updates            | 10120      |
# |    policy_gradient_loss | 0.0156     |
# |    std                  | 0.204      |
# |    value_loss           | 0.00472    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 34          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.029091496 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.387       |
# |    explained_variance   | -13.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 10130       |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.202       |
# |    value_loss           | 0.00371     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.43        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 35          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.019755648 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.4         |
# |    explained_variance   | -9.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 10140       |
# |    policy_gradient_loss | 0.00586     |
# |    std                  | 0.201       |
# |    value_loss           | 0.00381     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 36          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.021486387 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.419       |
# |    explained_variance   | -18         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0327     |
# |    n_updates            | 10150       |
# |    policy_gradient_loss | 0.00668     |
# |    std                  | 0.198       |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 37          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.023182103 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.418       |
# |    explained_variance   | -5.66       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00985    |
# |    n_updates            | 10160       |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.2         |
# |    value_loss           | 0.00617     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 38          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.031728677 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.416       |
# |    explained_variance   | -38.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 10170       |
# |    policy_gradient_loss | 0.00685     |
# |    std                  | 0.198       |
# |    value_loss           | 0.00372     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 39          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.028334845 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.429       |
# |    explained_variance   | -3.44       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00908     |
# |    n_updates            | 10180       |
# |    policy_gradient_loss | 0.00502     |
# |    std                  | 0.197       |
# |    value_loss           | 0.0037      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 388        |
# |    iterations           | 40         |
# |    time_elapsed         | 210        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02537458 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.427      |
# |    explained_variance   | -9.23      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0178     |
# |    n_updates            | 10190      |
# |    policy_gradient_loss | 0.00299    |
# |    std                  | 0.198      |
# |    value_loss           | 0.00304    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 41          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028692843 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.416       |
# |    explained_variance   | 3.59e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.455       |
# |    n_updates            | 10200       |
# |    policy_gradient_loss | 0.00544     |
# |    std                  | 0.198       |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 382        |
# |    iterations           | 42         |
# |    time_elapsed         | 224        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.08186729 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.418      |
# |    explained_variance   | -123       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00448    |
# |    n_updates            | 10210      |
# |    policy_gradient_loss | 0.00202    |
# |    std                  | 0.196      |
# |    value_loss           | 0.0827     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.1        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 377        |
# |    iterations           | 43         |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01832566 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.423      |
# |    explained_variance   | -206       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0424     |
# |    n_updates            | 10220      |
# |    policy_gradient_loss | 0.0195     |
# |    std                  | 0.199      |
# |    value_loss           | 0.0065     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 44          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.030342191 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.429       |
# |    explained_variance   | -18.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 10230       |
# |    policy_gradient_loss | 0.00671     |
# |    std                  | 0.196       |
# |    value_loss           | 0.00378     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 45          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.020747509 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.448       |
# |    explained_variance   | -10.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0191      |
# |    n_updates            | 10240       |
# |    policy_gradient_loss | 0.000274    |
# |    std                  | 0.195       |
# |    value_loss           | 0.00616     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 46          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.022671457 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.473       |
# |    explained_variance   | -11.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0044     |
# |    n_updates            | 10250       |
# |    policy_gradient_loss | 0.00428     |
# |    std                  | 0.191       |
# |    value_loss           | 0.00338     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 47          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018980663 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.499       |
# |    explained_variance   | -10.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0236      |
# |    n_updates            | 10260       |
# |    policy_gradient_loss | 0.00401     |
# |    std                  | 0.189       |
# |    value_loss           | 0.00852     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.47        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 48          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.026708636 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.527       |
# |    explained_variance   | -10.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0243     |
# |    n_updates            | 10270       |
# |    policy_gradient_loss | 0.0122      |
# |    std                  | 0.187       |
# |    value_loss           | 0.00445     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 49          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.023415549 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.557       |
# |    explained_variance   | -6.78       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 10280       |
# |    policy_gradient_loss | 0.00675     |
# |    std                  | 0.183       |
# |    value_loss           | 0.00325     |
# -----------------------------------------
# --- 268.07624340057373 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-700000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.98 +/- 4.48
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.23 +/- 27.77
# Focus Polytopes:
# mean_reward:0.92 +/- 8.95
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.96 +/- 6.33
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.98 +/- 4.48
# Focus Polytopes:
# mean_reward:0.91 +/- 9.50
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.80 +/- 14.15
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.95 +/- 7.08
# Focus Polytopes:
# mean_reward:0.67 +/- 18.18

# %%
results_overall
# Out:
# {0.0: [(0.94, 7.75),
#   (0.97998, 4.476563324649836),
#   (0.93994, 7.7534800442382),
#   (0.97998, 4.476563324649836),
#   (0.91992, 8.952858046099026),
#   (0.98999, 3.16542411058929),
#   (0.98999, 3.1654241105892895)],
#  0.05: [(0.97, 5.48),
#   (0.67968, 17.903567105401088),
#   (0.67968, 17.903567105401088),
#   (0.84985, 12.258776650934628),
#   (0.80981, 13.796521944457595),
#   (0.03904, 30.999959933496687),
#   (0.22923, 27.765926665737272)],
#  0.1: [(0.94, 7.75),
#   (0.86987, 11.412414125990173),
#   (0.97998, 4.476563324649836),
#   (1.0, 0.0),
#   (1.0, 0.0),
#   (0.97998, 4.476563324649836),
#   (0.98999, 3.1654241105892895)],
#  0.5: [(0.98, 4.48),
#   (0.95996, 6.330753256793382),
#   (0.95996, 6.330753256793382),
#   (0.94995, 7.077961923993376),
#   (1.0, 0.0),
#   (0.94995, 7.077961923993375),
#   (0.97998, 4.476563324649836)],
#  0.9: [(0.97, 5.48),
#   (0.96997, 5.4826205594678905),
#   (0.98999, 3.1654241105892904),
#   (0.98999, 3.1654241105892895),
#   (1.0, 0.0),
#   (1.0, 0.0),
#   (0.98999, 3.1654241105892895)],
#  1.0: [(0.97, 5.48),
#   (0.94995, 7.077961923993375),
#   (0.96997, 5.4826205594678905),
#   (0.95996, 6.330753256793382),
#   (0.96997, 5.4826205594678905),
#   (0.8999, 10.009499487486877),
#   (0.94995, 7.077961923993376)]}

# %%
results_polys
# Out:
# {0.0: [(0.58, 20.51),
#   (0.87988, 10.964747657178437),
#   (0.8999, 10.009499487486877),
#   (0.95996, 6.330753256793382),
#   (1.0, 0.0),
#   (1.0, 0.0),
#   (0.97998, 4.476563324649836)],
#  0.05: [(0.58, 20.51),
#   (0.77978, 14.845596086099071),
#   (-0.83183, 42.78207836058342),
#   (0.70971, 17.04394384278181),
#   (0.57958, 20.510086957972653),
#   (0.6997, 17.335227714397067),
#   (0.91992, 8.952858046099026)],
#  0.1: [(0.72, 16.75),
#   (0.77978, 14.845596086099071),
#   (0.84985, 12.258776650934628),
#   (0.8999, 10.009499487486877),
#   (0.95996, 6.330753256793382),
#   (0.8999, 10.009499487486876),
#   (0.95996, 6.330753256793382)],
#  0.5: [(0.8, 14.15),
#   (0.80981, 13.796521944457595),
#   (0.8999, 10.009499487486876),
#   (-0.39139, 37.294040058270696),
#   (0.91992, 8.952858046099026),
#   (0.70971, 17.043943842781815),
#   (0.90991, 9.495892469478584)],
#  0.9: [(0.48, 22.82),
#   (0.40941, 24.307031769673152),
#   (0.5996, 20.0159955995199),
#   (0.42943, 23.89173538852086),
#   (0.58959, 20.264549677500856),
#   (0.81982, 13.428615534283496),
#   (0.7998, 14.154862060790277)],
#  1.0: [(-0.29, 35.93),
#   (0.65966, 18.45438995698314),
#   (0.85986, 11.843162617324818),
#   (0.54955, 21.2296383576711),
#   (0.66967, 18.18106740791365),
#   (0.46947, 23.03864292702806),
#   (0.66967, 18.18106740791365)]}

# %%
results_overall={0.0: [(0.94, 7.75),
  (0.97998, 4.476563324649836),
  (0.93994, 7.7534800442382),
  (0.97998, 4.476563324649836),
  (0.91992, 8.952858046099026),
  (0.98999, 3.16542411058929),
  (0.98999, 3.1654241105892895)],
 0.05: [(0.97, 5.48),
  (0.67968, 17.903567105401088),
  (0.67968, 17.903567105401088),
  (0.84985, 12.258776650934628),
  (0.80981, 13.796521944457595),
  (0.03904, 30.999959933496687),
  (0.22923, 27.765926665737272)],
 0.1: [(0.94, 7.75),
  (0.86987, 11.412414125990173),
  (0.97998, 4.476563324649836),
  (1.0, 0.0),
  (1.0, 0.0),
  (0.97998, 4.476563324649836),
  (0.98999, 3.1654241105892895)],
 0.5: [(0.98, 4.48),
  (0.95996, 6.330753256793382),
  (0.95996, 6.330753256793382),
  (0.94995, 7.077961923993376),
  (1.0, 0.0),
  (0.94995, 7.077961923993375),
  (0.97998, 4.476563324649836)],
 0.9: [(0.97, 5.48),
  (0.96997, 5.4826205594678905),
  (0.98999, 3.1654241105892904),
  (0.98999, 3.1654241105892895),
  (1.0, 0.0),
  (1.0, 0.0),
  (0.98999, 3.1654241105892895)],
 1.0: [(0.97, 5.48),
  (0.94995, 7.077961923993375),
  (0.96997, 5.4826205594678905),
  (0.95996, 6.330753256793382),
  (0.96997, 5.4826205594678905),
  (0.8999, 10.009499487486877),
  (0.94995, 7.077961923993376)]}
results_polys={0.0: [(0.58, 20.51),
  (0.87988, 10.964747657178437),
  (0.8999, 10.009499487486877),
  (0.95996, 6.330753256793382),
  (1.0, 0.0),
  (1.0, 0.0),
  (0.97998, 4.476563324649836)],
 0.05: [(0.58, 20.51),
  (0.77978, 14.845596086099071),
  (-0.83183, 42.78207836058342),
  (0.70971, 17.04394384278181),
  (0.57958, 20.510086957972653),
  (0.6997, 17.335227714397067),
  (0.91992, 8.952858046099026)],
 0.1: [(0.72, 16.75),
  (0.77978, 14.845596086099071),
  (0.84985, 12.258776650934628),
  (0.8999, 10.009499487486877),
  (0.95996, 6.330753256793382),
  (0.8999, 10.009499487486876),
  (0.95996, 6.330753256793382)],
 0.5: [(0.8, 14.15),
  (0.80981, 13.796521944457595),
  (0.8999, 10.009499487486876),
  (-0.39139, 37.294040058270696),
  (0.91992, 8.952858046099026),
  (0.70971, 17.043943842781815),
  (0.90991, 9.495892469478584)],
 0.9: [(0.48, 22.82),
  (0.40941, 24.307031769673152),
  (0.5996, 20.0159955995199),
  (0.42943, 23.89173538852086),
  (0.58959, 20.264549677500856),
  (0.81982, 13.428615534283496),
  (0.7998, 14.154862060790277)],
 1.0: [(-0.29, 35.93),
  (0.65966, 18.45438995698314),
  (0.85986, 11.843162617324818),
  (0.54955, 21.2296383576711),
  (0.66967, 18.18106740791365),
  (0.46947, 23.03864292702806),
  (0.66967, 18.18106740791365)]}

# %%
eval_episode_length=100000
training_episode_length=100000
env.seed(2022)
torch.manual_seed(2022)

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-700000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-800000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.81     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 289      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.031546764 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.208       |
# |    explained_variance   | -3.93       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0135      |
# |    n_updates            | 10300       |
# |    policy_gradient_loss | 0.0134      |
# |    std                  | 0.218       |
# |    value_loss           | 0.00574     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.024020646 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.21        |
# |    explained_variance   | -4.9        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0233      |
# |    n_updates            | 10310       |
# |    policy_gradient_loss | -9e-05      |
# |    std                  | 0.218       |
# |    value_loss           | 0.00332     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.91        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 4           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018590553 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.212       |
# |    explained_variance   | 0.000395    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00497    |
# |    n_updates            | 10320       |
# |    policy_gradient_loss | 0.00518     |
# |    std                  | 0.218       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 5           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.034028806 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.215       |
# |    explained_variance   | -420        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 10330       |
# |    policy_gradient_loss | 0.00926     |
# |    std                  | 0.217       |
# |    value_loss           | 0.0226      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 6           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021480933 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.224       |
# |    explained_variance   | -41.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 10340       |
# |    policy_gradient_loss | 0.00301     |
# |    std                  | 0.216       |
# |    value_loss           | 0.0039      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 7           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013795605 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.228       |
# |    explained_variance   | -8.72       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0225      |
# |    n_updates            | 10350       |
# |    policy_gradient_loss | 0.00432     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00166     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 8           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.021780621 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.238       |
# |    explained_variance   | -37.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0343      |
# |    n_updates            | 10360       |
# |    policy_gradient_loss | 0.00848     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00363     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.91        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 9           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018217469 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.242       |
# |    explained_variance   | -24.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00963     |
# |    n_updates            | 10370       |
# |    policy_gradient_loss | 0.00514     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00346     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 10          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.029101728 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.236       |
# |    explained_variance   | -57.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00869    |
# |    n_updates            | 10380       |
# |    policy_gradient_loss | 0.0036      |
# |    std                  | 0.215       |
# |    value_loss           | 0.00961     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 11          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.018945675 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.227       |
# |    explained_variance   | -9.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00678     |
# |    n_updates            | 10390       |
# |    policy_gradient_loss | 0.00213     |
# |    std                  | 0.217       |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 12          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025134342 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.221       |
# |    explained_variance   | -0.81       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0402      |
# |    n_updates            | 10400       |
# |    policy_gradient_loss | 0.00899     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00104     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 13          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025419502 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.217       |
# |    explained_variance   | -3.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0095     |
# |    n_updates            | 10410       |
# |    policy_gradient_loss | 0.00597     |
# |    std                  | 0.218       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.92       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 14         |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.03281295 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.194      |
# |    explained_variance   | -15.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0197    |
# |    n_updates            | 10420      |
# |    policy_gradient_loss | 0.00419    |
# |    std                  | 0.221      |
# |    value_loss           | 0.00801    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 15          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017476184 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.194       |
# |    explained_variance   | -11.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0532      |
# |    n_updates            | 10430       |
# |    policy_gradient_loss | 0.00696     |
# |    std                  | 0.219       |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 16          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021850064 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.213       |
# |    explained_variance   | -53.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0368      |
# |    n_updates            | 10440       |
# |    policy_gradient_loss | 0.00519     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00213     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 17          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.027746003 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.228       |
# |    explained_variance   | -13.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0652      |
# |    n_updates            | 10450       |
# |    policy_gradient_loss | 0.00572     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00318     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 18          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.047820345 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.237       |
# |    explained_variance   | -2          |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0289      |
# |    n_updates            | 10460       |
# |    policy_gradient_loss | 0.00514     |
# |    std                  | 0.215       |
# |    value_loss           | 0.000882    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.8         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 19          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.030035134 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.233       |
# |    explained_variance   | -2.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0182     |
# |    n_updates            | 10470       |
# |    policy_gradient_loss | 0.00759     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.91        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 20          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.018699173 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.23        |
# |    explained_variance   | -4.32       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000358    |
# |    n_updates            | 10480       |
# |    policy_gradient_loss | 0.00353     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00258     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 21          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.030608995 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.238       |
# |    explained_variance   | -1.62       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00419    |
# |    n_updates            | 10490       |
# |    policy_gradient_loss | 0.00694     |
# |    std                  | 0.214       |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 22          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015896117 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.246       |
# |    explained_variance   | 0.00016     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0276      |
# |    n_updates            | 10500       |
# |    policy_gradient_loss | 0.00396     |
# |    std                  | 0.214       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.83        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 23          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.020892978 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.232       |
# |    explained_variance   | -510        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000219   |
# |    n_updates            | 10510       |
# |    policy_gradient_loss | 0.0023      |
# |    std                  | 0.216       |
# |    value_loss           | 0.023       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.09       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 24         |
# |    time_elapsed         | 191        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03091526 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.215      |
# |    explained_variance   | -62        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0238    |
# |    n_updates            | 10520      |
# |    policy_gradient_loss | 0.00513    |
# |    std                  | 0.218      |
# |    value_loss           | 0.00193    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2          |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 25         |
# |    time_elapsed         | 198        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02004711 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.224      |
# |    explained_variance   | -6.23      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000642   |
# |    n_updates            | 10530      |
# |    policy_gradient_loss | 0.00177    |
# |    std                  | 0.215      |
# |    value_loss           | 0.00641    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 26          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012659405 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.225       |
# |    explained_variance   | -12.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0311      |
# |    n_updates            | 10540       |
# |    policy_gradient_loss | 0.0101      |
# |    std                  | 0.217       |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 27          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013720683 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.212       |
# |    explained_variance   | -44.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 10550       |
# |    policy_gradient_loss | 0.00981     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00226     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 28          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.024496686 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.21        |
# |    explained_variance   | 0.000383    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.153       |
# |    n_updates            | 10560       |
# |    policy_gradient_loss | 0.00724     |
# |    std                  | 0.218       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 29          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.018536408 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.194       |
# |    explained_variance   | 0.00446     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0332      |
# |    n_updates            | 10570       |
# |    policy_gradient_loss | -0.00264    |
# |    std                  | 0.22        |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 30          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.021534204 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.187       |
# |    explained_variance   | 0.00441     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 10580       |
# |    policy_gradient_loss | 0.00108     |
# |    std                  | 0.22        |
# |    value_loss           | 487         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 31         |
# |    time_elapsed         | 250        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.03006416 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.194      |
# |    explained_variance   | -77.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0128     |
# |    n_updates            | 10590      |
# |    policy_gradient_loss | 0.00461    |
# |    std                  | 0.219      |
# |    value_loss           | 0.00748    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 32          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017820165 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.193       |
# |    explained_variance   | -21.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00444    |
# |    n_updates            | 10600       |
# |    policy_gradient_loss | 0.00502     |
# |    std                  | 0.22        |
# |    value_loss           | 0.00908     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.88       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 248        |
# |    iterations           | 33         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.03018342 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.184      |
# |    explained_variance   | -26.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0204     |
# |    n_updates            | 10610      |
# |    policy_gradient_loss | 0.00828    |
# |    std                  | 0.221      |
# |    value_loss           | 0.0026     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 34          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018330604 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.173       |
# |    explained_variance   | -26.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00483     |
# |    n_updates            | 10620       |
# |    policy_gradient_loss | 0.00442     |
# |    std                  | 0.222       |
# |    value_loss           | 0.00519     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.15      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 248       |
# |    iterations           | 35        |
# |    time_elapsed         | 288       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.5853018 |
# |    clip_fraction        | 0.23      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.178     |
# |    explained_variance   | -14.7     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0212   |
# |    n_updates            | 10630     |
# |    policy_gradient_loss | 0.00308   |
# |    std                  | 0.221     |
# |    value_loss           | 0.0026    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 36          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.024037024 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.196       |
# |    explained_variance   | -17.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0132      |
# |    n_updates            | 10640       |
# |    policy_gradient_loss | 0.0154      |
# |    std                  | 0.218       |
# |    value_loss           | 0.000895    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.84       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 37         |
# |    time_elapsed         | 307        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01812211 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.216      |
# |    explained_variance   | -1.83      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00333   |
# |    n_updates            | 10650      |
# |    policy_gradient_loss | 0.00528    |
# |    std                  | 0.216      |
# |    value_loss           | 0.00264    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.79        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 38          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017131012 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.218       |
# |    explained_variance   | -90.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 10660       |
# |    policy_gradient_loss | 0.0037      |
# |    std                  | 0.218       |
# |    value_loss           | 0.00561     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 39          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.022009702 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.224       |
# |    explained_variance   | -21.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0184      |
# |    n_updates            | 10670       |
# |    policy_gradient_loss | 0.00441     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00261     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 40          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.028452393 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.22        |
# |    explained_variance   | -17         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 10680       |
# |    policy_gradient_loss | 0.00508     |
# |    std                  | 0.218       |
# |    value_loss           | 0.0052      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 41          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.025786875 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.212       |
# |    explained_variance   | -11         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 10690       |
# |    policy_gradient_loss | 0.0103      |
# |    std                  | 0.218       |
# |    value_loss           | 0.00081     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 42         |
# |    time_elapsed         | 349        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.03076389 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.214      |
# |    explained_variance   | 0.000542   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0194    |
# |    n_updates            | 10700      |
# |    policy_gradient_loss | 0.00147    |
# |    std                  | 0.217      |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 43          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.021991728 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.207       |
# |    explained_variance   | -150        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.025      |
# |    n_updates            | 10710       |
# |    policy_gradient_loss | 0.0031      |
# |    std                  | 0.218       |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.11       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 44         |
# |    time_elapsed         | 365        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01615431 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.226      |
# |    explained_variance   | -51.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0236    |
# |    n_updates            | 10720      |
# |    policy_gradient_loss | 0.00528    |
# |    std                  | 0.214      |
# |    value_loss           | 0.0117     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.08       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 45         |
# |    time_elapsed         | 377        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.10493047 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.251      |
# |    explained_variance   | -22.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0102    |
# |    n_updates            | 10730      |
# |    policy_gradient_loss | 0.00716    |
# |    std                  | 0.213      |
# |    value_loss           | 0.00514    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2          |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 46         |
# |    time_elapsed         | 385        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01664497 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.238      |
# |    explained_variance   | -20.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00129   |
# |    n_updates            | 10740      |
# |    policy_gradient_loss | 0.0112     |
# |    std                  | 0.216      |
# |    value_loss           | 0.00423    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 47          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018780472 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.223       |
# |    explained_variance   | -26.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 10750       |
# |    policy_gradient_loss | 0.00933     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.02       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 48         |
# |    time_elapsed         | 407        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02040803 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.217      |
# |    explained_variance   | -3.93      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0138    |
# |    n_updates            | 10760      |
# |    policy_gradient_loss | 0.00327    |
# |    std                  | 0.217      |
# |    value_loss           | 0.003      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 49          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.016928464 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.219       |
# |    explained_variance   | -16.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0149     |
# |    n_updates            | 10770       |
# |    policy_gradient_loss | 0.014       |
# |    std                  | 0.217       |
# |    value_loss           | 0.000862    |
# -----------------------------------------
# --- 417.11422300338745 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.92     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 326      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.060050793 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.833       |
# |    explained_variance   | -15.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0309      |
# |    n_updates            | 10300       |
# |    policy_gradient_loss | 0.0104      |
# |    std                  | 0.161       |
# |    value_loss           | 0.00212     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 260        |
# |    iterations           | 3          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.10004643 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.807      |
# |    explained_variance   | -56.4      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0145    |
# |    n_updates            | 10310      |
# |    policy_gradient_loss | 0.00842    |
# |    std                  | 0.163      |
# |    value_loss           | 0.00906    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.023747362 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.801       |
# |    explained_variance   | -13.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 10320       |
# |    policy_gradient_loss | 0.0097      |
# |    std                  | 0.162       |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.39       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 266        |
# |    iterations           | 5          |
# ...
# |    entropy_loss         | 0.439      |
# |    explained_variance   | -52.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.017     |
# |    n_updates            | 10600      |
# |    policy_gradient_loss | 0.0053     |
# |    std                  | 0.195      |
# |    value_loss           | 0.0105     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 33          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.015404621 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.458       |
# |    explained_variance   | -19         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.025      |
# |    n_updates            | 10610       |
# |    policy_gradient_loss | 0.0114      |
# |    std                  | 0.193       |
# |    value_loss           | 0.00509     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 325        |
# |    iterations           | 34         |
# |    time_elapsed         | 213        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01729393 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.465      |
# |    explained_variance   | -29.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0433    |
# |    n_updates            | 10620      |
# |    policy_gradient_loss | 0.00615    |
# |    std                  | 0.193      |
# |    value_loss           | 0.00756    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.06       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 326        |
# |    iterations           | 35         |
# |    time_elapsed         | 219        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01920394 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.448      |
# |    explained_variance   | -77.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00531   |
# |    n_updates            | 10630      |
# |    policy_gradient_loss | 0.00812    |
# |    std                  | 0.196      |
# |    value_loss           | 0.00914    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.35        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 36          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023047198 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.445       |
# |    explained_variance   | -13         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00405     |
# |    n_updates            | 10640       |
# |    policy_gradient_loss | 0.00462     |
# |    std                  | 0.195       |
# |    value_loss           | 0.00249     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 328        |
# |    iterations           | 37         |
# |    time_elapsed         | 230        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01773001 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.461      |
# |    explained_variance   | -26.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00508    |
# |    n_updates            | 10650      |
# |    policy_gradient_loss | 0.00208    |
# |    std                  | 0.193      |
# |    value_loss           | 0.0126     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.57       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 329        |
# |    iterations           | 38         |
# |    time_elapsed         | 235        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02312622 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.465      |
# |    explained_variance   | -17        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00252    |
# |    n_updates            | 10660      |
# |    policy_gradient_loss | 0.00486    |
# |    std                  | 0.194      |
# |    value_loss           | 0.00367    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 39          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.026785124 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.455       |
# |    explained_variance   | -13         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 10670       |
# |    policy_gradient_loss | 0.0127      |
# |    std                  | 0.195       |
# |    value_loss           | 0.00243     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 40          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.017134886 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.449       |
# |    explained_variance   | 4.79e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0432      |
# |    n_updates            | 10680       |
# |    policy_gradient_loss | 0.00528     |
# |    std                  | 0.195       |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 41          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.034559302 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.457       |
# |    explained_variance   | -188        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 10690       |
# |    policy_gradient_loss | 0.00336     |
# |    std                  | 0.194       |
# |    value_loss           | 0.448       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 42          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.047968425 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.454       |
# |    explained_variance   | -90.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 10700       |
# |    policy_gradient_loss | 0.0084      |
# |    std                  | 0.195       |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 43          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.024311077 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.45        |
# |    explained_variance   | -24.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00465     |
# |    n_updates            | 10710       |
# |    policy_gradient_loss | 0.0014      |
# |    std                  | 0.196       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 44          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.029151108 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.44        |
# |    explained_variance   | -14.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00304    |
# |    n_updates            | 10720       |
# |    policy_gradient_loss | 0.00698     |
# |    std                  | 0.197       |
# |    value_loss           | 0.00382     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 45          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.022094896 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.419       |
# |    explained_variance   | -21.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00555     |
# |    n_updates            | 10730       |
# |    policy_gradient_loss | 0.0103      |
# |    std                  | 0.199       |
# |    value_loss           | 0.00475     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 46          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.026730388 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.428       |
# |    explained_variance   | -12.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000361    |
# |    n_updates            | 10740       |
# |    policy_gradient_loss | 0.00741     |
# |    std                  | 0.197       |
# |    value_loss           | 0.00442     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 47          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.024516365 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.433       |
# |    explained_variance   | -11.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0197      |
# |    n_updates            | 10750       |
# |    policy_gradient_loss | 0.00616     |
# |    std                  | 0.198       |
# |    value_loss           | 0.00473     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.33       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 325        |
# |    iterations           | 48         |
# |    time_elapsed         | 301        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.03813031 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.406      |
# |    explained_variance   | -21.2      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0157    |
# |    n_updates            | 10760      |
# |    policy_gradient_loss | 0.0148     |
# |    std                  | 0.202      |
# |    value_loss           | 0.00344    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.26       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 324        |
# |    iterations           | 49         |
# |    time_elapsed         | 309        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.05688946 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.391      |
# |    explained_variance   | -16        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00128    |
# |    n_updates            | 10770      |
# |    policy_gradient_loss | 0.0123     |
# |    std                  | 0.201      |
# |    value_loss           | 0.00776    |
# ----------------------------------------
# --- 312.22135519981384 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-800000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.99 +/- 3.17
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.35 +/- 25.51
# Focus Polytopes:
# mean_reward:1.00 +/- 0.00
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.95 +/- 7.08
# Focus Polytopes:
# mean_reward:0.98 +/- 4.48
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.99 +/- 3.17
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.96 +/- 6.33
# Focus Polytopes:
# mean_reward:0.77 +/- 15.18
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.86 +/- 11.84
# Focus Polytopes:
# mean_reward:0.34 +/- 25.71

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-800000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-900000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.03     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 190      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 2           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.031140193 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.179       |
# |    explained_variance   | -30.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 10790       |
# |    policy_gradient_loss | 0.00333     |
# |    std                  | 0.222       |
# |    value_loss           | 0.00221     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.91       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 3          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02823745 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.176      |
# |    explained_variance   | -14        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00552    |
# |    n_updates            | 10800      |
# |    policy_gradient_loss | -0.00637   |
# |    std                  | 0.221      |
# |    value_loss           | 0.00467    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.01       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 193        |
# |    iterations           | 4          |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02053336 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.182      |
# |    explained_variance   | -12.6      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0173     |
# |    n_updates            | 10810      |
# |    policy_gradient_loss | 0.00522    |
# |    std                  | 0.221      |
# |    value_loss           | 0.00528    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.91        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 5           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.029209401 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.182       |
# |    explained_variance   | -66.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 10820       |
# |    policy_gradient_loss | 0.00872     |
# |    std                  | 0.221       |
# |    value_loss           | 0.00126     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.03       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 6          |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01977975 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.19       |
# |    explained_variance   | -31.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00206    |
# |    n_updates            | 10830      |
# |    policy_gradient_loss | 0.00469    |
# |    std                  | 0.22       |
# |    value_loss           | 0.00526    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.83        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 7           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018122965 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.205       |
# |    explained_variance   | -21.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0188     |
# |    n_updates            | 10840       |
# |    policy_gradient_loss | 0.00826     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 8           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.040864453 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.202       |
# |    explained_variance   | -2.53       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 10850       |
# |    policy_gradient_loss | 0.004       |
# |    std                  | 0.22        |
# |    value_loss           | 0.00322     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 9           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.024126168 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.185       |
# |    explained_variance   | -5.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00352    |
# |    n_updates            | 10860       |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.221       |
# |    value_loss           | 0.00162     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 10          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.037188612 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.192       |
# |    explained_variance   | -14.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0266     |
# |    n_updates            | 10870       |
# |    policy_gradient_loss | 0.00596     |
# |    std                  | 0.219       |
# |    value_loss           | 0.000801    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 11          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013727346 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.205       |
# |    explained_variance   | -3.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0241      |
# |    n_updates            | 10880       |
# |    policy_gradient_loss | 0.00161     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00295     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.89      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 209       |
# |    iterations           | 12        |
# |    time_elapsed         | 117       |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0194375 |
# |    clip_fraction        | 0.172     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.206     |
# |    explained_variance   | -10.3     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000363  |
# |    n_updates            | 10890     |
# |    policy_gradient_loss | 0.0048    |
# |    std                  | 0.219     |
# |    value_loss           | 0.00153   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 13          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017957138 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.207       |
# |    explained_variance   | -3.62       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0263     |
# |    n_updates            | 10900       |
# |    policy_gradient_loss | 0.00476     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00354     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 14          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.031621363 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.214       |
# |    explained_variance   | -4.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0517      |
# |    n_updates            | 10910       |
# |    policy_gradient_loss | 0.00715     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00401     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 15          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020762874 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.231       |
# |    explained_variance   | 9.09e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00523    |
# |    n_updates            | 10920       |
# |    policy_gradient_loss | 0.00406     |
# |    std                  | 0.215       |
# |    value_loss           | 487         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.09       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 213        |
# |    iterations           | 16         |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02368822 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.252      |
# |    explained_variance   | -0.000212  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0246     |
# |    n_updates            | 10930      |
# |    policy_gradient_loss | 0.00709    |
# |    std                  | 0.212      |
# |    value_loss           | 489        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 17          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.045307565 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.273       |
# |    explained_variance   | -21.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00414     |
# |    n_updates            | 10940       |
# |    policy_gradient_loss | 0.00442     |
# |    std                  | 0.21        |
# |    value_loss           | 0.00434     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 18          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022543151 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.295       |
# |    explained_variance   | -23.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0179      |
# |    n_updates            | 10950       |
# |    policy_gradient_loss | 0.00604     |
# |    std                  | 0.208       |
# |    value_loss           | 0.00366     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 19          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.029229451 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.294       |
# |    explained_variance   | -56.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0286      |
# |    n_updates            | 10960       |
# |    policy_gradient_loss | 0.00968     |
# |    std                  | 0.21        |
# |    value_loss           | 0.00622     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 20          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015694097 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.279       |
# |    explained_variance   | -47.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0156      |
# |    n_updates            | 10970       |
# |    policy_gradient_loss | 0.00861     |
# |    std                  | 0.211       |
# |    value_loss           | 0.000751    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.02       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 216        |
# |    iterations           | 21         |
# |    time_elapsed         | 198        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01905473 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.288      |
# |    explained_variance   | -2.79      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0223     |
# |    n_updates            | 10980      |
# |    policy_gradient_loss | 0.00395    |
# |    std                  | 0.208      |
# |    value_loss           | 0.000714   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.82       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 217        |
# |    iterations           | 22         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01867193 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.305      |
# |    explained_variance   | -1.39      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00963    |
# |    n_updates            | 10990      |
# |    policy_gradient_loss | 0.00872    |
# |    std                  | 0.207      |
# |    value_loss           | 0.000845   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 23          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.023701541 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.315       |
# |    explained_variance   | -12.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0161      |
# |    n_updates            | 11000       |
# |    policy_gradient_loss | 0.00313     |
# |    std                  | 0.206       |
# |    value_loss           | 0.000832    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.9         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 24          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.029330553 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.332       |
# |    explained_variance   | -3.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 11010       |
# |    policy_gradient_loss | 0.0128      |
# |    std                  | 0.204       |
# |    value_loss           | 0.00507     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 25          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.016258437 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.342       |
# |    explained_variance   | -10.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 11020       |
# |    policy_gradient_loss | 0.00949     |
# |    std                  | 0.205       |
# |    value_loss           | 0.00372     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 26          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014411461 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.338       |
# |    explained_variance   | 0.000218    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 11030       |
# |    policy_gradient_loss | 0.0083      |
# |    std                  | 0.204       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 27          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.019987859 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.338       |
# |    explained_variance   | -281        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00965    |
# |    n_updates            | 11040       |
# |    policy_gradient_loss | 0.0045      |
# |    std                  | 0.204       |
# |    value_loss           | 0.00818     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 28          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.029578883 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.357       |
# |    explained_variance   | -20.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00795     |
# |    n_updates            | 11050       |
# |    policy_gradient_loss | 0.00548     |
# |    std                  | 0.201       |
# |    value_loss           | 0.00393     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 29          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.029419012 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.381       |
# |    explained_variance   | -26.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 11060       |
# |    policy_gradient_loss | 0.00799     |
# |    std                  | 0.199       |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 30          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020453863 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.388       |
# |    explained_variance   | -3.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00255    |
# |    n_updates            | 11070       |
# |    policy_gradient_loss | 0.00767     |
# |    std                  | 0.2         |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 31          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.020513693 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.372       |
# |    explained_variance   | -32.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0273      |
# |    n_updates            | 11080       |
# |    policy_gradient_loss | 0.00861     |
# |    std                  | 0.202       |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 32          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017255258 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.352       |
# |    explained_variance   | -7.55       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0285      |
# |    n_updates            | 11090       |
# |    policy_gradient_loss | 0.00353     |
# |    std                  | 0.203       |
# |    value_loss           | 0.000302    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 33          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.028848294 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.342       |
# |    explained_variance   | -0.585      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0165      |
# |    n_updates            | 11100       |
# |    policy_gradient_loss | 0.00183     |
# |    std                  | 0.204       |
# |    value_loss           | 0.00285     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 34          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.035326228 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.328       |
# |    explained_variance   | -22         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 11110       |
# |    policy_gradient_loss | 0.0134      |
# |    std                  | 0.207       |
# |    value_loss           | 0.00275     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 35          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.018932573 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.307       |
# |    explained_variance   | 0.000383    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00441    |
# |    n_updates            | 11120       |
# |    policy_gradient_loss | 0.00166     |
# |    std                  | 0.208       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 36          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.018556187 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.29        |
# |    explained_variance   | -493        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00449     |
# |    n_updates            | 11130       |
# |    policy_gradient_loss | 0.0079      |
# |    std                  | 0.211       |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.91       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 219        |
# |    iterations           | 37         |
# |    time_elapsed         | 345        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02226087 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.276      |
# |    explained_variance   | -34.4      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0591     |
# |    n_updates            | 11140      |
# |    policy_gradient_loss | 0.00749    |
# |    std                  | 0.211      |
# |    value_loss           | 0.00364    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 38          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017380767 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.278       |
# |    explained_variance   | -12.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 11150       |
# |    policy_gradient_loss | 0.00655     |
# |    std                  | 0.21        |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 39          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.026772399 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.283       |
# |    explained_variance   | -23.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0417      |
# |    n_updates            | 11160       |
# |    policy_gradient_loss | 0.00356     |
# |    std                  | 0.21        |
# |    value_loss           | 0.00604     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 40          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.016743368 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.265       |
# |    explained_variance   | -12         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00874    |
# |    n_updates            | 11170       |
# |    policy_gradient_loss | 0.00235     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00255     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.77        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 41          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014572992 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.241       |
# |    explained_variance   | -56.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00713     |
# |    n_updates            | 11180       |
# |    policy_gradient_loss | 0.005       |
# |    std                  | 0.215       |
# |    value_loss           | 0.00574     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.83        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 42          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.035262752 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.244       |
# |    explained_variance   | -35.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0368      |
# |    n_updates            | 11190       |
# |    policy_gradient_loss | 0.00439     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.94       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 43         |
# |    time_elapsed         | 421        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01996504 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.273      |
# |    explained_variance   | -8.05      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0192    |
# |    n_updates            | 11200      |
# |    policy_gradient_loss | 0.00649    |
# |    std                  | 0.209      |
# |    value_loss           | 0.00179    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.8         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 44          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.023015372 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.282       |
# |    explained_variance   | -4.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00354    |
# |    n_updates            | 11210       |
# |    policy_gradient_loss | 0.00583     |
# |    std                  | 0.211       |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 45          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.029534683 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.257       |
# |    explained_variance   | 0.000343    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00942    |
# |    n_updates            | 11220       |
# |    policy_gradient_loss | 0.00373     |
# |    std                  | 0.215       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 46          |
# |    time_elapsed         | 453         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.024002336 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.233       |
# |    explained_variance   | -502        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00463    |
# |    n_updates            | 11230       |
# |    policy_gradient_loss | 0.00447     |
# |    std                  | 0.216       |
# |    value_loss           | 0.0187      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 47          |
# |    time_elapsed         | 461         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.026513025 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.23        |
# |    explained_variance   | -16.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0316      |
# |    n_updates            | 11240       |
# |    policy_gradient_loss | -0.00133    |
# |    std                  | 0.216       |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 48          |
# |    time_elapsed         | 471         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016090583 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.236       |
# |    explained_variance   | -5.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00815     |
# |    n_updates            | 11250       |
# |    policy_gradient_loss | 0.00385     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00218     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 49          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.034079354 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.238       |
# |    explained_variance   | -6          |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0231      |
# |    n_updates            | 11260       |
# |    policy_gradient_loss | 0.0069      |
# |    std                  | 0.215       |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# --- 483.1634261608124 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.9      |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 309      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.82        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.031488895 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.728       |
# |    explained_variance   | -7.48       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.031      |
# |    n_updates            | 10790       |
# |    policy_gradient_loss | 0.00357     |
# |    std                  | 0.169       |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2          |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 3          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02135818 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.71       |
# |    explained_variance   | -27.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0415     |
# |    n_updates            | 10800      |
# |    policy_gradient_loss | 0.00868    |
# |    std                  | 0.171      |
# |    value_loss           | 0.00213    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.034603577 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.691       |
# |    explained_variance   | 0.00033     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.9e+03     |
# |    n_updates            | 10810       |
# |    policy_gradient_loss | 0.0148      |
# |    std                  | 0.172       |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# ...
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.53       |
# |    explained_variance   | -53.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00626   |
# |    n_updates            | 11090      |
# |    policy_gradient_loss | 0.00949    |
# |    std                  | 0.186      |
# |    value_loss           | 0.00804    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 2.23     |
# |    ep_rew_mean          | 1        |
# | time/                   |          |
# |    fps                  | 398      |
# |    iterations           | 33       |
# |    time_elapsed         | 169      |
# |    total_timesteps      | 67584    |
# | train/                  |          |
# |    approx_kl            | 0.040994 |
# |    clip_fraction        | 0.291    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0.541    |
# |    explained_variance   | -155     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.102    |
# |    n_updates            | 11100    |
# |    policy_gradient_loss | 0.0187   |
# |    std                  | 0.186    |
# |    value_loss           | 0.00983  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 34          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022069313 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.557       |
# |    explained_variance   | -64.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00305    |
# |    n_updates            | 11110       |
# |    policy_gradient_loss | 0.00454     |
# |    std                  | 0.183       |
# |    value_loss           | 0.00697     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.15       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 35         |
# |    time_elapsed         | 180        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.03285235 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.57       |
# |    explained_variance   | -30.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0258    |
# |    n_updates            | 11120      |
# |    policy_gradient_loss | 0.00608    |
# |    std                  | 0.183      |
# |    value_loss           | 0.00469    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 36          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.041644037 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.574       |
# |    explained_variance   | -24.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 11130       |
# |    policy_gradient_loss | 0.00996     |
# |    std                  | 0.182       |
# |    value_loss           | 0.00532     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.37      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 397       |
# |    iterations           | 37        |
# |    time_elapsed         | 190       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0201371 |
# |    clip_fraction        | 0.216     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.584     |
# |    explained_variance   | -57.7     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00254  |
# |    n_updates            | 11140     |
# |    policy_gradient_loss | -0.00113  |
# |    std                  | 0.181     |
# |    value_loss           | 0.00977   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 38          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.025602818 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.585       |
# |    explained_variance   | -50.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00103    |
# |    n_updates            | 11150       |
# |    policy_gradient_loss | 0.0206      |
# |    std                  | 0.182       |
# |    value_loss           | 0.00662     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 39          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.025475834 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.585       |
# |    explained_variance   | -15.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0266      |
# |    n_updates            | 11160       |
# |    policy_gradient_loss | 0.00927     |
# |    std                  | 0.181       |
# |    value_loss           | 0.00591     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 40          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.027775854 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.61        |
# |    explained_variance   | -14.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0354      |
# |    n_updates            | 11170       |
# |    policy_gradient_loss | 0.0109      |
# |    std                  | 0.178       |
# |    value_loss           | 0.00228     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.42        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 41          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.018487414 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.638       |
# |    explained_variance   | -18.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 11180       |
# |    policy_gradient_loss | 0.00698     |
# |    std                  | 0.176       |
# |    value_loss           | 0.0038      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 42          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.014950056 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.632       |
# |    explained_variance   | -58         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 11190       |
# |    policy_gradient_loss | 0.0167      |
# |    std                  | 0.178       |
# |    value_loss           | 0.00867     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.16         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 43           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0142612485 |
# |    clip_fraction        | 0.185        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.625        |
# |    explained_variance   | -15.1        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0198       |
# |    n_updates            | 11200        |
# |    policy_gradient_loss | 0.0119       |
# |    std                  | 0.178        |
# |    value_loss           | 0.00458      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18       |
# |    ep_rew_mean          | -9.01      |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 44         |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03711408 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.622      |
# |    explained_variance   | -13.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00465   |
# |    n_updates            | 11210      |
# |    policy_gradient_loss | 0.0127     |
# |    std                  | 0.178      |
# |    value_loss           | 0.00404    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 45          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.024468208 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.618       |
# |    explained_variance   | 0.000306    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 11220       |
# |    policy_gradient_loss | 0.00465     |
# |    std                  | 0.178       |
# |    value_loss           | 2.18e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.92       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 46         |
# |    time_elapsed         | 237        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.05435263 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.635      |
# |    explained_variance   | 0.0116     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.239      |
# |    n_updates            | 11230      |
# |    policy_gradient_loss | 0.0103     |
# |    std                  | 0.176      |
# |    value_loss           | 1.29e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 47          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.035333846 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.653       |
# |    explained_variance   | -72.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0213      |
# |    n_updates            | 11240       |
# |    policy_gradient_loss | 0.00536     |
# |    std                  | 0.175       |
# |    value_loss           | 0.142       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.25       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 48         |
# |    time_elapsed         | 247        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02918558 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.667      |
# |    explained_variance   | -150       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0206     |
# |    n_updates            | 11250      |
# |    policy_gradient_loss | 0.0129     |
# |    std                  | 0.173      |
# |    value_loss           | 0.0274     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 49          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.025280967 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.683       |
# |    explained_variance   | 0.00216     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0432      |
# |    n_updates            | 11260       |
# |    policy_gradient_loss | 0.00903     |
# |    std                  | 0.172       |
# |    value_loss           | 486         |
# -----------------------------------------
# --- 254.49679613113403 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-900000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.97 +/- 5.48
# Focus Polytopes:
# mean_reward:0.98 +/- 4.48
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.47 +/- 23.04
# Focus Polytopes:
# mean_reward:1.00 +/- 0.00
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.85 +/- 12.26
# Focus Polytopes:
# mean_reward:0.99 +/- 3.17
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.98 +/- 4.48
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.99 +/- 3.17
# Focus Polytopes:
# mean_reward:0.86 +/- 11.84
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.90 +/- 10.01
# Focus Polytopes:
# mean_reward:0.98 +/- 4.48

# %%
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-900000-"+str(p))
    model.set_env(env)
    
    print("p=",p)

    env.init_polytopes(p,retrain_polytopes)
    start_time = time.time()
    model=model.learn(total_timesteps=training_episode_length)
    print("--- %s seconds ---" % (time.time() - start_time))

    model.save("model_backup/zeppelin-avoidance-windsystem-small2-1400000-1000000-"+str(p))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.81     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 304      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016252391 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.254       |
# |    explained_variance   | -3.36       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00648    |
# |    n_updates            | 11280       |
# |    policy_gradient_loss | 0.00958     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012810392 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.244       |
# |    explained_variance   | -24.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000141    |
# |    n_updates            | 11290       |
# |    policy_gradient_loss | 0.00592     |
# |    std                  | 0.215       |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018830828 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.231       |
# |    explained_variance   | -56.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0833      |
# |    n_updates            | 11300       |
# |    policy_gradient_loss | 0.00635     |
# |    std                  | 0.216       |
# |    value_loss           | 0.000725    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 5           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.028308664 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.228       |
# |    explained_variance   | -3.25       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0163      |
# |    n_updates            | 11310       |
# |    policy_gradient_loss | 0.00327     |
# |    std                  | 0.216       |
# |    value_loss           | 0.000687    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 6           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.019463234 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.219       |
# |    explained_variance   | -38.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 11320       |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.218       |
# |    value_loss           | 0.00471     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 7           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020459887 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.206       |
# |    explained_variance   | -61.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00895    |
# |    n_updates            | 11330       |
# |    policy_gradient_loss | 0.00333     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.83        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 8           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.022271425 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.22        |
# |    explained_variance   | -2.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00142    |
# |    n_updates            | 11340       |
# |    policy_gradient_loss | 0.00388     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 9           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023450585 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.228       |
# |    explained_variance   | -5.82       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 11350       |
# |    policy_gradient_loss | 0.00229     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00491     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 10          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.044858657 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.213       |
# |    explained_variance   | -3.62       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 11360       |
# |    policy_gradient_loss | 0.00535     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 11          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019787671 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.212       |
# |    explained_variance   | -0.737      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00761     |
# |    n_updates            | 11370       |
# |    policy_gradient_loss | 0.00673     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00123     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 12          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015473191 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.217       |
# |    explained_variance   | -3.18e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 11380       |
# |    policy_gradient_loss | 0.0048      |
# |    std                  | 0.217       |
# |    value_loss           | 488         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 13         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01773364 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.202      |
# |    explained_variance   | -78.8      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0265    |
# |    n_updates            | 11390      |
# |    policy_gradient_loss | 0.00561    |
# |    std                  | 0.22       |
# |    value_loss           | 0.00853    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 14          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016218886 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.202       |
# |    explained_variance   | -28.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0147     |
# |    n_updates            | 11400       |
# |    policy_gradient_loss | 0.00354     |
# |    std                  | 0.218       |
# |    value_loss           | 0.00438     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 15          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017924393 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.215       |
# |    explained_variance   | -8.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0168      |
# |    n_updates            | 11410       |
# |    policy_gradient_loss | 0.0119      |
# |    std                  | 0.217       |
# |    value_loss           | 0.000939    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 16          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022438817 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.239       |
# |    explained_variance   | -13         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00768     |
# |    n_updates            | 11420       |
# |    policy_gradient_loss | 0.00107     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 17          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.024105223 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.258       |
# |    explained_variance   | -29.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 11430       |
# |    policy_gradient_loss | 0.00465     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00105     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 18          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026429977 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.257       |
# |    explained_variance   | -3.75       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0355      |
# |    n_updates            | 11440       |
# |    policy_gradient_loss | 0.00204     |
# |    std                  | 0.213       |
# |    value_loss           | 0.0031      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 19          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013125392 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.266       |
# |    explained_variance   | -9.1        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00202    |
# |    n_updates            | 11450       |
# |    policy_gradient_loss | 0.00407     |
# |    std                  | 0.211       |
# |    value_loss           | 0.0025      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.85       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 20         |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02297139 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.275      |
# |    explained_variance   | -1.88      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00694    |
# |    n_updates            | 11460      |
# |    policy_gradient_loss | 0.00553    |
# |    std                  | 0.211      |
# |    value_loss           | 0.0032     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 21          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.025880918 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.271       |
# |    explained_variance   | -0.438      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00119     |
# |    n_updates            | 11470       |
# |    policy_gradient_loss | 0.00236     |
# |    std                  | 0.211       |
# |    value_loss           | 0.0009      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 22          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.043453578 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.266       |
# |    explained_variance   | -10.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0871      |
# |    n_updates            | 11480       |
# |    policy_gradient_loss | 0.0098      |
# |    std                  | 0.212       |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 23          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.046147257 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.249       |
# |    explained_variance   | -50.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00766     |
# |    n_updates            | 11490       |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.216       |
# |    value_loss           | 0.00988     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 24          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.029758746 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.244       |
# |    explained_variance   | -6.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0161     |
# |    n_updates            | 11500       |
# |    policy_gradient_loss | 0.0038      |
# |    std                  | 0.213       |
# |    value_loss           | 0.000879    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.03       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 25         |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02758693 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.262      |
# |    explained_variance   | -0.75      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0307     |
# |    n_updates            | 11510      |
# |    policy_gradient_loss | 0.0057     |
# |    std                  | 0.212      |
# |    value_loss           | 0.000831   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 26          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.016034935 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.265       |
# |    explained_variance   | -11.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0307      |
# |    n_updates            | 11520       |
# |    policy_gradient_loss | 0.00727     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 27          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.028011404 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.261       |
# |    explained_variance   | -2.59       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 11530       |
# |    policy_gradient_loss | 0.00286     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00396     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.86       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 28         |
# |    time_elapsed         | 241        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.15844281 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.259      |
# |    explained_variance   | -16        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00711    |
# |    n_updates            | 11540      |
# |    policy_gradient_loss | 0.00893    |
# |    std                  | 0.213      |
# |    value_loss           | 0.00113    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 29          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.036941633 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.261       |
# |    explained_variance   | -0.758      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0223     |
# |    n_updates            | 11550       |
# |    policy_gradient_loss | 0.00936     |
# |    std                  | 0.212       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.85      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 237       |
# |    iterations           | 30        |
# |    time_elapsed         | 258       |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0238186 |
# |    clip_fraction        | 0.191     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.256     |
# |    explained_variance   | -29.8     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.029     |
# |    n_updates            | 11560     |
# |    policy_gradient_loss | 0.00303   |
# |    std                  | 0.214     |
# |    value_loss           | 0.00505   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 31          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.021148797 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.245       |
# |    explained_variance   | 0.000106    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0573      |
# |    n_updates            | 11570       |
# |    policy_gradient_loss | 0.0114      |
# |    std                  | 0.215       |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.74        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 32          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.027048722 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.223       |
# |    explained_variance   | -162        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00875    |
# |    n_updates            | 11580       |
# |    policy_gradient_loss | 0.00282     |
# |    std                  | 0.218       |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 33          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014690313 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.213       |
# |    explained_variance   | -332        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 11590       |
# |    policy_gradient_loss | 0.00277     |
# |    std                  | 0.217       |
# |    value_loss           | 0.00939     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 34          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.025629707 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.219       |
# |    explained_variance   | -11.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0493      |
# |    n_updates            | 11600       |
# |    policy_gradient_loss | 0.00629     |
# |    std                  | 0.216       |
# |    value_loss           | 0.00393     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 35          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.018697755 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.228       |
# |    explained_variance   | -21.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0332      |
# |    n_updates            | 11610       |
# |    policy_gradient_loss | 0.0124      |
# |    std                  | 0.216       |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 36          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.020299427 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.236       |
# |    explained_variance   | -10.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0127      |
# |    n_updates            | 11620       |
# |    policy_gradient_loss | 0.000509    |
# |    std                  | 0.214       |
# |    value_loss           | 0.00148     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 37          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.019533047 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.242       |
# |    explained_variance   | -12.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000278    |
# |    n_updates            | 11630       |
# |    policy_gradient_loss | 0.00601     |
# |    std                  | 0.215       |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 38          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020359876 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.245       |
# |    explained_variance   | -8.57       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000654   |
# |    n_updates            | 11640       |
# |    policy_gradient_loss | 0.00311     |
# |    std                  | 0.214       |
# |    value_loss           | 0.00366     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 39          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.018448424 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.262       |
# |    explained_variance   | -32.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0505      |
# |    n_updates            | 11650       |
# |    policy_gradient_loss | 0.00506     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.91       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 235        |
# |    iterations           | 40         |
# |    time_elapsed         | 348        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.01867554 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.272      |
# |    explained_variance   | -2.2       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00699   |
# |    n_updates            | 11660      |
# |    policy_gradient_loss | 0.0057     |
# |    std                  | 0.211      |
# |    value_loss           | 0.00996    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 41          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015057983 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.269       |
# |    explained_variance   | -15.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.011       |
# |    n_updates            | 11670       |
# |    policy_gradient_loss | 0.00448     |
# |    std                  | 0.212       |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 42          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.028661527 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.274       |
# |    explained_variance   | -2.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00407     |
# |    n_updates            | 11680       |
# |    policy_gradient_loss | 0.00335     |
# |    std                  | 0.21        |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 43          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.024828838 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.288       |
# |    explained_variance   | -52.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 11690       |
# |    policy_gradient_loss | 0.00582     |
# |    std                  | 0.209       |
# |    value_loss           | 0.00243     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 44          |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.021615809 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.307       |
# |    explained_variance   | -1.27       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0879      |
# |    n_updates            | 11700       |
# |    policy_gradient_loss | 0.00345     |
# |    std                  | 0.207       |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 45         |
# |    time_elapsed         | 394        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02753382 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.321      |
# |    explained_variance   | -39.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.036      |
# |    n_updates            | 11710      |
# |    policy_gradient_loss | 0.0364     |
# |    std                  | 0.206      |
# |    value_loss           | 0.0042     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 46          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019511746 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.328       |
# |    explained_variance   | -91.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 11720       |
# |    policy_gradient_loss | 0.0104      |
# |    std                  | 0.205       |
# |    value_loss           | 0.00054     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 47          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.022533529 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.32        |
# |    explained_variance   | -5.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00973     |
# |    n_updates            | 11730       |
# |    policy_gradient_loss | 0.00917     |
# |    std                  | 0.207       |
# |    value_loss           | 0.00197     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 232        |
# |    iterations           | 48         |
# |    time_elapsed         | 422        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01773177 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.312      |
# |    explained_variance   | -36.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0212     |
# |    n_updates            | 11740      |
# |    policy_gradient_loss | 0.00823    |
# |    std                  | 0.207      |
# |    value_loss           | 0.000778   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.9        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 49         |
# |    time_elapsed         | 430        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.03675251 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.303      |
# |    explained_variance   | -0.186     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00382   |
# |    n_updates            | 11750      |
# |    policy_gradient_loss | 0.00623    |
# |    std                  | 0.209      |
# |    value_loss           | 0.00289    |
# ----------------------------------------
# --- 432.4721710681915 seconds ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.28     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 296      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.76       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 268        |
# |    iterations           | 2          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.04854371 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.688      |
# |    explained_variance   | -6.61      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00733    |
# |    n_updates            | 11280      |
# |    policy_gradient_loss | 0.00388    |
# |    std                  | 0.172      |
# |    value_loss           | 0.0067     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.06      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 252       |
# |    iterations           | 3         |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0705933 |
# |    clip_fraction        | 0.29      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.683     |
# |    explained_variance   | -6.72     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0345    |
# |    n_updates            | 11290     |
# |    policy_gradient_loss | 0.00795   |
# |    std                  | 0.173     |
# |    value_loss           | 0.00329   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.8         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 4           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.048295617 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.673       |
# |    explained_variance   | -6.48       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0254      |
# |    n_updates            | 11300       |
# |    policy_gradient_loss | 0.000456    |
# |    std                  | 0.173       |
# |    value_loss           | 0.00757     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.85       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 242        |
# ...
# |    explained_variance   | -57.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 11580       |
# |    policy_gradient_loss | 0.00962     |
# |    std                  | 0.175       |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 33          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.050401587 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.644       |
# |    explained_variance   | -70.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00329     |
# |    n_updates            | 11590       |
# |    policy_gradient_loss | 0.0148      |
# |    std                  | 0.176       |
# |    value_loss           | 0.00865     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 34          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.036582828 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.645       |
# |    explained_variance   | -50         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.344       |
# |    n_updates            | 11600       |
# |    policy_gradient_loss | 0.0139      |
# |    std                  | 0.175       |
# |    value_loss           | 0.00714     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 35          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.034781765 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.645       |
# |    explained_variance   | -67.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 11610       |
# |    policy_gradient_loss | 0.018       |
# |    std                  | 0.176       |
# |    value_loss           | 0.00966     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 36          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.019339751 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.65        |
# |    explained_variance   | -27.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0546      |
# |    n_updates            | 11620       |
# |    policy_gradient_loss | 0.0098      |
# |    std                  | 0.174       |
# |    value_loss           | 0.00476     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 37          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.026163228 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.652       |
# |    explained_variance   | -14.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0312      |
# |    n_updates            | 11630       |
# |    policy_gradient_loss | 0.00872     |
# |    std                  | 0.175       |
# |    value_loss           | 0.00698     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 38          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020201836 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.664       |
# |    explained_variance   | -23.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0263      |
# |    n_updates            | 11640       |
# |    policy_gradient_loss | 0.0172      |
# |    std                  | 0.172       |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 39          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.029030442 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.675       |
# |    explained_variance   | -38.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0243      |
# |    n_updates            | 11650       |
# |    policy_gradient_loss | 0.0159      |
# |    std                  | 0.173       |
# |    value_loss           | 0.00779     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 40         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02554352 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.672      |
# |    explained_variance   | -3.98e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0527     |
# |    n_updates            | 11660      |
# |    policy_gradient_loss | 0.0133     |
# |    std                  | 0.173      |
# |    value_loss           | 1.3e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 41          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.034891494 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.682       |
# |    explained_variance   | -115        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0192      |
# |    n_updates            | 11670       |
# |    policy_gradient_loss | 0.0053      |
# |    std                  | 0.172       |
# |    value_loss           | 0.0641      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 42          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.044189274 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.689       |
# |    explained_variance   | -123        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0149      |
# |    n_updates            | 11680       |
# |    policy_gradient_loss | 0.00521     |
# |    std                  | 0.172       |
# |    value_loss           | 0.0179      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 43          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.024219107 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.692       |
# |    explained_variance   | -69.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 11690       |
# |    policy_gradient_loss | 0.00345     |
# |    std                  | 0.171       |
# |    value_loss           | 0.0157      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.27      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 296       |
# |    iterations           | 44        |
# |    time_elapsed         | 304       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 1.0192292 |
# |    clip_fraction        | 0.428     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.697     |
# |    explained_variance   | -55       |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.026    |
# |    n_updates            | 11700     |
# |    policy_gradient_loss | 0.0185    |
# |    std                  | 0.171     |
# |    value_loss           | 0.00852   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 45          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.033431232 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.699       |
# |    explained_variance   | 0.000703    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.926       |
# |    n_updates            | 11710       |
# |    policy_gradient_loss | 0.0263      |
# |    std                  | 0.171       |
# |    value_loss           | 2.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 46          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.045105852 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.693       |
# |    explained_variance   | -144        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0359      |
# |    n_updates            | 11720       |
# |    policy_gradient_loss | 0.00806     |
# |    std                  | 0.172       |
# |    value_loss           | 0.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 47          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.040198617 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.675       |
# |    explained_variance   | -126        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0972      |
# |    n_updates            | 11730       |
# |    policy_gradient_loss | 0.0138      |
# |    std                  | 0.173       |
# |    value_loss           | 0.0485      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.15       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 48         |
# |    time_elapsed         | 330        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02746626 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.668      |
# |    explained_variance   | -164       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0192     |
# |    n_updates            | 11740      |
# |    policy_gradient_loss | 0.00947    |
# |    std                  | 0.173      |
# |    value_loss           | 0.0162     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.15       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 49         |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.15240121 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.664      |
# |    explained_variance   | -114       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00118   |
# |    n_updates            | 11750      |
# |    policy_gradient_loss | 0.0222     |
# |    std                  | 0.174      |
# |    value_loss           | 0.0128     |
# ----------------------------------------
# --- 338.601450920105 seconds ---

# %%
# Performance of models on focus polytopes only?
for p in [0.0, 0.05, 0.1, 0.5, 0.9, 1.0]:
    model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-1000000-"+str(p))
    model.set_env(env)
    print("p=",p)
    
    print("Overall:")
    env.init_polytopes(1.0,[])
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_overall[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    
    print("Focus Polytopes:")
    env.init_polytopes(0.0,retrain_polytopes)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
    results_polys[p].append((mean_reward, std_reward))
    print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.0
# Overall:
# mean_reward:0.96 +/- 6.33
# Focus Polytopes:
# mean_reward:1.00 +/- 0.00
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.05
# Overall:
# mean_reward:0.85 +/- 12.26
# Focus Polytopes:
# mean_reward:0.99 +/- 3.17
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.1
# Overall:
# mean_reward:0.51 +/- 22.15
# Focus Polytopes:
# mean_reward:0.99 +/- 3.17
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.5
# Overall:
# mean_reward:1.00 +/- 0.00
# Focus Polytopes:
# mean_reward:1.00 +/- 0.00
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 0.9
# Overall:
# mean_reward:0.97 +/- 5.48
# Focus Polytopes:
# mean_reward:0.76 +/- 15.51
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# p= 1.0
# Overall:
# mean_reward:0.92 +/- 8.95
# Focus Polytopes:
# mean_reward:0.83 +/- 13.05

# %% [markdown]
# ## After retraining

# %%
eval_episode_length=100000
training_episode_length=100000

# %%
env.seed(42)
torch.manual_seed(42)

# %%
retrain_polytopes = None
with open("zeppelin-1400000-retrain-1000000-0.5-polytopes.pickle","rb") as f:
    retrain_polytopes = pickle.load(f)

# %%
# Total volume of polytopes?
# Share of instances usually (i.e. without "focus polytopes")

# Volume of state space:
N = 100000
n=4
l_b = np.array([env.unwrapped.MIN_X,env.unwrapped.MIN_Y,env.unwrapped.MIN_C,env.unwrapped.MAX_VELOCITY-env.unwrapped.MAX_TURBULENCE+0.1])
u_b = np.array([env.unwrapped.MAX_X,env.unwrapped.MAX_Y,env.unwrapped.MAX_C,env.unwrapped.MAX_WIND_SPEED])
xs = env.unwrapped.np_random.uniform(low=l_b,high=u_b,size=(N,n))
s = 0
for x in xs:
    if not env.unwrapped.is_crash(x) and not env.unwrapped.reached_goal(x) and env.unwrapped.is_in_bounds(x):
        s+=1
print("s: ",s)
total_vol = np.prod(u_b - l_b) * (s / N)
print("total volume: ", total_vol)

poly_region = pc.Region(retrain_polytopes)
l_b, u_b = poly_region.bounding_box
l_b = l_b.flatten()
u_b = u_b.flatten()
print(l_b,",",u_b)
xs = env.unwrapped.np_random.uniform(low=l_b,high=u_b,size=(N,n))
s = 0
for x in xs:
    if x in poly_region:
        if not env.unwrapped.is_crash(x) and not env.unwrapped.reached_goal(x) and env.unwrapped.is_in_bounds(x):
                s+=1
poly_vol = np.prod(u_b - l_b) * (s / N)
print("poly volume: ", poly_vol)

# We only have an upper bound for the share, since polytopes may be partially outside the state space of interest
poly_share = poly_vol/total_vol
print("max share: ", poly_share)
# Out:
# s:  4512
# total volume:  50332262.4
# [-146.37511  -97.5       10.         5.     ] , [400. 400.  80.  30.]
# poly volume:  35609990.77787027
# max share:  0.7074983138026052

# %%
model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-1000000-0.5")
model.set_env(env)

env.init_polytopes(0.0,retrain_polytopes)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=eval_episode_length)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,

# %%
model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-1000000-0.5")
model.set_env(env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
env.init_polytopes(0.0,retrain_polytopes)
#orig_observation = env.reset()
for i_episode in range(100):
    observation = env.reset()
    #env.unwrapped.state=[4.545,13,10,5.5]
    #env.unwrapped.state = [167.10239, -10.34823,  79.3649,    5.99876]
    #env.unwrapped.state = orig_observation
    observation = env.unwrapped.state
    total_reward=0
    for t in range(1000):
        print(observation)
        action, _states = model.predict(observation,deterministic=True)
        print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        #print[[action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)]]
        #x1_norm = observation[0]/np.sqrt(observation[0]**2+observation[1]**2)
        #x2_norm = observation[1]/np.sqrt(observation[0]**2+observation[1]**2)
        #f = 1.0 if (x2_norm) < 0 else -1.0
        #action = [f, f*(0-x1_norm)]
        observation, reward, done, info = env.step(action)
        total_reward=0.99*total_reward+reward
        env.render()
        time.sleep(0.2)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            break
env.close()
# Out:
# [ 69.90218 -61.54047  49.81218  10.69485]
# [1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-91.02743  -1.26261  64.68677  28.64434]
# [-1.0, -0.0]
# [-100.78373  -14.21089   64.68677   28.64434]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 22.9063  -35.31046  35.30115  10.49014]
# [0.2238152, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-66.35822 -41.74392  32.21763  27.21313]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 45.00846 -68.21664  58.33325  25.08126]
# [0.39631796, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 32.37697 -47.3785   42.63395  23.36719]
# [0.09334865, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-102.74506    7.67821   70.81089   21.19506]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-118.38648  -39.77077   46.2788     7.19695]
# [-1.0, -0.0]
# [-132.37303  -41.12658   46.2788     7.19695]
# [-1.0, -0.0]
# [-140.38629  -47.81653   46.2788     7.19695]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [ 37.16578 -55.42036  53.28078  24.49039]
# [0.22792113, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 27.2808  -35.11782  34.08442  13.47861]
# [0.1480847, -0.0]
# [ 25.77863 -50.28288  34.08442  13.47861]
# [0.5679221, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 92.98486 -61.96037  47.83458  11.799  ]
# [1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [  2.77188 -10.00111  10.00108   9.07354]
# [-0.03995481, 0.10969180471317558]
# [  2.59476 -18.26795  10.00108   9.07354]
# [0.13660437, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 42.48887 -17.66591  32.2773   25.21951]
# [-0.36722535, 0.3590697729710361]
# [ 37.52812 -39.84262  32.2773   25.21951]
# [0.12875885, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-97.59669   6.45523  73.80562  22.49411]
# [-1.0, -0.0]
# [-107.74981   -3.08333   73.80562   22.49411]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 35.90105 -45.33702  43.18272  22.04587]
# [0.12093338, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-85.15092   5.34486  48.18382  16.52285]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 48.26629 -37.79694  28.16627  19.25518]
# [0.8003363, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-45.95104   1.29319  31.91931  13.31645]
# [-1.0, -0.0]
# [-55.28472  -6.6615   31.91931  13.31645]
# [-1.0, -0.0]
# [-67.18434 -14.62406  31.91931  13.31645]
# [-1.0, -0.0]
# [-77.45937 -19.53594  31.91931  13.31645]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [ 45.55103 -70.35516  64.36017  26.62297]
# [0.41838968, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-84.62963  14.4353   54.67499  13.23787]
# [-1.0, -0.0]
# [-96.80725   5.76595  54.67499  13.23787]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-103.65762  -34.79015   34.94748    6.21293]
# [-1.0, -0.0]
# [-110.06929  -38.64719   34.94748    6.21293]
# [-1.0, -0.0]
# [-122.929    -38.34481   34.94748    6.21293]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [-88.21233   0.32021  73.96992  29.64146]
# [-1.0, -0.0]
# [-100.37809  -11.79903   73.96992   29.64146]
# [-1.0, -0.0]
# [-110.07563  -29.00225   73.96992   29.64146]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [ 60.47555 -92.39409  76.05463  11.04597]
# [1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 58.54211 -71.49423  67.82318  28.05303]
# [0.42317045, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-84.19822  11.62114  70.87457  26.12485]
# [-1.0, -0.0]
# [-95.10586  -0.00962  70.87457  26.12485]
# [-1.0, -0.0]
# [-102.22627   -9.27634   70.87457   26.12485]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [-54.00097 248.32232  77.26713  21.56809]
# [-1.0, -0.0]
# [-59.86838 235.61124  77.26713  21.56809]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-122.39372  -13.68755   59.08241    8.37186]
# [-1.0, -0.0]
# [-133.46531  -17.35505   59.08241    8.37186]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-136.63779   26.45226   75.09951    7.17872]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-99.06614  22.67148  77.6793   16.33899]
# [-1.0, -0.0]
# [-109.04657   13.75597   77.6793    16.33899]
# [-1.0, -0.0]
# [-119.58767    7.9318    77.6793    16.33899]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [ 48.061   -71.06656  60.54964  26.16585]
# [0.42156464, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-70.15089  42.28003  51.20653  11.78616]
# [-1.0, -0.0]
# [-80.96714  35.32752  51.20653  11.78616]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-76.48741  19.17955  57.85897  13.65902]
# [-1.0, -0.0]
# [-85.04177   7.01433  57.85897  13.65902]
# [-1.0, -0.0]
# [-95.05148   1.14976  57.85897  13.65902]
# [-1.0, -0.0]
# [-104.99479   -3.71055   57.85897   13.65902]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [-94.00945  22.46236  76.8442   20.52668]
# [-1.0, -0.0]
# [-102.53659   10.07126   76.8442    20.52668]
# [-1.0, -0.0]
# [-109.39132    0.84881   76.8442    20.52668]
# [-1.0, -0.0]
# [-118.72293  -11.19485   76.8442    20.52668]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [-98.50138  30.86171  74.70845  16.97662]
# [-1.0, -0.0]
# [-108.80019   23.85197   74.70845   16.97662]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-44.53949   1.57541  31.78952  12.96161]
# [-1.0, -0.0]
# [-54.7659   -2.79934  31.78952  12.96161]
# [-1.0, -0.0]
# [-65.74251  -7.5264   31.78952  12.96161]
# [-1.0, -0.0]
# [-73.65358 -14.87342  31.78952  12.96161]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [ 34.93789 -53.18484  49.45854  18.77347]
# [0.31917974, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [  1.86345 -89.16476  76.12739  19.16897]
# [0.5956746, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-88.99961  31.60032  74.03985  15.70399]
# [-1.0, -0.0]
# [-98.09403  21.56803  74.03985  15.70399]
# [-1.0, -0.0]
# [-107.87304   14.35093   74.03985   15.70399]
# [-1.0, -0.0]
# [-115.80022    3.47608   74.03985   15.70399]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [-85.95696  36.33756  48.35446   6.04432]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-42.88924   6.517    30.56676  10.07586]
# [-1.0, -0.0]
# [-55.17417  -0.28836  30.56676  10.07586]
# [-1.0, -0.0]
# [-65.92858  -3.57794  30.56676  10.07586]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [ 64.36123 -85.16281  70.24621  11.84191]
# [1.0, -0.0]
# [ 77.4116  -86.85945  70.24621  11.84191]
# [1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-59.85837  36.53059  38.06013  12.51876]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 47.03365 -20.50355  35.47524  29.51247]
# [-0.51278925, 0.2299858904391355]
# [ 42.46511 -41.48353  35.47524  29.51247]
# [0.103052765, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 85.84513 -27.15998  33.92445   6.17245]
# [1.0, -0.0]
# [ 97.41478 -29.64104  33.92445   6.17245]
# [1.0, -0.0]
# [103.31226 -34.66191  33.92445   6.17245]
# [1.0, -0.0]
# [115.06258 -34.70092  33.92445   6.17245]
# [1.0, -0.0]
# [127.017   -39.15372  33.92445   6.17245]
# [1.0, -0.0]
# Episode finished after 5 timesteps
# Reward:  1.0
# [-97.51328 -34.42817  37.78449   8.30192]
# [-1.0, -0.0]
# [-107.9514   -39.23146   37.78449    8.30192]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-36.13446 -10.9534   14.46416  29.23458]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-70.87134 -72.03872  58.53919  18.55224]
# [0.28976586, -0.9570975622716995]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 46.85801 -19.78674  34.5346   28.05693]
# [-0.5366149, 0.15106295579781392]
# [ 37.34649 -38.50151  34.5346   28.05693]
# [0.095360905, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 37.51696 -15.90008  18.69438  25.47826]
# [-0.22426745, 0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-99.03375  16.21814  78.2933   23.68649]
# [-1.0, -0.0]
# [-109.2324     8.21563   78.2933    23.68649]
# [-1.0, -0.0]
# [-118.81058   -2.94711   78.2933    23.68649]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [169.36915 -69.45054  69.30192   9.57287]
# [1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-74.83928   8.36575  57.36565  18.2947 ]
# [-1.0, -0.0]
# [-84.54839  -5.40875  57.36565  18.2947 ]
# [-1.0, -0.0]
# [-93.98117  -8.25805  57.36565  18.2947 ]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [-91.50156  26.08675  63.25625  13.45368]
# [-1.0, -0.0]
# [-97.57281  24.3559   63.25625  13.45368]
# [-1.0, -0.0]
# [-105.766     15.34429   63.25625   13.45368]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [-67.36741 -49.71029  45.93739  28.27703]
# [-0.93687975, -0.349651721603592]
# [-75.30053 -60.53092  45.93739  28.27703]
# [-0.9667293, -0.255801666817875]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-146.90766   -9.47057   79.9122     7.58837]
# [-1.0, -0.0]
# [-153.19368  -13.20897   79.9122     7.58837]
# [-1.0, -0.0]
# [-162.94532  -16.22664   79.9122     7.58837]
# [-1.0, -0.0]
# [-173.05322  -19.24465   79.9122     7.58837]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [ 72.65759 -65.63762  51.60282  10.58289]
# [1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-146.7409   -12.19247   79.28306    8.51589]
# [-1.0, -0.0]
# [-157.07962  -14.71101   79.28306    8.51589]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 24.54137 -32.44307  29.05078  10.16079]
# [0.16732064, -0.0]
# [ 26.90652 -46.01102  29.05078  10.16079]
# [0.8951375, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 67.07396 -19.4861   52.26879  27.04972]
# [-0.2782528, 0.4727086427818379]
# [ 65.22819 -35.69934  52.26879  27.04972]
# [-0.09902972, 0.0]
# [ 63.00084 -58.70169  52.26879  27.04972]
# [0.286931, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [ 23.67525 -37.58976  36.15254  10.37957]
# [0.25661564, -0.0]
# [ 27.68621 -50.24981  36.15254  10.37957]
# [0.7491861, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 46.88012 -70.37418  61.17765  29.07319]
# [0.3405699, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-78.65241   6.89832  60.55805  16.55054]
# [-1.0, -0.0]
# [-92.82216  -5.22659  60.55805  16.55054]
# [-1.0, -0.0]
# [-98.95846 -11.79131  60.55805  16.55054]
# [-1.0, -0.0]
# [-102.96299  -16.74232   60.55805   16.55054]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [-90.19802  26.78716  72.14983  18.38198]
# [-1.0, -0.0]
# [-98.36084  23.07779  72.14983  18.38198]
# [-1.0, -0.0]
# [-108.06306   13.243     72.14983   18.38198]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [ 48.59044 -20.90055  36.82789  29.35565]
# [-0.52280724, 0.19138290516638407]
# [ 41.55085 -41.6144   36.82789  29.35565]
# [0.07934129, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 23.71456 -34.47265  33.8154   11.31661]
# [0.18827298, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 48.02431 -74.26905  63.03143  28.54118]
# [0.40729946, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-101.42321   10.9704    74.16149   16.66822]
# [-1.0, -0.0]
# [-112.28789    5.17397   74.16149   16.66822]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-133.69597  -10.51837   61.32964    7.21396]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 52.05286 -65.33436  64.2688   27.62868]
# [0.35455614, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 57.52663 -67.02064  66.67372  27.31502]
# [0.37833804, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 42.80713 -19.1866   32.4793   27.69765]
# [-0.44019538, 0.2954897834441697]
# [ 39.63018 -36.6092   32.4793   27.69765]
# [0.047216147, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 29.30348 -64.46637  58.90958  21.33615]
# [0.38347894, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-107.15992   17.39691   78.04741   19.63216]
# [-1.0, -0.0]
# [-119.51943    6.08538   78.04741   19.63216]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-81.50558   2.19361  58.19624  22.20874]
# [-1.0, -0.0]
# [-91.21938 -11.73531  58.19624  22.20874]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-99.28799 -31.58702  37.12553   9.08289]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-102.76992  -34.91102   35.60776    7.79296]
# [-1.0, -0.0]
# [-112.76271  -37.59897   35.60776    7.79296]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ -2.267   -77.29193  65.19047  13.94618]
# [0.5589864, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-112.67439  -34.66028   36.29934    7.70666]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-69.77622  76.03072  65.72685   6.79998]
# [-1.0, -0.0]
# [-85.83923  76.25429  65.72685   6.79998]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-103.40399    7.53725   77.44917   26.07458]
# [-1.0, -0.0]
# [-112.36109   -1.89942   77.44917   26.07458]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-87.98622  23.39016  63.61106  13.83392]
# [-1.0, -0.0]
# [-100.35831   12.36278   63.61106   13.83392]
# [-1.0, -0.0]
# [-110.31236    6.64531   63.61106   13.83392]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [-93.27227  11.53817  78.48522  24.29261]
# [-1.0, -0.0]
# [-107.43548   -3.76179   78.48522   24.29261]
# [-1.0, -0.0]
# [-120.18579  -14.62795   78.48522   24.29261]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [120.81923 -66.26467  59.82336  11.63745]
# [1.0, -0.0]
# [130.95682 -73.23351  59.82336  11.63745]
# [1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 51.17825 -23.22266  35.7645   20.24212]
# [-0.14423046, 0.0]
# [ 50.69369 -45.87495  35.7645   20.24212]
# [0.69500303, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 43.44946 -18.4247   33.2854   26.34786]
# [-0.38224372, 0.35391663029355175]
# [ 39.75962 -35.07294  33.2854   26.34786]
# [-0.06261146, 0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 76.90847 -64.06699  58.34177  12.41939]
# [1.0, -0.0]
# [ 87.24536 -69.18611  58.34177  12.41939]
# [1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-19.56696 -41.36687  36.24742   8.94889]
# [0.016859025, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-72.85018 -74.84596  66.80616  12.9274 ]
# [0.35191527, -0.8039774183594407]
# [-69.21525 -81.88339  66.80616  12.9274 ]
# [0.46043557, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [ 22.00483 -35.76014  32.48712   8.6611 ]
# [0.25340968, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 25.91307 -37.6945   35.43248   9.96056]
# [0.27208096, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 47.82455 -64.00847  62.97008  26.47041]
# [0.36184853, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-94.81526  11.49642  58.66659  15.45341]
# [-1.0, -0.0]
# [-101.62922    3.19991   58.66659   15.45341]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-71.60212   3.67918  53.16855  16.60323]
# [-1.0, -0.0]
# [-81.72983  -1.34087  53.16855  16.60323]
# [-1.0, -0.0]
# [-91.87822  -8.49891  53.16855  16.60323]
# [-1.0, -0.0]
# Episode finished after 3 timesteps
# Reward:  1.0
# [-87.34291   2.35845  73.45877  26.24521]
# [-1.0, -0.0]
# [-95.27435 -13.80556  73.45877  26.24521]
# [-1.0, -0.0]
# [-105.03409  -26.0998    73.45877   26.24521]
# [-1.0, -0.0]
# [-115.8612   -39.94424   73.45877   26.24521]
# [-1.0, -0.0]
# Episode finished after 4 timesteps
# Reward:  1.0
# [-102.29239   13.33804   75.95184   22.58554]
# [-1.0, -0.0]
# [-112.8588    -0.53882   75.95184   22.58554]
# [-1.0, -0.0]
# Episode finished after 2 timesteps
# Reward:  1.0
# [-110.77794   21.82032   73.51999   18.72528]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-74.43719 -93.1792   78.23724  18.99523]
# [0.15538564, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-100.77355    3.87011   64.68853   23.73796]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [ 45.87623 -61.33003  60.52671  24.71976]
# [0.35789543, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0
# [-114.8077    10.38782   74.61519   16.87501]
# [-1.0, -0.0]
# Episode finished after 1 timesteps
# Reward:  1.0

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
env.init_polytopes(1.0,[])
#orig_observation = env.reset()
for i_episode in range(10):
    observation = env.reset()
    #env.unwrapped.state=[4.545,13,10,5.5]
    #env.unwrapped.state = orig_observation
    observation = env.unwrapped.state
    total_reward=0
    for t in range(1000):
        print(observation)
        action, _states = model.predict(observation,deterministic=True)
        print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        #print[[action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)]]
        #x1_norm = observation[0]/np.sqrt(observation[0]**2+observation[1]**2)
        #x2_norm = observation[1]/np.sqrt(observation[0]**2+observation[1]**2)
        #f = 1.0 if (x2_norm) < 0 else -1.0
        #action = [f, f*(0-x1_norm)]
        observation, reward, done, info = env.step(action)
        total_reward=0.99*total_reward+reward
        env.render()
        time.sleep(0.5)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            time.sleep(5.0)
            break
env.close()

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
env.init_polytopes(0.0,retrain_polytopes_certain)
for i_episode in range(100000):
    observation = env.reset()
    observation = env.unwrapped.state
    total_reward=0
    for t in range(1000):
        print(observation)
        action, _states = model.predict(observation,deterministic=True)
        print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        observation, reward, done, info = env.step(action)
        assert reward >= 0, f"reward: {reward}"
        total_reward=0.99*total_reward+reward
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            break
env.close()

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
bounds = pc.box2poly([[-100.,100.],[-100.,400.],[49.9,50.1],[24.9,25.1]])
env.init_polytopes(0.0,[bounds])
for i_episode in range(100000):
    observation = env.reset()
    observation = env.unwrapped.state
    total_reward=0
    for t in range(1000):
        print(observation)
        action, _states = model.predict(observation,deterministic=True)
        print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        observation, reward, done, info = env.step(action)
        assert reward >= 0, f"reward: {reward}"
        total_reward=0.99*total_reward+reward
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            break
env.close()

# %%
x = [  3.55826, 253.8157,   24.94608,  50.0919 ]
print("certain")
for p in retrain_polytopes_certain:
    if x in p:
        print("found p")
print("uncertain")
for p in retrain_polytopes_uncertain:
    if x in p:
        print("found p")
