# %% [markdown]
# This time we will train with a modified reward scheme...

# %%
import gym
import time

# %%
import numpy as np

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import torch
from torch import nn

# %%
import zeppelin_gym.env4

# %%
torch.manual_seed(42)

# %%
env = gym.make('zeppelin-v4')

# %%
env.seed(42)

# %%
env.unwrapped.FUEL_RESTRAINT = False
env.unwrapped.OBSTACLE_REWARD = -1000.
env.unwrapped.NO_FUEL_REWARD = 0.1
# done reward = (FUEL_RESTRAINT) ? r+fuel*r : 2*r
env.unwrapped.DONE_REWARD = 0.5
env.unwrapped.TIME_STEP_REWARD = 0.
env.unwrapped.INCLUDE_UNWINNABLE = False

# %%
architecture = [dict(pi=[8,8], vf=[8,8])]
model = PPO("MlpPolicy", env, verbose=1,policy_kwargs={"activation_fn":nn.ReLU,"net_arch":architecture})
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /root/miniconda3/envs/snnt/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-275.89 +/- 447.09

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.2     |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    fps             | 1233     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.3       |
# |    ep_rew_mean          | -139       |
# | time/                   |            |
# |    fps                  | 895        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.20150107 |
# |    clip_fraction        | 0.331      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.0833     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.32e+04   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.0259     |
# |    std                  | 1          |
# |    value_loss           | 9.07e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 53.1      |
# |    ep_rew_mean          | -190      |
# | time/                   |           |
# |    fps                  | 822       |
# |    iterations           | 3         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0260117 |
# |    clip_fraction        | 0.249     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.26     |
# |    explained_variance   | 0.0936    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.41e+03  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.00539   |
# |    std                  | 1         |
# |    value_loss           | 1.52e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.4        |
# |    ep_rew_mean          | -270        |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.026060846 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0452      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.1e+03     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00495     |
# |    std                  | 1           |
# |    value_loss           | 2.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.8        |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017834483 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00149     |
# |    std                  | 1           |
# |    value_loss           | 2.79e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.4        |
# |    ep_rew_mean          | -310        |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007781866 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.48e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00303     |
# |    std                  | 1           |
# |    value_loss           | 3.73e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.3        |
# |    ep_rew_mean          | -240        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023314554 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.21e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00666     |
# |    std                  | 1           |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | -210        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019634482 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.01e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000273   |
# |    std                  | 1           |
# |    value_loss           | 1.68e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.1       |
# |    ep_rew_mean          | -210       |
# | time/                   |            |
# |    fps                  | 719        |
# |    iterations           | 9          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.05072629 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.393      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.03e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.00379    |
# |    std                  | 1          |
# |    value_loss           | 1.51e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.1        |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.076223746 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0189      |
# |    std                  | 1           |
# |    value_loss           | 1e+04       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.9        |
# |    ep_rew_mean          | -240        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017402112 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.54e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 1.61e-05    |
# |    std                  | 0.998       |
# |    value_loss           | 1.75e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.3        |
# |    ep_rew_mean          | -210        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017425895 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 250         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.000465    |
# |    std                  | 0.999       |
# |    value_loss           | 2.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.6        |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.024123553 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00983     |
# |    std                  | 0.999       |
# |    value_loss           | 1.51e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.5       |
# |    ep_rew_mean          | -270       |
# | time/                   |            |
# |    fps                  | 712        |
# |    iterations           | 14         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.04001894 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.373      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.6e+04    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.00682    |
# |    std                  | 0.998      |
# |    value_loss           | 2.04e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.5        |
# |    ep_rew_mean          | -270        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 15          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025901053 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.000728    |
# |    std                  | 0.997       |
# |    value_loss           | 3.32e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.4        |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 16          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018895019 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00337     |
# |    std                  | 1           |
# |    value_loss           | 1.92e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.1        |
# |    ep_rew_mean          | -210        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 17          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.028715614 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.014       |
# |    std                  | 1           |
# |    value_loss           | 2.25e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.2        |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 18          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.030641064 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.07e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00866     |
# |    std                  | 1.01        |
# |    value_loss           | 1.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.7        |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 19          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019878304 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00717     |
# |    std                  | 1.01        |
# |    value_loss           | 1.3e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.4        |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 20          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.110551864 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.4e+03     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0162      |
# |    std                  | 1.01        |
# |    value_loss           | 1.58e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.4        |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 21          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023874447 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.94e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00776     |
# |    std                  | 1.01        |
# |    value_loss           | 2.42e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 58.5      |
# |    ep_rew_mean          | -210      |
# | time/                   |           |
# |    fps                  | 705       |
# |    iterations           | 22        |
# |    time_elapsed         | 63        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 2.8283267 |
# |    clip_fraction        | 0.448     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.29     |
# |    explained_variance   | 0.516     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.24e+03  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | 0.0214    |
# |    std                  | 1.01      |
# |    value_loss           | 1.32e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.9        |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 23          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025325397 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 850         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00556     |
# |    std                  | 1.01        |
# |    value_loss           | 8.4e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.3       |
# |    ep_rew_mean          | -120       |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 24         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02455261 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.29      |
# |    explained_variance   | 0.327      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 457        |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0155     |
# |    std                  | 1.01       |
# |    value_loss           | 9.32e+03   |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 49.5     |
# |    ep_rew_mean          | -89.9    |
# | time/                   |          |
# |    fps                  | 705      |
# |    iterations           | 25       |
# |    time_elapsed         | 72       |
# |    total_timesteps      | 51200    |
# | train/                  |          |
# |    approx_kl            | 9.209768 |
# |    clip_fraction        | 0.399    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.29    |
# |    explained_variance   | 0.209    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 7.34e+03 |
# |    n_updates            | 240      |
# |    policy_gradient_loss | 0.0577   |
# |    std                  | 1.01     |
# |    value_loss           | 1.39e+04 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.8        |
# |    ep_rew_mean          | -99.8       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 26          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.030665103 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.0933      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 150         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0198      |
# |    std                  | 1.01        |
# |    value_loss           | 629         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58.2       |
# |    ep_rew_mean          | -89.8      |
# | time/                   |            |
# |    fps                  | 703        |
# |    iterations           | 27         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01333482 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.3       |
# |    explained_variance   | 0.0955     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.23e+03   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.00211    |
# |    std                  | 1.01       |
# |    value_loss           | 1.64e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58         |
# |    ep_rew_mean          | -89.9      |
# | time/                   |            |
# |    fps                  | 704        |
# |    iterations           | 28         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.11905284 |
# |    clip_fraction        | 0.328      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.3       |
# |    explained_variance   | 0.279      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22         |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.011      |
# |    std                  | 1.01       |
# |    value_loss           | 5.79e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56          |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 29          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.018081775 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 723         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0223      |
# |    std                  | 1.01        |
# |    value_loss           | 4.7e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.9       |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 705        |
# |    iterations           | 30         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.08549041 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.29      |
# |    explained_variance   | 0.0211     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.19e+03   |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0184     |
# |    std                  | 1.01       |
# |    value_loss           | 2.82e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.2       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 31         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.03099046 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.29      |
# |    explained_variance   | 0.456      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.1       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0281     |
# |    std                  | 1.01       |
# |    value_loss           | 216        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.9        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 32          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.035885245 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.0806      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 151         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00858     |
# |    std                  | 1.01        |
# |    value_loss           | 6.04e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 55.2      |
# |    ep_rew_mean          | -79.9     |
# | time/                   |           |
# |    fps                  | 705       |
# |    iterations           | 33        |
# |    time_elapsed         | 95        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.8976848 |
# |    clip_fraction        | 0.372     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.27     |
# |    explained_variance   | 0.364     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.57e+03  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | 0.0208    |
# |    std                  | 1         |
# |    value_loss           | 5.1e+03   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.2        |
# |    ep_rew_mean          | -69.8       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 34          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.024533836 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.0778      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 172         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00601     |
# |    std                  | 1           |
# |    value_loss           | 8.05e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.5       |
# |    ep_rew_mean          | -39.8      |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 35         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.07112419 |
# |    clip_fraction        | 0.304      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.102      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 92         |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0151     |
# |    std                  | 0.996      |
# |    value_loss           | 4.83e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50.4      |
# |    ep_rew_mean          | -29.8     |
# | time/                   |           |
# |    fps                  | 707       |
# |    iterations           | 36        |
# |    time_elapsed         | 104       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 1.6666617 |
# |    clip_fraction        | 0.408     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.27     |
# |    explained_variance   | 0.297     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 12.3      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 0.0244    |
# |    std                  | 1.01      |
# |    value_loss           | 95.7      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.6       |
# |    ep_rew_mean          | -9.85      |
# | time/                   |            |
# |    fps                  | 707        |
# |    iterations           | 37         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.08944853 |
# |    clip_fraction        | 0.473      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.31      |
# |    explained_variance   | -0.0325    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.4       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0562     |
# |    std                  | 1.03       |
# |    value_loss           | 1.97e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.6       |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 708        |
# |    iterations           | 38         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.06809587 |
# |    clip_fraction        | 0.29       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.34      |
# |    explained_variance   | 0.238      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.01       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.0207     |
# |    std                  | 1.03       |
# |    value_loss           | 17.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.4        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 39          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.046611287 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | -0.00643    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.739       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0155      |
# |    std                  | 1.03        |
# |    value_loss           | 2.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.5        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 40          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.039531387 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | -0.00178    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.38e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0158      |
# |    std                  | 1.04        |
# |    value_loss           | 3.83e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.2       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 710        |
# |    iterations           | 41         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02617808 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.38      |
# |    explained_variance   | -0.00353   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.71e+03   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00683    |
# |    std                  | 1.05       |
# |    value_loss           | 5.08e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.2        |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 42          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.059827525 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.00333     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.978       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0119      |
# |    std                  | 1.05        |
# |    value_loss           | 5.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.6        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 43          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.064483486 |
# |    clip_fraction        | 0.415       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.00634     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.76e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0169      |
# |    std                  | 1.06        |
# |    value_loss           | 2.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.1        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 44          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.027289163 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.327       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00563     |
# |    std                  | 1.06        |
# |    value_loss           | 1.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.3        |
# |    ep_rew_mean          | 0.109       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 45          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.029739559 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | -0.621      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0882      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00729     |
# |    std                  | 1.06        |
# |    value_loss           | 0.504       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.1        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 46          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018924315 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.186       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0159      |
# |    std                  | 1.04        |
# |    value_loss           | 0.577       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 47          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005999455 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.00158     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.12        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00214     |
# |    std                  | 1.04        |
# |    value_loss           | 5.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.9        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 48          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019845886 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | -0.00219    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.11e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00315     |
# |    std                  | 1.05        |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | -19.8        |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 49           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0119984755 |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | -0.714       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.19         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00717      |
# |    std                  | 1.05         |
# |    value_loss           | 0.63         |
# ------------------------------------------
# --- 143.97327733039856 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-15.84 +/- 125.50

# %%
model.save("zeppelin-v2.0.1-100000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.3     |
# |    ep_rew_mean     | -38.3    |
# | time/              |          |
# |    fps             | 1327     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.8        |
# |    ep_rew_mean          | -17.4       |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.032384537 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.00167     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00167     |
# |    std                  | 1.06        |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68          |
# |    ep_rew_mean          | -11         |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.038875088 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0683      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00772     |
# |    std                  | 1.05        |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55          |
# |    ep_rew_mean          | -9.85       |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018040245 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0799      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.008       |
# |    std                  | 1.06        |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.4        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 763         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.046101376 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | -0.000366   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.81e+03    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00522     |
# |    std                  | 1.07        |
# |    value_loss           | 2.99e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.5        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018146072 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | -0.000251   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00656     |
# |    std                  | 1.06        |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.2        |
# |    ep_rew_mean          | -9.83       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017077476 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | -0.0202     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.00869     |
# |    std                  | 1.05        |
# |    value_loss           | 0.276       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.9        |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.045556642 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | -0.155      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0825      |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.00936     |
# |    std                  | 1.06        |
# |    value_loss           | 0.202       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.8        |
# |    ep_rew_mean          | 0.199       |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 9           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.019839186 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.0891      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0764      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.00398     |
# |    std                  | 1.06        |
# |    value_loss           | 0.128       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.3        |
# |    ep_rew_mean          | -9.79       |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018697029 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | -0.0671     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.00721     |
# |    std                  | 1.06        |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.6        |
# |    ep_rew_mean          | -9.8        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.030311648 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.000452    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0562      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.000852    |
# |    std                  | 1.05        |
# |    value_loss           | 1.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015769947 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0368      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.00311     |
# |    std                  | 1.05        |
# |    value_loss           | 0.103       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012426216 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.00117     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0627      |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.0029      |
# |    std                  | 1.05        |
# |    value_loss           | 3.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.2        |
# |    ep_rew_mean          | -49.8       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017036341 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.000983    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00053     |
# |    std                  | 1.05        |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.9         |
# |    ep_rew_mean          | -49.8        |
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 15           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0098953415 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.4         |
# |    explained_variance   | 0.00248      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34         |
# |    n_updates            | 630          |
# |    policy_gradient_loss | 0.000182     |
# |    std                  | 1.05         |
# |    value_loss           | 6.12e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.9        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 16          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013218716 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.00915     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.566       |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00216     |
# |    std                  | 1.04        |
# |    value_loss           | 483         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55          |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 17          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018653436 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.397       |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.0116      |
# |    std                  | 1.04        |
# |    value_loss           | 0.661       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.4        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 18          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017958866 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.000378    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.78e+03    |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.0025      |
# |    std                  | 1.04        |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.3       |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 708        |
# |    iterations           | 19         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02258503 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.36      |
# |    explained_variance   | 0.00121    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0124     |
# |    n_updates            | 670        |
# |    policy_gradient_loss | 0.000504   |
# |    std                  | 1.03       |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.7        |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 20          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.030589439 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.0028      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.53e+03    |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00798     |
# |    std                  | 1.04        |
# |    value_loss           | 3.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.4        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 21          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.019153502 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | -0.264      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.167       |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.000223   |
# |    std                  | 1.03        |
# |    value_loss           | 0.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.2        |
# |    ep_rew_mean          | -9.85       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 22          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.022974081 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.000174    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0674      |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -5.62e-05   |
# |    std                  | 1.01        |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.8        |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 23          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.017729558 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | -0.197      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0495      |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.0017      |
# |    std                  | 1.02        |
# |    value_loss           | 0.0938      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.5        |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 24          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.026862253 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -0.112      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0345      |
# |    n_updates            | 720         |
# |    policy_gradient_loss | 0.00149     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0963      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.3        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 25          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.019017164 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0333      |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.000123   |
# |    std                  | 1.03        |
# |    value_loss           | 0.047       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.5        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 26          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014017306 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.00121     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0456      |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.00518     |
# |    std                  | 1.03        |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.8        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 27          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009047202 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.0134      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | 0.000797    |
# |    std                  | 1.03        |
# |    value_loss           | 7.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.4        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 28          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013249014 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | -0.347      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0876      |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.00405     |
# |    std                  | 1.03        |
# |    value_loss           | 4.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.2        |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 29          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.025580825 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -4.26       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0821      |
# |    n_updates            | 770         |
# |    policy_gradient_loss | 0.00348     |
# |    std                  | 1.02        |
# |    value_loss           | 2.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 30          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.023294616 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | -10.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.1         |
# |    n_updates            | 780         |
# |    policy_gradient_loss | 0.00422     |
# |    std                  | 1.01        |
# |    value_loss           | 0.304       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.9        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 31          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.026768059 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.866      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0441      |
# |    n_updates            | 790         |
# |    policy_gradient_loss | 0.00125     |
# |    std                  | 1.01        |
# |    value_loss           | 0.183       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.8        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 32          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.015073335 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.00283     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.86e+03    |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.000152    |
# |    std                  | 1.01        |
# |    value_loss           | 6.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.5        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 33          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.018297106 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.097       |
# |    n_updates            | 810         |
# |    policy_gradient_loss | 0.00475     |
# |    std                  | 0.999       |
# |    value_loss           | 0.277       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.6        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 34          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016926352 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.0214      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.67e+03    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.000196    |
# |    std                  | 0.992       |
# |    value_loss           | 4.65e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.7       |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 704        |
# |    iterations           | 35         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02752427 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.24      |
# |    explained_variance   | -0.656     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0984     |
# |    n_updates            | 830        |
# |    policy_gradient_loss | 0.0079     |
# |    std                  | 0.995      |
# |    value_loss           | 0.111      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.7         |
# |    ep_rew_mean          | -9.86        |
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 36           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0062902216 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.00152      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52e+03     |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00073     |
# |    std                  | 0.994        |
# |    value_loss           | 3.84e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.2        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 37          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.037597716 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.318       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00928     |
# |    std                  | 0.991       |
# |    value_loss           | 0.991       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.3        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 38          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004804043 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.00749     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.84        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.000257    |
# |    std                  | 0.991       |
# |    value_loss           | 5.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.4        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 39          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.042153977 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.566       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | 0.00345     |
# |    std                  | 0.992       |
# |    value_loss           | 2.94        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61.7       |
# |    ep_rew_mean          | -9.86      |
# | time/                   |            |
# |    fps                  | 707        |
# |    iterations           | 40         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03160408 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.23      |
# |    explained_variance   | 0.0236     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | 0.00435    |
# |    std                  | 0.993      |
# |    value_loss           | 3.08e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.8        |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 41          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.043926798 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -2.91       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.168       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.00396     |
# |    std                  | 1           |
# |    value_loss           | 0.805       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.6        |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 42          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.037271693 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -3.39       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0685      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00373     |
# |    std                  | 0.992       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47          |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 43          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020236908 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -0.245      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0362      |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.00265     |
# |    std                  | 0.999       |
# |    value_loss           | 0.117       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.5       |
# |    ep_rew_mean          | -49.8      |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 44         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00447944 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.00118    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.03e+03   |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.000651  |
# |    std                  | 0.999      |
# |    value_loss           | 1.14e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.9        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 45          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.027143665 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -4.88       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.439       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.000282    |
# |    std                  | 0.993       |
# |    value_loss           | 4.53        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.9         |
# |    ep_rew_mean          | -39.9        |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 46           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0066380054 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.0116       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.62         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.00185      |
# |    std                  | 0.996        |
# |    value_loss           | 6.7e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.3        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 47          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.048116136 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.43e+03    |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00166     |
# |    std                  | 0.997       |
# |    value_loss           | 5.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.9        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 48          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011498265 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.517       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.00186     |
# |    std                  | 0.996       |
# |    value_loss           | 1.92e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 63.5         |
# |    ep_rew_mean          | -29.8        |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 49           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0077854525 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.0383       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.44         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.000507    |
# |    std                  | 0.995        |
# |    value_loss           | 3.62e+03     |
# ------------------------------------------
# --- 142.9997124671936 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-13.83 +/- 117.51

# %%
model.save("zeppelin-v2.0.1-200000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -24.2    |
# | time/              |          |
# |    fps             | 1296     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.5        |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.033021796 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.0182      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0952      |
# |    n_updates            | 990         |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.994       |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.1       |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 863        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.03170832 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | -0.00591   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.306      |
# |    n_updates            | 1000       |
# |    policy_gradient_loss | 0.0035     |
# |    std                  | 0.983      |
# |    value_loss           | 1.64e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.058284856 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | -0.00167    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | 0.00424     |
# |    std                  | 0.972       |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.024758503 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.00635     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.308       |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | 0.00662     |
# |    std                  | 0.968       |
# |    value_loss           | 4.59e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.1       |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 788        |
# |    iterations           | 6          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.04597121 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | -7.85      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.06       |
# |    n_updates            | 1030       |
# |    policy_gradient_loss | 0.00915    |
# |    std                  | 0.961      |
# |    value_loss           | 0.458      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.8       |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 781        |
# |    iterations           | 7          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01945595 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | -0.00174   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0769     |
# |    n_updates            | 1040       |
# |    policy_gradient_loss | 0.00844    |
# |    std                  | 0.969      |
# |    value_loss           | 1.3e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.7       |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 776        |
# |    iterations           | 8          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.06988756 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | 0.000386   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.17       |
# |    n_updates            | 1050       |
# |    policy_gradient_loss | 0.000513   |
# |    std                  | 0.965      |
# |    value_loss           | 2.82e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.2       |
# |    ep_rew_mean          | -59.9      |
# | time/                   |            |
# |    fps                  | 771        |
# |    iterations           | 9          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.03088789 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.11      |
# |    explained_variance   | 0.00486    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0315     |
# |    n_updates            | 1060       |
# |    policy_gradient_loss | 0.000971   |
# |    std                  | 0.946      |
# |    value_loss           | 2.62e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.9        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007015067 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.00191     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.67e+03    |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.00333    |
# |    std                  | 0.947       |
# |    value_loss           | 8.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.2        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.025783114 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | 0.00197     |
# |    std                  | 0.944       |
# |    value_loss           | 4.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.1        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025315681 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.00297     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.435       |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | 0.0063      |
# |    std                  | 0.933       |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.9        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 13          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018835416 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.00656     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.478       |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | 0.00661     |
# |    std                  | 0.934       |
# |    value_loss           | 3.22e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.5       |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 752        |
# |    iterations           | 14         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.05622948 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.03      |
# |    explained_variance   | 0.0512     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.37       |
# |    n_updates            | 1110       |
# |    policy_gradient_loss | 0.00264    |
# |    std                  | 0.933      |
# |    value_loss           | 6.15e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.4        |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.042355724 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | -5.54       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.227       |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | 0.0025      |
# |    std                  | 0.916       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 16          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.056664683 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | -0.156      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -3.78e-05   |
# |    std                  | 0.908       |
# |    value_loss           | 1.72        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.9       |
# |    ep_rew_mean          | 0.145      |
# | time/                   |            |
# |    fps                  | 750        |
# |    iterations           | 17         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.03753627 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.95      |
# |    explained_variance   | 0.0021     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.137      |
# |    n_updates            | 1140       |
# |    policy_gradient_loss | 0.000372   |
# |    std                  | 0.904      |
# |    value_loss           | 0.447      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.1        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 18          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020890169 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | 0.026       |
# |    std                  | 0.906       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.9       |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 746        |
# |    iterations           | 19         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.05390292 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.95      |
# |    explained_variance   | 0.000825   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.9e+03    |
# |    n_updates            | 1160       |
# |    policy_gradient_loss | 0.00166    |
# |    std                  | 0.901      |
# |    value_loss           | 2.22e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.8        |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 20          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.027571574 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | -2.91       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0359      |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | 0.00553     |
# |    std                  | 0.906       |
# |    value_loss           | 0.0818      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.3        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 21          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015888091 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.00285     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | 0.000566    |
# |    std                  | 0.913       |
# |    value_loss           | 3.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59          |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 22          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019607585 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | -0.857      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.013       |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | 0.000104    |
# |    std                  | 0.903       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 64        |
# |    ep_rew_mean          | 0.172     |
# | time/                   |           |
# |    fps                  | 733       |
# |    iterations           | 23        |
# |    time_elapsed         | 64        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0191202 |
# |    clip_fraction        | 0.158     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.96     |
# |    explained_variance   | 0.123     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000865  |
# |    n_updates            | 1200      |
# |    policy_gradient_loss | 0.00134   |
# |    std                  | 0.91      |
# |    value_loss           | 0.183     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.1        |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 24          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019213028 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | -1.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00265    |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | 0.0041      |
# |    std                  | 0.907       |
# |    value_loss           | 0.157       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64          |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 25          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.030076444 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | -0.0813     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | 0.000657    |
# |    std                  | 0.913       |
# |    value_loss           | 0.0475      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58          |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 26          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.018409606 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | -1.48       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0345      |
# |    n_updates            | 1230        |
# |    policy_gradient_loss | 0.00175     |
# |    std                  | 0.909       |
# |    value_loss           | 0.0381      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.3        |
# |    ep_rew_mean          | 0.118       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 27          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.014608486 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | -0.788      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0151      |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.00192    |
# |    std                  | 0.902       |
# |    value_loss           | 0.0357      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.9        |
# |    ep_rew_mean          | 0.118       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 28          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.024755113 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | -0.195      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00792     |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | 0.00333     |
# |    std                  | 0.904       |
# |    value_loss           | 0.0441      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.9        |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 29          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.023558889 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | 0.000997    |
# |    std                  | 0.899       |
# |    value_loss           | 0.0193      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.6        |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 30          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.017275764 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | 0.00399     |
# |    std                  | 0.902       |
# |    value_loss           | 0.0192      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | 0.181       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 31          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.020172987 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | -0.227      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00357    |
# |    std                  | 0.895       |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 32          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.021676335 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | -0.0311     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00673     |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | 0.00301     |
# |    std                  | 0.889       |
# |    value_loss           | 0.0197      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.7        |
# |    ep_rew_mean          | 0.172       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 33          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.018150266 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0382      |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | 0.0055      |
# |    std                  | 0.899       |
# |    value_loss           | 0.0376      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.2        |
# |    ep_rew_mean          | -9.84       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 34          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015147338 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0056      |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.004      |
# |    std                  | 0.898       |
# |    value_loss           | 0.0189      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.4        |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 35          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.022294015 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.00108     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.37        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | 0.00157     |
# |    std                  | 0.898       |
# |    value_loss           | 2.97e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.4        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 36          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.020390049 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | -8.98       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0535      |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | 0.0079      |
# |    std                  | 0.898       |
# |    value_loss           | 5.54        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.1       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 733        |
# |    iterations           | 37         |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02220375 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.94      |
# |    explained_variance   | -0.000435  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0493     |
# |    n_updates            | 1340       |
# |    policy_gradient_loss | 0.000325   |
# |    std                  | 0.903      |
# |    value_loss           | 4.05e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.8        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 38          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017236464 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | -0.00675    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0376      |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.00158    |
# |    std                  | 0.904       |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 39          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.016169945 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 9.54e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0427      |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | 0.00282     |
# |    std                  | 0.905       |
# |    value_loss           | 2.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 40          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.050365034 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.000398    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00748     |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | 0.00413     |
# |    std                  | 0.914       |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.6        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 41          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.026431378 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.033       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00522     |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | 0.00745     |
# |    std                  | 0.918       |
# |    value_loss           | 0.0159      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.3        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 42          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006788514 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.00135     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+03    |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00101    |
# |    std                  | 0.918       |
# |    value_loss           | 9.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.8        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 43          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.019235931 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | -1.02       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.902       |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.00155    |
# |    std                  | 0.914       |
# |    value_loss           | 21.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.7        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 44          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.019527461 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | -0.00362    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+04    |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | 0.00131     |
# |    std                  | 0.906       |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.8        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 45          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.023539443 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.00751     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.203       |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00239    |
# |    std                  | 0.907       |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.9       |
# |    ep_rew_mean          | -39.8      |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 46         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.09950703 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.95      |
# |    explained_variance   | 0.00328    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0505     |
# |    n_updates            | 1430       |
# |    policy_gradient_loss | 0.00302    |
# |    std                  | 0.901      |
# |    value_loss           | 4.57e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.2       |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 47         |
# |    time_elapsed         | 133        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.03536568 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.93      |
# |    explained_variance   | -0.294     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.03       |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | 0.00431    |
# |    std                  | 0.892      |
# |    value_loss           | 0.152      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.1        |
# |    ep_rew_mean          | -9.84       |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 48          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.028451037 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | -0.272      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0243      |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.00221    |
# |    std                  | 0.871       |
# |    value_loss           | 0.0871      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53          |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 49          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.030537441 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.000685    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81e+03    |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.000141   |
# |    std                  | 0.86        |
# |    value_loss           | 920         |
# -----------------------------------------
# --- 140.61891317367554 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-33.85 +/- 181.26

# %%
model.save("zeppelin-v2.0.1-300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -23.1    |
# | time/              |          |
# |    fps             | 1309     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.5        |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.035688035 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 8.48e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0416      |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | 0.00396     |
# |    std                  | 0.873       |
# |    value_loss           | 488         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.1        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018840335 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | 0.000259    |
# |    std                  | 0.874       |
# |    value_loss           | 0.0173      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.7        |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 828         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006959241 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.000979    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.9        |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 0.875       |
# |    value_loss           | 5.08e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 59.4         |
# |    ep_rew_mean          | -39.8        |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0062127216 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.85        |
# |    explained_variance   | -0.000279    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 1510         |
# |    policy_gradient_loss | -0.00177     |
# |    std                  | 0.874        |
# |    value_loss           | 4.48e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.4        |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010565726 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52        |
# |    n_updates            | 1520        |
# |    policy_gradient_loss | -0.00254    |
# |    std                  | 0.867       |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009255218 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.0542      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+03    |
# |    n_updates            | 1530        |
# |    policy_gradient_loss | 0.00165     |
# |    std                  | 0.866       |
# |    value_loss           | 3.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.9        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 8           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.028344804 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | -0.0041     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0752      |
# |    n_updates            | 1540        |
# |    policy_gradient_loss | 0.00518     |
# |    std                  | 0.842       |
# |    value_loss           | 1.79e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58.4       |
# |    ep_rew_mean          | -39.8      |
# | time/                   |            |
# |    fps                  | 760        |
# |    iterations           | 9          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02310538 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.74      |
# |    explained_variance   | 0.0686     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17e+03   |
# |    n_updates            | 1550       |
# |    policy_gradient_loss | 0.00503    |
# |    std                  | 0.842      |
# |    value_loss           | 3.12e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.6        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 10          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015633216 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.0219      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.74        |
# |    n_updates            | 1560        |
# |    policy_gradient_loss | 0.00236     |
# |    std                  | 0.841       |
# |    value_loss           | 2.92e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.4       |
# |    ep_rew_mean          | -9.79      |
# | time/                   |            |
# |    fps                  | 750        |
# |    iterations           | 11         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.05076197 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | -2.7       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0896     |
# |    n_updates            | 1570       |
# |    policy_gradient_loss | 0.00348    |
# |    std                  | 0.829      |
# |    value_loss           | 0.748      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.3        |
# |    ep_rew_mean          | -9.82       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.037714988 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | -0.000453   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00974     |
# |    n_updates            | 1580        |
# |    policy_gradient_loss | 0.00612     |
# |    std                  | 0.824       |
# |    value_loss           | 2.81e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.2        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 13          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015121858 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0366      |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | 0.00599     |
# |    std                  | 0.817       |
# |    value_loss           | 0.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 14          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006252871 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.0011      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.5e+03     |
# |    n_updates            | 1600        |
# |    policy_gradient_loss | -0.00247    |
# |    std                  | 0.816       |
# |    value_loss           | 8.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.5        |
# |    ep_rew_mean          | -79.8       |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 15          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012710877 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0542      |
# |    n_updates            | 1610        |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 0.822       |
# |    value_loss           | 0.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.7        |
# |    ep_rew_mean          | -59.8       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 16          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.033277377 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.000435    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | 0.00634     |
# |    std                  | 0.822       |
# |    value_loss           | 7.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 17          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.031588756 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.00125     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 1630        |
# |    policy_gradient_loss | 0.00164     |
# |    std                  | 0.815       |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.4        |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 18          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.024760526 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | -9.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0239      |
# |    n_updates            | 1640        |
# |    policy_gradient_loss | 0.00409     |
# |    std                  | 0.805       |
# |    value_loss           | 0.378       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 19          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.029224448 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | -0.677      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0456      |
# |    n_updates            | 1650        |
# |    policy_gradient_loss | 0.00644     |
# |    std                  | 0.805       |
# |    value_loss           | 0.062       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.2         |
# |    ep_rew_mean          | -59.9        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 20           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0065866755 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.6         |
# |    explained_variance   | 0.000413     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 614          |
# |    n_updates            | 1660         |
# |    policy_gradient_loss | 0.000983     |
# |    std                  | 0.805        |
# |    value_loss           | 6.28e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.3         |
# |    ep_rew_mean          | -39.9        |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 21           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0004110827 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.6         |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+04     |
# |    n_updates            | 1670         |
# |    policy_gradient_loss | -0.000388    |
# |    std                  | 0.805        |
# |    value_loss           | 5.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 22          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019662961 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | -0.722      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54        |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | 0.000141    |
# |    std                  | 0.803       |
# |    value_loss           | 733         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.6        |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 23          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025281489 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | -0.0205     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.193       |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | 0.00302     |
# |    std                  | 0.79        |
# |    value_loss           | 1.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.1        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 24          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.054856323 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | -16         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0583      |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 0.784       |
# |    value_loss           | 1.87        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.1       |
# |    ep_rew_mean          | -9.85      |
# | time/                   |            |
# |    fps                  | 735        |
# |    iterations           | 25         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03422794 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.53      |
# |    explained_variance   | 0.0142     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0239     |
# |    n_updates            | 1710       |
# |    policy_gradient_loss | 0.00709    |
# |    std                  | 0.786      |
# |    value_loss           | 1.24e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 26          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.027206268 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | -35.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 1720        |
# |    policy_gradient_loss | 0.00263     |
# |    std                  | 0.771       |
# |    value_loss           | 1.93        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61.4         |
# |    ep_rew_mean          | -9.87        |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 27           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0069280057 |
# |    clip_fraction        | 0.0997       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.47        |
# |    explained_variance   | 4.17e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.87e+03     |
# |    n_updates            | 1730         |
# |    policy_gradient_loss | -0.00307     |
# |    std                  | 0.77         |
# |    value_loss           | 3.76e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.3        |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 28          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.047896273 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.565       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.996       |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | 0.00599     |
# |    std                  | 0.763       |
# |    value_loss           | 4.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.5        |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 29          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.056767393 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.445       |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | 0.00366     |
# |    std                  | 0.766       |
# |    value_loss           | 0.954       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.5        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 30          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.038000878 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | -0.454      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 1760        |
# |    policy_gradient_loss | 0.00234     |
# |    std                  | 0.756       |
# |    value_loss           | 0.376       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.8        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 31          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.072780356 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.0191      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66e+03    |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | 0.00436     |
# |    std                  | 0.754       |
# |    value_loss           | 5.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 32          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010505712 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.6        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.000679    |
# |    std                  | 0.754       |
# |    value_loss           | 82.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.7       |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 730        |
# |    iterations           | 33         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.07629831 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | -4.88      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.109      |
# |    n_updates            | 1790       |
# |    policy_gradient_loss | 0.00975    |
# |    std                  | 0.749      |
# |    value_loss           | 29.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.5        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 34          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007572121 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.6         |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00285    |
# |    std                  | 0.749       |
# |    value_loss           | 3.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.9        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 35          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010914454 |
# |    clip_fraction        | 0.0856      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.0643      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.65        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00434    |
# |    std                  | 0.749       |
# |    value_loss           | 2.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.2        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 36          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.024689808 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.11        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.00388     |
# |    std                  | 0.744       |
# |    value_loss           | 3.34e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 55.1      |
# |    ep_rew_mean          | -9.76     |
# | time/                   |           |
# |    fps                  | 730       |
# |    iterations           | 37        |
# |    time_elapsed         | 103       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 2.3767715 |
# |    clip_fraction        | 0.379     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.37     |
# |    explained_variance   | -5.48     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.61      |
# |    n_updates            | 1830      |
# |    policy_gradient_loss | 0.0267    |
# |    std                  | 0.741     |
# |    value_loss           | 11.2      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.2       |
# |    ep_rew_mean          | -29.8      |
# | time/                   |            |
# |    fps                  | 730        |
# |    iterations           | 38         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02866774 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | -0.0245    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.109      |
# |    n_updates            | 1840       |
# |    policy_gradient_loss | 0.00511    |
# |    std                  | 0.736      |
# |    value_loss           | 923        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.1        |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 39          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.041170195 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.00226     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81e+03    |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | 0.00593     |
# |    std                  | 0.74        |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 40          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.045957785 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | -0.000381   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0995      |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.00437     |
# |    std                  | 0.745       |
# |    value_loss           | 4.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53          |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 41          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028916493 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | -5.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0769      |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | 0.00623     |
# |    std                  | 0.743       |
# |    value_loss           | 0.406       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 42          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.020621259 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | -0.338      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0248      |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.00118     |
# |    std                  | 0.753       |
# |    value_loss           | 0.074       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.2        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 43          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.030453373 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.0183      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0154      |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | 0.00366     |
# |    std                  | 0.765       |
# |    value_loss           | 0.0855      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.9        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 44          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.027939672 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | -5.7e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.187       |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.00346     |
# |    std                  | 0.774       |
# |    value_loss           | 3.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 45          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.026601939 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0161     |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.00415     |
# |    std                  | 0.782       |
# |    value_loss           | 0.0682      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.2        |
# |    ep_rew_mean          | -9.83       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 46          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012183386 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | -0.000601   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0215      |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.00227     |
# |    std                  | 0.789       |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57          |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 47          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.025404971 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | -1.83       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0336      |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.000867    |
# |    std                  | 0.795       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.1       |
# |    ep_rew_mean          | -9.88      |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 48         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01035485 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.00155    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.47e+03   |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | -0.0021    |
# |    std                  | 0.795      |
# |    value_loss           | 3.98e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.5       |
# |    ep_rew_mean          | -9.87      |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 49         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.03592337 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | -1.79      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.052      |
# |    n_updates            | 1950       |
# |    policy_gradient_loss | -6.74e-05  |
# |    std                  | 0.785      |
# |    value_loss           | 0.522      |
# ----------------------------------------
# --- 139.4295961856842 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-11.82 +/- 108.91

# %%
model.save("zeppelin-v2.0.1-400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.7     |
# |    ep_rew_mean     | 0.177    |
# | time/              |          |
# |    fps             | 1292     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.6       |
# |    ep_rew_mean          | 0.194      |
# | time/                   |            |
# |    fps                  | 938        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.02184986 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | -1.4       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0174     |
# |    n_updates            | 1970       |
# |    policy_gradient_loss | -0.000274  |
# |    std                  | 0.777      |
# |    value_loss           | 0.14       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.8       |
# |    ep_rew_mean          | 0.163      |
# | time/                   |            |
# |    fps                  | 864        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01680554 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.574      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0338     |
# |    n_updates            | 1980       |
# |    policy_gradient_loss | 0.00212    |
# |    std                  | 0.784      |
# |    value_loss           | 0.0873     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.7        |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016935844 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | -3.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0469      |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | 0.00429     |
# |    std                  | 0.781       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.6        |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.021082941 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.0243      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.019       |
# |    n_updates            | 2000        |
# |    policy_gradient_loss | 0.00207     |
# |    std                  | 0.78        |
# |    value_loss           | 0.0577      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.6        |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.019721352 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | -0.374      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0335      |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | 0.00129     |
# |    std                  | 0.786       |
# |    value_loss           | 0.055       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57          |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019940738 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0241      |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | 0.00696     |
# |    std                  | 0.794       |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.1        |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.026172722 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 2030        |
# |    policy_gradient_loss | 0.00421     |
# |    std                  | 0.805       |
# |    value_loss           | 0.0416      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.2        |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026176965 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | -1.2        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0236      |
# |    n_updates            | 2040        |
# |    policy_gradient_loss | -0.00282    |
# |    std                  | 0.819       |
# |    value_loss           | 0.0203      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.3        |
# |    ep_rew_mean          | -9.87       |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024130745 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.000484    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.163       |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | 0.00622     |
# |    std                  | 0.818       |
# |    value_loss           | 2.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.9        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 765         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017464492 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | -7.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0142      |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | 0.00247     |
# |    std                  | 0.807       |
# |    value_loss           | 0.0849      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 62.7       |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 761        |
# |    iterations           | 12         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01448643 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.59      |
# |    explained_variance   | -0.000417  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.471      |
# |    n_updates            | 2070       |
# |    policy_gradient_loss | 0.000554   |
# |    std                  | 0.801      |
# |    value_loss           | 3.96e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.2        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 13          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018079894 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.00154     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.319       |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | 0.00132     |
# |    std                  | 0.804       |
# |    value_loss           | 3.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.6        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 14          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.030189324 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | -0.536      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0452      |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | 0.00215     |
# |    std                  | 0.807       |
# |    value_loss           | 0.259       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | 0.181       |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 15          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021867856 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 2100        |
# |    policy_gradient_loss | 0.0058      |
# |    std                  | 0.806       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.5        |
# |    ep_rew_mean          | -9.83       |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 16          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017509181 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | -0.265      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.034       |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | 0.00337     |
# |    std                  | 0.807       |
# |    value_loss           | 0.0868      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.8        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 17          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015806392 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.000259    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | -0.00175    |
# |    std                  | 0.817       |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.3        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 18          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017449427 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 3.34e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0701      |
# |    n_updates            | 2130        |
# |    policy_gradient_loss | -0.00141    |
# |    std                  | 0.829       |
# |    value_loss           | 2.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.5        |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 19          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024911022 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | -0.842      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0417      |
# |    n_updates            | 2140        |
# |    policy_gradient_loss | -0.000674   |
# |    std                  | 0.837       |
# |    value_loss           | 0.0668      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.6        |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 20          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015466342 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0182      |
# |    n_updates            | 2150        |
# |    policy_gradient_loss | 0.00411     |
# |    std                  | 0.849       |
# |    value_loss           | 0.0548      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.2        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 21          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.027179806 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | -0.0257     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0538      |
# |    n_updates            | 2160        |
# |    policy_gradient_loss | -0.0018     |
# |    std                  | 0.86        |
# |    value_loss           | 0.0556      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53          |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 22          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.025848933 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | -5.36e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0636      |
# |    n_updates            | 2170        |
# |    policy_gradient_loss | -0.00317    |
# |    std                  | 0.853       |
# |    value_loss           | 2.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.7        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 23          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.018231675 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.000337    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.069       |
# |    n_updates            | 2180        |
# |    policy_gradient_loss | -0.000137   |
# |    std                  | 0.848       |
# |    value_loss           | 1.94e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 62.3       |
# |    ep_rew_mean          | -29.8      |
# | time/                   |            |
# |    fps                  | 739        |
# |    iterations           | 24         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01610899 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.74      |
# |    explained_variance   | -0.19      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0783     |
# |    n_updates            | 2190       |
# |    policy_gradient_loss | -0.00335   |
# |    std                  | 0.838      |
# |    value_loss           | 0.0584     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 63           |
# |    ep_rew_mean          | -29.8        |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 25           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0099431835 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.73        |
# |    explained_variance   | 0.000722     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.74e+03     |
# |    n_updates            | 2200         |
# |    policy_gradient_loss | -0.00156     |
# |    std                  | 0.841        |
# |    value_loss           | 6.07e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.2        |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 26          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.042669997 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.00734     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 2210        |
# |    policy_gradient_loss | 0.0029      |
# |    std                  | 0.834       |
# |    value_loss           | 2.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.9        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 27          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.020636134 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.0011      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0407      |
# |    n_updates            | 2220        |
# |    policy_gradient_loss | -0.000151   |
# |    std                  | 0.822       |
# |    value_loss           | 1.94e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.4       |
# |    ep_rew_mean          | -29.8      |
# | time/                   |            |
# |    fps                  | 737        |
# |    iterations           | 28         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.02315981 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.65      |
# |    explained_variance   | -0.000244  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0365     |
# |    n_updates            | 2230       |
# |    policy_gradient_loss | -0.000379  |
# |    std                  | 0.816      |
# |    value_loss           | 919        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.7        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 29          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014588574 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.000923    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0718      |
# |    n_updates            | 2240        |
# |    policy_gradient_loss | 5.3e-05     |
# |    std                  | 0.825       |
# |    value_loss           | 4.13e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.3       |
# |    ep_rew_mean          | -29.8      |
# | time/                   |            |
# |    fps                  | 733        |
# |    iterations           | 30         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.01752964 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.66      |
# |    explained_variance   | -0.000227  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0694     |
# |    n_updates            | 2250       |
# |    policy_gradient_loss | 0.00394    |
# |    std                  | 0.821      |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.1        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 31          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013383386 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | -0.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0677      |
# |    n_updates            | 2260        |
# |    policy_gradient_loss | 0.00527     |
# |    std                  | 0.821       |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51          |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 32          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.020610873 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.000153    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.823       |
# |    value_loss           | 4.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.4        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 33          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.020722663 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | -1.17       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | 0.00537     |
# |    std                  | 0.819       |
# |    value_loss           | 0.648       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.3        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 34          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014394725 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.0687      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 0.82        |
# |    value_loss           | 0.295       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.9        |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 35          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.023670264 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.000996    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.97e+03    |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | 0.00182     |
# |    std                  | 0.822       |
# |    value_loss           | 9.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.3        |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 36          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.022945177 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | -0.00291    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.391       |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | 0.00149     |
# |    std                  | 0.822       |
# |    value_loss           | 1.64e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.3       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 728        |
# |    iterations           | 37         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01782582 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.65      |
# |    explained_variance   | 0.00841    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.186      |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | 0.00455    |
# |    std                  | 0.819      |
# |    value_loss           | 2.78e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.8        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 38          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.035978276 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.0111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.252       |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.000995   |
# |    std                  | 0.815       |
# |    value_loss           | 2.92e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.8       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 727        |
# |    iterations           | 39         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.02232879 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.62      |
# |    explained_variance   | 0.00119    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.45       |
# |    n_updates            | 2340       |
# |    policy_gradient_loss | 0.000564   |
# |    std                  | 0.81       |
# |    value_loss           | 6.17e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.8       |
# |    ep_rew_mean          | -39.9      |
# | time/                   |            |
# |    fps                  | 727        |
# |    iterations           | 40         |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03202215 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.61      |
# |    explained_variance   | 0.0488     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.285      |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | 0.00379    |
# |    std                  | 0.805      |
# |    value_loss           | 3.93e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.6        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 41          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014313661 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.0912      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.00148     |
# |    std                  | 0.804       |
# |    value_loss           | 2.82e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.2       |
# |    ep_rew_mean          | -19.8      |
# | time/                   |            |
# |    fps                  | 727        |
# |    iterations           | 42         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.03650412 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.6       |
# |    explained_variance   | -0.0327    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.15       |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | 0.00598    |
# |    std                  | 0.803      |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.4        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 43          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.030111577 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | -1.97       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0957      |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00201     |
# |    std                  | 0.806       |
# |    value_loss           | 0.243       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.3        |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 44          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.033501603 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.0664      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.076       |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | 0.00418     |
# |    std                  | 0.802       |
# |    value_loss           | 2.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -49.8       |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 45          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.026700879 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | 0.00507     |
# |    std                  | 0.8         |
# |    value_loss           | 2.52e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 56.4         |
# |    ep_rew_mean          | -39.8        |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 46           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0059007825 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.58        |
# |    explained_variance   | 0.0712       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | 0.00262      |
# |    std                  | 0.8          |
# |    value_loss           | 6.94e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54          |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 47          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005393018 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 0.8         |
# |    value_loss           | 86.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.9        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 48          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011945103 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00167    |
# |    std                  | 0.8         |
# |    value_loss           | 3.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.2        |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 49          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.020055056 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | -4.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.04        |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00379    |
# |    std                  | 0.8         |
# |    value_loss           | 20.1        |
# -----------------------------------------
# --- 139.13955640792847 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-21.83 +/- 146.71

# %%
model.save("zeppelin-v2.0.1-500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000,log_interval=10000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 699.8814315795898 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-5.84 +/- 77.24

# %%
model.save("zeppelin-v2.0.1-1000000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 765.484269618988 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-31.84 +/- 176.03

# %%
model.save("zeppelin-v2.0.1-1500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1407.379601240158 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.16 +/- 0.23

# %%
model.save("zeppelin-v2.0.1-2500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1395.537888765335 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.15 +/- 0.21

# %%
model.save("zeppelin-v2.0.1-3500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1449.7114081382751 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.14 +/- 0.18

# %%
model.save("zeppelin-v2.0.1-4500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1394.8880515098572 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.14 +/- 0.19

# %%
model.save("zeppelin-v2.0.1-5500000")

# %%
torch.manual_seed(43)
env.seed(43)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:0.15 +/- 0.21

# %% [markdown]
# Above ran while tab was closed...

# %%
model = PPO.load("zeppelin-v2.0.1-5500000")
model.set_env(env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-v2.0.1-400000")
model.set_env(env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=500)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-6500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1500000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1500000")
model.set_env(env)

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1600000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1700000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1800000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=1000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=4000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
print("hi")
for i_episode in range(5):
    observation = env.reset()
    env.unwrapped.state=[-5,110,50,22]
    total_reward=0
    for t in range(1000):
        action, _states = model.predict(observation)
        #x1_norm = observation[0]/np.sqrt(observation[0]**2+observation[1]**2)
        #x2_norm = observation[1]/np.sqrt(observation[0]**2+observation[1]**2)
        #f = 1.0 if (x2_norm) < 0 else -1.0
        #action = [f, f*(0-x1_norm)]
        observation, reward, done, info = env.step(action)
        print(observation)
        total_reward=0.99*total_reward+reward
        env.render()
        time.sleep(0.5)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            time.sleep(5.0)
            break
env.close()

# %%
env.close()

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("model_backup/zeppelin-avoidance-windsystem-small2-1400000-100000-0.5")
model.set_env(env)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-v2.0.1-5500000")
model.set_env(env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
#env.init_polytopes(0.0,retrain_polytopes_certain)
for i_episode in range(10):
    observation = env.reset()
    observation = env.unwrapped.state
    total_reward=0
    emergencies=0
    for t in range(1000):
        #print(observation)
        x1,x2,c,w,g1,g2 = observation
        #action = [0.,0.,1.0]
        action, _states = model.predict(observation,deterministic=True)
        if action[2] > env.unwrapped.EMERGENCY_THRESHOLD:
            emergencies+=1
        #print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        observation, reward, done, info = env.step(action)
        #assert reward >= 0, f"reward: {reward}"
        total_reward=0.99*total_reward+reward
        env.render()
        if done:
            print(observation)
            print("Episode finished after {} timesteps ({} emergencies)".format(t+1,emergencies))
            print("Reward: ", total_reward)
            break
env.close()
# Out:
# [ 121.88338 -407.22286   28.21523   26.55055 -392.41448  -25.24618]
# Episode finished after 36 timesteps (36 emergencies)
# Reward:  0.1
# [-264.03675 -411.00211   68.53316   11.19426 -229.29302  294.36004]
# Episode finished after 48 timesteps (48 emergencies)
# Reward:  0.1
# [ 296.92473 -107.91249   35.35513   13.7953   269.99002 -104.1941 ]
# Episode finished after 42 timesteps (42 emergencies)
# Reward:  1.0
# [-405.51078   28.04049   75.99033   15.41872  256.34823 -162.98145]
# Episode finished after 319 timesteps (319 emergencies)
# Reward:  0.1
# [ -84.75833 -414.53934   16.97939   26.99139 -121.11184  299.41366]
# Episode finished after 34 timesteps (34 emergencies)
# Reward:  0.1
# [-181.65822  -57.51006   76.04558   24.46936 -197.98345  -66.80005]
# Episode finished after 14 timesteps (14 emergencies)
# Reward:  1.0
# [  80.42177 -410.13229   10.04238   12.42808  335.87302  132.77637]
# Episode finished after 42 timesteps (42 emergencies)
# Reward:  0.1
# [-117.55035 -407.18127   77.80371   20.97781 -312.87933 -184.65925]
# Episode finished after 17 timesteps (17 emergencies)
# Reward:  0.1
# [-102.52076 -403.10764   18.57469   28.30042   14.97618 -350.63005]
# Episode finished after 32 timesteps (29 emergencies)
# Reward:  0.1
# [ -62.17795 -419.05858   12.16008   19.58169 -174.27878  347.61181]
# Episode finished after 29 timesteps (29 emergencies)
# Reward:  0.1
