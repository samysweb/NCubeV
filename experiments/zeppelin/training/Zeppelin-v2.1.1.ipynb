# %% [markdown]
# This time we will train with a modified reward scheme...

# %%
import gym
import time

# %%
import numpy as np

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import torch
from torch import nn

# %%
import zeppelin_gym.env5
# Out:
# `polytope` failed to import `cvxopt.glpk`.
# will use `scipy.optimize.linprog`

# %%
torch.manual_seed(42)

# %%
env = gym.make('zeppelin-v4')
# Out:
# /home/samuel/anaconda3/envs/nnv/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
env.seed(42)

# %%
env.unwrapped.FUEL_RESTRAINT = False
env.unwrapped.OBSTACLE_REWARD = -1000.
env.unwrapped.NO_FUEL_REWARD = -10
# done reward = (FUEL_RESTRAINT) ? r+fuel*r : 2*r
env.unwrapped.DONE_REWARD = 0.5
env.unwrapped.TIME_STEP_REWARD = 0.
env.unwrapped.INCLUDE_UNWINNABLE = False
env.unwrapped.EMERGENCY_REWARD = 0.05
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
architecture = [dict(pi=[8,8], vf=[8,8])]
model = PPO("MlpPolicy", env, verbose=1,policy_kwargs={"activation_fn":nn.ReLU,"net_arch":architecture})
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /home/samuel/anaconda3/envs/nnv/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-390.58 +/- 482.19

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.9     |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    fps             | 2884     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | -198        |
# | time/                   |             |
# |    fps                  | 2028        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.034599446 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.0615      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 1.01        |
# |    value_loss           | 4.9e+04     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.3       |
# |    ep_rew_mean          | -257       |
# | time/                   |            |
# |    fps                  | 1861       |
# |    iterations           | 3          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.38662165 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.3       |
# |    explained_variance   | -0.0184    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.61e+04   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.031      |
# |    std                  | 1.02       |
# |    value_loss           | 3.92e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.7        |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 1790        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016051535 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.0653      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.000169    |
# |    std                  | 1.02        |
# |    value_loss           | 5.46e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 9.11      |
# |    ep_rew_mean          | -227      |
# | time/                   |           |
# |    fps                  | 1739      |
# |    iterations           | 5         |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0516618 |
# |    clip_fraction        | 0.236     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.33     |
# |    explained_variance   | 0.175     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.95e+03  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | 0.00574   |
# |    std                  | 1.03      |
# |    value_loss           | 4.25e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.24        |
# |    ep_rew_mean          | -247        |
# | time/                   |             |
# |    fps                  | 1701        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.025689133 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.01e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00528     |
# |    std                  | 1.03        |
# |    value_loss           | 4.1e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | -198        |
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013432724 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 1.03        |
# |    value_loss           | 4.47e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.1        |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013736608 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00222     |
# |    std                  | 1.03        |
# |    value_loss           | 3.06e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.89        |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 1682        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.025594044 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.95e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00474     |
# |    std                  | 1.03        |
# |    value_loss           | 2.43e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.06       |
# |    ep_rew_mean          | -148       |
# | time/                   |            |
# |    fps                  | 1674       |
# |    iterations           | 10         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.03076195 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.35      |
# |    explained_variance   | 0.368      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.08e+04   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.00977    |
# |    std                  | 1.03       |
# |    value_loss           | 3.32e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.54        |
# |    ep_rew_mean          | -228        |
# | time/                   |             |
# |    fps                  | 1668        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021099571 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00555     |
# |    std                  | 1.03        |
# |    value_loss           | 3.13e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 1659        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018985612 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00132     |
# |    std                  | 1.04        |
# |    value_loss           | 3.47e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.37        |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 1661        |
# |    iterations           | 13          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.078710616 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.91e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.0136      |
# |    std                  | 1.04        |
# |    value_loss           | 1.65e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.39       |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 1662       |
# |    iterations           | 14         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01761424 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.39      |
# |    explained_variance   | 0.435      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.72e+04   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.00244    |
# |    std                  | 1.05       |
# |    value_loss           | 3.51e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.78        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1660        |
# |    iterations           | 15          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.030910913 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.86e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0104      |
# |    std                  | 1.05        |
# |    value_loss           | 2.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.45        |
# |    ep_rew_mean          | -59         |
# | time/                   |             |
# |    fps                  | 1660        |
# |    iterations           | 16          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.026837632 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00196     |
# |    std                  | 1.05        |
# |    value_loss           | 2.68e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.1       |
# |    ep_rew_mean          | -68.9      |
# | time/                   |            |
# |    fps                  | 1660       |
# |    iterations           | 17         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.11944471 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.41      |
# |    explained_variance   | 0.46       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.62e+03   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.00707    |
# |    std                  | 1.05       |
# |    value_loss           | 1.82e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.29        |
# |    ep_rew_mean          | -88.7       |
# | time/                   |             |
# |    fps                  | 1661        |
# |    iterations           | 18          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.036899887 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00468     |
# |    std                  | 1.06        |
# |    value_loss           | 2.21e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.19      |
# |    ep_rew_mean          | -39.4     |
# | time/                   |           |
# |    fps                  | 1662      |
# |    iterations           | 19        |
# |    time_elapsed         | 23        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.4034528 |
# |    clip_fraction        | 0.429     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.44     |
# |    explained_variance   | 0.165     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.23e+03  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 0.0253    |
# |    std                  | 1.06      |
# |    value_loss           | 1.49e+04  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.44       |
# |    ep_rew_mean          | -19.6      |
# | time/                   |            |
# |    fps                  | 1663       |
# |    iterations           | 20         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.18825616 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.45      |
# |    explained_variance   | -0.145     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 289        |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0449     |
# |    std                  | 1.07       |
# |    value_loss           | 7.36e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.48      |
# |    ep_rew_mean          | -68.8     |
# | time/                   |           |
# |    fps                  | 1664      |
# |    iterations           | 21        |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 2.5512576 |
# |    clip_fraction        | 0.487     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.48     |
# |    explained_variance   | -0.259    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 94.8      |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.0636    |
# |    std                  | 1.09      |
# |    value_loss           | 2.63e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.37       |
# |    ep_rew_mean          | -19.4      |
# | time/                   |            |
# |    fps                  | 1664       |
# |    iterations           | 22         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.13158318 |
# |    clip_fraction        | 0.303      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.51      |
# |    explained_variance   | 0.0677     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.8e+03    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0149     |
# |    std                  | 1.09       |
# |    value_loss           | 1.11e+04   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.58      |
# |    ep_rew_mean          | -29.3     |
# | time/                   |           |
# |    fps                  | 1664      |
# |    iterations           | 23        |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 1.3354263 |
# |    clip_fraction        | 0.442     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.52     |
# |    explained_variance   | 0.164     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 46.4      |
# |    n_updates            | 220       |
# |    policy_gradient_loss | 0.0439    |
# |    std                  | 1.09      |
# |    value_loss           | 3.99e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 6.99     |
# |    ep_rew_mean          | -49.1    |
# | time/                   |          |
# |    fps                  | 1665     |
# |    iterations           | 24       |
# |    time_elapsed         | 29       |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 1.637807 |
# |    clip_fraction        | 0.434    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.51    |
# |    explained_variance   | 0.036    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.16e+04 |
# |    n_updates            | 230      |
# |    policy_gradient_loss | 0.0509   |
# |    std                  | 1.09     |
# |    value_loss           | 1.04e+04 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.13       |
# |    ep_rew_mean          | -29.3      |
# | time/                   |            |
# |    fps                  | 1666       |
# |    iterations           | 25         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.89393914 |
# |    clip_fraction        | 0.433      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.5       |
# |    explained_variance   | 0.0163     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35         |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0484     |
# |    std                  | 1.09       |
# |    value_loss           | 7.6e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.64        |
# |    ep_rew_mean          | -39.1       |
# | time/                   |             |
# |    fps                  | 1667        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.060339283 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | -0.00357    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+04     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00985     |
# |    std                  | 1.09        |
# |    value_loss           | 1.09e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.97        |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1668        |
# |    iterations           | 27          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.036088437 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.00645     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 200         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0152      |
# |    std                  | 1.09        |
# |    value_loss           | 7.68e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.9        |
# |    ep_rew_mean          | -29.2      |
# | time/                   |            |
# |    fps                  | 1669       |
# |    iterations           | 28         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.12569553 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.52      |
# |    explained_variance   | 0.0015     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.3e+03    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.0129     |
# |    std                  | 1.1        |
# |    value_loss           | 5.24e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.72       |
# |    ep_rew_mean          | -29.5      |
# | time/                   |            |
# |    fps                  | 1669       |
# |    iterations           | 29         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.07522906 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | -0.00275   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31         |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0235     |
# |    std                  | 1.1        |
# |    value_loss           | 4.78e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.11        |
# |    ep_rew_mean          | -39.2       |
# | time/                   |             |
# |    fps                  | 1670        |
# |    iterations           | 30          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.036207072 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.00728     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.34        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0153      |
# |    std                  | 1.08        |
# |    value_loss           | 5.97e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.54       |
# |    ep_rew_mean          | -19.5      |
# | time/                   |            |
# |    fps                  | 1671       |
# |    iterations           | 31         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.12856592 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.47      |
# |    explained_variance   | 0.00525    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.84e+03   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0156     |
# |    std                  | 1.07       |
# |    value_loss           | 5.91e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.25        |
# |    ep_rew_mean          | -19.5       |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 32          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.056320805 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | -0.0119     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0242      |
# |    std                  | 1.08        |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.91        |
# |    ep_rew_mean          | -9.6        |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 33          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.023713602 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.000496    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.74e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00835     |
# |    std                  | 1.08        |
# |    value_loss           | 4.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.53        |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.033982877 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | -0.00738    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.46        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0203      |
# |    std                  | 1.07        |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.43        |
# |    ep_rew_mean          | -9.39       |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 35          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.020423777 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | -0.0091     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.71        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00607     |
# |    std                  | 1.06        |
# |    value_loss           | 3.75e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.31       |
# |    ep_rew_mean          | -39.3      |
# | time/                   |            |
# |    fps                  | 1672       |
# |    iterations           | 36         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.05619932 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | 9.26e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.59       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0125     |
# |    std                  | 1.06       |
# |    value_loss           | 5.51e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.66       |
# |    ep_rew_mean          | -19.5      |
# | time/                   |            |
# |    fps                  | 1672       |
# |    iterations           | 37         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02792713 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.42      |
# |    explained_variance   | -0.00438   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.72       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0086     |
# |    std                  | 1.05       |
# |    value_loss           | 6.52e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63        |
# |    ep_rew_mean          | -19.2       |
# | time/                   |             |
# |    fps                  | 1673        |
# |    iterations           | 38          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.035036758 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | -0.00555    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.28        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00518     |
# |    std                  | 1.05        |
# |    value_loss           | 9.26e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.53      |
# |    ep_rew_mean          | -29.5     |
# | time/                   |           |
# |    fps                  | 1673      |
# |    iterations           | 39        |
# |    time_elapsed         | 47        |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0406058 |
# |    clip_fraction        | 0.209     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.37     |
# |    explained_variance   | -0.00722  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.69      |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0.0077    |
# |    std                  | 1.03      |
# |    value_loss           | 2.92e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14        |
# |    ep_rew_mean          | -29.3       |
# | time/                   |             |
# |    fps                  | 1674        |
# |    iterations           | 40          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.016630953 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.00532     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.31e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00464     |
# |    std                  | 1.03        |
# |    value_loss           | 5.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.1         |
# |    ep_rew_mean          | -19.1       |
# | time/                   |             |
# |    fps                  | 1674        |
# |    iterations           | 41          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.018003076 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.00233     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0055      |
# |    std                  | 1.03        |
# |    value_loss           | 6.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.83        |
# |    ep_rew_mean          | -9.59       |
# | time/                   |             |
# |    fps                  | 1674        |
# |    iterations           | 42          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.029448323 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.0024      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.73e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0101      |
# |    std                  | 1.03        |
# |    value_loss           | 7.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.4         |
# |    ep_rew_mean          | -39         |
# | time/                   |             |
# |    fps                  | 1674        |
# |    iterations           | 43          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009517987 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.00695     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+04     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00374     |
# |    std                  | 1.03        |
# |    value_loss           | 7.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.58        |
# |    ep_rew_mean          | -39.1       |
# | time/                   |             |
# |    fps                  | 1675        |
# |    iterations           | 44          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.031007571 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.00482     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0114      |
# |    std                  | 1.03        |
# |    value_loss           | 4.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.59        |
# |    ep_rew_mean          | -29.3       |
# | time/                   |             |
# |    fps                  | 1675        |
# |    iterations           | 45          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.021592805 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -0.00408    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.93        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00198     |
# |    std                  | 1.02        |
# |    value_loss           | 7.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.05        |
# |    ep_rew_mean          | -59         |
# | time/                   |             |
# |    fps                  | 1675        |
# |    iterations           | 46          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.051495288 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.00368     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.07        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.012       |
# |    std                  | 1.02        |
# |    value_loss           | 9.05e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.57         |
# |    ep_rew_mean          | -59.1        |
# | time/                   |              |
# |    fps                  | 1675         |
# |    iterations           | 47           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0065123853 |
# |    clip_fraction        | 0.0972       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.3         |
# |    explained_variance   | 0.00791      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.01e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 1.01         |
# |    value_loss           | 9.16e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.85        |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1674        |
# |    iterations           | 48          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.044449974 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | -0.00728    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.69e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.014       |
# |    std                  | 1.01        |
# |    value_loss           | 7.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.05        |
# |    ep_rew_mean          | -39.1       |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 49          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.031543553 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.00376     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.5         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0116      |
# |    std                  | 0.995       |
# |    value_loss           | 5.38e+03    |
# -----------------------------------------
# --- 60.55402588844299 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-65.92 +/- 229.65

# %%
model.save("zeppelin-v2.1.1-100000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.75     |
# |    ep_rew_mean     | -49.1    |
# | time/              |          |
# |    fps             | 2880     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.1         |
# |    ep_rew_mean          | -9.6        |
# | time/                   |             |
# |    fps                  | 2132        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004453467 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.00563     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.35e+03    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.000615   |
# |    std                  | 0.999       |
# |    value_loss           | 1.17e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.9        |
# |    ep_rew_mean          | -19.4       |
# | time/                   |             |
# |    fps                  | 1943        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.035854757 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.00909     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.63        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00683     |
# |    std                  | 0.998       |
# |    value_loss           | 2.84e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.84       |
# |    ep_rew_mean          | -19.5      |
# | time/                   |            |
# |    fps                  | 1854       |
# |    iterations           | 4          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01956249 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.00962    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.26       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.00613    |
# |    std                  | 0.997      |
# |    value_loss           | 5.8e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.24        |
# |    ep_rew_mean          | -39.3       |
# | time/                   |             |
# |    fps                  | 1800        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.025980301 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.00201     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00564     |
# |    std                  | 0.987       |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.2       |
# |    ep_rew_mean          | -19.5      |
# | time/                   |            |
# |    fps                  | 1777       |
# |    iterations           | 6          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.06816533 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.00596    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.85       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.0122     |
# |    std                  | 0.987      |
# |    value_loss           | 5.97e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.5       |
# |    ep_rew_mean          | -29.5      |
# | time/                   |            |
# |    fps                  | 1755       |
# |    iterations           | 7          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.04989049 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.19      |
# |    explained_variance   | 0.00162    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.41       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.00179    |
# |    std                  | 0.973      |
# |    value_loss           | 7.66e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.1        |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 1748        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015427948 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.00601     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29e+04    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.000916    |
# |    std                  | 0.97        |
# |    value_loss           | 7.73e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.1         |
# |    ep_rew_mean          | -38.9        |
# | time/                   |              |
# |    fps                  | 1740         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0026960736 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | 0.0122       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+04     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00221     |
# |    std                  | 0.97         |
# |    value_loss           | 7.37e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | -39.1       |
# | time/                   |             |
# |    fps                  | 1731        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.055750452 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.0178      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+04    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.00467     |
# |    std                  | 0.972       |
# |    value_loss           | 7.83e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.31         |
# |    ep_rew_mean          | -29.5        |
# | time/                   |              |
# |    fps                  | 1728         |
# |    iterations           | 11           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0050209807 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0.0231       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 174          |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.971        |
# |    value_loss           | 1.54e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.1       |
# |    ep_rew_mean          | -19.3      |
# | time/                   |            |
# |    fps                  | 1720       |
# |    iterations           | 12         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.06246895 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.16      |
# |    explained_variance   | 0.000211   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.6e+03    |
# |    n_updates            | 600        |
# |    policy_gradient_loss | 0.00469    |
# |    std                  | 0.971      |
# |    value_loss           | 6.85e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | -39.1       |
# | time/                   |             |
# |    fps                  | 1718        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021604808 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.034       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.51e+03    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.000384   |
# |    std                  | 0.972       |
# |    value_loss           | 7.8e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 1710        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.039023794 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.015       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.19        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00829     |
# |    std                  | 0.973       |
# |    value_loss           | 7.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.8        |
# |    ep_rew_mean          | -49.2       |
# | time/                   |             |
# |    fps                  | 1705        |
# |    iterations           | 15          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.038298607 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.017       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.71e+03    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.00785     |
# |    std                  | 0.974       |
# |    value_loss           | 8.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.1        |
# |    ep_rew_mean          | -39         |
# | time/                   |             |
# |    fps                  | 1702        |
# |    iterations           | 16          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.058107287 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.0198      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.76        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00277     |
# |    std                  | 0.968       |
# |    value_loss           | 5.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 1701        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011247094 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.023       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.86e+03    |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.000845   |
# |    std                  | 0.963       |
# |    value_loss           | 8.45e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.5         |
# |    ep_rew_mean          | -39.3        |
# | time/                   |              |
# |    fps                  | 1700         |
# |    iterations           | 18           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0043656905 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 0.0415       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 137          |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 0.963        |
# |    value_loss           | 1e+04        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.55        |
# |    ep_rew_mean          | -49.1       |
# | time/                   |             |
# |    fps                  | 1698        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019298537 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.00114     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 670         |
# |    policy_gradient_loss | 0.00359     |
# |    std                  | 0.956       |
# |    value_loss           | 6.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.79        |
# |    ep_rew_mean          | -38.6       |
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.018223383 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.0294      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42e+04    |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00266     |
# |    std                  | 0.958       |
# |    value_loss           | 1.06e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012480242 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.0335      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 690         |
# |    policy_gradient_loss | 0.000448    |
# |    std                  | 0.96        |
# |    value_loss           | 9.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 1696        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010646716 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.0486      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.5e+03     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | 0.000419    |
# |    std                  | 0.963       |
# |    value_loss           | 6.24e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.76       |
# |    ep_rew_mean          | -19.3      |
# | time/                   |            |
# |    fps                  | 1695       |
# |    iterations           | 23         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.17450461 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.13      |
# |    explained_variance   | -0.00762   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.2       |
# |    n_updates            | 710        |
# |    policy_gradient_loss | 0.0161     |
# |    std                  | 0.954      |
# |    value_loss           | 2.74e+03   |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 9.85     |
# |    ep_rew_mean          | -19.3    |
# | time/                   |          |
# |    fps                  | 1694     |
# |    iterations           | 24       |
# |    time_elapsed         | 29       |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 0.611631 |
# |    clip_fraction        | 0.282    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.1     |
# |    explained_variance   | 0.0157   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 6.69     |
# |    n_updates            | 720      |
# |    policy_gradient_loss | 0.031    |
# |    std                  | 0.949    |
# |    value_loss           | 3.65e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.7        |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 1694        |
# |    iterations           | 25          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012828121 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.0243      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.24e+03    |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00214    |
# |    std                  | 0.951       |
# |    value_loss           | 8.13e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.44         |
# |    ep_rew_mean          | -68.9        |
# | time/                   |              |
# |    fps                  | 1693         |
# |    iterations           | 26           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0051869424 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.1         |
# |    explained_variance   | 0.0257       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.93e+03     |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00532     |
# |    std                  | 0.951        |
# |    value_loss           | 1.47e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.7       |
# |    ep_rew_mean          | -28.9      |
# | time/                   |            |
# |    fps                  | 1692       |
# |    iterations           | 27         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01721296 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.1       |
# |    explained_variance   | 0.0364     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.51e+03   |
# |    n_updates            | 750        |
# |    policy_gradient_loss | 0.000653   |
# |    std                  | 0.951      |
# |    value_loss           | 1.08e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -29.5       |
# | time/                   |             |
# |    fps                  | 1690        |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.033907592 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.0662      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.02e+03    |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.00117     |
# |    std                  | 0.948       |
# |    value_loss           | 7.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | -49.3       |
# | time/                   |             |
# |    fps                  | 1690        |
# |    iterations           | 29          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.056396786 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.0286      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.38e+03    |
# |    n_updates            | 770         |
# |    policy_gradient_loss | 0.00883     |
# |    std                  | 0.939       |
# |    value_loss           | 7.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 1689        |
# |    iterations           | 30          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.053473957 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.0403      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 780         |
# |    policy_gradient_loss | 0.00646     |
# |    std                  | 0.941       |
# |    value_loss           | 6.6e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.95        |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 31          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.006817272 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.0386      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.37e+03    |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.000533   |
# |    std                  | 0.942       |
# |    value_loss           | 1.04e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.2        |
# |    ep_rew_mean          | -9.51       |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 32          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006585236 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.063       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.7        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00232    |
# |    std                  | 0.945       |
# |    value_loss           | 1.28e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.1       |
# |    ep_rew_mean          | -49.1      |
# | time/                   |            |
# |    fps                  | 1685       |
# |    iterations           | 33         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.15830088 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.09      |
# |    explained_variance   | -9.7       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.5       |
# |    n_updates            | 810        |
# |    policy_gradient_loss | 0.00561    |
# |    std                  | 0.955      |
# |    value_loss           | 78.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.5        |
# |    ep_rew_mean          | -59.1       |
# | time/                   |             |
# |    fps                  | 1683        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.078264624 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.0402      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.00468     |
# |    std                  | 0.944       |
# |    value_loss           | 7.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | -49.3       |
# | time/                   |             |
# |    fps                  | 1683        |
# |    iterations           | 35          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.024325512 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.0231      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.54e+03    |
# |    n_updates            | 830         |
# |    policy_gradient_loss | 0.0035      |
# |    std                  | 0.944       |
# |    value_loss           | 1.19e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.23         |
# |    ep_rew_mean          | -29.3        |
# | time/                   |              |
# |    fps                  | 1679         |
# |    iterations           | 36           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0059641763 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.07        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.9e+03      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00297     |
# |    std                  | 0.943        |
# |    value_loss           | 1.17e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.4       |
# |    ep_rew_mean          | -39.4      |
# | time/                   |            |
# |    fps                  | 1678       |
# |    iterations           | 37         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.15526094 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.08      |
# |    explained_variance   | -0.157     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.8       |
# |    n_updates            | 850        |
# |    policy_gradient_loss | 0.0107     |
# |    std                  | 0.947      |
# |    value_loss           | 2.5e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.1        |
# |    ep_rew_mean          | -39         |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 38          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.030489605 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.0438      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.1        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.0055      |
# |    std                  | 0.941       |
# |    value_loss           | 6.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 39          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019111712 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.0536      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.77e+03    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | 0.000931    |
# |    std                  | 0.942       |
# |    value_loss           | 8.26e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.1       |
# |    ep_rew_mean          | -19.6      |
# | time/                   |            |
# |    fps                  | 1678       |
# |    iterations           | 40         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.22768158 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.07      |
# |    explained_variance   | 0.0125     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.3       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | 0.00195    |
# |    std                  | 0.943      |
# |    value_loss           | 6.91e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | -19.4       |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 41          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021139385 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.0699      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.8        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.0139      |
# |    std                  | 0.934       |
# |    value_loss           | 5.6e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | -29.3       |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 42          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.043512356 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | -0.00334    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.0026      |
# |    std                  | 0.933       |
# |    value_loss           | 2.77e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.5       |
# |    ep_rew_mean          | -19.6      |
# | time/                   |            |
# |    fps                  | 1677       |
# |    iterations           | 43         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.04184695 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.03      |
# |    explained_variance   | 0.0112     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.09       |
# |    n_updates            | 910        |
# |    policy_gradient_loss | 0.0108     |
# |    std                  | 0.924      |
# |    value_loss           | 4.37e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.8        |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 44          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.047119275 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.00728     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.8e+03     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.0191      |
# |    std                  | 0.93        |
# |    value_loss           | 3.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | -19.2       |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 45          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.045577854 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.0223      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.9e+03     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.0068      |
# |    std                  | 0.905       |
# |    value_loss           | 2.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.5        |
# |    ep_rew_mean          | -9.72       |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 46          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.034906786 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.0147      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.5e+03     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | 0.0102      |
# |    std                  | 0.891       |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.8        |
# |    ep_rew_mean          | -19.4       |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 47          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.032241166 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.913       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00869     |
# |    std                  | 0.871       |
# |    value_loss           | 3.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 48          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.027944991 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | -0.0103     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.00087     |
# |    std                  | 0.865       |
# |    value_loss           | 3.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.9        |
# |    ep_rew_mean          | -19.2       |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 49          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005260973 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.00675     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.54e+03    |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.00164     |
# |    std                  | 0.865       |
# |    value_loss           | 9.89e+03    |
# -----------------------------------------
# --- 60.355555057525635 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-64.91 +/- 227.75

# %%
model.save("zeppelin-v2.1.1-200000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.9     |
# |    ep_rew_mean     | -19.5    |
# | time/              |          |
# |    fps             | 3054     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.4        |
# |    ep_rew_mean          | -29.6       |
# | time/                   |             |
# |    fps                  | 2206        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.021357654 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.00761     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64e+03    |
# |    n_updates            | 990         |
# |    policy_gradient_loss | 0.00616     |
# |    std                  | 0.852       |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.8         |
# |    ep_rew_mean          | -29.4        |
# | time/                   |              |
# |    fps                  | 1990         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0029497403 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.77        |
# |    explained_variance   | 0.012        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.86e+03     |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | 0.000144     |
# |    std                  | 0.853        |
# |    value_loss           | 9.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 1870        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015726319 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.35e+03    |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.00164    |
# |    std                  | 0.843       |
# |    value_loss           | 3.68e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.8         |
# |    ep_rew_mean          | -78.7        |
# | time/                   |              |
# |    fps                  | 1825         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0072535966 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.73        |
# |    explained_variance   | -0.0136      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.000811    |
# |    std                  | 0.843        |
# |    value_loss           | 8.31e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.6         |
# |    ep_rew_mean          | -58.8        |
# | time/                   |              |
# |    fps                  | 1798         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0038743485 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.73        |
# |    explained_variance   | 0.0313       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.3         |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | 0.000333     |
# |    std                  | 0.843        |
# |    value_loss           | 1.42e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17           |
# |    ep_rew_mean          | -29.2        |
# | time/                   |              |
# |    fps                  | 1777         |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0018987925 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.73        |
# |    explained_variance   | 0.0798       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 332          |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.843        |
# |    value_loss           | 1.04e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.8        |
# |    ep_rew_mean          | -39.4       |
# | time/                   |             |
# |    fps                  | 1763        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009303492 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.3        |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.0022     |
# |    std                  | 0.841       |
# |    value_loss           | 4.51e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.2         |
# |    ep_rew_mean          | -29.3        |
# | time/                   |              |
# |    fps                  | 1752         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0081498455 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.73        |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.68e+03     |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.000646    |
# |    std                  | 0.841        |
# |    value_loss           | 8.31e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.2         |
# |    ep_rew_mean          | -29          |
# | time/                   |              |
# |    fps                  | 1745         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0050444524 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.72        |
# |    explained_variance   | 0.0961       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 250          |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.00335     |
# |    std                  | 0.84         |
# |    value_loss           | 8.93e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.6        |
# |    ep_rew_mean          | -29.1       |
# | time/                   |             |
# |    fps                  | 1740        |
# |    iterations           | 11          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009542095 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.15e+03    |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | 0.000145    |
# |    std                  | 0.837       |
# |    value_loss           | 5.51e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 19.6      |
# |    ep_rew_mean          | -39.1     |
# | time/                   |           |
# |    fps                  | 1734      |
# |    iterations           | 12        |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.6622846 |
# |    clip_fraction        | 0.161     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.71     |
# |    explained_variance   | -0.0659   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 22.6      |
# |    n_updates            | 1090      |
# |    policy_gradient_loss | 0.0224    |
# |    std                  | 0.834     |
# |    value_loss           | 1.43e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.7        |
# |    ep_rew_mean          | -29.1       |
# | time/                   |             |
# |    fps                  | 1728        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032601506 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.0548      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.44e+03    |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | 0.00608     |
# |    std                  | 0.833       |
# |    value_loss           | 2.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.8       |
# |    ep_rew_mean          | -49.2      |
# | time/                   |            |
# |    fps                  | 1724       |
# |    iterations           | 14         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.05507972 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.68      |
# |    explained_variance   | 0.0819     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.8       |
# |    n_updates            | 1110       |
# |    policy_gradient_loss | 0.00772    |
# |    std                  | 0.827      |
# |    value_loss           | 4.89e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.8        |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1721        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025483526 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.0528      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.14e+03    |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | 0.00924     |
# |    std                  | 0.831       |
# |    value_loss           | 7.89e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.9         |
# |    ep_rew_mean          | -68.5        |
# | time/                   |              |
# |    fps                  | 1718         |
# |    iterations           | 16           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0045963926 |
# |    clip_fraction        | 0.0857       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.68        |
# |    explained_variance   | 0.041        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 628          |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | 0.000195     |
# |    std                  | 0.83         |
# |    value_loss           | 6.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.6         |
# |    ep_rew_mean          | -39.3        |
# | time/                   |              |
# |    fps                  | 1716         |
# |    iterations           | 17           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0036013694 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.68        |
# |    explained_variance   | 0.154        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 254          |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.831        |
# |    value_loss           | 8.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.6        |
# |    ep_rew_mean          | -9.71       |
# | time/                   |             |
# |    fps                  | 1714        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008717312 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.0943      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 129         |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.00254    |
# |    std                  | 0.832       |
# |    value_loss           | 9.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.4        |
# |    ep_rew_mean          | -19.5       |
# | time/                   |             |
# |    fps                  | 1710        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.032801628 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | -1.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.7        |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | 0.00277     |
# |    std                  | 0.827       |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.7        |
# |    ep_rew_mean          | -9.51       |
# | time/                   |             |
# |    fps                  | 1706        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.057904378 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.0329      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | 0.00163     |
# |    std                  | 0.823       |
# |    value_loss           | 1.84e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 16        |
# |    ep_rew_mean          | -29.3     |
# | time/                   |           |
# |    fps                  | 1704      |
# |    iterations           | 21        |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0738802 |
# |    clip_fraction        | 0.187     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.64     |
# |    explained_variance   | -1.66     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.14      |
# |    n_updates            | 1180      |
# |    policy_gradient_loss | 0.0048    |
# |    std                  | 0.813     |
# |    value_loss           | 14.4      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.8        |
# |    ep_rew_mean          | -39.4       |
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.100608915 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.0559      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.94e+03    |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | 0.022       |
# |    std                  | 0.82        |
# |    value_loss           | 3.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | -19.4       |
# | time/                   |             |
# |    fps                  | 1701        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.027442116 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.0473      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2         |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | 0.0071      |
# |    std                  | 0.821       |
# |    value_loss           | 3.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.9        |
# |    ep_rew_mean          | -9.18       |
# | time/                   |             |
# |    fps                  | 1698        |
# |    iterations           | 24          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.060017597 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.0331      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.21        |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | 0.00531     |
# |    std                  | 0.826       |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.3       |
# |    ep_rew_mean          | -29.1      |
# | time/                   |            |
# |    fps                  | 1696       |
# |    iterations           | 25         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.07418722 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.64      |
# |    explained_variance   | -0.732     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.49       |
# |    n_updates            | 1220       |
# |    policy_gradient_loss | 0.0103     |
# |    std                  | 0.813      |
# |    value_loss           | 6.66       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | -29.5       |
# | time/                   |             |
# |    fps                  | 1695        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.052219514 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.0241      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.24        |
# |    n_updates            | 1230        |
# |    policy_gradient_loss | 0.0133      |
# |    std                  | 0.812       |
# |    value_loss           | 4.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -39         |
# | time/                   |             |
# |    fps                  | 1694        |
# |    iterations           | 27          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.041434657 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.016       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | 0.00358     |
# |    std                  | 0.801       |
# |    value_loss           | 2.76e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -39.1       |
# | time/                   |             |
# |    fps                  | 1694        |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017802414 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.02        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31e+03    |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | 0.00235     |
# |    std                  | 0.797       |
# |    value_loss           | 6.5e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.1         |
# |    ep_rew_mean          | -49.1        |
# | time/                   |              |
# |    fps                  | 1693         |
# |    iterations           | 29           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0048550908 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.56        |
# |    explained_variance   | 0.0596       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.37e+03     |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.000718    |
# |    std                  | 0.797        |
# |    value_loss           | 5e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.6         |
# |    ep_rew_mean          | -49          |
# | time/                   |              |
# |    fps                  | 1693         |
# |    iterations           | 30           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0026253941 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.56        |
# |    explained_variance   | 0.0664       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.27e+03     |
# |    n_updates            | 1270         |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 0.797        |
# |    value_loss           | 8.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.2         |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 1693         |
# |    iterations           | 31           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0025145132 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.56        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16e+04     |
# |    n_updates            | 1280         |
# |    policy_gradient_loss | -0.000598    |
# |    std                  | 0.798        |
# |    value_loss           | 9.36e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.8       |
# |    ep_rew_mean          | -19.5      |
# | time/                   |            |
# |    fps                  | 1692       |
# |    iterations           | 32         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01029837 |
# |    clip_fraction        | 0.0543     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | -0.0554    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.8       |
# |    n_updates            | 1290       |
# |    policy_gradient_loss | -0.0016    |
# |    std                  | 0.796      |
# |    value_loss           | 2.48e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 1693        |
# |    iterations           | 33          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016608628 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.00283     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | -0.00187    |
# |    std                  | 0.784       |
# |    value_loss           | 2.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.6        |
# |    ep_rew_mean          | -9.71       |
# | time/                   |             |
# |    fps                  | 1693        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010500537 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.0893      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.36e+03    |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | 0.000464    |
# |    std                  | 0.784       |
# |    value_loss           | 7.33e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.6       |
# |    ep_rew_mean          | -9.52      |
# | time/                   |            |
# |    fps                  | 1692       |
# |    iterations           | 35         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.20852175 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | -5.6       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.47       |
# |    n_updates            | 1320       |
# |    policy_gradient_loss | 0.01       |
# |    std                  | 0.781      |
# |    value_loss           | 35.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28         |
# |    ep_rew_mean          | -29.3      |
# | time/                   |            |
# |    fps                  | 1692       |
# |    iterations           | 36         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.23927249 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | -4.4       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.72       |
# |    n_updates            | 1330       |
# |    policy_gradient_loss | 0.0119     |
# |    std                  | 0.772      |
# |    value_loss           | 9.86       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24        |
# |    ep_rew_mean          | -29.2     |
# | time/                   |           |
# |    fps                  | 1692      |
# |    iterations           | 37        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.2613572 |
# |    clip_fraction        | 0.124     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.45     |
# |    explained_variance   | 0.0175    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.92      |
# |    n_updates            | 1340      |
# |    policy_gradient_loss | 0.00277   |
# |    std                  | 0.771     |
# |    value_loss           | 2.82e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.3       |
# |    ep_rew_mean          | -29.2      |
# | time/                   |            |
# |    fps                  | 1691       |
# |    iterations           | 38         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02392181 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.00498    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.6       |
# |    n_updates            | 1350       |
# |    policy_gradient_loss | 0.00409    |
# |    std                  | 0.771      |
# |    value_loss           | 5.73e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.3       |
# |    ep_rew_mean          | -39.2      |
# | time/                   |            |
# |    fps                  | 1691       |
# |    iterations           | 39         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.04748305 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.45      |
# |    explained_variance   | 0.0389     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12       |
# |    n_updates            | 1360       |
# |    policy_gradient_loss | 0.00477    |
# |    std                  | 0.767      |
# |    value_loss           | 1.34e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.6       |
# |    ep_rew_mean          | -49.2      |
# | time/                   |            |
# |    fps                  | 1691       |
# |    iterations           | 40         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.26756802 |
# |    clip_fraction        | 0.078      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.42      |
# |    explained_variance   | 0.0531     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.91       |
# |    n_updates            | 1370       |
# |    policy_gradient_loss | -0.00154   |
# |    std                  | 0.759      |
# |    value_loss           | 1.72e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | -9.41       |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 41          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.002306465 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.4        |
# |    explained_variance   | 0.0154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.000485   |
# |    std                  | 0.758       |
# |    value_loss           | 5.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17          |
# |    ep_rew_mean          | -49.2       |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 42          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.036758836 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.0473      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.92        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | 0.000538    |
# |    std                  | 0.765       |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.9        |
# |    ep_rew_mean          | -19.5       |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 43          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.053636782 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.0494      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.89e+03    |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | 0.00183     |
# |    std                  | 0.765       |
# |    value_loss           | 5.94e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.5       |
# |    ep_rew_mean          | -39.4      |
# | time/                   |            |
# |    fps                  | 1691       |
# |    iterations           | 44         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.10085887 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.41      |
# |    explained_variance   | 0.017      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.24       |
# |    n_updates            | 1410       |
# |    policy_gradient_loss | -0.000606  |
# |    std                  | 0.758      |
# |    value_loss           | 2.55e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.8       |
# |    ep_rew_mean          | -59.3      |
# | time/                   |            |
# |    fps                  | 1690       |
# |    iterations           | 45         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.22701368 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.36      |
# |    explained_variance   | 0.0263     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.16       |
# |    n_updates            | 1420       |
# |    policy_gradient_loss | 0.0146     |
# |    std                  | 0.744      |
# |    value_loss           | 4.24e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.5       |
# |    ep_rew_mean          | -29.5      |
# | time/                   |            |
# |    fps                  | 1690       |
# |    iterations           | 46         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.09828792 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.33      |
# |    explained_variance   | 0.0692     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.02e+03   |
# |    n_updates            | 1430       |
# |    policy_gradient_loss | 0.00876    |
# |    std                  | 0.744      |
# |    value_loss           | 6.05e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38         |
# |    ep_rew_mean          | -9.62      |
# | time/                   |            |
# |    fps                  | 1690       |
# |    iterations           | 47         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.06656622 |
# |    clip_fraction        | 0.0974     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.32      |
# |    explained_variance   | -8.29      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.08       |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | 0.0237     |
# |    std                  | 0.738      |
# |    value_loss           | 16.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 32.4       |
# |    ep_rew_mean          | -48.9      |
# | time/                   |            |
# |    fps                  | 1689       |
# |    iterations           | 48         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.14079814 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.28      |
# |    explained_variance   | -3.19      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.13       |
# |    n_updates            | 1450       |
# |    policy_gradient_loss | -0.00478   |
# |    std                  | 0.725      |
# |    value_loss           | 6.32       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.6         |
# |    ep_rew_mean          | -48.9        |
# | time/                   |              |
# |    fps                  | 1688         |
# |    iterations           | 49           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0041772267 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.26        |
# |    explained_variance   | 0.0143       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.27e+03     |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.000501    |
# |    std                  | 0.728        |
# |    value_loss           | 9.96e+03     |
# ------------------------------------------
# --- 59.99892854690552 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-84.72 +/- 262.50

# %%
model.save("zeppelin-v2.1.1-300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.4     |
# |    ep_rew_mean     | -56.7    |
# | time/              |          |
# |    fps             | 2956     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.8        |
# |    ep_rew_mean          | -29.5       |
# | time/                   |             |
# |    fps                  | 2066        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004092701 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.0658      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+04    |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | 0.000175    |
# |    std                  | 0.727       |
# |    value_loss           | 8.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.7        |
# |    ep_rew_mean          | -9.83       |
# | time/                   |             |
# |    fps                  | 1915        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.107190646 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.045       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45        |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | 0.00188     |
# |    std                  | 0.728       |
# |    value_loss           | 2.72e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 20        |
# |    ep_rew_mean          | -29.2     |
# | time/                   |           |
# |    fps                  | 1835      |
# |    iterations           | 4         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.2018509 |
# |    clip_fraction        | 0.0977    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.28     |
# |    explained_variance   | -2.14     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.41      |
# |    n_updates            | 1500      |
# |    policy_gradient_loss | 0.0029    |
# |    std                  | 0.735     |
# |    value_loss           | 7.27      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 22.5     |
# |    ep_rew_mean          | -29.3    |
# | time/                   |          |
# |    fps                  | 1786     |
# |    iterations           | 5        |
# |    time_elapsed         | 5        |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 0.046907 |
# |    clip_fraction        | 0.131    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.3     |
# |    explained_variance   | 0.0579   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 18.7     |
# |    n_updates            | 1510     |
# |    policy_gradient_loss | 0.00438  |
# |    std                  | 0.734    |
# |    value_loss           | 2.38e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 1759        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.057371758 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.0784      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86e+03    |
# |    n_updates            | 1520        |
# |    policy_gradient_loss | 0.00738     |
# |    std                  | 0.732       |
# |    value_loss           | 3.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.2        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 1750        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018545322 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.0561      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+04    |
# |    n_updates            | 1530        |
# |    policy_gradient_loss | -0.000728   |
# |    std                  | 0.735       |
# |    value_loss           | 9.12e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.1       |
# |    ep_rew_mean          | -68.5      |
# | time/                   |            |
# |    fps                  | 1743       |
# |    iterations           | 8          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.04021117 |
# |    clip_fraction        | 0.0607     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.00122    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.411      |
# |    n_updates            | 1540       |
# |    policy_gradient_loss | 0.00302    |
# |    std                  | 0.735      |
# |    value_loss           | 2.97e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.8         |
# |    ep_rew_mean          | -68.9        |
# | time/                   |              |
# |    fps                  | 1737         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0065205204 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.023        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 1550         |
# |    policy_gradient_loss | -9.21e-05    |
# |    std                  | 0.734        |
# |    value_loss           | 5.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.4         |
# |    ep_rew_mean          | -69          |
# | time/                   |              |
# |    fps                  | 1730         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0040787933 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08         |
# |    n_updates            | 1560         |
# |    policy_gradient_loss | 0.00135      |
# |    std                  | 0.732        |
# |    value_loss           | 4.64e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.4        |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 1726        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.074295044 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.34        |
# |    n_updates            | 1570        |
# |    policy_gradient_loss | 0.00427     |
# |    std                  | 0.722       |
# |    value_loss           | 2.02e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 48        |
# |    ep_rew_mean          | -59.1     |
# | time/                   |           |
# |    fps                  | 1721      |
# |    iterations           | 12        |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.3373454 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.22     |
# |    explained_variance   | 0.00195   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.27      |
# |    n_updates            | 1580      |
# |    policy_gradient_loss | 0.00496   |
# |    std                  | 0.709     |
# |    value_loss           | 4.73e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.1        |
# |    ep_rew_mean          | -88.9       |
# | time/                   |             |
# |    fps                  | 1709        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.056934543 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | 0.00373     |
# |    std                  | 0.711       |
# |    value_loss           | 2.91e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67.8       |
# |    ep_rew_mean          | -129       |
# | time/                   |            |
# |    fps                  | 1707       |
# |    iterations           | 14         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.16200617 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.0733     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.29e+03   |
# |    n_updates            | 1600       |
# |    policy_gradient_loss | 0.0424     |
# |    std                  | 0.711      |
# |    value_loss           | 9.28e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | -198       |
# | time/                   |            |
# |    fps                  | 1702       |
# |    iterations           | 15         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00816427 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.12       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.14e+03   |
# |    n_updates            | 1610       |
# |    policy_gradient_loss | 0.00918    |
# |    std                  | 0.711      |
# |    value_loss           | 1.15e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.4        |
# |    ep_rew_mean          | -98.8       |
# | time/                   |             |
# |    fps                  | 1700        |
# |    iterations           | 16          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.001307579 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+04    |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | -0.00302    |
# |    std                  | 0.711       |
# |    value_loss           | 1.33e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.2         |
# |    ep_rew_mean          | -68.8        |
# | time/                   |              |
# |    fps                  | 1696         |
# |    iterations           | 17           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0041234177 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | -0.646       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.05e+03     |
# |    n_updates            | 1630         |
# |    policy_gradient_loss | -0.00426     |
# |    std                  | 0.711        |
# |    value_loss           | 1.71e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.1       |
# |    ep_rew_mean          | -98.5      |
# | time/                   |            |
# |    fps                  | 1694       |
# |    iterations           | 18         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01606258 |
# |    clip_fraction        | 0.025      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.412      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 310        |
# |    n_updates            | 1640       |
# |    policy_gradient_loss | 0.00405    |
# |    std                  | 0.71       |
# |    value_loss           | 3.23e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 57.6         |
# |    ep_rew_mean          | -98.5        |
# | time/                   |              |
# |    fps                  | 1694         |
# |    iterations           | 19           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0018233866 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 701          |
# |    n_updates            | 1650         |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.71         |
# |    value_loss           | 7.44e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.1       |
# |    ep_rew_mean          | -98.5      |
# | time/                   |            |
# |    fps                  | 1694       |
# |    iterations           | 20         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.13997334 |
# |    clip_fraction        | 0.0708     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.445      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 625        |
# |    n_updates            | 1660       |
# |    policy_gradient_loss | 0.0189     |
# |    std                  | 0.709      |
# |    value_loss           | 1.72e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.2        |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 1693        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005501817 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.61e+03    |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | 0.00366     |
# |    std                  | 0.712       |
# |    value_loss           | 8.97e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.8        |
# |    ep_rew_mean          | -148        |
# | time/                   |             |
# |    fps                  | 1692        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.038959857 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.35e+03    |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | 0.00748     |
# |    std                  | 0.712       |
# |    value_loss           | 5.94e+03    |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 52.5     |
# |    ep_rew_mean          | -148     |
# | time/                   |          |
# |    fps                  | 1692     |
# |    iterations           | 23       |
# |    time_elapsed         | 27       |
# |    total_timesteps      | 47104    |
# | train/                  |          |
# |    approx_kl            | 0.523423 |
# |    clip_fraction        | 0.311    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.2     |
# |    explained_variance   | 0.349    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.98e+03 |
# |    n_updates            | 1690     |
# |    policy_gradient_loss | 0.0788   |
# |    std                  | 0.712    |
# |    value_loss           | 5.67e+03 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.6       |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 1691       |
# |    iterations           | 24         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.35543647 |
# |    clip_fraction        | 0.0956     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.52       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 585        |
# |    n_updates            | 1700       |
# |    policy_gradient_loss | 0.0138     |
# |    std                  | 0.715      |
# |    value_loss           | 3.02e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.7        |
# |    ep_rew_mean          | -78.8       |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 25          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014088229 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.48e+03    |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | 0.000225    |
# |    std                  | 0.715       |
# |    value_loss           | 1.02e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.017143779 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.01e+03    |
# |    n_updates            | 1720        |
# |    policy_gradient_loss | 0.00266     |
# |    std                  | 0.714       |
# |    value_loss           | 6.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.9        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1690        |
# |    iterations           | 27          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.059233505 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+03    |
# |    n_updates            | 1730        |
# |    policy_gradient_loss | 0.00287     |
# |    std                  | 0.715       |
# |    value_loss           | 3.68e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.3       |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 1690       |
# |    iterations           | 28         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.16815403 |
# |    clip_fraction        | 0.0851     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03       |
# |    n_updates            | 1740       |
# |    policy_gradient_loss | 0.0153     |
# |    std                  | 0.722      |
# |    value_loss           | 794        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.1       |
# |    ep_rew_mean          | -98.5      |
# | time/                   |            |
# |    fps                  | 1689       |
# |    iterations           | 29         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.18833788 |
# |    clip_fraction        | 0.0647     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.59e+03   |
# |    n_updates            | 1750       |
# |    policy_gradient_loss | 0.00977    |
# |    std                  | 0.724      |
# |    value_loss           | 5.7e+03    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 43.3      |
# |    ep_rew_mean          | -88.5     |
# | time/                   |           |
# |    fps                  | 1689      |
# |    iterations           | 30        |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.6875418 |
# |    clip_fraction        | 0.103     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24     |
# |    explained_variance   | 0.573     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 145       |
# |    n_updates            | 1760      |
# |    policy_gradient_loss | 0.0365    |
# |    std                  | 0.723     |
# |    value_loss           | 1.16e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.4       |
# |    ep_rew_mean          | -68.5      |
# | time/                   |            |
# |    fps                  | 1688       |
# |    iterations           | 31         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.13965568 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.295      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.78       |
# |    n_updates            | 1770       |
# |    policy_gradient_loss | 0.0101     |
# |    std                  | 0.722      |
# |    value_loss           | 5.44e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 49.6      |
# |    ep_rew_mean          | -108      |
# | time/                   |           |
# |    fps                  | 1688      |
# |    iterations           | 32        |
# |    time_elapsed         | 38        |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.2650013 |
# |    clip_fraction        | 0.0869    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24     |
# |    explained_variance   | 0.385     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.11      |
# |    n_updates            | 1780      |
# |    policy_gradient_loss | 0.0226    |
# |    std                  | 0.722     |
# |    value_loss           | 2.89e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.3        |
# |    ep_rew_mean          | -88.5       |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 33          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005231324 |
# |    clip_fraction        | 0.0388      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.5e+03     |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.000517    |
# |    std                  | 0.722       |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60.6      |
# |    ep_rew_mean          | -78.9     |
# | time/                   |           |
# |    fps                  | 1687      |
# |    iterations           | 34        |
# |    time_elapsed         | 41        |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.4322173 |
# |    clip_fraction        | 0.0789    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.22     |
# |    explained_variance   | -26       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.8e+03   |
# |    n_updates            | 1800      |
# |    policy_gradient_loss | 0.0237    |
# |    std                  | 0.712     |
# |    value_loss           | 392       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.2        |
# |    ep_rew_mean          | -59.3       |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 35          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.112412065 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.00884     |
# |    std                  | 0.712       |
# |    value_loss           | 467         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.5        |
# |    ep_rew_mean          | -98.8       |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.117830224 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62e+03    |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.0118      |
# |    std                  | 0.711       |
# |    value_loss           | 4.77e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 43        |
# |    ep_rew_mean          | -138      |
# | time/                   |           |
# |    fps                  | 1686      |
# |    iterations           | 37        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.1418191 |
# |    clip_fraction        | 0.0626    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.19     |
# |    explained_variance   | 0.683     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.57e+03  |
# |    n_updates            | 1830      |
# |    policy_gradient_loss | 0.0144    |
# |    std                  | 0.713     |
# |    value_loss           | 2.66e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.6        |
# |    ep_rew_mean          | -148        |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 38          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006844626 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64e+03    |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.000751    |
# |    std                  | 0.712       |
# |    value_loss           | 1.24e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.8         |
# |    ep_rew_mean          | -128         |
# | time/                   |              |
# |    fps                  | 1686         |
# |    iterations           | 39           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0004177051 |
# |    clip_fraction        | 0.00181      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1e+03        |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.000225    |
# |    std                  | 0.712        |
# |    value_loss           | 9.86e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 28.5      |
# |    ep_rew_mean          | -98.7     |
# | time/                   |           |
# |    fps                  | 1685      |
# |    iterations           | 40        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.3876499 |
# |    clip_fraction        | 0.0915    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.2      |
# |    explained_variance   | 0.66      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.95      |
# |    n_updates            | 1860      |
# |    policy_gradient_loss | 0.00465   |
# |    std                  | 0.713     |
# |    value_loss           | 1.42e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.5        |
# |    ep_rew_mean          | -148        |
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 41          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008242944 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.78e+03    |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | 0.00771     |
# |    std                  | 0.713       |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.5        |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 42          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.021969784 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38e+03    |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.000431   |
# |    std                  | 0.713       |
# |    value_loss           | 6.65e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.1       |
# |    ep_rew_mean          | -88.5      |
# | time/                   |            |
# |    fps                  | 1683       |
# |    iterations           | 43         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.06793295 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.374      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.04e+03   |
# |    n_updates            | 1890       |
# |    policy_gradient_loss | 0.0135     |
# |    std                  | 0.713      |
# |    value_loss           | 4.75e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.3       |
# |    ep_rew_mean          | -88.5      |
# | time/                   |            |
# |    fps                  | 1683       |
# |    iterations           | 44         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.04945627 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.134      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.65e+03   |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | 0.00478    |
# |    std                  | 0.712      |
# |    value_loss           | 5.17e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51         |
# |    ep_rew_mean          | -138       |
# | time/                   |            |
# |    fps                  | 1683       |
# |    iterations           | 45         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.65026224 |
# |    clip_fraction        | 0.34       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.31       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.2       |
# |    n_updates            | 1910       |
# |    policy_gradient_loss | 0.0246     |
# |    std                  | 0.711      |
# |    value_loss           | 4.03e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.9       |
# |    ep_rew_mean          | -158       |
# | time/                   |            |
# |    fps                  | 1683       |
# |    iterations           | 46         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.20895413 |
# |    clip_fraction        | 0.39       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 972        |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | 0.0252     |
# |    std                  | 0.712      |
# |    value_loss           | 4.52e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 77.2       |
# |    ep_rew_mean          | -158       |
# | time/                   |            |
# |    fps                  | 1682       |
# |    iterations           | 47         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.04636021 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.715      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.44e+03   |
# |    n_updates            | 1930       |
# |    policy_gradient_loss | 0.0237     |
# |    std                  | 0.715      |
# |    value_loss           | 1.46e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.9        |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 1682        |
# |    iterations           | 48          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010371366 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.0173      |
# |    std                  | 0.707       |
# |    value_loss           | 964         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.2         |
# |    ep_rew_mean          | -168         |
# | time/                   |              |
# |    fps                  | 1682         |
# |    iterations           | 49           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0059789172 |
# |    clip_fraction        | 0.0908       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.538        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.26e+03     |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | 0.00429      |
# |    std                  | 0.706        |
# |    value_loss           | 1.05e+04     |
# ------------------------------------------
# --- 60.18279814720154 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-110.09 +/- 299.92

# %%
model.save("zeppelin-v2.1.1-400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.9     |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    fps             | 3094     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.1        |
# |    ep_rew_mean          | -75.4       |
# | time/                   |             |
# |    fps                  | 2224        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.003980473 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+03    |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | 0.00142     |
# |    std                  | 0.707       |
# |    value_loss           | 5e+03       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 65.6       |
# |    ep_rew_mean          | -79.3      |
# | time/                   |            |
# |    fps                  | 2011       |
# |    iterations           | 3          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.09246501 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.141      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.2       |
# |    n_updates            | 1980       |
# |    policy_gradient_loss | 0.00394    |
# |    std                  | 0.703      |
# |    value_loss           | 2.75e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.8       |
# |    ep_rew_mean          | -70.4      |
# | time/                   |            |
# |    fps                  | 1905       |
# |    iterations           | 4          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.28262863 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.326      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.5       |
# |    n_updates            | 1990       |
# |    policy_gradient_loss | 0.0124     |
# |    std                  | 0.703      |
# |    value_loss           | 2.51e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 71.1       |
# |    ep_rew_mean          | -98        |
# | time/                   |            |
# |    fps                  | 1855       |
# |    iterations           | 5          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.15569465 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | -17        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 128        |
# |    n_updates            | 2000       |
# |    policy_gradient_loss | 0.0148     |
# |    std                  | 0.698      |
# |    value_loss           | 309        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.3        |
# |    ep_rew_mean          | -97.9       |
# | time/                   |             |
# |    fps                  | 1826        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011862125 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | 0.0034      |
# |    std                  | 0.699       |
# |    value_loss           | 9.06e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 64.2       |
# |    ep_rew_mean          | -97.9      |
# | time/                   |            |
# |    fps                  | 1803       |
# |    iterations           | 7          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.12850964 |
# |    clip_fraction        | 0.366      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.314      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.1e+03    |
# |    n_updates            | 2020       |
# |    policy_gradient_loss | 0.0217     |
# |    std                  | 0.703      |
# |    value_loss           | 2.64e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72.3       |
# |    ep_rew_mean          | -98.3      |
# | time/                   |            |
# |    fps                  | 1788       |
# |    iterations           | 8          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.12089906 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.03       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 100        |
# |    n_updates            | 2030       |
# |    policy_gradient_loss | 0.0114     |
# |    std                  | 0.707      |
# |    value_loss           | 3.56e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 78         |
# |    ep_rew_mean          | -98.3      |
# | time/                   |            |
# |    fps                  | 1761       |
# |    iterations           | 9          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.12596421 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.315      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.62       |
# |    n_updates            | 2040       |
# |    policy_gradient_loss | 0.0201     |
# |    std                  | 0.704      |
# |    value_loss           | 2.11e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.8        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009721951 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 247         |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | -0.000393   |
# |    std                  | 0.704       |
# |    value_loss           | 8.59e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.3        |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 1726        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.025134414 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.704       |
# |    value_loss           | 1.99e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.9        |
# |    ep_rew_mean          | -98.3       |
# | time/                   |             |
# |    fps                  | 1713        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.027758852 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+03    |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | 0.00959     |
# |    std                  | 0.709       |
# |    value_loss           | 1.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.5        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.059217274 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79        |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | 0.0148      |
# |    std                  | 0.716       |
# |    value_loss           | 610         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 71.5      |
# |    ep_rew_mean          | -148      |
# | time/                   |           |
# |    fps                  | 1696      |
# |    iterations           | 14        |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 2.7684138 |
# |    clip_fraction        | 0.318     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.22     |
# |    explained_variance   | 0.441     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 229       |
# |    n_updates            | 2090      |
# |    policy_gradient_loss | 0.0267    |
# |    std                  | 0.717     |
# |    value_loss           | 2.97e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.1       |
# |    ep_rew_mean          | -188       |
# | time/                   |            |
# |    fps                  | 1695       |
# |    iterations           | 15         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.27111113 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.747      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1e+04      |
# |    n_updates            | 2100       |
# |    policy_gradient_loss | 0.0139     |
# |    std                  | 0.716      |
# |    value_loss           | 4.96e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 67.1      |
# |    ep_rew_mean          | -178      |
# | time/                   |           |
# |    fps                  | 1694      |
# |    iterations           | 16        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.1527772 |
# |    clip_fraction        | 0.122     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.21     |
# |    explained_variance   | 0.7       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 430       |
# |    n_updates            | 2110      |
# |    policy_gradient_loss | 0.00815   |
# |    std                  | 0.714     |
# |    value_loss           | 3.74e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 1694        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.025383035 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | -0.0272     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | -0.00248    |
# |    std                  | 0.713       |
# |    value_loss           | 2.13e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.1         |
# |    ep_rew_mean          | -157         |
# | time/                   |              |
# |    fps                  | 1691         |
# |    iterations           | 18           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0034900764 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76e+03     |
# |    n_updates            | 2130         |
# |    policy_gradient_loss | -0.000138    |
# |    std                  | 0.713        |
# |    value_loss           | 1.42e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.4       |
# |    ep_rew_mean          | -168       |
# | time/                   |            |
# |    fps                  | 1691       |
# |    iterations           | 19         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.06013828 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.3        |
# |    n_updates            | 2140       |
# |    policy_gradient_loss | 0.0208     |
# |    std                  | 0.715      |
# |    value_loss           | 852        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.3        |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 1689        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029170403 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45e+03    |
# |    n_updates            | 2150        |
# |    policy_gradient_loss | 0.00546     |
# |    std                  | 0.716       |
# |    value_loss           | 8.65e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.5       |
# |    ep_rew_mean          | -79        |
# | time/                   |            |
# |    fps                  | 1688       |
# |    iterations           | 21         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.44116268 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.241      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.68       |
# |    n_updates            | 2160       |
# |    policy_gradient_loss | 0.0148     |
# |    std                  | 0.714      |
# |    value_loss           | 4.67e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.8       |
# |    ep_rew_mean          | -78.5      |
# | time/                   |            |
# |    fps                  | 1686       |
# |    iterations           | 22         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.17905942 |
# |    clip_fraction        | 0.571      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.837      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.29       |
# |    n_updates            | 2170       |
# |    policy_gradient_loss | 0.0445     |
# |    std                  | 0.714      |
# |    value_loss           | 649        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.2        |
# |    ep_rew_mean          | -98.1       |
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.044802174 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.89e+03    |
# |    n_updates            | 2180        |
# |    policy_gradient_loss | 0.00798     |
# |    std                  | 0.715       |
# |    value_loss           | 1.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.8        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 24          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006614702 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | 0.00133     |
# |    std                  | 0.715       |
# |    value_loss           | 2.93e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 70         |
# |    ep_rew_mean          | -98.4      |
# | time/                   |            |
# |    fps                  | 1684       |
# |    iterations           | 25         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.12076357 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.69e+03   |
# |    n_updates            | 2200       |
# |    policy_gradient_loss | 0.00943    |
# |    std                  | 0.716      |
# |    value_loss           | 1.35e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 70.9       |
# |    ep_rew_mean          | -78.5      |
# | time/                   |            |
# |    fps                  | 1684       |
# |    iterations           | 26         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.18029672 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.312      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.18e+03   |
# |    n_updates            | 2210       |
# |    policy_gradient_loss | 0.0212     |
# |    std                  | 0.719      |
# |    value_loss           | 741        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.4        |
# |    ep_rew_mean          | -68.6       |
# | time/                   |             |
# |    fps                  | 1683        |
# |    iterations           | 27          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018011216 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 362         |
# |    n_updates            | 2220        |
# |    policy_gradient_loss | 6.17e-05    |
# |    std                  | 0.727       |
# |    value_loss           | 411         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.6       |
# |    ep_rew_mean          | -98.4      |
# | time/                   |            |
# |    fps                  | 1682       |
# |    iterations           | 28         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.11797076 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.532      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.07e+03   |
# |    n_updates            | 2230       |
# |    policy_gradient_loss | 0.00452    |
# |    std                  | 0.723      |
# |    value_loss           | 2.67e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.9       |
# |    ep_rew_mean          | -88.8      |
# | time/                   |            |
# |    fps                  | 1682       |
# |    iterations           | 29         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.08757703 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.474      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.55e+03   |
# |    n_updates            | 2240       |
# |    policy_gradient_loss | 0.0281     |
# |    std                  | 0.717      |
# |    value_loss           | 5.67e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50.8      |
# |    ep_rew_mean          | -59.1     |
# | time/                   |           |
# |    fps                  | 1682      |
# |    iterations           | 30        |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.2504679 |
# |    clip_fraction        | 0.224     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.21     |
# |    explained_variance   | 0.194     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.66      |
# |    n_updates            | 2250      |
# |    policy_gradient_loss | 0.0128    |
# |    std                  | 0.719     |
# |    value_loss           | 1.99e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.3        |
# |    ep_rew_mean          | -59.1       |
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 31          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.039883703 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.44        |
# |    n_updates            | 2260        |
# |    policy_gradient_loss | 0.0154      |
# |    std                  | 0.719       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.4        |
# |    ep_rew_mean          | -68.8       |
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 32          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004562916 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -7.86e-05   |
# |    std                  | 0.717       |
# |    value_loss           | 4.85e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58.5       |
# |    ep_rew_mean          | -78.7      |
# | time/                   |            |
# |    fps                  | 1681       |
# |    iterations           | 33         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.03557875 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.664      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.52e+03   |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | 0.00531    |
# |    std                  | 0.715      |
# |    value_loss           | 2.31e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.9        |
# |    ep_rew_mean          | -78.9       |
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.037499838 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.12e+03    |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | 0.00739     |
# |    std                  | 0.722       |
# |    value_loss           | 551         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 69.6      |
# |    ep_rew_mean          | -78.8     |
# | time/                   |           |
# |    fps                  | 1680      |
# |    iterations           | 35        |
# |    time_elapsed         | 42        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0663337 |
# |    clip_fraction        | 0.195     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.23     |
# |    explained_variance   | 0.486     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.96      |
# |    n_updates            | 2300      |
# |    policy_gradient_loss | 0.00847   |
# |    std                  | 0.721     |
# |    value_loss           | 2.24e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51          |
# |    ep_rew_mean          | -98.3       |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.024435198 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | -0.0269     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | 0.00148     |
# |    std                  | 0.731       |
# |    value_loss           | 4.74e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.3       |
# |    ep_rew_mean          | -78.4      |
# | time/                   |            |
# |    fps                  | 1677       |
# |    iterations           | 37         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.06530973 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.0353     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.27e+03   |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | 0.0051     |
# |    std                  | 0.731      |
# |    value_loss           | 8.33e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.3       |
# |    ep_rew_mean          | -98        |
# | time/                   |            |
# |    fps                  | 1676       |
# |    iterations           | 38         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.12430985 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.58       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.56       |
# |    n_updates            | 2330       |
# |    policy_gradient_loss | 0.00365    |
# |    std                  | 0.731      |
# |    value_loss           | 3.26e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.8       |
# |    ep_rew_mean          | -118       |
# | time/                   |            |
# |    fps                  | 1676       |
# |    iterations           | 39         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.08630546 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.492      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.28       |
# |    n_updates            | 2340       |
# |    policy_gradient_loss | 0.0182     |
# |    std                  | 0.731      |
# |    value_loss           | 5.63e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60.6       |
# |    ep_rew_mean          | -128       |
# | time/                   |            |
# |    fps                  | 1675       |
# |    iterations           | 40         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.19039275 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.783      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 266        |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | 0.0109     |
# |    std                  | 0.73       |
# |    value_loss           | 2.25e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 65.8       |
# |    ep_rew_mean          | -138       |
# | time/                   |            |
# |    fps                  | 1674       |
# |    iterations           | 41         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.03924869 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.673      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 265        |
# |    n_updates            | 2360       |
# |    policy_gradient_loss | 0.00337    |
# |    std                  | 0.731      |
# |    value_loss           | 3.84e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 63.6      |
# |    ep_rew_mean          | -119      |
# | time/                   |           |
# |    fps                  | 1670      |
# |    iterations           | 42        |
# |    time_elapsed         | 51        |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0255498 |
# |    clip_fraction        | 0.0838    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.26     |
# |    explained_variance   | 0.481     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.39e+03  |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | 0.00123   |
# |    std                  | 0.727     |
# |    value_loss           | 8.78e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.2        |
# |    ep_rew_mean          | -68.7       |
# | time/                   |             |
# |    fps                  | 1670        |
# |    iterations           | 43          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016615791 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.00409     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.82        |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00316     |
# |    std                  | 0.726       |
# |    value_loss           | 4.91e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.6       |
# |    ep_rew_mean          | -58.7      |
# | time/                   |            |
# |    fps                  | 1669       |
# |    iterations           | 44         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.19539851 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.491      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.1e+03    |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | 0.0126     |
# |    std                  | 0.724      |
# |    value_loss           | 2.8e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.6        |
# |    ep_rew_mean          | -58.6       |
# | time/                   |             |
# |    fps                  | 1668        |
# |    iterations           | 45          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.020987187 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | -2.34       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.0019     |
# |    std                  | 0.725       |
# |    value_loss           | 144         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 65.7       |
# |    ep_rew_mean          | -68.7      |
# | time/                   |            |
# |    fps                  | 1668       |
# |    iterations           | 46         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.24113399 |
# |    clip_fraction        | 0.0821     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | -0.0552    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.788      |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | 0.0205     |
# |    std                  | 0.728      |
# |    value_loss           | 3.16e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 70.3      |
# |    ep_rew_mean          | -98.6     |
# | time/                   |           |
# |    fps                  | 1668      |
# |    iterations           | 47        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.2843337 |
# |    clip_fraction        | 0.082     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24     |
# |    explained_variance   | 0.0449    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.36      |
# |    n_updates            | 2420      |
# |    policy_gradient_loss | 0.00777   |
# |    std                  | 0.722     |
# |    value_loss           | 2.24e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 78.8       |
# |    ep_rew_mean          | -108       |
# | time/                   |            |
# |    fps                  | 1668       |
# |    iterations           | 48         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.04089499 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.0691     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 71.1       |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | 0.014      |
# |    std                  | 0.722      |
# |    value_loss           | 8.28e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.1        |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 1669        |
# |    iterations           | 49          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.041609943 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+03     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | 0.00826     |
# |    std                  | 0.722       |
# |    value_loss           | 1.13e+03    |
# -----------------------------------------
# --- 60.6717255115509 seconds ---

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-116.24 +/- 307.51

# %%
model.save("zeppelin-v2.1.1-500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000,log_interval=10000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2.1.1-1000000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=500000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2.1.1-1500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2.1.1-2500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2.1.1-3500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2.1.1-4500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000,log_interval=1000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-v2.1.1-5500000")

# %%
torch.manual_seed(43)
env.seed(43)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %% [markdown]
# Above ran while tab was closed...

# %%
model = PPO.load("zeppelin-v2-5500000")
model.set_env(env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-v2-400000")
model.set_env(env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
start_time = time.time()
model=model.learn(total_timesteps=1000000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-6500000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1300000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1400000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1500000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1500000")
model.set_env(env)

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1600000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1700000")

# %%
start_time = time.time()
model=model.learn(total_timesteps=100000)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.save("zeppelin-avoidance-windsystem-small2-1800000")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=1000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, reward_threshold=1.0, n_eval_episodes=4000000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
print("hi")
for i_episode in range(5):
    observation = env.reset()
    env.unwrapped.state=[-5,110,50,22]
    total_reward=0
    for t in range(1000):
        action, _states = model.predict(observation)
        #x1_norm = observation[0]/np.sqrt(observation[0]**2+observation[1]**2)
        #x2_norm = observation[1]/np.sqrt(observation[0]**2+observation[1]**2)
        #f = 1.0 if (x2_norm) < 0 else -1.0
        #action = [f, f*(0-x1_norm)]
        observation, reward, done, info = env.step(action)
        print(observation)
        total_reward=0.99*total_reward+reward
        env.render()
        time.sleep(0.5)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            print("Reward: ", total_reward)
            time.sleep(5.0)
            break
env.close()

# %%
env.close()

# %%
torch.manual_seed(43)
env.seed(43)

# %%
model = PPO.load("zeppelin-avoidance-windsystem-small2-1400000")
model.set_env(env)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
torch.manual_seed(43)
env.seed(43)

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.unwrapped.WORST_CASE_TURBULENCE=False

# %%
start_time = time.time()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30000)
print("--- %s seconds ---" % (time.time() - start_time))
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model = PPO.load("zeppelin-v2.1.1-200000")
model.set_env(env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env.unwrapped.WORST_CASE_TURBULENCE=True

# %%
env.unwrapped.INCLUDE_UNWINNABLE = False
#env.init_polytopes(0.0,retrain_polytopes_certain)
for i_episode in range(10):
    observation = env.reset()
    #env.unwrapped.state = [23.550572435813912, 65.8283840822939, 28.38660660476438, 23.88779049570146, 263.12261900519, -153.83683975422704]
    observation = env.unwrapped.state
    startstate = observation
    total_reward=0
    emergencies=0
    for t in range(1000):
        #print(observation)
        x1,x2,c,w,g1,g2 = observation
        #action = [0.,0.,1.0]
        obsold = observation
        action, _states = model.predict(observation,deterministic=True)
        if action[2] > env.unwrapped.EMERGENCY_THRESHOLD:
            emergencies+=1
        #print([action[1]*action[0],action[1]*np.sqrt(1-action[0]**2)])
        observation, reward, done, info = env.step(action)
        #print(observation-obsold)
        #assert reward >= 0, f"reward: {reward}"
        total_reward=0.99*total_reward+reward
        env.render()
        if done:
            print(startstate)
            print(observation)
            print("Episode finished after {} timesteps ({} emergencies)".format(t+1,emergencies))
            print("Reward: ", total_reward)
            break
env.close()
# Out:
# (-139.8050459928633, 16.884895332716425, 67.97406357635143, 11.247202093526477, -294.39475839605285, -236.18558225847534)
# [-352.79331  457.51329   67.97406   11.2472  -294.39476 -236.18558]
# Episode finished after 6 timesteps (6 emergencies)
# Reward:  -9.757400747005
# (-2.4569625094730583, 77.02398444802174, 19.54675654011706, 22.302555149195392, 296.87797430207354, 29.80735558964261)
# [ -2.45696 412.41887  19.54676  22.30256 296.87797  29.80736]
# Episode finished after 4 timesteps (4 emergencies)
# Reward:  -9.85298005
# (-39.56755410184761, 96.04097894805005, 44.39458232996142, 18.017419245161864, 247.40680651783964, 182.17539366559947)
# [-122.63143  477.09941   44.39458   18.01742  247.40681  182.17539]
# Episode finished after 5 timesteps (5 emergencies)
# Reward:  -9.8049502495
# (-91.52973335426756, 52.963665824589924, 72.62651623284836, 27.104376502426668, 82.48126792512141, 317.1733756061967)
# [-448.03959  130.28712   72.62652   27.10438   82.48127  317.17338]
# Episode finished after 4 timesteps (4 emergencies)
# Reward:  -9.85298005
# (-103.04574636494218, -49.39925312145361, 38.611417912120075, 17.251195258310084, -86.55241375666537, 198.51228538415046)
# [-183.45652 -402.95282   38.61142   17.2512   -86.55241  198.51229]
# Episode finished after 17 timesteps (3 emergencies)
# Reward:  -9.865909243713192
# (-21.36205553778755, 143.66346988694568, 50.28522010367129, 18.395838595723305, 272.54102587505986, 137.7023725796887)
# [-21.36206 401.06971  50.28522  18.39584 272.54103 137.70237]
# Episode finished after 3 timesteps (3 emergencies)
# Reward:  -9.901495
# (15.09852243432747, 212.99796417721026, 54.93807805145812, 26.779199906878794, 273.5588153374739, -314.3248780252121)
# [  15.09852  457.82916   54.93808   26.7792   273.55882 -314.32488]
# Episode finished after 3 timesteps (3 emergencies)
# Reward:  -9.901495
# (-18.75052043957676, 57.35344018742258, 24.467459367384137, 12.981388374648471, -362.2296845811066, -30.58286457697693)
# [ -18.75052  411.39066   24.46746   12.98139 -362.22968  -30.58286]
# Episode finished after 4 timesteps (4 emergencies)
# Reward:  -9.85298005
# (37.08329050238349, -23.836973669987977, 16.167963537527086, 13.317808871999286, 330.1559804939777, 168.90418671100576)
# [ 139.32104 -400.23258   16.16796   13.31781  330.15598  168.90419]
# Episode finished after 770 timesteps (0 emergencies)
# Reward:  -10.0
# (46.89666863520924, 36.4605783863804, 26.352934682002918, 20.10884362309134, -308.49920290371756, -391.61984790146585)
# [ 217.0216   440.7361    26.35293   20.10884 -308.4992  -391.61985]
# Episode finished after 6 timesteps (6 emergencies)
# Reward:  -9.757400747005
