# %%
using Plots

# %%
x=collect(100:100:1400)
mean_reward = [
    #-538.24,
    -0.87,
    0.27,
    0.53,
    0.63,
    0.3,
    0.73,
    0.43,
    0.63,
    0.8,
    0.9,
    0.8,
    0.83,
    0.9,
    1.0
]
std_reward= [
    #499.0,
    43.21,
    27.10,
    21.62,
    19.16,
    26.47,
    16.34,
    23.82,
    19.16,
    14.15,
    10.01,
    14.15,
    12.92,
    10.01,
    0.0
]
# Out:
# 14-element Vector{Float64}:
#  43.21
#  27.1
#  21.62
#  19.16
#  26.47
#  16.34
#  23.82
#  19.16
#  14.15
#  10.01
#  14.15
#  12.92
#  10.01
#   0.0

# %%
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
fig=plot(x,mean_reward;
    grid=false,
    xticks = 100:100:1400,
    #yerr=std_reward,
    legend=:bottomright,
    label="Reward",
    linecolor=:indigo,
    xguide="Training steps (in 1000s)",
    yguide="Mean reward\n(over 30,000 steps)",
    size=(600,200))#,yerr=std_reward)

# %%
savefig(fig,"reward-plot.eps")
