# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.evaluation import evaluate_policy
import time
import numpy as np

from torch import nn

# %%
env = gym.make("acc-variant-v0")
model = PPO("MlpPolicy", env, verbose=1,policy_kwargs={"activation_fn":nn.ReLU})
# Out:
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/gym/logger.py:34: UserWarning: WARN: Environment '<class 'gym.envs.safety.acc.ACCEnv'>' has deprecated methods '_step' and '_reset' rather than 'step' and 'reset'. Compatibility code invoked. Set _gym_disable_underscore_compat = True to disable this behavior.
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Use a separate environement for evaluation
eval_env = gym.make('acc-variant-v0')
# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean_reward:-120.82 +/- 80.89

# %%
model.learn(total_timesteps=500000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    fps             | 730      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.3         |
# |    ep_rew_mean          | -117         |
# | time/                   |              |
# |    fps                  | 548          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038918701 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# ...

# %%
# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-46.51 +/- 190.61

# %%
model.save("all_ppo_acc_500000_steps")

# %%
obs = env.reset()
for i in range(0,3000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
    if dones:
        env.reset()

# %%
model.learn(total_timesteps=500000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.4     |
# |    ep_rew_mean     | -56.1    |
# | time/              |          |
# |    fps             | 716      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72.9       |
# |    ep_rew_mean          | -51.5      |
# | time/                   |            |
# |    fps                  | 527        |
# |    iterations           | 2          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.87157947 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.99      |
# ...

# %%
# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /home/steuber/anaconda3/envs/nnequiv-tf1/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean_reward:-9.58 +/- 233.81

# %%
model.save("all_ppo_acc_1000000_steps")

# %%
model.learn(total_timesteps=1000000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.5     |
# |    ep_rew_mean     | -35.4    |
# | time/              |          |
# |    fps             | 507      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.9       |
# |    ep_rew_mean          | -23.8      |
# | time/                   |            |
# |    fps                  | 396        |
# |    iterations           | 2          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.17097118 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# ...

# %%
# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:122.10 +/- 284.26

# %%
model.save("all_ppo_acc_2000000_steps")

# %%
model.learn(total_timesteps=1000000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | 87.4     |
# | time/              |          |
# |    fps             | 544      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 62.7        |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005631529 |
# |    clip_fraction        | 0.0194      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# ...

# %%
# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:45.39 +/- 259.24

# %%
model.save("all_ppo_acc_3000000_steps")
