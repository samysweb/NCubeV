# %%
using SNNT
using JLD
using Glob

# %%
using Plots

# %%
include("Analysis.jl")
# Out:
# plot_trajectory (generic function with 1 method)

# %% [markdown]
# # Vertical CAS Advisories
#
# **Assumptions:**
# - Ignore any COC
# - Level flight of intruder (constant)

# %% [markdown]
# ### Previous Advisory: DNC

# %%
folder = "./vertcas-pra02"
prefix = "vertcas-full-compressed-pra02"
# Out:
# "vertcas-full-compressed-pra02"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra02/vertcas-full-compressed-pra02-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Safe, Any[SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(18, 0), SNNT.SMTInterface.SmtFilterMeta(11, 0), SNNT.SMTInterface.SmtFilterMeta(14, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0)  …  SNNT.SMTInterface.SmtFilterMeta(16, 0), SNNT.SMTInterface.SmtFilterMeta(27, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(38, 0), SNNT.SMTInterface.SmtFilterMeta(39, 0), SNNT.SMTInterface.SmtFilterMeta(82, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(29, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0)], SNNT.VerifierInterface.Star[]), Dict{String, Any}("approx" => 1, "linear" => false, "output" => "experiments/acas/vertcas-pra02/vertcas-full-compressed-pra02", "mapping" => "test/parsing/examples/acas/mapping", "verifier" => "NNEnum", "rigorous" => false, "fixed" => "test/parsing/examples/acas/fixed", "network" => "test/networks/VertCAS_pra02_v4_45HU_200.onnx", "formula" => "test/parsing/examples/acas/property-dnc-compressed", "smt" => "Z3"…))

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Safe
# Enumerated Stars:
# 20509
# Filtered Stars:
# 139

# %% [markdown]
# ### Previous Advisory: DND

# %%
folder = "./vertcas-pra03"
prefix = "vertcas-full-compressed-pra03"
# Out:
# "vertcas-full-compressed-pra03"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra03/vertcas-full-compressed-pra03-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Safe, Any[SNNT.SMTInterface.SmtFilterMeta(43, 0), SNNT.SMTInterface.SmtFilterMeta(41, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0), SNNT.SMTInterface.SmtFilterMeta(47, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0), SNNT.SMTInterface.SmtFilterMeta(11, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0)  …  SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(74, 0), SNNT.SMTInterface.SmtFilterMeta(12, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(1, 0), SNNT.SMTInterface.SmtFilterMeta(27, 0), SNNT.SMTInterface.SmtFilterMeta(15, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0), SNNT.SMTInterface.SmtFilterMeta(9, 0)], SNNT.VerifierInterface.Star[]), Dict{String, Any}("approx" => 1, "linear" => false, "output" => "experiments/acas/vertcas-pra03/vertcas-full-compressed-pra03", "mapping" => "test/parsing/examples/acas/mapping", "verifier" => "NNEnum", "rigorous" => false, "fixed" => "test/parsing/examples/acas/fixed", "network" => "test/networks/VertCAS_pra03_v4_45HU_200.onnx", "formula" => "test/parsing/examples/acas/property-dnd-compressed", "smt" => "Z3"…))

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Safe
# Enumerated Stars:
# 17781
# Filtered Stars:
# 0

# %% [markdown]
# ### Previous Advisory: DES1500

# %%
folder = "./vertcas-pra04"
prefix = "vertcas-full-compressed-pra04"
# Out:
# "vertcas-full-compressed-pra04"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra04/vertcas-full-compressed-pra04-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Unknown, Any[SNNT.SMTInterface.SmtFilterMeta(15, 0), SNNT.SMTInterface.SmtFilterMeta(14, 0), SNNT.SMTInterface.SmtFilterMeta(120, 3), SNNT.SMTInterface.SmtFilterMeta(24, 0), SNNT.SMTInterface.SmtFilterMeta(25, 0), SNNT.SMTInterface.SmtFilterMeta(21, 0), SNNT.SMTInterface.SmtFilterMeta(52, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(10, 0), SNNT.SMTInterface.SmtFilterMeta(10, 0)  …  SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(29, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(14, 0)], SNNT.VerifierInterface.Star[SNNT.VerifierInterface.Star(Float32[0.0 0.52781475 0.0 -0.8493596; 0.0 0.52781475 0.0 -0.8493596; … ; -0.93910676 -0.061850227 -0.25504318 -0.22182423; 0.8160742 -0.28019544 0.48918533 0.127323], Float32[0.43433163, 0.43433163, 0.4246798, 0.4246798, 3.533931, 3.533931, 0.4343316, 0.4343316, 0.42467973, 0.42467973  …  0.0027831953, 0.08021685, -0.06960771, 0.028379373, -0.012441353, -0.011321203, 0.012170973, 0.019101668, 0.0476819, 0.0039253305], Float32[1.1132498 -0.34586346 0.50750446 0.98638666; -0.85932815 0.11185122 -0.4890566 0.0031189397; … ; 2.1930225 -0.37330282 0.60522586 0.51473075; 0.3783665 -0.13125217 0.05991423 0.23136327], Float32[0.124821685, -0.2836723, 0.11717862, 0.14016199, 0.107287005, 0.14783719, 0.08522707, -0.19718447, -0.2243358], [(-0.017776638776487386, -0.015678076593834696), (-0.10984693488003239, -0.10626646204379527), (5.000000328436727e-6, 5.000000328436727e-6), (-0.11683930356699401, -0.09962380063714801)], (Float32[-0.015986774, -0.10839844, 5.0f-6, -0.105773926], Float32[0.04018402, -0.28239128, 0.07939054, 0.08725122, 0.08835321, 0.10595579, 0.10594456, -0.24622045, -0.24062905]), true), SNNT.VerifierInterface.Star(Float32[0.0 0.52781475 0.0 -0.8493596; 0.0 0.52781475 0.0 -0.8493596; … ; -0.93910676 -0.061850227 -0.25504318 -0.22182423; -0.8160742 0.28019544 -0.48918533 -0.127323], Float32[0.43433163, 0.43433163, 0.4246798, 0.4246798, 3.533931, 3.533931, 0.4343316, 0.4343316, 0.42467973, 0.42467973  …  0.0027831953, 0.08021685, -0.06960771, 0.028379373, -0.012441353, -0.011321203, 0.012170973, 0.019101668, 0.0476819, -0.0039253305], Float32[1.0415871 -0.3212584 0.4645472 0.9752059; -0.84808975 0.10799257 -0.4823199 0.0048723444; … ; 2.2915432 -0.4071294 0.66428274 0.53010184; 0.40986395 -0.14206666 0.078794986 0.23627748], Float32[0.12516639, -0.28372636, 0.12116602, 0.14159495, 0.106602654, 0.15079708, 0.07843154, -0.19765836, -0.2244873], [(-0.016191706773392933, -0.015972026019403066), (-0.10948443011670388, -0.10883958193196361), (5.000000328436727e-6, 5.000000328436727e-6), (-0.10747216863489714, -0.10613784646176253)], (Float32[-0.016006015, -0.109375, 5.0f-6, -0.106933594], Float32[0.039352417, -0.28248695, 0.07912884, 0.08702261, 0.08817671, 0.1059314, 0.1058826, -0.24648944, -0.24077466]), true), SNNT.VerifierInterface.Star(Float32[0.0 0.52781475 0.0 -0.8493596; 0.0 0.52781475 0.0 -0.8493596; … ; -0.96991366 0.06833356 -0.21613976 -0.08877768; 0.8239656 -0.27515495 0.48414645 0.10475006], Float32[0.43433163, 0.43433163, 0.4246798, 0.4246798, 3.533931, 3.533931, 0.4343316, 0.4343316, 0.42467973, 0.42467973  …  0.1058961, 0.0027831953, 0.08021685, -0.06960771, 0.028379373, -0.012441353, 0.011321203, 0.012170973, 0.01882353, 0.005646255], Float32[1.0663383 -0.32534155 0.47381833 0.9655074; 0.37611687 -0.42859724 0.3980724 0.5529773; … ; 2.0156357 -0.29570436 0.4778505 0.43578118; 0.4852503 -0.17800882 0.1366638 0.27893406], Float32[0.12408863, -0.26436725, 0.113131724, 0.12847748, 0.101829775, 0.1389164, 0.08806233, -0.19995636, -0.22266561], [(-0.01908617868586792, -0.01595709143027086), (-0.1101398920763 ...

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Unknown
# Enumerated Stars:
# 154979
# Filtered Stars:
# 2112

# %%
print("Certain counter-examples:")
print(length(filter(x->x.certain,result_summary.stars)))
# Out:
# Certain counter-examples:49426

# %%
print("Concrete crashes found using heuristic: ")
concrete_crashes = filter(x->acas_simulate(x;do_print=false,vI_override=0.0)|>has_nmac,filter(x->x[6]!="COC",map(x->acas_interpret_cex(x.counter_example;do_print=false),filter(x->x.certain,result_summary.stars))))
#concrete_crashes = filter(x->acas_simulate(x;do_print=false)|>has_nmac,map(x->acas_interpret_cex(x.counter_example;do_print=false)),result_summary.stars)
print(length(concrete_crashes))
# Out:
# Concrete crashes found using heuristic: 14545

# %%
closest_nmac = argmin(x->acas_simulate(x;vI_override=0.0)|>minimum_distance,concrete_crashes)
cex_i = closest_nmac
#cex_i = concrete_crashes[closest_nmac_i]
#cex_i = concrete_crashes[12000]
println(cex_i)
crash_trace = acas_simulate(cex_i;vI_override=0.0)
print("Has NMAC: ", has_nmac(crash_trace))
# Out:
# (-17.387775f0, -38.671875f0, 0.0009999999f0, 14958.984f0, 6.5722656f0, "SCL1500")
# Has NMAC: true

# %% [markdown]
# Counterfactual: Keep DES1500 course

# %%
cex_cf = [x for x in cex_i]
cex_cf[6]="DES1500"
print(cex_cf)
cf_trace = acas_simulate(cex_cf;vI_override=0.0)
print("Has NMAC: ", has_nmac(cf_trace))
# Out:
# Any[-17.387775f0, -38.671875f0, 0.0009999999f0, 14958.984f0, 6.5722656f0, "DES1500"]Has NMAC: false

# %%
include("Analysis.jl")
plot_trajectory("des1500",crash_trace,cf_trace)
# Out:
# -18.886340047010336
# 2.0
# -0.32962881747159095
# "/home/samuel/Dokumente/Projects/CPS/NN-Safety-via-dL/repos/NCubeV/experiments/acas/des1500.png"

# %% [markdown]
# ### Previous Advisory: CL1500

# %%
folder = "./vertcas-pra05"
prefix = "vertcas-full-compressed-pra05"
# Out:
# "vertcas-full-compressed-pra05"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra05/vertcas-full-compressed-pra05-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Unsafe, Any[SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0)  …  SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(1, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(1, 0)], SNNT.VerifierInterface.Star[SNNT.VerifierInterface.Star(Float32[0.0 -0.52781475 0.0 -0.84935945; 0.0 -0.52781475 0.0 -0.84935945; … ; 0.87455755 0.44923055 0.14314225 0.11336308; -0.8294127 -0.54604113 -0.060144607 0.10147028], Float32[0.4343316, 0.4343316, 0.42467973, 0.42467973, 3.5339313, 3.5339313, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.12267048, -0.005248268, 0.11858983, 0.0059175505, -0.011253631, 0.082784355, 0.12454272, -0.028744187, -0.08342138, 0.05539135], Float32[11.143278 5.0221457 1.9589211 1.5059838; 9.715737 -0.08694911 1.3651551 1.2474834; … ; 10.309783 3.9824162 1.6151866 1.0885168; 4.052351 2.6099305 0.7078772 0.61126596], Float32[1.0671098, 0.02529458, 0.28761113, 0.8610411, 0.24282882, 1.1495813, -0.06330672, 0.5400808, 0.22298485], [(-0.008515684225658864, -0.0078009004872450615), (-0.12399584522371312, -0.12210494431843982), (5.000000328436727e-6, 5.000000328436727e-6), (-0.1901019670307842, -0.1840286889679304)], (Float32[-0.007956663, -0.123046875, 5.0f-6, -0.1875], Float32[0.078125, -0.2752078, 0.06317869, 0.08234034, 0.09283758, 0.11173411, 0.111325815, -0.23606339, -0.24501097]), true), SNNT.VerifierInterface.Star(Float32[0.0 -0.52781475 0.0 -0.84935945; 0.0 -0.52781475 0.0 -0.84935945; … ; -0.8294127 -0.54604113 -0.060144607 0.10147028; -0.49583364 -0.8597488 -0.11315272 0.04666464], Float32[0.4343316, 0.4343316, 0.42467973, 0.42467973, 3.5339313, 3.5339313, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.005248268, 0.11858983, 0.0059175505, -0.011253631, 0.082784355, 0.12454272, -0.028744187, 0.08342138, 0.05539135, 0.100052565], Float32[4.514085 1.0324475 0.84298396 0.7538543; 3.6383243 -3.1634865 0.3728325 0.45141673; … ; 3.8032622 -0.076109245 0.51235557 0.37646097; 0.4761805 -0.010086179 0.08114028 0.29128373], Float32[0.38380656, -0.5504682, 0.015628118, 0.16341148, -0.111015216, 0.97750354, -0.024368469, -0.14301662, -0.18641227], [(-0.007931342748887368, -0.007922220143805002), (-0.1221139877562666, -0.12210920692888635), (5.000000328436727e-6, 5.000000328436727e-6), (-0.18992404361581705, -0.18986033162878985)], (Float32[-0.0079234475, -0.122112274, 5.0f-6, -0.18991089], Float32[0.078804016, -0.27872285, 0.0609471, 0.08268786, 0.08930899, 0.11552337, 0.10871503, -0.23534918, -0.24427117]), true), SNNT.VerifierInterface.Star(Float32[0.0 -0.52781475 0.0 -0.84935945; 0.0 -0.52781475 0.0 -0.84935945; … ; -0.8294127 -0.54604113 -0.060144607 0.10147028; 0.49583364 0.8597488 0.11315272 -0.04666464], Float32[0.4343316, 0.4343316, 0.42467973, 0.42467973, 3.5339313, 3.5339313, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.005248268, 0.11858983, 0.0059175505, -0.011253631, 0.082784355, 0.12454272, -0.028744187, 0.08342138, 0.05539135, -0.100052565], Float32[4.993079 1.8629972 0.95229375 0.7087745; 3.601264 -3.2277474 0.36437503 0.45490462; … ; 4.3902965 0.94177675 0.64632094 0.32121313; 1.1178846 1.1025947 0.22758174 0.23089063], Float32[0.4804611, -0.55794656, 0.10098705, 0.29258692, -0.062435675, 0.881481, 0.04116198, -0.024560943, -0.05692494], [(-0.008461909173531785, -0.007891333972301209), (-0.12347988906066718, -0.12210738063670126) ...

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Unsafe
# Enumerated Stars:
# 137438
# Filtered Stars:
# 1584

# %%
print("Certain counter-examples:")
print(length(filter(x->x.certain,result_summary.stars)))
# Out:
# Certain counter-examples:34675

# %%
print("Concrete crashes found using heuristic: ")
concrete_crashes = filter(x->acas_simulate(x;do_print=false,vI_override=0.0)|>has_nmac,filter(x->x[6]!="COC",map(x->acas_interpret_cex(x.counter_example;do_print=false),filter(x->x.certain,result_summary.stars))))
#concrete_crashes = filter(x->acas_simulate(x;do_print=false)|>has_nmac,map(x->acas_interpret_cex(x.counter_example;do_print=false)),result_summary.stars)
print(length(concrete_crashes))
# Out:
# Concrete crashes found using heuristic: 9146

# %%
closest_nmac = argmin(x->acas_simulate(x;vI_override=0.0)|>minimum_distance,concrete_crashes)
cex_i = closest_nmac
#cex_i = concrete_crashes[closest_nmac_i]
#cex_i = concrete_crashes[12000]
println(cex_i)
crash_trace = acas_simulate(cex_i;vI_override=0.0)
print("Has NMAC: ", has_nmac(crash_trace))
# Out:
# (16.451572f0, 36.71875f0, 0.0009999999f0, 14078.125f0, 6.171875f0, "SDES1500")
# Has NMAC: true

# %% [markdown]
# Counterfactual: Keep CL1500 course

# %%
cex_cf = [x for x in cex_i]
cex_cf[6]="CL1500"
print(cex_cf)
cf_trace = acas_simulate(cex_cf;vI_override=0.0)
print("Has NMAC: ", has_nmac(cf_trace))
# Out:
# Any[16.451572f0, 36.71875f0, 0.0009999999f0, 14078.125f0, 6.171875f0, "CL1500"]
# Has NMAC: false

# %%
plot_trajectory("cl1500",crash_trace,cf_trace,ylims=(9750,10500),figsize=(1000,200),imgmodifier=1.8)
# Out:
# 25.800050782326334
# 2.0
# 0.45029583333333334
# "/home/samuel/Dokumente/Projects/CPS/NN-Safety-via-dL/repos/NCubeV/experiments/acas/cl1500.png"

# %% [markdown]
# ### Previous Advisory: SDES1500

# %%
folder = "./vertcas-pra06"
prefix = "vertcas-full-compressed-pra06"
# Out:
# "vertcas-full-compressed-pra06"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra06/vertcas-full-compressed-pra06-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Unsafe, Any[SNNT.SMTInterface.SmtFilterMeta(80, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(11, 0), SNNT.SMTInterface.SmtFilterMeta(19, 0), SNNT.SMTInterface.SmtFilterMeta(27, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(12, 0), SNNT.SMTInterface.SmtFilterMeta(31, 0), SNNT.SMTInterface.SmtFilterMeta(29, 0)  …  SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(0, 0), SNNT.SMTInterface.SmtFilterMeta(0, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(0, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0)], SNNT.VerifierInterface.Star[SNNT.VerifierInterface.Star(Float32[0.0 0.42253843 0.0 -0.906345; 0.0 0.42253843 0.0 -0.906345; … ; 0.9861775 -0.019151172 0.06275411 -0.15214793; -0.9727309 0.06318463 -0.09284165 0.20293559], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 2.7158663, 2.7158663, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.02312399, 0.052016973, -0.040331516, 0.0686201, -0.04055671, 0.06938088, 0.045635086, -0.162952, 0.057216357, -0.06926496], Float32[-0.7925972 0.47631553 0.06410902 -2.3829603; 10.004997 -0.764826 0.7058576 -0.9905788; … ; 41.504707 -2.6504116 2.4176044 0.5642748; -58.84915 2.8705907 -4.159177 5.7288375], Float32[-1.1054857, -0.5604324, -0.5000456, -0.023733564, -0.016366173, -0.34632862, 0.2111291, 0.118373826, 1.8730533], [(0.0062500000931322575, 0.00666439212358008), (0.11967476383907132, 0.125), (5.000000328436727e-6, 5.000000328436727e-6), (-0.3499999940395355, -0.3484994022373047)], (Float32[0.006261786, 0.123046875, 5.0f-6, -0.34960938], Float32[-0.21873403, -0.24557352, -0.58319974, -0.22267261, -0.5241876, -0.16903254, -0.52254355, -0.14512111, -0.14510638]), true), SNNT.VerifierInterface.Star(Float32[0.0 0.42253843 0.0 -0.906345; 0.0 0.42253843 0.0 -0.906345; … ; 0.9861775 -0.019151172 0.06275411 -0.15214793; 0.9727309 -0.06318463 0.09284165 -0.20293559], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 2.7158663, 2.7158663, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.02312399, 0.052016973, -0.040331516, 0.0686201, -0.04055671, 0.06938088, 0.045635086, -0.162952, 0.057216357, 0.06926496], Float32[-6.654936 0.85710907 -0.49541804 -1.1599319; 2.6999555 -0.29032028 0.008632783 0.5334326; … ; 40.203056 -2.5658615 2.293369 0.8358312; -60.035507 2.9476514 -4.2724075 5.9763403], Float32[-0.6880478, -0.040264416, -0.01329286, 0.24426538, 0.4196269, -0.11691807, 0.28164837, 0.21106015, 1.9575298], [(0.0062500000931322575, 0.006620171366758174), (0.12154571925999821, 0.125), (5.000000328436727e-6, 5.000000328436727e-6), (-0.3499999940395355, -0.3477179965441223)], (Float32[0.0062549543, 0.123046875, 5.0f-6, -0.34960938], Float32[-0.21868896, -0.24559233, -0.5831384, -0.22264537, -0.5241184, -0.16902643, -0.5225658, -0.14539577, -0.14469625]), true), SNNT.VerifierInterface.Star(Float32[0.0 0.42253843 0.0 -0.906345; 0.0 0.42253843 0.0 -0.906345; … ; 0.97307664 -0.06358443 0.09284699 -0.20114258; 0.9950072 -0.071451284 0.06838697 0.013361291], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 2.7158663, 2.7158663, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  0.045635086, 0.162952, 0.023898372, -0.08622392, -0.09337355, -0.002284114, 0.055007473, -0.0023909905, 0.06859244, -0.0065050544], Float32[-6.1164107 0.7477855 -0.4494653 -0.90481627; 2.5709946 -0.26414162 -0.0023710951 0.47234216; … ; 38.96526 -2.314582 2.1877477 0.24945119; -59.83012 2.9059577 -4.254883 6.0736356], Float32[-0.58904004, -0.063972786, -0.039990757, 0.20725124, 0.34399912, -0.112599984, 0.19637269, -0.016507668, 1.9952891], [(0.0062500000931322575, 0.0070814553691130105), (0.11897679868941709, 0.125), (5.000000328436727e-6, 5.000000328436727e-6), (-0 ...

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Unsafe
# Enumerated Stars:
# 170633
# Filtered Stars:
# 88

# %%
print("Certain counter-examples:")
print(length(filter(x->x.certain,result_summary.stars)))
# Out:
# Certain counter-examples:5360

# %%
print("Concrete crashes found using heuristic: ")
concrete_crashes = filter(x->acas_simulate(x;do_print=false,vI_override=0.0)|>has_nmac,filter(x->x[6]!="COC",map(x->acas_interpret_cex(x.counter_example;do_print=false),filter(x->x.certain,result_summary.stars))))
#concrete_crashes = filter(x->acas_simulate(x;do_print=false)|>has_nmac,map(x->acas_interpret_cex(x.counter_example;do_print=false)),result_summary.stars)
print(length(concrete_crashes))
# Out:
# Concrete crashes found using heuristic: 107

# %%
closest_nmac = argmin(x->acas_simulate(x;vI_override=0.0)|>minimum_distance,concrete_crashes)
cex_i = closest_nmac
#cex_i = concrete_crashes[closest_nmac_i]
#cex_i = concrete_crashes[12000]
println(cex_i)
crash_trace = acas_simulate(cex_i;vI_override=0.0)
print("Has NMAC: ", has_nmac(crash_trace))
# Out:
# (-157.10776f0, -42.96875f0, 0.0009999999f0, 14078.125f0, 6.171875f0, "SCL1500")
# Has NMAC: true

# %% [markdown]
# Counterfactual: Keep SDES1500 course

# %%
cex_cf = [x for x in cex_i]
cex_cf[6]="SDES1500"
print(cex_cf)
cf_trace = acas_simulate(cex_cf;vI_override=0.0)
print("Has NMAC: ", has_nmac(cf_trace))
# Out:
# Any[-157.10776f0, -42.96875f0, 0.0009999999f0, 14078.125f0, 6.171875f0, "SDES1500"]Has NMAC: false

# %%
plot_trajectory("sdes1500",crash_trace,cf_trace)
# Out:
# -21.735121403867605
# 2.0
# -0.37934943181818187
# "/home/samuel/Dokumente/Projects/CPS/NN-Safety-via-dL/repos/NCubeV/experiments/acas/sdes1500.png"

# %% [markdown]
# ### Previous Advisory: SCL1500

# %%
folder = "./vertcas-pra07"
prefix = "vertcas-full-compressed-pra07"
# Out:
# "vertcas-full-compressed-pra07"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra07/vertcas-full-compressed-pra07-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Unsafe, Any[SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0)  …  SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0), SNNT.SMTInterface.SmtFilterMeta(13, 0), SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(12, 0), SNNT.SMTInterface.SmtFilterMeta(1, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0)], SNNT.VerifierInterface.Star[SNNT.VerifierInterface.Star(Float32[0.0 -0.42253846 0.0 -0.906345; 0.0 -0.42253846 0.0 -0.906345; … ; -0.9967985 0.048237324 -0.06276318 0.011252777; -0.99424744 -0.03136539 -0.06265035 0.08101402], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 2.7158663, 2.7158663, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  0.23174164, 0.0035694654, -0.12671642, 0.0048079235, 0.23893301, -0.053623904, -0.23690894, -0.020655489, -0.0034526235, -0.044108957], Float32[-35.349785 3.8073373 -2.2427206 1.6617718; 30.299768 -5.0302744 1.8177446 -2.3159568; … ; -13.446862 4.4121423 -0.9827304 3.9839468; -31.987175 -436.74622 5.8898277 46.17845], Float32[-0.089922994, -0.19479518, -1.4090118, 1.1829436, -1.431584, 0.3642765, -1.4521319, 0.35489237, 110.17189], [(0.010176552428661091, 0.010283383524747202), (0.21700085218488938, 0.21734569309362273), (5.000000328436727e-6, 5.000000328436727e-6), (-0.33582151435390484, -0.3341411022961555)], (Float32[0.010187514, 0.21704102, 5.0f-6, -0.33544922], Float32[-0.18115234, -0.20099673, -0.5319596, -0.19331366, -0.541752, -0.1719855, -0.51365215, -0.16089866, -0.43631786]), true), SNNT.VerifierInterface.Star(Float32[0.0 -0.42253846 0.0 -0.906345; 0.0 -0.42253846 0.0 -0.906345; … ; -0.9967985 0.048237324 -0.06276318 0.011252777; 0.99424744 0.03136539 0.06265035 -0.08101402], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 2.7158663, 2.7158663, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  0.23174164, 0.0035694654, -0.12671642, 0.0048079235, 0.23893301, -0.053623904, -0.23690894, -0.020655489, -0.0034526235, 0.044108957], Float32[-35.77649 3.7938762 -2.2696087 1.6965408; 43.934868 -4.6001296 2.676931 -3.4269822; … ; -26.642097 3.995874 -1.8141997 5.059131; -25.105343 -436.5291 6.3234715 45.6177], Float32[-0.07099253, -0.799705, -2.05915, -0.2722042, -2.425846, 0.84392655, -3.028095, 0.940288, 109.866585], [(0.01015913735049424, 0.010284193077825705), (0.21644656758553887, 0.21742230632766807), (5.000000328436727e-6, 5.000000328436727e-6), (-0.3355507520760733, -0.33239726702411976)], (Float32[0.0101900995, 0.21679688, 5.0f-6, -0.33398438], Float32[-0.1796875, -0.20472619, -0.5363312, -0.1933003, -0.5460198, -0.16748312, -0.51671034, -0.15458447, -0.26295584]), true), SNNT.VerifierInterface.Star(Float32[0.0 -0.42253846 0.0 -0.906345; 0.0 -0.42253846 0.0 -0.906345; … ; 0.9967985 -0.048237324 0.06276318 -0.011252777; -0.99424744 -0.03136539 -0.06265035 0.08101402], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 2.7158663, 2.7158663, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  0.23174164, 0.0035694654, -0.12671642, 0.0048079235, 0.23893301, -0.053623904, -0.23690894, -0.020655489, 0.0034526235, -0.044108957], Float32[-24.900139 3.3016555 -1.5847611 1.5438066; 50.34268 -6.000196 3.079742 -2.5422196; … ; -21.384521 4.7962637 -1.4825232 4.0735545; -20.603678 -437.2971 6.606587 46.049946], Float32[-0.12611756, -0.2642181, -1.4707537, 1.1492434, -1.4644544, 0.23782781, -1.4787832, 0.38238615, 110.13246], [(0.010084040364849115, 0.010190919309128712), (0.2169391929243919, 0.2172354194257303), (5.000000328436727e-6, 5.00 ...

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Unsafe
# Enumerated Stars:
# 173598
# Filtered Stars:
# 200

# %%
print("Certain counter-examples:")
print(length(filter(x->x.certain,result_summary.stars)))
# Out:
# Certain counter-examples:11280

# %%
print("Concrete crashes found using heuristic: ")
concrete_crashes = filter(x->acas_simulate(x;do_print=false,vI_override=0.0)|>has_nmac,filter(x->x[6]!="COC",map(x->acas_interpret_cex(x.counter_example;do_print=false),filter(x->x.certain,result_summary.stars))))
#concrete_crashes = filter(x->acas_simulate(x;do_print=false)|>has_nmac,map(x->acas_interpret_cex(x.counter_example;do_print=false)),result_summary.stars)
print(length(concrete_crashes))
# Out:
# Concrete crashes found using heuristic: 84

# %%
closest_nmac = argmin(x->acas_simulate(x;vI_override=0.0)|>minimum_distance,concrete_crashes)
cex_i = closest_nmac
#cex_i = concrete_crashes[closest_nmac_i]
#cex_i = concrete_crashes[12000]
println(cex_i)
crash_trace = acas_simulate(cex_i;vI_override=0.0)
print("Has NMAC: ", has_nmac(crash_trace))
# Out:
# (148.39893f0, 43.310547f0, 0.0009999999f0, 14303.711f0, 6.274414f0, "SDES2500")
# Has NMAC: true

# %% [markdown]
# Counterfactual: Keep SCL1500 course

# %%
cex_cf = [x for x in cex_i]
cex_cf[6]="SCL1500"
print(cex_cf)
cf_trace = acas_simulate(cex_cf;vI_override=0.0)
print("Has NMAC: ", has_nmac(cf_trace))
# Out:
# Any[148.39893f0, 43.310547f0, 0.0009999999f0, 14303.711f0, 6.274414f0, "SCL1500"]Has NMAC: false

# %%
plot_trajectory("scl1500",crash_trace,cf_trace)
# Out:
# 21.96175612121538
# 2.0
# 0.3833049538352273
# "/home/samuel/Dokumente/Projects/CPS/NN-Safety-via-dL/repos/NCubeV/experiments/acas/scl1500.png"

# %% [markdown]
# ### Previous Advisory: SDES2500

# %%
folder = "./vertcas-pra08"
prefix = "vertcas-full-compressed-pra08"
# Out:
# "vertcas-full-compressed-pra08"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra08/vertcas-full-compressed-pra08-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Unsafe, Any[SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(4, 0), SNNT.SMTInterface.SmtFilterMeta(13, 0), SNNT.SMTInterface.SmtFilterMeta(10, 0), SNNT.SMTInterface.SmtFilterMeta(10, 0), SNNT.SMTInterface.SmtFilterMeta(0, 0), SNNT.SMTInterface.SmtFilterMeta(0, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0)  …  SNNT.SMTInterface.SmtFilterMeta(14, 0), SNNT.SMTInterface.SmtFilterMeta(16, 0), SNNT.SMTInterface.SmtFilterMeta(12, 0), SNNT.SMTInterface.SmtFilterMeta(9, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0), SNNT.SMTInterface.SmtFilterMeta(9, 0), SNNT.SMTInterface.SmtFilterMeta(8, 0), SNNT.SMTInterface.SmtFilterMeta(13, 0), SNNT.SMTInterface.SmtFilterMeta(13, 0)], SNNT.VerifierInterface.Star[SNNT.VerifierInterface.Star(Float32[0.0 0.42253843 0.0 -0.906345; 0.0 0.42253843 0.0 -0.906345; … ; 0.95506465 -0.080649674 -0.03625279 -0.28290093; 0.8416498 -0.53022325 0.062856786 -0.08085808], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 4.8285584, 4.8285584, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  0.081205286, 0.019681182, 0.10505497, 0.03989527, -0.10348272, 0.03904823, 0.0155013455, -0.02027962, 0.089128435, -0.03386017], Float32[-20.607412 6.0201516 -1.578994 1.4290643; -19.282158 4.9411783 -1.6656473 2.5273442; … ; 23.301569 2.6619058 1.534826 3.6746645; -56.13294 7.136887 -4.7988696 3.5880163], Float32[-0.3642168, 0.085179, 0.5435196, 0.50353074, 28.57085, -0.65569216, 28.945436, 0.6338862, 0.55401045], [(0.0062500000931322575, 0.0066148168149757994), (0.12258404035004805, 0.12319037488663348), (5.000000328436727e-6, 5.000000328436727e-6), (-0.32393499472508513, -0.31772268234608125)], (Float32[0.006271443, 0.123046875, 5.0f-6, -0.3203125], Float32[-0.21044922, -0.23729968, -0.54910904, -0.23255698, -0.51988053, -0.20001704, -0.51306504, -0.06947344, -0.06916288]), true), SNNT.VerifierInterface.Star(Float32[0.0 0.42253843 0.0 -0.906345; 0.0 0.42253843 0.0 -0.906345; … ; 0.95506465 -0.080649674 -0.03625279 -0.28290093; -0.8416498 0.53022325 -0.062856786 0.08085808], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 4.8285584, 4.8285584, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  0.081205286, 0.019681182, 0.10505497, 0.03989527, -0.10348272, 0.03904823, 0.0155013455, -0.02027962, 0.089128435, 0.03386017], Float32[-6.932009 -2.5950913 -0.55767626 0.115255356; -6.324621 -3.2218232 -0.6979416 1.2825016; … ; 39.613262 -7.6141477 2.7530296 2.107585; -44.503582 -0.18938541 -3.9303565 2.470773], Float32[0.18595445, 0.60647, 1.0160617, 1.0382771, 29.135551, -0.25869617, 29.36552, 1.2901173, 1.0218679], [(0.0062500000931322575, 0.00696061153766098), (0.12177838730308838, 0.1235110481643765), (5.000000328436727e-6, 5.000000328436727e-6), (-0.32809678789367897, -0.3180388548066326)], (Float32[0.0062575163, 0.123046875, 5.0f-6, -0.32421875], Float32[-0.21411133, -0.24535626, -0.55612713, -0.240533, -0.498516, -0.20763646, -0.49268287, -0.082203954, -0.081007905]), true), SNNT.VerifierInterface.Star(Float32[0.0 0.42253843 0.0 -0.906345; 0.0 0.42253843 0.0 -0.906345; … ; 0.95674604 -0.026498955 -0.03714365 -0.2873242; 0.98970604 -0.05366224 0.091076426 -0.09647486], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 4.8285584, 4.8285584, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.26314467, -0.11004159, 0.081205286, 0.019681182, -0.10505497, 0.03989527, 0.016041484, -0.012095679, 0.09727372, 0.030827535], Float32[-19.092813 1.5815904 -1.5708232 1.2920718; -17.748579 0.44699234 -1.6573737 2.3886354; … ; 24.314096 -0.30530643 1.5402886 3.5830843; -54.350105 1.9122534 -4.789251 3.4267628], Float32[0.12868825, 0.5842611, 0.24315915, 0.65673715, 0.36140564, 0.45526096, 0.45101908, 0.96339744, 1.1342095], [(0.0062500000931322575, 0.006669734863988315), (0.12305900605987496, 0.125), (5.000000328436727e-6, 5.000000328436727e-6), ...

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Unsafe
# Enumerated Stars:
# 130845
# Filtered Stars:
# 21

# %%
print("Certain counter-examples:")
print(length(filter(x->x.certain,result_summary.stars)))
# Out:
# Certain counter-examples:5259

# %%
print("Concrete crashes found using heuristic: ")
concrete_crashes = filter(x->acas_simulate(x;do_print=false,vI_override=0.0)|>has_nmac,filter(x->x[6]!="COC",map(x->acas_interpret_cex(x.counter_example;do_print=false),filter(x->x.certain,result_summary.stars))))
#concrete_crashes = filter(x->acas_simulate(x;do_print=false)|>has_nmac,map(x->acas_interpret_cex(x.counter_example;do_print=false)),result_summary.stars)
print(length(concrete_crashes))
# Out:
# Concrete crashes found using heuristic: 116

# %%
non_sdes2500_crashes = filter(x->x[6]!="SDES2500",concrete_crashes)
closest_nmac = argmin(x->acas_simulate(x;vI_override=0.0)|>minimum_distance,non_sdes2500_crashes)
cex_i = closest_nmac
#cex_i = concrete_crashes[closest_nmac_i]
#cex_i = concrete_crashes[12000]
println(cex_i)
crash_trace = acas_simulate(cex_i;vI_override=0.0)
print("Has NMAC: ", has_nmac(crash_trace))
# Out:
# (161.7653f0, 41.69922f0, 0.0009999999f0, 14078.125f0, 6.171875f0, "SCL2500")
# Has NMAC:
# true

# %% [markdown]
# Counterfactual: Keep SDES2500 course

# %%
cex_cf = [x for x in cex_i]
cex_cf[6]="SDES2500"
print(cex_cf)
cf_trace = acas_simulate(cex_cf;vI_override=0.0)
print("Has NMAC: ", has_nmac(cf_trace))
# Out:
# Any[161.7653f0, 41.69922f0, 0.0009999999f0, 14078.125f0, 6.171875f0, "SDES2500"]Has NMAC: false

# %%
plot_trajectory("sdes2500",crash_trace,cf_trace)
# Out:
# 27.649435516429044
# 2.0
# 0.4825736860795455
# "/home/samuel/Dokumente/Projects/CPS/NN-Safety-via-dL/repos/NCubeV/experiments/acas/sdes2500.png"

# %% [markdown]
# ### Previous Advisory: SCL2500

# %%
folder = "./vertcas-pra09"
prefix = "vertcas-full-compressed-pra09"
# Out:
# "vertcas-full-compressed-pra09"

# %%
result_summary, metadata = summarize_and_load(folder,prefix)
# Out:
# Loading results from ./vertcas-pra09/vertcas-full-compressed-pra09-*.jld
# (SNNT.VerifierInterface.OlnnvResult(SNNT.VerifierInterface.Unsafe, Any[SNNT.SMTInterface.SmtFilterMeta(12, 0), SNNT.SMTInterface.SmtFilterMeta(13, 0), SNNT.SMTInterface.SmtFilterMeta(23, 0), SNNT.SMTInterface.SmtFilterMeta(22, 0), SNNT.SMTInterface.SmtFilterMeta(19, 0), SNNT.SMTInterface.SmtFilterMeta(26, 0), SNNT.SMTInterface.SmtFilterMeta(12, 0), SNNT.SMTInterface.SmtFilterMeta(10, 0), SNNT.SMTInterface.SmtFilterMeta(11, 0), SNNT.SMTInterface.SmtFilterMeta(7, 0)  …  SNNT.SMTInterface.SmtFilterMeta(6, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(0, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(3, 0), SNNT.SMTInterface.SmtFilterMeta(5, 0), SNNT.SMTInterface.SmtFilterMeta(2, 0)], SNNT.VerifierInterface.Star[SNNT.VerifierInterface.Star(Float32[0.0 -0.42253846 0.0 -0.906345; 0.0 -0.42253846 0.0 -0.906345; … ; -0.73239285 -0.634146 -0.18179384 0.16855471; -0.95066124 0.17291975 -0.2185805 0.13625135], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 4.8285584, 4.8285584, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.1678752, 0.15703131, -0.18581028, 0.13567792, 0.046869352, -0.13844185, 0.1941092, 0.17442624, 0.09647791, -0.057865795], Float32[30.627205 -3.5595174 3.2481713 3.2993603; 34.030476 -6.1407404 3.4647532 3.629252; … ; 26.451202 2.7082522 3.4358938 1.7830063; -6.070007 -6.866878 -1.7829218 2.1204631], Float32[0.49824688, -0.2554173, 1.039547, -3.0543787, 1.0577289, -2.6881392, 1.14206, 1.4124656, -0.8362716], [(-0.013148022855277088, -0.011329731582096086), (-0.20697979010602693, -0.20435655830741561), (5.000000328436727e-6, 5.000000328436727e-6), (-0.27435917617250044, -0.2547065061808304)], (Float32[-0.011488143, -0.20507812, 5.0f-6, -0.265625], Float32[0.0, -0.35103545, -0.00034796936, -0.33468905, 0.003115033, -0.33699593, 0.015473227, 0.079593234, 0.07845105]), true), SNNT.VerifierInterface.Star(Float32[0.0 -0.42253846 0.0 -0.906345; 0.0 -0.42253846 0.0 -0.906345; … ; -0.73239285 -0.634146 -0.18179384 0.16855471; -0.95066124 0.17291975 -0.2185805 0.13625135], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 4.8285584, 4.8285584, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  0.012551954, 0.018127916, -0.1678752, 0.15703131, -0.18581028, 0.13567792, 0.046869352, 0.13844185, 0.09647791, -0.057865795], Float32[29.55459 -2.1701703 3.1328325 3.1939158; 34.58633 -6.860734 3.5245247 3.6838958; … ; 26.922138 2.0982544 3.4865339 1.829302; -5.7359853 -7.2995324 -1.7470043 2.1532993], Float32[0.74220353, -0.38184166, 0.97445625, -3.1513498, 0.9617375, -2.779356, 1.0930591, 1.3053553, -0.91224176], [(-0.013191026849731842, -0.011511340993821846), (-0.20563377419155868, -0.20424709721100642), (5.000000328436727e-6, 5.000000328436727e-6), (-0.2757551507445375, -0.2549122868677324)], (Float32[-0.011562887, -0.20458984, 5.0f-6, -0.265625], Float32[-0.00390625, -0.3566402, -0.0030574328, -0.34656125, 0.0011979683, -0.3468031, 0.014239116, 0.07888525, 0.07551411]), true), SNNT.VerifierInterface.Star(Float32[0.0 -0.42253846 0.0 -0.906345; 0.0 -0.42253846 0.0 -0.906345; … ; -0.9612291 0.060611468 -0.2270336 0.1442934; 0.85776186 -0.48425722 0.09001349 0.14709534], Float32[0.46347192, 0.46347192, 0.4531725, 0.4531725, 4.8285584, 4.8285584, 0.43433163, 0.43433163, 0.4246798, 0.4246798  …  -0.081436835, 0.012551954, 0.018127916, -0.1678752, 0.15703131, 0.18581028, 0.11028323, -0.115611665, -0.036767058, 0.050675675], Float32[27.761742 2.1810522 2.9328542 3.2208667; 30.271536 3.6112242 3.0432427 3.7487574; … ; 26.332952 3.5281997 3.4208145 1.8381586; -10.926949 5.298891 -2.3260174 2.2313318], Float32[1.6174501, 1.724588, 2.1988187, 3.1411583, 1.8055257, 2.2354045, 2.000026, 1.5929884, 1.6219251], [(-0.013222002705523046, -0.011576246355041628), (-0.20499527614997218, -0.20403693652189203), (5.000000328436727e-6, 5.000000328436727e-6), (-0.2703627081 ...

# %%
println("Status:")
println(result_summary.status)
println("Enumerated Stars:")
println(sum(x->x.original_meta,result_summary.metadata))
println("Filtered Stars:")
println(sum(x->x.filtered_out,result_summary.metadata))
# Out:
# Status:
# Unsafe
# Enumerated Stars:
# 177635
# Filtered Stars:
# 101

# %%
print("Certain counter-examples:")
print(length(filter(x->x.certain,result_summary.stars)))
# Out:
# Certain counter-examples:7846

# %%
print("Concrete crashes found using heuristic: ")
concrete_crashes = filter(x->acas_simulate(x;do_print=false,vI_override=0.0)|>has_nmac,filter(x->x[6]!="COC",map(x->acas_interpret_cex(x.counter_example;do_print=false),filter(x->x.certain,result_summary.stars))))
#concrete_crashes = filter(x->acas_simulate(x;do_print=false)|>has_nmac,map(x->acas_interpret_cex(x.counter_example;do_print=false)),result_summary.stars)
print(length(concrete_crashes))
# Out:
# Concrete crashes found using heuristic: 228

# %%
closest_nmac = argmin(x->acas_simulate(x;vI_override=0.0)|>minimum_distance,concrete_crashes)
cex_i = closest_nmac
#cex_i = concrete_crashes[closest_nmac_i]
#cex_i = concrete_crashes[12000]
println(cex_i)
crash_trace = acas_simulate(cex_i;vI_override=0.0)
print("Has NMAC: ", has_nmac(crash_trace))
# Out:
# (358.98788f0, 76.5625f0, 0.0009999999f0, 14088.867f0, 6.176758f0, "SDES1500")
# Has NMAC: true

# %% [markdown]
# Counterfactual: Keep SCL1500 course

# %%
cex_cf = [x for x in cex_i]
cex_cf[6]="SCL2500"
print(cex_cf)
cf_trace = acas_simulate(cex_cf;vI_override=0.0)
print("Has NMAC: ", has_nmac(cf_trace))
# Out:
# Any[358.98788f0, 76.5625f0, 0.0009999999f0, 14088.867f0, 6.176758f0, "SCL2500"]Has NMAC: false

# %%
include("Analysis.jl")
# Out:
# plot_trajectory (generic function with 1 method)

# %%
plot_trajectory("scl2500",crash_trace,cf_trace)
# Out:
# 44.01041728442127
# 2.0
# 0.7681266867897728
# "/home/samuel/Dokumente/Projects/CPS/NN-Safety-via-dL/repos/NCubeV/experiments/acas/scl2500.png"
